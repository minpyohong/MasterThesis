# %%
import chardet
import pandas as pd
import urllib.request

    
#print(encoding_result)
data = pd.read_csv('../news/scraping_result/en/2019_up1/2019_up1_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up1/2019_up1_Cointelegraph.csv',error_bad_lines=False))
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up1/2019_up1_CryptoNews.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up1/2019_up1_Forbes.csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 9839

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 9839

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.000*"exmo" + 0.000*"livecoin" + 0.000*"xanax" + 0.000*"popularity" + 0.000*"macri" + 0.000*"wireless" + 0.000*"dashboard" + 0.000*"hitbtc"')
# (1, '0.000*"hongfei" + 0.000*"minnow" + 0.000*"youtubers" + 0.000*"opera" + 0.000*"xfers" + 0.000*"singaporean" + 0.000*"nbrv" + 0.000*"coworker"')
# (2, '0.000*"bitcoinhappy" + 0.000*"hectare" + 0.000*"tenet" + 0.000*"negociecoins" + 0.000*"costco" + 0.000*"paulo" + 0.000*"artificial" + 0.000*"whisker"')
# (3, '0.000*"hartnett" + 0.000*"miscreant" + 0.000*"pile" + 0.000*"lynch" + 0.000*"punishable" + 0.000*"merrill" + 0.000*"amro" + 0.000*"overvalue"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el62271402054348395042317551895"></div>
# <script type="text/javascript">
#
# var ldavis_el62271402054348395042317551895_data = {"mdsDat": {"x": [-0.12498757312762811, 0.07257100659209853, 0.027387976323908027, 0.025028590211621543], "y": [0.0243035617515226, 0.07966052133666217, -0.05989972743145127, -0.04406435565673342], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [29.914125442504883, 26.520071029663086, 21.929914474487305, 21.63589096069336]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3",  ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 9839

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 9839

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 1330.7550351739444

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.04985743206667581

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 6.128002284346868

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(30)  # 긍정적 감정
# Out:
#                                                raw_data              word  \
# 7922  [0.0016470057889819145, -0.01716674491763115, ...          telegraf
# 21    [-0.0051693483255803585, -0.022018324583768845...          outshine
# 97    [-0.005530425347387791, -0.011590425856411457,...        writinghot
# 6169  [-0.002288993913680315, -0.005931708961725235,...             dwarf
# 5752  [-0.0020954995416104794, -0.012100600637495518...       unconvinced
# 5963  [-0.002876437036320567, -0.009776322171092033,...            stifle
# 5672  [-0.004631834104657173, -0.013270596973598003,...          stubborn
# 3531  [-0.005257606040686369, -0.018457407131791115,...         handpicks
# 6879  [-0.0007672050851397216, -0.012841512449085712...     preconfigured
# 7185  [0.0024798244703561068, -0.010158886201679707,...        undetected
# 7961  [-0.0007919765776023269, -0.003900709562003612...            cachet
# 6298  [-0.00979014951735735, -0.007033145055174828, ...         realistic
# 2812  [0.0018554427661001682, -0.008388054557144642,...             adham
# 5870  [-0.005763257388025522, -0.005244084633886814,...             craze
# 8917  [-0.0032883163075894117, -0.000721979071386158...           eyening
# 6348  [0.0013649050379171968, 0.000783354218583554, ...         twitteras
# 4421  [-0.00015262150554917753, -0.00464983982965350...            admins
# 7284  [-0.004295483697205782, -0.011117932386696339,...       disillusion
# 6174  [-0.003392659593373537, -0.007208185736089945,...             planb
# 4222  [0.004043141845613718, -0.010555007494986057, ...              pboc
# 7744  [0.0016935506137087941, -0.005667135585099459,...          remitano
# 5753  [0.002711020177230239, -0.0007113063475117087,...       mudslinging
# 6186  [-0.0016276865499094129, -0.006063283421099186...            retake
# 8502  [-0.00105840724427253, -0.0026384657248854637,...  coinmarketcapbsv
# 6187  [-0.002384192543104291, 0.0004891616408713162,...            serial
# 6388  [-0.0004198727256152779, -0.004124348051846027...        bagholders
# 6302  [-0.00582902180030942, -0.001683645648881793, ...     levelssupport
# 3924  [0.0020789289847016335, -0.0063567436300218105...     nederlandsche
# 9643  [-0.002158219926059246, -0.0007495048339478672...     contextualize
# 1157  [0.003858505515381694, -0.0008315364830195904,...         codenamed
#
#       cluster                                           centroid  distance  \
# 7922        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.092548
# 21          0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.141160
# 97          0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.171807
# 6169        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.191774
# 5752        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.241865
# 5963        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.243339
# 5672        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.268769
# 3531        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.273821
# 6879        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.306314
# 7185        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.311992
# 7961        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.340236
# 6298        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.349044
# 2812        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.401940
# 5870        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.430127
# 8917        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.446048
# 6348        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.484972
# 4421        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.499370
# 7284        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.504264
# 6174        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.505397
# 4222        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.536925
# 7744        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.539479
# 5753        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.549273
# 6186        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.552603
# 8502        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.556975
# 6187        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.591768
# 6388        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.592175
# 6302        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.649071
# 3924        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.652067
# 9643        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.658487
# 1157        0  [-0.00053914404, -0.0046009086, 0.0018516786, ...  0.694635
#
#          tfidf     score closer#
# 7922  0.000154  1.092394     NaN
# 21    0.000154  1.141006     NaN
# 97    0.000154  1.171653     NaN
# 6169  0.000154  1.191621     NaN
# 5752  0.000154  1.241711     NaN
# 5963  0.000154  1.243185     NaN
# 5672  0.000154  1.268615     NaN
# 3531  0.000154  1.273667     NaN
# 6879  0.000154  1.306160     NaN
# 7185  0.000154  1.311838     NaN
# 7961  0.000154  1.340082     NaN
# 6298  0.000154  1.348890     NaN
# 2812  0.000154  1.401786     NaN
# 5870  0.000154  1.429974     NaN
# 8917  0.000154  1.445894     NaN
# 6348  0.000154  1.484818     NaN
# 4421  0.000154  1.499216     NaN
# 7284  0.000154  1.504110     NaN
# 6174  0.000154  1.505243     NaN
# 4222  0.000154  1.536771     NaN
# 7744  0.000154  1.539325     NaN
# 5753  0.000154  1.549120     NaN
# 6186  0.000154  1.552449     NaN
# 8502  0.000154  1.556821     NaN
# 6187  0.000308  1.591460     NaN
# 6388  0.000154  1.592021     NaN
# 6302  0.000154  1.648917     NaN
# 3924  0.000154  1.651914     NaN
# 9643  0.000154  1.658333     NaN
# 1157  0.000154  1.694481     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회적 이슈
# Out:
#                                                raw_data              word  \
# 16    [0.2518806457519531, 1.2731740474700928, -0.52...           bitcoin
# 2     [0.27233344316482544, 1.4565097093582153, -0.5...    cryptocurrency
# 35    [0.18859677016735077, 1.449790120124817, -0.46...            report
# 22    [0.2763775587081909, 1.435113549232483, -0.540...  cryptocurrencies
# 91    [0.2850094735622406, 1.3965988159179688, -0.55...              take
# 115   [0.2772756814956665, 1.416480302810669, -0.577...              come
# 27    [0.22194357216358185, 1.3991223573684692, -0.5...              data
# 891   [0.24184495210647583, 1.3405468463897705, -0.4...            future
# 112   [0.2522736191749573, 1.181052565574646, -0.503...            number
# 210   [0.2193811535835266, 1.4129669666290283, -0.52...             first
# 442   [0.20686864852905273, 1.2106982469558716, -0.4...             major
# 176   [0.24317039549350739, 1.1704071760177612, -0.4...           binance
# 208   [0.24466057121753693, 1.315314769744873, -0.51...              note
# 39    [0.24986369907855988, 1.2927510738372803, -0.5...              sell
# 359   [0.2423858344554901, 1.2907350063323975, -0.51...             start
# 247   [0.26025456190109253, 1.1864439249038696, -0.4...              open
# 947   [0.26389244198799133, 1.266519546508789, -0.50...          ethereum
# 329   [0.2656514644622803, 1.2027515172958374, -0.51...          interest
# 63    [0.2228618711233139, 1.2835049629211426, -0.47...              lead
# 961   [0.25928258895874023, 1.290303111076355, -0.51...              news
# 6166  [0.20423932373523712, 1.2669346332550049, -0.4...     cointelegraph
# 42    [0.22480778396129608, 1.5110334157943726, -0.5...              look
# 47    [0.275554358959198, 1.448590636253357, -0.5643...             write
# 48    [0.1827435940504074, 1.4160184860229492, -0.52...          continue
# 201   [0.2266683578491211, 1.3316179513931274, -0.51...            result
# 461   [0.26986342668533325, 1.3479052782058716, -0.5...              seem
# 931   [0.22176693379878998, 1.308286190032959, -0.49...              gold
# 24    [0.2230270504951477, 1.07675039768219, -0.4277...              back
# 597   [0.2403712421655655, 1.145884394645691, -0.468...              lose
# 168   [0.28611212968826294, 1.2595458030700684, -0.5...              fact
#
#       cluster                                           centroid  distance  \
# 16          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.003227
# 2           1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.018627
# 35          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.022015
# 22          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.005803
# 91          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000270
# 115         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000439
# 27          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.008439
# 891         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.004448
# 112         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.002426
# 210         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.006153
# 442         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.001672
# 176         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.011570
# 208         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000575
# 39          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.001012
# 359         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000668
# 247         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000779
# 947         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000785
# 329         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.001489
# 63          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.002287
# 961         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000396
# 6166        1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.004377
# 42          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.015006
# 47          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.001156
# 48          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.015882
# 201         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.003626
# 461         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000162
# 931         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.002282
# 24          1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000284
# 597         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.000226
# 168         1  [0.02841437, 0.14008702, -0.05694861, -0.04554...  0.001963
#
#          tfidf     score closer#
# 16    0.452330  0.550897     NaN
# 2     0.187086  0.831541     NaN
# 35    0.127852  0.894163     NaN
# 22    0.078773  0.927030     NaN
# 91    0.065080  0.935190     NaN
# 115   0.057849  0.942590     NaN
# 27    0.057541  0.950898     NaN
# 891   0.052464  0.951984     NaN
# 112   0.044618  0.957809     NaN
# 210   0.046772  0.959381     NaN
# 442   0.042156  0.959516     NaN
# 176   0.051387  0.960183     NaN
# 208   0.039079  0.961496     NaN
# 39    0.039387  0.961626     NaN
# 359   0.037540  0.963128     NaN
# 247   0.032771  0.968008     NaN
# 947   0.032617  0.968168     NaN
# 329   0.032309  0.969180     NaN
# 63    0.033079  0.969208     NaN
# 961   0.028924  0.971472     NaN
# 6166  0.032463  0.971914     NaN
# 42    0.042771  0.972235     NaN
# 47    0.028463  0.972693     NaN
# 48    0.039540  0.976342     NaN
# 201   0.027232  0.976394     NaN
# 461   0.023540  0.976622     NaN
# 931   0.024617  0.977665     NaN
# 24    0.022155  0.978129     NaN
# 597   0.021386  0.978841     NaN
# 168   0.022924  0.979039     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 투자
# Out:
#                                                raw_data         word  cluster  \
# 143   [0.37887275218963623, 1.2109079360961914, -0.5...       crypto        2
# 32    [0.3619096875190735, 1.096129059791565, -0.526...     exchange        2
# 166   [0.41621580719947815, 1.349592685699463, -0.66...         make        2
# 174   [0.4972020387649536, 1.2183077335357666, -0.70...         user        2
# 125   [0.4712359607219696, 1.2215770483016968, -0.65...      company        2
# 60    [0.4720728397369385, 1.2359397411346436, -0.67...   blockchain        2
# 745   [0.37260472774505615, 1.1521285772323608, -0.6...  transaction        2
# 821   [0.4198060929775238, 1.3617773056030273, -0.66...        state        2
# 109   [0.3444855809211731, 1.364052653312683, -0.604...     investor        2
# 52    [0.38051772117614746, 1.385854959487915, -0.64...         mine        2
# 587   [0.445273756980896, 1.1946500539779663, -0.620...         fund        2
# 151   [0.4782482385635376, 1.3800615072250366, -0.55...        asset        2
# 594   [0.38001877069473267, 1.2382315397262573, -0.5...     platform        2
# 1244  [0.4546981155872345, 1.3323839902877808, -0.67...       people        2
# 948   [0.34971392154693604, 1.2750049829483032, -0.5...        token        2
# 68    [0.3888629078865051, 1.255806565284729, -0.590...     facebook        2
# 799   [0.40556982159614563, 1.2749212980270386, -0.6...         base        2
# 836   [0.4603396952152252, 1.3682032823562622, -0.66...        claim        2
# 129   [0.4370047152042389, 1.306268334388733, -0.647...      include        2
# 128   [0.37361058592796326, 1.2760406732559204, -0.6...         many        2
#
#                                                centroid  distance     tfidf  \
# 143   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.011894  0.212472
# 32    [0.043526568, 0.16562597, -0.074351266, -0.065...  0.025220  0.190471
# 166   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.005851  0.098774
# 174   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.042182  0.114621
# 125   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.035585  0.104928
# 60    [0.043526568, 0.16562597, -0.074351266, -0.065...  0.036589  0.105082
# 745   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.015880  0.082619
# 821   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.009805  0.069542
# 109   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.001025  0.060003
# 52    [0.043526568, 0.16562597, -0.074351266, -0.065...  0.001839  0.059541
# 587   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.017259  0.073696
# 151   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.025757  0.081081
# 594   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.012216  0.065542
# 1244  [0.043526568, 0.16562597, -0.074351266, -0.065...  0.015333  0.063695
# 948   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.005377  0.053233
# 68    [0.043526568, 0.16562597, -0.074351266, -0.065...  0.007682  0.055387
# 799   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.011595  0.059234
# 836   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.006721  0.053387
# 129   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.012798  0.058618
# 128   [0.043526568, 0.16562597, -0.074351266, -0.065...  0.001776  0.046002
#
#          score closer#
# 143   0.799422     NaN
# 32    0.834749     NaN
# 166   0.907077     NaN
# 174   0.927561     NaN
# 125   0.930656     NaN
# 60    0.931507     NaN
# 745   0.933261     NaN
# 821   0.940263     NaN
# 109   0.941022     NaN
# 52    0.942298     NaN
# 587   0.943563     NaN
# 151   0.944676     NaN
# 594   0.946674     NaN
# 1244  0.951637     NaN
# 948   0.952143     NaN
# 68    0.952294     NaN
# 799   0.952361     NaN
# 836   0.953334     NaN
# 129   0.954180     NaN
# 128   0.955774     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 사회적 시도
# Out:
#                                               raw_data     word  cluster  \
# 3    [0.08088155090808868, 1.6752866506576538, -0.4...   market        3
# 5    [0.07515804469585419, 1.5690245628356934, -0.3...    trade        3
# 17   [-0.07463861256837845, 2.0703518390655518, -0....    price        3
# 1    [0.09787560254335403, 1.7753829956054688, -0.4...     time        3
# 6    [-0.08447109162807465, 2.0231728553771973, -0....     high        3
# 62   [0.11775581538677216, 1.4886573553085327, -0.4...     year        3
# 178  [0.15388478338718414, 1.6173025369644165, -0.4...     coin        3
# 246  [0.11818958818912506, 1.7369210720062256, -0.5...  support        3
# 15   [0.17565418779850006, 1.5194255113601685, -0.4...   accord        3
# 10   [0.028275910764932632, 1.578377604484558, -0.4...    month        3
# 33   [-0.02860676497220993, 1.6238301992416382, -0....     last        3
# 214  [-0.02639590948820114, 1.8485608100891113, -0....     week        3
# 312  [0.12902796268463135, 1.6725211143493652, -0.5...     show        3
# 211  [0.10906993597745895, 1.585790991783142, -0.48...    early        3
# 37   [-0.0028619675431400537, 1.8162624835968018, -...     move        3
# 85   [0.14911718666553497, 1.581478238105774, -0.53...     term        3
# 452  [0.12264475226402283, 1.5199782848358154, -0.4...    april        3
# 171  [0.13923221826553345, 1.4197152853012085, -0.4...    large        3
# 96   [0.33949989080429077, 1.5877177715301514, -0.5...     hold        3
# 103  [0.1736934930086136, 1.4571179151535034, -0.46...    value        3
#
#                                               centroid  distance     tfidf  \
# 3    [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.011527  0.207395
# 5    [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.024016  0.185855
# 17   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.049783  0.198933
# 1    [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.022091  0.158008
# 6    [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.035326  0.119698
# 62   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.005936  0.089543
# 178  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.010250  0.087543
# 246  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.016186  0.078927
# 15   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.016326  0.072773
# 10   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.006283  0.061080
# 33   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.016722  0.068773
# 214  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.022180  0.072465
# 312  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.000598  0.048772
# 211  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.002096  0.047233
# 37   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.031269  0.073388
# 85   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.005205  0.046618
# 452  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.003012  0.041540
# 171  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.019780  0.057387
# 96   [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.026064  0.061695
# 103  [0.02687615, 0.34484783, -0.10821818, -0.05831...  0.018192  0.053695
#
#         score closer#
# 3    0.804132     NaN
# 5    0.838161     NaN
# 17   0.850850     NaN
# 1    0.864083     NaN
# 6    0.915628     NaN
# 62   0.916394     NaN
# 178  0.922708     NaN
# 246  0.937260     NaN
# 15   0.943553     NaN
# 10   0.945203     NaN
# 33   0.947950     NaN
# 214  0.949714     NaN
# 312  0.951826     NaN
# 211  0.954863     NaN
# 37   0.957881     NaN
# 85   0.958587     NaN
# 452  0.961472     NaN
# 171  0.962393     NaN
# 96   0.964369     NaN
# 103  0.964497     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 긍정적 감정
# Out:
# 56

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 기타
# Out:
# 4734

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 투자
# Out:
# 4467

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 사회적 시도
# Out:
# 582

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 1324.924780855449

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [3 3 3 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -1324.9247

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.7657786

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # Influencer활동
# Out:
#                                                raw_data          word  \
# 4994  [0.015463975258171558, 0.05879330635070801, -0...       iceberg
# 5487  [0.011203092522919178, 0.06274357438087463, -0...       steemit
# 7681  [0.009958877228200436, 0.058664120733737946, -...        lassen
# 2247  [0.013570379465818405, 0.05842287465929985, -0...     negotiate
# 2652  [0.01648847945034504, 0.05697858706116676, -0....        animal
# 6557  [0.016092685982584953, 0.06138511747121811, -0...       roubini
# 7594  [0.013768952339887619, 0.05926058441400528, -0...      bewegung
# 9073  [0.013308138586580753, 0.06141756474971771, -0...    𝘤𝘰𝘮𝘮𝘦𝘳𝘤𝘪𝘢𝘭
# 409   [0.007917102426290512, 0.060936082154512405, -...      decouple
# 8473  [0.014969667419791222, 0.0591927245259285, -0....      donoghue
# 8913  [0.014197622425854206, 0.062467824667692184, -...         kakao
# 7640  [0.01828121580183506, 0.06057891994714737, -0....        anfang
# 7822  [0.011048057116568089, 0.05869908258318901, -0...      wordplay
# 5691  [0.015161750838160515, 0.06132255494594574, -0...      whatever
# 7771  [0.014143204316496849, 0.06375234574079514, -0...       student
# 9194  [0.010367186740040779, 0.05623704567551613, -0...         wound
# 4180  [0.014083067886531353, 0.056931059807538986, -...      reinhart
# 6696  [0.009284022264182568, 0.06338231265544891, -0...      kirchner
# 8508  [0.01170460507273674, 0.05834854394197464, -0....        taylor
# 4619  [0.0116952583193779, 0.06022142991423607, -0.0...          nodl
# 8085  [0.012826120480895042, 0.055618252605199814, -...         coone
# 5251  [0.010609752498567104, 0.059367645531892776, -...  dispositivos
# 4686  [0.012663576751947403, 0.057254608720541, -0.0...     diversity
# 5612  [0.011962641961872578, 0.0577898807823658, -0....         angel
# 5032  [0.009270498529076576, 0.05906316637992859, -0...       anatoly
# 5471  [0.010300325229763985, 0.05595535412430763, -0...        heintz
# 1029  [0.008689886890351772, 0.053029946982860565, -...         sixth
# 4816  [0.008954507298767567, 0.05874691158533096, -0...     unlimited
# 4660  [0.012207978405058384, 0.057316869497299194, -...    mindedness
# 4135  [0.009631338529288769, 0.06284841150045395, -0...     unaudited
#
#       cluster                                           centroid  distance  \
# 4994        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.026379
# 5487        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.026699
# 7681        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.026927
# 2247        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027256
# 2652        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027132
# 6557        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027342
# 7594        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027197
# 9073        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027226
# 409         0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027702
# 8473        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027497
# 8913        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027515
# 7640        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027441
# 7822        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027447
# 5691        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027605
# 7771        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027656
# 9194        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027537
# 4180        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028157
# 6696        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.027926
# 8508        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028003
# 4619        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028391
# 8085        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028106
# 5251        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028097
# 4686        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028451
# 5612        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028518
# 5032        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028677
# 5471        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028218
# 1029        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028890
# 4816        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028772
# 4660        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028310
# 4135        0  [0.0133644175, 0.05959189, -0.025166709, -0.02...  0.028639
#
#          tfidf     score closer#
# 4994  0.000462  1.025918     NaN
# 5487  0.000308  1.026391     NaN
# 7681  0.000154  1.026774     NaN
# 2247  0.000462  1.026794     NaN
# 2652  0.000308  1.026824     NaN
# 6557  0.000462  1.026880     NaN
# 7594  0.000154  1.027043     NaN
# 9073  0.000154  1.027072     NaN
# 409   0.000615  1.027087     NaN
# 8473  0.000308  1.027190     NaN
# 8913  0.000308  1.027207     NaN
# 7640  0.000154  1.027287     NaN
# 7822  0.000154  1.027293     NaN
# 5691  0.000308  1.027297     NaN
# 7771  0.000308  1.027348     NaN
# 9194  0.000154  1.027383     NaN
# 4180  0.000615  1.027541     NaN
# 6696  0.000308  1.027618     NaN
# 8508  0.000308  1.027696     NaN
# 4619  0.000615  1.027776     NaN
# 8085  0.000308  1.027798     NaN
# 5251  0.000154  1.027944     NaN
# 4686  0.000462  1.027990     NaN
# 5612  0.000462  1.028056     NaN
# 5032  0.000615  1.028061     NaN
# 5471  0.000154  1.028064     NaN
# 1029  0.000769  1.028121     NaN
# 4816  0.000615  1.028156     NaN
# 4660  0.000154  1.028156     NaN
# 4135  0.000462  1.028177     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(30,'score') # 투자, 긍정적 현상
# Out:
#                                                raw_data        word  cluster  \
# 524   [0.25349071621894836, 1.0099071264266968, -0.4...       party        1
# 1156  [0.2399744838476181, 1.0163359642028809, -0.43...     concern        1
# 468   [0.24831567704677582, 1.0143283605575562, -0.4...   potential        1
# 1057  [0.24428462982177734, 1.0085245370864868, -0.4...        deal        1
# 603   [0.2599789500236511, 1.0410077571868896, -0.45...       clear        1
# 304   [0.256997287273407, 1.035016655921936, -0.4579...       thing        1
# 1521  [0.24267542362213135, 1.017057180404663, -0.44...   president        1
# 72    [0.24024038016796112, 1.005288004875183, -0.43...    adoption        1
# 997   [0.2595042586326599, 1.008374810218811, -0.447...      client        1
# 2510  [0.23645944893360138, 1.0084571838378906, -0.4...       stake        1
# 1176  [0.26102280616760254, 1.0019361972808838, -0.4...       space        1
# 703   [0.2551843523979187, 1.0696468353271484, -0.46...      reason        1
# 976   [0.25030985474586487, 1.0651588439941406, -0.4...     publish        1
# 1229  [0.2722350060939789, 0.9941765666007996, -0.44...        code        1
# 700   [0.24260105192661285, 0.9792389273643494, -0.4...       limit        1
# 1269  [0.2734246850013733, 1.0262210369110107, -0.46...     venture        1
# 161   [0.2576260566711426, 0.9979082345962524, -0.44...       exist        1
# 1061  [0.24601876735687256, 1.0740363597869873, -0.4...     example        1
# 1241  [0.26891598105430603, 1.0316083431243896, -0.4...        full        1
# 867   [0.24848228693008423, 1.0389940738677979, -0.4...   important        1
# 1038  [0.2408534586429596, 1.0847972631454468, -0.46...    economic        1
# 1613  [0.2332545816898346, 1.0028926134109497, -0.42...   something        1
# 776   [0.23416627943515778, 1.0373443365097046, -0.4...        head        1
# 1733  [0.26441264152526855, 1.0913785696029663, -0.4...    question        1
# 834   [0.24922803044319153, 0.9806822538375854, -0.4...       model        1
# 980   [0.2722417116165161, 0.9971146583557129, -0.45...   available        1
# 1024  [0.24954058229923248, 0.9733874201774597, -0.4...        york        1
# 2719  [0.259779691696167, 1.1019619703292847, -0.470...        meet        1
# 505   [0.2409966140985489, 0.9634650945663452, -0.42...      manage        1
# 1281  [0.26260989904403687, 0.9716839790344238, -0.4...  individual        1
#
#                                                centroid  distance     tfidf  \
# 524   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.066318  0.015385
# 1156  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.084700  0.015693
# 468   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.087667  0.016462
# 1057  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.091219  0.014616
# 603   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.094584  0.017539
# 304   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.112209  0.014001
# 1521  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.110155  0.008924
# 72    [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.118831  0.016155
# 997   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.128677  0.018616
# 2510  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.127280  0.015539
# 1176  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.141269  0.016616
# 703   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.152835  0.019232
# 976   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.154217  0.016924
# 1229  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.164138  0.014308
# 700   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.179448  0.018155
# 1269  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.179035  0.013693
# 161   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.181330  0.015847
# 1061  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.193268  0.018309
# 1241  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.196201  0.019078
# 867   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.205642  0.018770
# 1038  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.205476  0.013231
# 1613  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.208069  0.013231
# 776   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.216219  0.012616
# 1733  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.220467  0.015847
# 834   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.222880  0.012616
# 980   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.230857  0.019386
# 1024  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.232684  0.014924
# 2719  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.238329  0.012462
# 505   [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.241354  0.015385
# 1281  [0.2537547, 1.0300598, -0.4498009, -0.386494, ...  0.241677  0.013847
#
#          score closer#
# 524   1.050932     NaN
# 1156  1.069007     NaN
# 468   1.071204     NaN
# 1057  1.076603     NaN
# 603   1.077045     NaN
# 304   1.098208     NaN
# 1521  1.101231     NaN
# 72    1.102677     NaN
# 997   1.110060     NaN
# 2510  1.111741     NaN
# 1176  1.124653     NaN
# 703   1.133603     NaN
# 976   1.137293     NaN
# 1229  1.149829     NaN
# 700   1.161293     NaN
# 1269  1.165342     NaN
# 161   1.165483     NaN
# 1061  1.174959     NaN
# 1241  1.177123     NaN
# 867   1.186872     NaN
# 1038  1.192245     NaN
# 1613  1.194838     NaN
# 776   1.203603     NaN
# 1733  1.204620     NaN
# 834   1.210264     NaN
# 980   1.211472     NaN
# 1024  1.217760     NaN
# 2719  1.225867     NaN
# 505   1.225968     NaN
# 1281  1.227830     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(30,'score')  # 기술
# Out:
#                                                raw_data          word  \
# 631   [0.10112803429365158, 0.4504941999912262, -0.1...         zcash
# 1492  [0.09470368921756744, 0.4525282680988312, -0.1...        battle
# 870   [0.09711220115423203, 0.44127050042152405, -0....    production
# 1580  [0.1013680249452591, 0.450000524520874, -0.184...         forum
# 2016  [0.10153152048587799, 0.44332510232925415, -0....       michael
# 3695  [0.09672949463129044, 0.4362108111381531, -0.1...          mass
# 635   [0.09916400909423828, 0.4401632249355316, -0.1...   speculative
# 3598  [0.10226814448833466, 0.45828986167907715, -0....          burn
# 293   [0.10275926440954208, 0.46386709809303284, -0....          vice
# 430   [0.10089369118213654, 0.45332351326942444, -0....        gather
# 1779  [0.10004191100597382, 0.4442001283168793, -0.1...          matt
# 591   [0.10726343095302582, 0.45657679438591003, -0....     guarantee
# 1489  [0.10617272555828094, 0.45773375034332275, -0....     mechanism
# 1033  [0.09667074680328369, 0.43434712290763855, -0....        street
# 1837  [0.0947277769446373, 0.4634777307510376, -0.18...  manipulation
# 1437  [0.09746382385492325, 0.4616610109806061, -0.1...          draw
# 2599  [0.0943480134010315, 0.43558651208877563, -0.1...          john
# 4091  [0.1032729521393776, 0.43851438164711, -0.1916...         visit
# 1973  [0.09433527290821075, 0.4289803206920624, -0.1...       minimum
# 3786  [0.10063928365707397, 0.46715766191482544, -0....        annual
# 1273  [0.09885087609291077, 0.46548670530319214, -0....         train
# 4128  [0.10118898004293442, 0.43776339292526245, -0....      minister
# 2877  [0.10266875475645065, 0.438150554895401, -0.18...          asia
# 2384  [0.10355567187070847, 0.4387478828430176, -0.1...   environment
# 5413  [0.09638571739196777, 0.46834686398506165, -0....         shrem
# 1622  [0.10296699404716492, 0.46229347586631775, -0....          hope
# 614   [0.10403739660978317, 0.4461043179035187, -0.1...    impossible
# 5502  [0.09271500259637833, 0.45202627778053284, -0....          pump
# 2960  [0.09521027654409409, 0.43358534574508667, -0....        assume
# 877   [0.09851428866386414, 0.45925232768058777, -0....       reflect
#
#       cluster                                           centroid  distance  \
# 631         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.039576
# 1492        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.040613
# 870         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.042297
# 1580        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.050150
# 2016        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.050333
# 3695        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.052362
# 635         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.052636
# 3598        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.054274
# 293         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.058378
# 430         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.060497
# 1779        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.058957
# 591         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.061331
# 1489        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.063870
# 1033        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.066977
# 1837        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.069237
# 1437        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.069159
# 2599        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.069003
# 4091        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.071067
# 1973        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.070998
# 3786        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.072834
# 1273        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.072591
# 4128        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.073634
# 2877        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.076561
# 2384        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.077971
# 5413        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.078225
# 1622        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.078787
# 614         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.079319
# 5502        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.080877
# 2960        2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.081503
# 877         2  [0.09608115, 0.44719574, -0.18546319, -0.15177...  0.081895
#
#          tfidf     score closer#
# 631   0.004308  1.035268     NaN
# 1492  0.003692  1.036920     NaN
# 870   0.003385  1.038912     NaN
# 1580  0.003385  1.046765     NaN
# 2016  0.003539  1.046794     NaN
# 3695  0.004154  1.048208     NaN
# 635   0.004000  1.048635     NaN
# 3598  0.002769  1.051505     NaN
# 293   0.004308  1.054071     NaN
# 430   0.004923  1.055574     NaN
# 1779  0.002462  1.056495     NaN
# 591   0.003846  1.057484     NaN
# 1489  0.004462  1.059409     NaN
# 1033  0.004769  1.062207     NaN
# 1837  0.004000  1.065237     NaN
# 1437  0.003846  1.065312     NaN
# 2599  0.003077  1.065925     NaN
# 4091  0.003692  1.067374     NaN
# 1973  0.003385  1.067614     NaN
# 3786  0.004154  1.068680     NaN
# 1273  0.002308  1.070283     NaN
# 4128  0.002923  1.070710     NaN
# 2877  0.004154  1.072407     NaN
# 2384  0.004000  1.073970     NaN
# 5413  0.004000  1.074225     NaN
# 1622  0.004308  1.074479     NaN
# 614   0.004154  1.075165     NaN
# 5502  0.004154  1.076723     NaN
# 2960  0.004308  1.077195     NaN
# 877   0.004616  1.077279     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 기타
# Out:
#                                               raw_data     word  cluster  \
# 236  [0.1217367947101593, 1.4778095483779907, -0.46...    close        3
# 232  [0.13238602876663208, 1.563322901725769, -0.51...     next        3
# 211  [0.10906993597745895, 1.585790991783142, -0.48...    early        3
# 385  [0.10556800663471222, 1.5409560203552246, -0.4...    today        3
# 303  [0.11424173414707184, 1.4671705961227417, -0.4...     bear        3
# 452  [0.12264475226402283, 1.5199782848358154, -0.4...    april        3
# 312  [0.12902796268463135, 1.6725211143493652, -0.5...     show        3
# 10   [0.028275910764932632, 1.578377604484558, -0.4...    month        3
# 88   [0.12204986810684204, 1.4669157266616821, -0.4...    short        3
# 62   [0.11775581538677216, 1.4886573553085327, -0.4...     year        3
# 224  [0.08393257856369019, 1.4143245220184326, -0.4...   strong        3
# 220  [0.08068040758371353, 1.4782311916351318, -0.4...    trend        3
# 216  [0.07257230579853058, 1.5563455820083618, -0.5...  bearish        3
# 85   [0.14911718666553497, 1.581478238105774, -0.53...     term        3
# 417  [0.14448612928390503, 1.505924105644226, -0.52...     line        3
# 539  [0.1712678074836731, 1.5088558197021484, -0.50...     loss        3
# 340  [0.11170713603496552, 1.3325289487838745, -0.4...     sign        3
# 178  [0.15388478338718414, 1.6173025369644165, -0.4...     coin        3
# 389  [0.12528832256793976, 1.4378589391708374, -0.4...    total        3
# 3    [0.08088155090808868, 1.6752866506576538, -0.4...   market        3
#
#                                               centroid  distance     tfidf  \
# 236  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.299564  0.030925
# 232  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.418884  0.036156
# 211  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.431285  0.047233
# 385  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.434462  0.037233
# 303  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.471568  0.025540
# 452  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.505469  0.041540
# 312  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.581959  0.048772
# 10   [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.594611  0.061080
# 88   [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.572297  0.029694
# 62   [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.648649  0.089543
# 224  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.619295  0.029078
# 220  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.624241  0.027694
# 216  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.625335  0.026155
# 85   [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.679025  0.046618
# 417  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.682565  0.024617
# 539  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.755624  0.031078
# 340  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.808177  0.028771
# 178  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.878101  0.087543
# 389  [0.11169037, 1.5374389, -0.4748079, -0.2457987...  0.822313  0.028924
# 3    [0.11169037, 1.5374389, -0.4748079, -0.2457987...  1.007745  0.207395
#
#         score closer#
# 236  1.268639     NaN
# 232  1.382728     NaN
# 211  1.384052     NaN
# 385  1.397229     NaN
# 303  1.446028     NaN
# 452  1.463928     NaN
# 312  1.533187     NaN
# 10   1.533531     NaN
# 88   1.542603     NaN
# 62   1.559106     NaN
# 224  1.590217     NaN
# 220  1.596548     NaN
# 216  1.599180     NaN
# 85   1.632407     NaN
# 417  1.657949     NaN
# 539  1.724546     NaN
# 340  1.779406     NaN
# 178  1.790558     NaN
# 389  1.793389     NaN
# 3    1.800350     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #Influencer활동
# Out:
# 8168

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #투자 긍정적 현상
# Out:
# 468

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #기술 긍정
# Out:
# 1114

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #기타
# Out:
# 89

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.9583951

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[ 5.31194906e+00,  3.96651996e+00],
#        [ 4.94564387e+00,  3.04198506e+00],
#        [ 4.45940575e+00,  6.16612941e-01],
#        ...,
#        [-4.96989858e-01, -6.03174856e-03],
#        [-5.36844166e-01, -3.20018782e-04],
#        [-5.30862946e-01,  1.05598789e-02]])

# %%
xys[:,0]
# Out:
# array([ 5.31194906,  4.94564387,  4.45940575, ..., -0.49698986,
#        -0.53684417, -0.53086295])

# %%
xys[:,1]
# Out:
# array([ 3.96651996e+00,  3.04198506e+00,  6.16612941e-01, ...,
#        -6.03174856e-03, -3.20018782e-04,  1.05598789e-02])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129315 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128079 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127829 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128079 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127829 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128170 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128170 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120374 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120371 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120374 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120358 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120371 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120365 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120329 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120365 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120378 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120378 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120362 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120362 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120359 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120359 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120355 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 120379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120355 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 120379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128073 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128073 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128721 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128678 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128721 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128678 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128081 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128081 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127793 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128189 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128189 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127926 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128071 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128584 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128071 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128584 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127345 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
