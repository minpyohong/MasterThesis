# %%
import chardet
import pandas as pd
import urllib.request

    
#print(encoding_result)
data = pd.read_csv('../news/scraping_result/en/2019_up3/2019_up3_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up3/2019_up3_Cointelegraph.csv',error_bad_lines=False))
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up3/2019_up3_CryptoNews.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../news/scraping_result/en/2019_up3/2019_up3_Forbes.csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 7384

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 7384

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.000*"ourlittlesecret" + 0.000*"brodjonegoro" + 0.000*"hotel" + 0.000*"tätigen" + 0.000*"lesson" + 0.000*"completó" + 0.000*"happy" + 0.000*"spillover"')
# (1, '0.001*"voorhees" + 0.001*"regain" + 0.001*"desperate" + 0.001*"passenger" + 0.001*"roundabout" + 0.001*"bloc" + 0.001*"katy" + 0.001*"newzoo"')
# (2, '0.000*"decay" + 0.000*"environmental" + 0.000*"tyranny" + 0.000*"vegan" + 0.000*"haris" + 0.000*"cholesterol" + 0.000*"anwar" + 0.000*"obesity"')
# (3, '0.000*"sufficient" + 0.000*"dominada" + 0.000*"manera" + 0.000*"mentira" + 0.000*"existencia" + 0.000*"tiburones" + 0.000*"carteras" + 0.000*"también"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el56001403454242795045981219268"></div>
# <script type="text/javascript">
#
# var ldavis_el56001403454242795045981219268_data = {"mdsDat": {"x": [-0.13174607630678709, 0.06730199118891939, 0.038236601308818785, 0.02620748380904888], "y": [0.01507237116258742, 0.07962811936023666, -0.07411546642499507, -0.020585024097829113], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [28.72829818725586, 25.91727638244629, 23.301626205444336, 22.05280303955078]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", " ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 7384

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 7384

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 7.3606982160992445

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 1.581659401350688e-05

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 5.102301456379359

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 부정적 감정 , 공포
# Out:
#                                                raw_data          word  \
# 4946  [-0.0026781493797898293, 0.0003427936171647161...       jiaming
# 4624  [-0.0035778756719082594, 0.0002795441541820764...       whistle
# 6640  [0.004217192064970732, -0.0013290679780766368,...    adjustment
# 1582  [0.00031160167418420315, 0.0019249854376539588...      recreate
# 7215  [-0.0006999055040068924, 0.0045261261984705925...         marry
# 4150  [0.00195450522005558, 0.0032666537445038557, 0...      follower
# 7231  [0.005209284368902445, 0.006702485028654337, -...       conjure
# 6920  [-0.0031346287578344345, 0.005449929274618626,...       whoever
# 3525  [0.001777528552338481, -1.9637496734503657e-05...         widow
# 6931  [-0.0031620969530194998, 0.005032622255384922,...   gauntletall
# 7313  [-0.0021419846452772617, 0.005417574197053909,...     sometimes
# 3125  [0.0023027483839541674, -0.002034489531069994,...     vindicate
# 2383  [0.003964036703109741, -0.001517183380201459, ...     sensation
# 6889  [0.003116219537332654, 0.00635638739913702, 0....  strugglesany
# 6421  [-0.004243143834173679, 0.0026154648512601852,...        eschew
# 4278  [0.0019927110988646746, -0.0024376504588872194...       weekday
# 4503  [-0.0026007406413555145, 0.0024027947802096605...        socios
# 5732  [0.003738261992111802, 0.0009444813476875424, ...    prometheum
# 4352  [0.0015465543838217854, 0.002303158398717642, ...        lessen
# 3845  [0.0008943933062255383, 0.0030109023209661245,...       chamath
#
#       cluster                                           centroid  distance  \
# 4946        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.096957
# 4624        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.097331
# 6640        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.102862
# 1582        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.102953
# 7215        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.115331
# 4150        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.116301
# 7231        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.127170
# 6920        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.128064
# 3525        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.129327
# 6931        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.148783
# 7313        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.150011
# 3125        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.156186
# 2383        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.174839
# 6889        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.178484
# 6421        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.179794
# 4278        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.183029
# 4503        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.194163
# 5732        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.195360
# 4352        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.195797
# 3845        0  [-0.00040639358, 0.0010414594, 0.0001995246, -...  0.197758
#
#          tfidf     score closer#
# 4946  0.000446  1.096511     NaN
# 4624  0.000446  1.096885     NaN
# 6640  0.000446  1.102416     NaN
# 1582  0.000446  1.102507     NaN
# 7215  0.000446  1.114885     NaN
# 4150  0.000446  1.115855     NaN
# 7231  0.000446  1.126724     NaN
# 6920  0.000446  1.127618     NaN
# 3525  0.000446  1.128881     NaN
# 6931  0.000446  1.148337     NaN
# 7313  0.000446  1.149565     NaN
# 3125  0.000446  1.155740     NaN
# 2383  0.000446  1.174393     NaN
# 6889  0.000446  1.178038     NaN
# 6421  0.000446  1.179348     NaN
# 4278  0.000446  1.182583     NaN
# 4503  0.000446  1.193717     NaN
# 5732  0.000446  1.194914     NaN
# 4352  0.000446  1.195352     NaN
# 3845  0.000446  1.197312     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회적 이슈
# Out:
#                                                raw_data              word  \
# 16    [0.13633574545383453, -0.08710343390703201, 1....           bitcoin
# 2     [0.14307580888271332, 0.0030799671076238155, 1...    cryptocurrency
# 35    [0.11817046999931335, 0.03068341314792633, 1.3...            report
# 22    [0.149251326918602, -0.05993717536330223, 1.45...  cryptocurrencies
# 178   [0.1885448843240738, 0.0916285440325737, 1.457...              coin
# 91    [0.11388405412435532, -0.17243622243404388, 1....              take
# 15    [0.15523704886436462, 0.009107835590839386, 1....            accord
# 115   [0.11524221301078796, -0.164931520819664, 1.36...              come
# 27    [0.11237987875938416, -0.026180820539593697, 1...              data
# 891   [0.09452706575393677, -0.09704854339361191, 1....            future
# 210   [0.1255580335855484, -0.08006928861141205, 1.3...             first
# 103   [0.14987623691558838, -0.0009591400157660246, ...             value
# 442   [0.09298326820135117, -0.07792408019304276, 1....             major
# 208   [0.11151446402072906, -0.1268417090177536, 1.2...              note
# 39    [0.10940369963645935, -0.08485744148492813, 1....              sell
# 359   [0.11663845181465149, -0.12058740109205246, 1....             start
# 374   [0.15547990798950195, -0.060232773423194885, 1...             point
# 42    [0.15522563457489014, -0.07845107465982437, 1....              look
# 171   [0.16377221047878265, 0.09153281897306442, 1.2...             large
# 48    [0.1385381817817688, -0.08676116913557053, 1.2...          continue
# 245   [0.15758860111236572, -0.08895327150821686, 1....              find
# 63    [0.11424513161182404, -0.09222934395074844, 1....              lead
# 247   [0.12544435262680054, -0.07727459818124771, 1....              open
# 93    [0.15158124268054962, -0.05126899480819702, 1....            follow
# 947   [0.1217399314045906, -0.11494914442300797, 1.2...          ethereum
# 6166  [0.08781301975250244, -0.08828413486480713, 1....     cointelegraph
# 329   [0.0974472388625145, -0.1522047221660614, 1.19...          interest
# 362   [0.13758336007595062, -0.07212172448635101, 1....            trader
# 47    [0.1368883103132248, -0.10374514013528824, 1.3...             write
# 268   [0.1438244730234146, -0.08116954565048218, 1.2...            change
#
#       cluster                                           centroid  distance  \
# 16          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.002098
# 2           1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.012421
# 35          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.012810
# 22          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.004180
# 178         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.020545
# 91          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.001236
# 15          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.010354
# 115         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.002251
# 27          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.004899
# 891         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.003190
# 210         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.001509
# 103         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.009673
# 442         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000942
# 208         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000374
# 39          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000760
# 359         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000115
# 374         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.004490
# 42          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.006851
# 171         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.022464
# 48          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.005821
# 245         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.006624
# 63          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000351
# 247         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000848
# 93          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.009065
# 947         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.001997
# 6166        1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.002186
# 329         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.003173
# 362         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.004604
# 47          1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.000542
# 268         1  [0.013026532, -0.012129969, 0.13719083, -0.032...  0.006968
#
#          tfidf     score closer#
# 16    0.452330  0.549768     NaN
# 2     0.187086  0.825334     NaN
# 35    0.127852  0.884958     NaN
# 22    0.078773  0.925407     NaN
# 178   0.087543  0.933002     NaN
# 91    0.065080  0.936156     NaN
# 15    0.072773  0.937581     NaN
# 115   0.057849  0.944402     NaN
# 27    0.057541  0.947358     NaN
# 891   0.052464  0.950726     NaN
# 210   0.046772  0.954737     NaN
# 103   0.053695  0.955978     NaN
# 442   0.042156  0.958786     NaN
# 208   0.039079  0.961295     NaN
# 39    0.039387  0.961374     NaN
# 359   0.037540  0.962575     NaN
# 374   0.041848  0.962641     NaN
# 42    0.042771  0.964079     NaN
# 171   0.057387  0.965076     NaN
# 48    0.039540  0.966281     NaN
# 245   0.039848  0.966776     NaN
# 63    0.033079  0.967272     NaN
# 247   0.032771  0.968077     NaN
# 93    0.040310  0.968756     NaN
# 947   0.032617  0.969380     NaN
# 6166  0.032463  0.969723     NaN
# 329   0.032309  0.970864     NaN
# 362   0.032617  0.971987     NaN
# 47    0.028463  0.972079     NaN
# 268   0.034771  0.972197     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 제도
# Out:
#                                                raw_data        word  cluster  \
# 2087  [0.006515380460768938, 0.021489698439836502, 0...      compel        2
# 2434  [0.005007245112210512, 0.02195478416979313, 0....     pending        2
# 3502  [-0.00018064715550281107, 0.01881515234708786,...    jamieson        2
# 3447  [0.004884224850684404, 0.015522596426308155, 0...      prison        2
# 3369  [0.004039295017719269, 0.014754914678633213, 0...    tomorrow        2
# 562   [0.005333307199180126, 0.016616839915513992, 0...    politics        2
# 5548  [0.0021661536302417517, 0.018573228269815445, ...      employ        2
# 5183  [0.0002709849504753947, 0.017078233882784843, ...      cuenta        2
# 3220  [-0.002074881223961711, 0.016314299777150154, ...     seagate        2
# 2722  [0.002310201758518815, 0.01359668280929327, 0....      exceed        2
# 6668  [-3.3185780921485275e-05, 0.009934330359101295...      tagomi        2
# 5810  [0.000158636859850958, 0.01460573822259903, 0....        ihre        2
# 5411  [0.0026835801545530558, 0.011238078586757183, ...      verdad        2
# 7127  [0.007864306680858135, 0.01795956864953041, 0....    quotient        2
# 7166  [0.0009415852837264538, 0.013436730019748211, ...   inventory        2
# 6379  [0.002727398881688714, 0.015118969604372978, 0...  escalation        2
# 123   [0.004337383434176445, 0.010422371327877045, 0...    observer        2
# 4445  [0.0024599889293313026, 0.012378127314150333, ...       input        2
# 384   [-0.001473233220167458, 0.010681349784135818, ...       dario        2
# 6733  [0.003982197493314743, 0.01669558510184288, 0....  uniqueness        2
#
#                                                centroid  distance     tfidf  \
# 2087  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.002381  0.002675
# 2434  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.004760  0.001784
# 3502  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.004925  0.001338
# 3447  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.006404  0.001338
# 3369  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.006595  0.001338
# 562   [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.007048  0.001784
# 5548  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.007167  0.001784
# 5183  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.006775  0.000892
# 3220  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.008148  0.002230
# 2722  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.007967  0.001784
# 6668  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.008541  0.002230
# 5810  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.007296  0.000892
# 5411  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.007795  0.000892
# 7127  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.008311  0.001338
# 7166  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.008651  0.001338
# 6379  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.008736  0.001338
# 123   [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.009723  0.001784
# 4445  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.009044  0.000892
# 384   [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.009632  0.001338
# 6733  [0.0010763927, 0.005506136, 0.0037119684, 0.00...  0.009718  0.001338
#
#          score closer#
# 2087  0.999705     NaN
# 2434  1.002976     NaN
# 3502  1.003588     NaN
# 3447  1.005066     NaN
# 3369  1.005258     NaN
# 562   1.005264     NaN
# 5548  1.005383     NaN
# 5183  1.005883     NaN
# 3220  1.005919     NaN
# 2722  1.006183     NaN
# 6668  1.006311     NaN
# 5810  1.006404     NaN
# 5411  1.006903     NaN
# 7127  1.006973     NaN
# 7166  1.007313     NaN
# 6379  1.007399     NaN
# 123   1.007940     NaN
# 4445  1.008153     NaN
# 384   1.008295     NaN
# 6733  1.008380     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 가격, 거래소, 돈
# Out:
#                                                raw_data            word  \
# 37    [0.08943404257297516, 0.41160330176353455, 0.2...         bitcoin
# 344   [0.08783181011676788, 0.38157084584236145, 0.2...      blockchain
# 122   [0.07674996554851532, 0.35065773129463196, 0.2...          crypto
# 61    [0.0721268579363823, 0.3408474326133728, 0.239...           trade
# 1     [0.07730618119239807, 0.3584815263748169, 0.24...          market
# 168   [0.07335671782493591, 0.33918777108192444, 0.2...        exchange
# 321   [0.07569863647222519, 0.3416253924369812, 0.24...        currency
# 0     [0.07769254595041275, 0.3402886390686035, 0.24...  cryptocurrency
# 455   [0.08801430463790894, 0.3621945381164551, 0.26...         company
# 78    [0.08141747862100601, 0.33724355697631836, 0.2...          report
# 112   [0.08745168149471283, 0.3840869665145874, 0.26...            time
# 17    [0.06727062910795212, 0.30421149730682373, 0.2...           price
# 172   [0.08264676481485367, 0.3447578251361847, 0.24...            year
# 663   [0.07714445143938065, 0.3357160687446594, 0.22...         digital
# 111   [0.07063822448253632, 0.32244235277175903, 0.2...           asset
# 376   [0.08057015389204025, 0.3725862503051758, 0.26...            make
# 1035  [0.07889773696660995, 0.32950347661972046, 0.2...            user
# 43    [0.07904475182294846, 0.35395196080207825, 0.2...            data
# 196   [0.07455180585384369, 0.3215416371822357, 0.22...            bank
# 410   [0.0724092647433281, 0.3199561536312103, 0.219...     transaction
#
#       cluster                                           centroid  distance  \
# 37          3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000020
# 344         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000020
# 122         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000024
# 61          3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000041
# 1           3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000024
# 168         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000028
# 321         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000030
# 0           3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000016
# 455         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000015
# 78          3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000028
# 112         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000024
# 17          3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000073
# 172         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000022
# 663         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000045
# 111         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000038
# 376         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000016
# 1035        3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000021
# 43          3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000022
# 196         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000033
# 410         3  [0.007504105, 0.03206768, 0.022592368, 0.00671...  0.000029
#
#          tfidf     score closer#
# 37    0.331751  0.668269     NaN
# 344   0.203332  0.796689     NaN
# 122   0.203332  0.796692     NaN
# 61    0.167659  0.832381     NaN
# 1     0.163646  0.836377     NaN
# 168   0.152053  0.847975     NaN
# 321   0.145810  0.854220     NaN
# 0     0.144918  0.855097     NaN
# 455   0.140459  0.859556     NaN
# 78    0.140459  0.859569     NaN
# 112   0.133325  0.866699     NaN
# 17    0.130204  0.869870     NaN
# 172   0.123961  0.876062     NaN
# 663   0.120840  0.879206     NaN
# 111   0.117272  0.882766     NaN
# 376   0.115489  0.884527     NaN
# 1035  0.094531  0.905489     NaN
# 43    0.092302  0.907720     NaN
# 196   0.091410  0.908623     NaN
# 410   0.088735  0.911294     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 공포
# Out:
# 105

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 사회이슈
# Out:
# 856

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 제도
# Out:
# 1058

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 가격,거래소,암호화폐
# Out:
# 5365

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 311.03024632296484

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [3 3 3 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -311.03027

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.75017333

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # 부정적 감정
# Out:
#                                                raw_data             word  \
# 5510  [0.0020425664260983467, 0.008967878296971321, ...       romantizar
# 4069  [0.0003969741228502244, 0.010132060386240482, ...       concurrent
# 4149  [0.004484379664063454, 0.012051347643136978, 0...             warm
# 3082  [0.0050619980320334435, 0.013321759179234505, ...          battery
# 1230  [0.006833598483353853, 0.012177584692835808, 0...            whale
# 2405  [-0.0016476496821269393, 0.011347604915499687,...      preparation
# 3912  [-0.0017007997957989573, 0.007587702479213476,...             slop
# 2586  [0.0011722980998456478, 0.008438993245363235, ...            moody
# 5533  [0.0015365033177658916, 0.005501434672623873, ...       expresadas
# 4187  [0.001243190374225378, 0.006382453721016645, 0...         tradable
# 5402  [0.005588391795754433, 0.005651991814374924, 0...          algunas
# 614   [-0.0018902987940236926, 0.00432690791785717, ...          devalue
# 3536  [0.0034242223482578993, 0.008824195712804794, ...          insurer
# 3224  [-0.0007948284619487822, 0.01204332523047924, ...          certify
# 3471  [0.0015491722151637077, 0.0064210533164441586,...            agent
# 3475  [0.0036635445430874825, 0.00903822761029005, 0...        paperwork
# 5188  [0.004474037326872349, 0.005937683396041393, 0...          minería
# 1267  [0.003006701823323965, 0.004677295219153166, 0...           accrue
# 3706  [0.0011237456928938627, 0.00774662708863616, 0...           avenue
# 3563  [0.004101808648556471, 0.013070865534245968, 0...      manipulator
# 3141  [0.0001819146127672866, 0.006672334391623735, ...           depose
# 4357  [0.0008780757198110223, 0.008648913353681564, ...        uncertain
# 6359  [0.004995575174689293, 0.008594747632741928, 0...            franc
# 2014  [0.002885910915210843, 0.007078874856233597, 0...           narrow
# 3701  [0.0010804260382428765, 0.012953258119523525, ...          ringgit
# 5860  [0.0007129553705453873, 0.012187247164547443, ...  brasilianischen
# 6394  [0.004160001408308744, 0.008957358077168465, 0...            spite
# 280   [0.003469218499958515, 0.009952671825885773, 0...           typeof
# 1506  [0.0034994559828191996, 0.008432039059698582, ...   correspondence
# 6922  [0.0033369790762662888, 0.004062686115503311, ...          gavekal
#
#       cluster                                           centroid  distance  \
# 5510        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.024076
# 4069        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.025343
# 4149        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.025796
# 3082        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.025455
# 1230        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027032
# 2405        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026422
# 3912        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026534
# 2586        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026825
# 5533        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026134
# 4187        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027083
# 5402        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026285
# 614         0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027652
# 3536        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026776
# 3224        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026810
# 3471        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027840
# 3475        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026961
# 5188        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026532
# 1267        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027452
# 3706        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027485
# 3563        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027931
# 3141        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026595
# 4357        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027498
# 6359        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027067
# 2014        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027080
# 3701        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027089
# 5860        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026695
# 6394        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027167
# 280         0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.026749
# 1506        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027196
# 6922        0  [0.0020468126, 0.00897228, 0.006364489, 0.0018...  0.027248
#
#          tfidf     score closer#
# 5510  0.000446  1.023630     NaN
# 4069  0.000892  1.024451     NaN
# 4149  0.001338  1.024458     NaN
# 3082  0.000892  1.024563     NaN
# 1230  0.002230  1.024803     NaN
# 2405  0.001338  1.025085     NaN
# 3912  0.001338  1.025196     NaN
# 2586  0.001338  1.025488     NaN
# 5533  0.000446  1.025688     NaN
# 4187  0.001338  1.025745     NaN
# 5402  0.000446  1.025839     NaN
# 614   0.001784  1.025868     NaN
# 3536  0.000892  1.025884     NaN
# 3224  0.000892  1.025918     NaN
# 3471  0.001784  1.026057     NaN
# 3475  0.000892  1.026069     NaN
# 5188  0.000446  1.026086     NaN
# 1267  0.001338  1.026114     NaN
# 3706  0.001338  1.026147     NaN
# 3563  0.001784  1.026147     NaN
# 3141  0.000446  1.026149     NaN
# 4357  0.001338  1.026161     NaN
# 6359  0.000892  1.026175     NaN
# 2014  0.000892  1.026188     NaN
# 3701  0.000892  1.026197     NaN
# 5860  0.000446  1.026249     NaN
# 6394  0.000892  1.026275     NaN
# 280   0.000446  1.026303     NaN
# 1506  0.000892  1.026304     NaN
# 6922  0.000892  1.026357     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') # 투자, 긍정적 현상
# Out:
#                                                raw_data        word  cluster  \
# 1001  [0.034205108880996704, 0.1418287754058838, 0.0...       spend        1
# 2078  [0.03409682214260101, 0.13577544689178467, 0.1...      client        1
# 1223  [0.035413727164268494, 0.14108173549175262, 0....   regulator        1
# 89    [0.028858762234449387, 0.14542849361896515, 0....      volume        1
# 367   [0.03653322905302048, 0.14091816544532776, 0.0...        earn        1
# 138   [0.027909575030207634, 0.14167262613773346, 0....     explain        1
# 770   [0.02961057238280773, 0.13321766257286072, 0.0...     involve        1
# 1186  [0.03017396852374077, 0.14418631792068481, 0.1...      agency        1
# 405   [0.03018491342663765, 0.14238101243972778, 0.0...     control        1
# 484   [0.03123626299202442, 0.1366843581199646, 0.09...    protocol        1
# 197   [0.03107677772641182, 0.14490649104118347, 0.0...     central        1
# 417   [0.03525220602750778, 0.13515862822532654, 0.0...     problem        1
# 1168  [0.031369682401418686, 0.14230364561080933, 0....        team        1
# 133   [0.02941194176673889, 0.14224795997142792, 0.0...  management        1
# 943   [0.029360635206103325, 0.14521123468875885, 0....        face        1
# 386   [0.028177578002214432, 0.13727860152721405, 0....   statement        1
# 217   [0.02880699746310711, 0.1456683874130249, 0.10...        form        1
# 906   [0.030751654878258705, 0.13307151198387146, 0....        hard        1
# 390   [0.0346582755446434, 0.14585936069488525, 0.10...        hear        1
# 841   [0.03231348842382431, 0.13681894540786743, 0.0...   authority        1
#
#                                                centroid  distance     tfidf  \
# 1001  [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.027195  0.021849
# 2078  [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.028575  0.023187
# 1223  [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.029231  0.023633
# 89    [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.034033  0.026754
# 367   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.034597  0.023187
# 138   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.031608  0.017836
# 770   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.036597  0.022295
# 1186  [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.034043  0.019620
# 405   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.035913  0.020512
# 484   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.037489  0.020512
# 197   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.039842  0.022295
# 417   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.037013  0.019174
# 1168  [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.039239  0.020512
# 133   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.044507  0.023633
# 943   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.040074  0.019174
# 386   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.045468  0.020066
# 217   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.054931  0.021403
# 906   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.055827  0.020066
# 390   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.055224  0.018728
# 841   [0.03176207, 0.14003575, 0.098435834, 0.029263...  0.055126  0.017390
#
#          score closer#
# 1001  1.005346     NaN
# 2078  1.005388     NaN
# 1223  1.005598     NaN
# 89    1.007279     NaN
# 367   1.011410     NaN
# 138   1.013772     NaN
# 770   1.014302     NaN
# 1186  1.014423     NaN
# 405   1.015401     NaN
# 484   1.016977     NaN
# 197   1.017547     NaN
# 417   1.017840     NaN
# 1168  1.018727     NaN
# 133   1.020874     NaN
# 943   1.020900     NaN
# 386   1.025402     NaN
# 217   1.033528     NaN
# 906   1.035761     NaN
# 390   1.036496     NaN
# 841   1.037736     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(30,'score')  # 기술, 블록체인보상
# Out:
#                                                raw_data          word  \
# 2006  [0.016202790662646294, 0.053794924169778824, 0...   performance
# 573   [0.008102850057184696, 0.05537969246506691, 0....     agreement
# 1332  [0.007455047219991684, 0.049365248531103134, 0...    compliance
# 2813  [0.011110766790807247, 0.05049091950058937, 0....         brave
# 1705  [0.0116733992472291, 0.05104794725775719, 0.04...         fraud
# 2454  [0.007626197766512632, 0.050275739282369614, 0...     attention
# 2079  [0.01595071516931057, 0.05891036614775658, 0.0...         fight
# 3541  [0.007929280400276184, 0.056369345635175705, 0...   uncertainty
# 2486  [0.011294851079583168, 0.05230969935655594, 0....     extension
# 1883  [0.01302446611225605, 0.05666331946849823, 0.0...          fast
# 1154  [0.01592371240258217, 0.05579788237810135, 0.0...          scam
# 1386  [0.012909633107483387, 0.049079980701208115, 0...          sort
# 1604  [0.015785645693540573, 0.05508486181497574, 0....         round
# 2533  [0.01388590969145298, 0.049694329500198364, 0....       million
# 1106  [0.010306714102625847, 0.05706982687115669, 0....  intelligence
# 2632  [0.012962105683982372, 0.05817747116088867, 0....       medical
# 2682  [0.011253372766077518, 0.04917936772108078, 0....     reduction
# 1733  [0.00994946900755167, 0.051159027963876724, 0....       prevent
# 1326  [0.008762483485043049, 0.053040020167827606, 0...          hire
# 1299  [0.015383622609078884, 0.05426550656557083, 0....        intend
# 618   [0.010687720961868763, 0.050986893475055695, 0...        status
# 1225  [0.010138517245650291, 0.05277128517627716, 0....        obtain
# 56    [0.012331030331552029, 0.053199660032987595, 0...       ongoing
# 2055  [0.011469105258584023, 0.049528077244758606, 0...     secretary
# 1385  [0.009547954425215721, 0.050196122378110886, 0...         grant
# 2284  [0.012395204044878483, 0.05359068885445595, 0....         pilot
# 690   [0.016435422003269196, 0.05671754479408264, 0....        depend
# 684   [0.015866953879594803, 0.05972247198224068, 0....       british
# 773   [0.013757564127445221, 0.051590412855148315, 0...         solve
# 1243  [0.016439585015177727, 0.059642594307661057, 0...          huge
#
#       cluster                                           centroid  distance  \
# 2006        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030762
# 573         2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.028120
# 1332        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030617
# 2813        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.027987
# 1705        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.029375
# 2454        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030312
# 2079        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.029493
# 3541        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030561
# 2486        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030264
# 1883        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.031735
# 1154        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030517
# 1386        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.029270
# 1604        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.031969
# 2533        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030694
# 1106        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.029847
# 2632        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.029465
# 2682        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032143
# 1733        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.031810
# 1326        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.031890
# 1299        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032399
# 618         2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032061
# 1225        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.033066
# 56          2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032612
# 2055        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.030501
# 1385        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032642
# 2284        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032304
# 690         2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.034207
# 684         2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.032904
# 773         2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.035411
# 1243        2  [0.01250679, 0.05399483, 0.038096823, 0.011304...  0.033829
#
#          tfidf     score closer#
# 2006  0.008918  1.021844     NaN
# 573   0.006243  1.021878     NaN
# 1332  0.008472  1.022144     NaN
# 2813  0.005351  1.022636     NaN
# 1705  0.006243  1.023133     NaN
# 2454  0.007134  1.023177     NaN
# 2079  0.006243  1.023250     NaN
# 3541  0.007134  1.023427     NaN
# 2486  0.006689  1.023575     NaN
# 1883  0.008026  1.023709     NaN
# 1154  0.006689  1.023829     NaN
# 1386  0.005351  1.023920     NaN
# 1604  0.008026  1.023943     NaN
# 2533  0.006689  1.024005     NaN
# 1106  0.005797  1.024050     NaN
# 2632  0.005351  1.024114     NaN
# 2682  0.008026  1.024117     NaN
# 1733  0.007134  1.024676     NaN
# 1326  0.007134  1.024756     NaN
# 1299  0.007580  1.024818     NaN
# 618   0.007134  1.024927     NaN
# 1225  0.008026  1.025040     NaN
# 56    0.007134  1.025477     NaN
# 2055  0.004905  1.025596     NaN
# 1385  0.006689  1.025953     NaN
# 2284  0.005797  1.026507     NaN
# 690   0.007580  1.026627     NaN
# 684   0.006243  1.026661     NaN
# 773   0.008472  1.026938     NaN
# 1243  0.006689  1.027140     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 기타
# Out:
#                                               raw_data              word  \
# 151  [0.059847209602594376, 0.2849145829677582, 0.1...           support
# 364  [0.0635339766740799, 0.2850053906440735, 0.197...              firm
# 372  [0.06434369087219238, 0.27760565280914307, 0.2...             claim
# 585  [0.06729566305875778, 0.2882137894630432, 0.19...              fund
# 454  [0.06972948461771011, 0.28126102685928345, 0.2...           service
# 652  [0.06822574138641357, 0.27934497594833374, 0.2...          business
# 170  [0.05756567791104317, 0.2839643359184265, 0.19...            dollar
# 470  [0.06343451887369156, 0.27869871258735657, 0.1...            launch
# 195  [0.06676256656646729, 0.27982833981513977, 0.1...            people
# 726  [0.06026207655668259, 0.2726086378097534, 0.19...             build
# 451  [0.05656988546252251, 0.27752578258514404, 0.1...           product
# 240  [0.061658505350351334, 0.2837164103984833, 0.2...             first
# 659  [0.06481433659791946, 0.28941085934638977, 0.1...             libra
# 140  [0.06507231295108795, 0.2733076214790344, 0.18...  cryptocurrencies
# 2    [0.06263034790754318, 0.2681397795677185, 0.18...             value
# 485  [0.06767599284648895, 0.2905701994895935, 0.20...             token
# 568  [0.07126397639513016, 0.28878870606422424, 0.2...            system
# 479  [0.07015933841466904, 0.2899799048900604, 0.20...              plan
# 184  [0.0710792988538742, 0.29046690464019775, 0.21...          investor
# 202  [0.061110105365514755, 0.26476049423217773, 0....            become
#
#      cluster                                           centroid  distance  \
# 151        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.036174
# 364        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.040565
# 372        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.032517
# 585        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.049876
# 454        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.061307
# 652        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.048033
# 170        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.065454
# 470        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.079512
# 195        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.069711
# 726        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.088835
# 451        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.101328
# 240        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.110938
# 659        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.155512
# 140        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.170729
# 2          3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.172097
# 485        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.203092
# 568        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.192202
# 479        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.196890
# 184        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.205208
# 202        3  [0.06426945, 0.28168738, 0.19760223, 0.0582435...  0.193365
#
#         tfidf     score closer#
# 151  0.057076  0.979098     NaN
# 364  0.060197  0.980368     NaN
# 372  0.043253  0.989265     NaN
# 585  0.057967  0.991908     NaN
# 454  0.067777  0.993530     NaN
# 652  0.051725  0.996308     NaN
# 170  0.051279  1.014175     NaN
# 470  0.061980  1.017531     NaN
# 195  0.050387  1.019324     NaN
# 726  0.049049  1.039786     NaN
# 451  0.055292  1.046036     NaN
# 240  0.060643  1.050296     NaN
# 659  0.068669  1.086843     NaN
# 140  0.061980  1.108748     NaN
# 2    0.058413  1.113684     NaN
# 485  0.072682  1.130410     NaN
# 568  0.059305  1.132897     NaN
# 479  0.056630  1.140260     NaN
# 184  0.060197  1.145011     NaN
# 202  0.045036  1.148329     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #부정적 감정, 공포
# Out:
# 6051

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #투자 긍정적 현상
# Out:
# 330

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #기술 긍정
# Out:
# 883

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #기타
# Out:
# 120

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.9996003

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[ 5.22672914e+00,  4.27398352e-03],
#        [ 5.48184554e+00,  1.34232329e-02],
#        [ 4.04767968e+00,  1.36480195e-02],
#        ...,
#        [-3.08723246e-01,  1.51817794e-03],
#        [-2.89445424e-01, -2.94173006e-03],
#        [-3.37104569e-01, -3.59480575e-03]])

# %%
xys[:,0]
# Out:
# array([ 5.22672914,  5.48184554,  4.04767968, ..., -0.30872325,
#        -0.28944542, -0.33710457])

# %%
xys[:,1]
# Out:
# array([ 0.00427398,  0.01342323,  0.01364802, ...,  0.00151818,
#        -0.00294173, -0.00359481])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 9989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 9989 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
