# %%
import pandas as pd
import urllib.request

data = pd.read_csv('../news/scraping_result/2017_up1_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../news/scraping_result/2017_up1_Cointelegraph.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../news/scraping_result/2017_up1_Forbes.csv', error_bad_lines=False))


#data = pd.read_csv('../news/scraping_result/Coindesk_down_1(2018).csv', error_bad_lines=False)
#data = data.append(pd.read_csv('../news/scraping_result/Cointelegraph_down_1(2018).csv', error_bad_lines=False))
#data = data.append(pd.read_csv('../news/scraping_result/Forbes_down_1(2018).csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 10334

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 10334

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.000*"injure" + 0.000*"hathaway" + 0.000*"poise" + 0.000*"dashboard" + 0.000*"trapping" + 0.000*"kpcb" + 0.000*"astonish" + 0.000*"cohn"')
# (1, '0.002*"paperless" + 0.002*"khan" + 0.002*"biomarkers" + 0.002*"airplane" + 0.002*"foley" + 0.002*"buttermilk" + 0.002*"exxonmobil" + 0.002*"female"')
# (2, '0.001*"rosenberg" + 0.001*"amplify" + 0.001*"sushchin" + 0.001*"diplomat" + 0.001*"handicapper" + 0.001*"bettor" + 0.001*"handicap" + 0.001*"wager"')
# (3, '0.001*"cohesiveness" + 0.001*"payscale" + 0.001*"amusement" + 0.001*"detract" + 0.001*"polishook" + 0.001*"emoji" + 0.001*"weisler" + 0.001*"peloton"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el10501407249894266403988658261"></div>
# <script type="text/javascript">
#
# var ldavis_el10501407249894266403988658261_data = {"mdsDat": {"x": [0.06117638866566727, 0.051688597746587385, 0.03456227211228104, -0.14742725852453567], "y": [0.08930707533942557, -0.08805027843760771, -0.006030979066975513, 0.004774182165157705], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [28.487140655517578, 26.055797576904297, 22.799583435058594, 22.657480239868164]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4 ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 10334

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 10334

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 123.5679832923201

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.0034768967609435375

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 4.698889190864682

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  #기타
# Out:
#                                                raw_data         word  cluster  \
# 2926  [0.0035926117561757565, -0.005330911371856928,...       kurman        0
# 2631  [0.001046386663801968, -0.008134358562529087, ...    grayscale        0
# 8606  [0.004921124316751957, -0.005361211020499468, ...      lowdown        0
# 1179  [0.0004229538608342409, -0.00899591576308012, ...  millionaire        0
# 8369  [0.00508425198495388, -0.0019791244994848967, ...    gazillion        0
# 2915  [0.0007142742979340255, -0.0096009261906147, -...    rootstock        0
# 1214  [-0.0002527312026359141, -0.007076753303408623...       anyway        0
# 2925  [0.005403449758887291, -0.006139389239251614, ...       ginger        0
# 2917  [0.006193820852786303, -0.0030601159669458866,...       buenos        0
# 1098  [0.005152786150574684, -0.007255402859300375, ...         dear        0
# 9796  [-0.0013042378704994917, -0.004796850029379129...       pepper        0
# 1081  [0.006551282946020365, -0.006216325797140598, ...   indecision        0
# 8354  [-0.003227937500923872, -0.004818950314074755,...         fdic        0
# 1738  [-0.000665835861582309, -0.004708836320787668,...         mall        0
# 3805  [0.001499062986113131, -0.0013833072734996676,...  encapsulate        0
# 9470  [0.002214419888332486, 0.0018124725902453065, ...    bilateral        0
# 328   [0.002297828206792474, -0.005618587601929903, ...    billboard        0
# 4284  [0.00424607889726758, -0.0012635606108233333, ...   ubiquitous        0
# 8349  [0.002550512319430709, -0.00024285359540954232...       crunch        0
# 315   [-0.000919562648050487, -0.005793224088847637,...    wonderful        0
#
#                                                centroid  distance     tfidf  \
# 2926  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.081415  0.000178
# 2631  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.086046  0.000533
# 8606  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.120199  0.000178
# 1179  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.151176  0.000178
# 8369  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.172963  0.000178
# 2915  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.177008  0.000533
# 1214  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.231947  0.000356
# 2925  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.270810  0.000356
# 2917  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.283260  0.000178
# 1098  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.301265  0.000178
# 9796  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.316570  0.000178
# 1081  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.336736  0.000178
# 8354  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.338666  0.000178
# 1738  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.366860  0.000178
# 3805  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.387056  0.000178
# 9470  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.391140  0.000178
# 328   [0.0011804787, -0.0026902647, -0.003787645, -0...  0.399813  0.000178
# 4284  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.406731  0.000178
# 8349  [0.0011804787, -0.0026902647, -0.003787645, -0...  0.416579  0.000178
# 315   [0.0011804787, -0.0026902647, -0.003787645, -0...  0.470493  0.000178
#
#          score closer#
# 2926  1.081237     NaN
# 2631  1.085512     NaN
# 8606  1.120021     NaN
# 1179  1.150999     NaN
# 8369  1.172785     NaN
# 2915  1.176475     NaN
# 1214  1.231591     NaN
# 2925  1.270454     NaN
# 2917  1.283082     NaN
# 1098  1.301088     NaN
# 9796  1.316392     NaN
# 1081  1.336558     NaN
# 8354  1.338488     NaN
# 1738  1.366682     NaN
# 3805  1.386879     NaN
# 9470  1.390963     NaN
# 328   1.399635     NaN
# 4284  1.406553     NaN
# 8349  1.416401     NaN
# 315   1.470316     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회적 이슈
# Out:
#                                                raw_data          word  \
# 10    [-0.47650766372680664, 0.663829505443573, 1.13...      currency
# 9     [-0.4305911958217621, 0.6622010469436646, 1.05...       digital
# 17    [-0.4133283793926239, 0.6239950060844421, 1.16...         asset
# 67    [-0.4307568669319153, 0.678197979927063, 1.180...         group
# 72    [-0.3655714690685272, 0.5801722407341003, 1.25...         image
# 73    [-0.2874634861946106, 0.45962291955947876, 0.8...  shutterstock
# 69    [-0.2937716245651245, 0.4697422981262207, 0.84...         stake
# 68    [-0.31350430846214294, 0.47043678164482117, 0....     ownership
# 2136  [-0.24574397504329681, 0.3802662789821625, 0.6...       virtual
# 1360  [-0.1601652354001999, 0.26078730821609497, 0.4...          fiat
# 66    [-0.1863935887813568, 0.28190428018569946, 0.4...    subsidiary
# 3020  [-0.10133250057697296, 0.16896334290504456, 0....    disclosure
# 5413  [-0.026523638516664505, 0.04249424859881401, 0...    everledger
# 1322  [-0.02914067916572094, 0.040681470185518265, 0...       genesis
# 5142  [-0.02234811708331108, 0.03185358643531799, 0....      champion
# 1233  [-0.017133276909589767, 0.027324043214321136, ...        advent
# 7451  [-0.01630389504134655, 0.02826850675046444, 0....       ambient
# 7047  [-0.014568965882062912, 0.030069448053836823, ...         steem
# 9691  [-0.017606738954782486, 0.023003268986940384, ...        tixsee
# 2308  [-0.015817824751138687, 0.025363724678754807, ...          pete
# 3268  [-0.016585418954491615, 0.02646441012620926, 0...      luyitong
# 1499  [-0.01758105680346489, 0.02111366018652916, 0....          dive
# 1299  [-0.009641469456255436, 0.02466495893895626, 0...      shortage
# 3143  [-0.01215778011828661, 0.0256641898304224, 0.0...         barry
# 7863  [-0.016789941117167473, 0.021295616403222084, ...      decipher
# 8581  [-0.01458932738751173, 0.01902325078845024, 0....    cyberspace
# 3108  [-0.01823679730296135, 0.02544492483139038, 0....         skirt
# 4672  [-0.01056226808577776, 0.021525800228118896, 0...     republish
# 379   [-0.016199465841054916, 0.025614600628614426, ...      kurzweil
# 5824  [-0.014703507535159588, 0.024229606613516808, ...        vulcan
#
#       cluster                                           centroid  distance  \
# 10          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.006720
# 9           1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.008197
# 17          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000837
# 67          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000164
# 72          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.006185
# 73          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.004068
# 69          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000444
# 68          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000348
# 2136        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000561
# 1360        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000744
# 66          1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.003089
# 3020        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.000526
# 5413        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.003741
# 1322        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.004282
# 5142        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.004756
# 1233        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.006728
# 7451        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.006885
# 7047        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.007423
# 9691        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.007538
# 2308        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.008029
# 3268        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.008219
# 1499        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.008962
# 1299        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.010179
# 3143        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.010737
# 7863        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.010353
# 8581        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.010694
# 3108        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.010829
# 4672        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.011115
# 379         1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.011801
# 5824        1  [-0.0099359825, 0.015112068, 0.026441474, 0.01...  0.011693
#
#          tfidf     score closer#
# 10    0.126581  0.880139     NaN
# 9     0.107025  0.901172     NaN
# 17    0.061868  0.938969     NaN
# 67    0.051023  0.949141     NaN
# 72    0.035912  0.970273     NaN
# 73    0.029512  0.974556     NaN
# 69    0.021156  0.979287     NaN
# 68    0.018489  0.981858     NaN
# 2136  0.014045  0.986516     NaN
# 1360  0.009956  0.990788     NaN
# 66    0.011200  0.991889     NaN
# 3020  0.004622  0.995903     NaN
# 5413  0.001067  1.002674     NaN
# 1322  0.001244  1.003037     NaN
# 5142  0.000711  1.004045     NaN
# 1233  0.000889  1.005839     NaN
# 7451  0.000356  1.006530     NaN
# 7047  0.000533  1.006890     NaN
# 9691  0.000356  1.007182     NaN
# 2308  0.000711  1.007317     NaN
# 3268  0.000356  1.007863     NaN
# 1499  0.000711  1.008251     NaN
# 1299  0.000711  1.009468     NaN
# 3143  0.001067  1.009670     NaN
# 7863  0.000533  1.009820     NaN
# 8581  0.000533  1.010161     NaN
# 3108  0.000356  1.010473     NaN
# 4672  0.000533  1.010582     NaN
# 379   0.001067  1.010735     NaN
# 5824  0.000711  1.010982     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 기술
# Out:
#                                                raw_data         word  cluster  \
# 61    [-0.33469340205192566, 0.5023223161697388, 0.9...     ethereum        2
# 62    [-0.3463604152202606, 0.5121638774871826, 0.96...        token        2
# 654   [-0.349325954914093, 0.3956235945224762, 0.972...     contract        2
# 682   [-0.2683214843273163, 0.5001567006111145, 0.98...        smart        2
# 4274  [-0.09550657123327255, 0.14601999521255493, 0....       oracle        2
# 4407  [-0.021074257791042328, 0.03584917262196541, 0...        dapps        2
# 4807  [-0.020169509574770927, 0.031033162027597427, ...   denominate        2
# 6256  [-0.019263900816440582, 0.022482335567474365, ...       gadget        2
# 6479  [-0.017760753631591797, 0.022335518151521683, ...     compiler        2
# 3250  [-0.013165714219212532, 0.023720812052488327, ...      fertile        2
# 7776  [-0.011544843204319477, 0.02721315436065197, 0...         ripe        2
# 4006  [-0.011235421523451805, 0.01876232400536537, 0...      juniper        2
# 2219  [-0.013916629366576672, 0.018007585778832436, ...     conceive        2
# 9744  [-0.015461773611605167, 0.019151262938976288, ...        attic        2
# 2834  [-0.014901976101100445, 0.023349914699792862, ...        drain        2
# 5259  [-0.017657695338129997, 0.017800873145461082, ...    alignment        2
# 7369  [-0.012796767987310886, 0.01943879947066307, 0...         usdt        2
# 4442  [-0.013221986591815948, 0.017741097137331963, ...        pique        2
# 2936  [-0.015222946181893349, 0.020969519391655922, ...     multisig        2
# 3125  [-0.009734666906297207, 0.019613485783338547, ...  unstoppable        2
#
#                                                centroid  distance     tfidf  \
# 61    [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.000710  0.102403
# 62    [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.001183  0.096180
# 654   [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.008795  0.048179
# 682   [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.004648  0.043379
# 4274  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.000688  0.004978
# 4407  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.003444  0.001778
# 4807  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.004159  0.001600
# 6256  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.006385  0.000533
# 6479  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.007454  0.000533
# 3250  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.007844  0.000533
# 7776  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.008194  0.000533
# 4006  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.008121  0.000356
# 2219  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.009087  0.000889
# 9744  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.008775  0.000178
# 2834  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.009338  0.000711
# 5259  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.009721  0.000533
# 7369  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.010726  0.000711
# 4442  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.010590  0.000533
# 2936  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.011143  0.000889
# 3125  [-0.005987495, 0.0094405385, 0.01917354, 0.013...  0.010656  0.000356
#
#          score closer#
# 61    0.898307     NaN
# 62    0.905003     NaN
# 654   0.960616     NaN
# 682   0.961269     NaN
# 4274  0.995710     NaN
# 4407  1.001666     NaN
# 4807  1.002559     NaN
# 6256  1.005852     NaN
# 6479  1.006921     NaN
# 3250  1.007311     NaN
# 7776  1.007661     NaN
# 4006  1.007765     NaN
# 2219  1.008198     NaN
# 9744  1.008598     NaN
# 2834  1.008626     NaN
# 5259  1.009187     NaN
# 7369  1.010015     NaN
# 4442  1.010056     NaN
# 2936  1.010254     NaN
# 3125  1.010301     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 가격, 거래소, 돈
# Out:
#                                               raw_data            word  \
# 1    [-0.3743109107017517, 0.5544778108596802, 1.09...         bitcoin
# 28   [-0.3643994927406311, 0.5794423818588257, 1.07...      blockchain
# 39   [-0.38614392280578613, 0.5691850781440735, 1.1...          market
# 184  [-0.40680521726608276, 0.6583867073059082, 1.2...            make
# 334  [-0.3818790316581726, 0.6267356872558594, 1.15...         company
# 8    [-0.3765188157558441, 0.5582709312438965, 1.09...            time
# 161  [-0.3521874248981476, 0.5235378742218018, 1.04...     transaction
# 26   [-0.35849323868751526, 0.6077291369438171, 1.1...      technology
# 337  [-0.4004489779472351, 0.6573329567909241, 1.19...            work
# 294  [-0.3825302720069885, 0.6574720740318298, 1.18...            bank
# 220  [-0.36436188220977783, 0.5508109927177429, 1.0...         network
# 36   [-0.37743043899536133, 0.6085328459739685, 1.1...            year
# 0    [-0.3700370490550995, 0.5223422646522522, 1.07...           price
# 544  [-0.35637542605400085, 0.5699120759963989, 1.0...            user
# 578  [-0.39683419466018677, 0.633152961730957, 1.17...          system
# 32   [-0.37653568387031555, 0.5896576046943665, 1.0...        exchange
# 47   [-0.3599512577056885, 0.5566774606704712, 1.06...  cryptocurrency
# 178  [-0.3508795201778412, 0.5732740759849548, 1.04...           money
# 132  [-0.395223468542099, 0.6133106350898743, 1.157...            data
# 266  [-0.37903064489364624, 0.6251516342163086, 1.1...          people
#
#      cluster                                           centroid  distance  \
# 1          3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000969
# 28         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.001090
# 39         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.001267
# 184        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000134
# 334        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000159
# 8          3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.001035
# 161        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000973
# 26         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000854
# 337        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000274
# 294        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.001763
# 220        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000764
# 36         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000950
# 0          3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.003477
# 544        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000411
# 578        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000577
# 32         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.001123
# 47         3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000516
# 178        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000906
# 132        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000238
# 266        3  [-0.045923125, 0.07212206, 0.13672602, 0.09806...  0.000140
#
#         tfidf     score closer#
# 1    0.457256  0.543713     NaN
# 28   0.271651  0.729439     NaN
# 39   0.146848  0.854419     NaN
# 184  0.137781  0.862353     NaN
# 334  0.135470  0.864689     NaN
# 8    0.134581  0.866454     NaN
# 161  0.125692  0.875281     NaN
# 26   0.119292  0.881562     NaN
# 337  0.112003  0.888271     NaN
# 294  0.108803  0.892961     NaN
# 220  0.104714  0.896051     NaN
# 36   0.104003  0.896947     NaN
# 0    0.105603  0.897874     NaN
# 544  0.101514  0.898897     NaN
# 578  0.093691  0.906886     NaN
# 32   0.093158  0.907965     NaN
# 47   0.088002  0.912514     NaN
# 178  0.087824  0.913082     NaN
# 132  0.086758  0.913480     NaN
# 266  0.086580  0.913560     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 기타
# Out:
# 49

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 사회이슈
# Out:
# 826

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 기술
# Out:
# 899

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 가격,거래소,암호화폐
# Out:
# 8560

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 618.5790215660627

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [1 1 1 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -618.579

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.7359063

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # 진영,세력다툼
# Out:
#                                                raw_data           word  \
# 2619  [-0.012111717835068703, 0.021399663761258125, ...        inquire
# 6528  [-0.01091543585062027, 0.01939707249403, 0.038...         tribal
# 5849  [-0.015898382291197777, 0.017587512731552124, ...          lynch
# 9611  [-0.01004008948802948, 0.016371343284845352, 0...      l'affaire
# 6283  [-0.014533096924424171, 0.021739959716796875, ...          micro
# 5280  [-0.012218541465699673, 0.02127155289053917, 0...     launderers
# 5985  [-0.016677891835570335, 0.014451295137405396, ...        divulge
# 6870  [-0.011522860266268253, 0.01820255070924759, 0...         dennis
# 5075  [-0.016315998509526253, 0.018909135833382607, ...        redondo
# 8838  [-0.015083052217960358, 0.02004629373550415, 0...          titov
# 7668  [-0.013311732560396194, 0.023844892159104347, ...   intimidation
# 6662  [-0.015961837023496628, 0.022327575832605362, ...        cassidy
# 7014  [-0.011679279617965221, 0.023786410689353943, ...  instantaneous
# 3116  [-0.009407313540577888, 0.015656977891921997, ...     corporates
# 9200  [-0.013318234123289585, 0.02019389718770981, 0...          ritzy
# 4828  [-0.012447105720639229, 0.022897623479366302, ...           nigh
# 7827  [-0.009251988492906094, 0.020941251888871193, ...    declaration
# 8984  [-0.008162167854607105, 0.023509856313467026, ...           bart
# 8663  [-0.00832219049334526, 0.014725367538630962, 0...          jrotc
# 2852  [-0.013536995276808739, 0.023242292925715446, ...        culprit
# 3122  [-0.015683313831686974, 0.02251894399523735, 0...         lament
# 5215  [-0.0068648261949419975, 0.022453943267464638,...      disruptor
# 8130  [-0.016989130526781082, 0.017378320917487144, ...         badass
# 6772  [-0.016685571521520615, 0.01655152440071106, 0...        prevail
# 4523  [-0.008874255232512951, 0.02359973080456257, 0...        conquer
# 6551  [-0.00864381156861782, 0.02502867951989174, 0....        jetblue
# 4610  [-0.016236426308751106, 0.022264862433075905, ...         starve
# 9413  [-0.009172829799354076, 0.023367702960968018, ...         hassan
# 1670  [-0.011921276338398457, 0.021346118301153183, ...         unjust
# 1016  [-0.012273497879505157, 0.020835841074585915, ...           dorm
#
#       cluster                                           centroid  distance  \
# 2619        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.025218
# 6528        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.025289
# 5849        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.025558
# 9611        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.028188
# 6283        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026326
# 5280        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026513
# 5985        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026563
# 6870        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026587
# 5075        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026531
# 8838        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026592
# 7668        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026795
# 6662        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027004
# 7014        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027031
# 3116        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026859
# 9200        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026760
# 4828        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026943
# 7827        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026990
# 8984        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027210
# 8663        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.026964
# 2852        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027517
# 3122        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027201
# 5215        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027543
# 8130        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027258
# 6772        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.028032
# 4523        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027692
# 6551        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027715
# 4610        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027606
# 9413        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027615
# 1670        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027621
# 1016        0  [-0.012181502, 0.019168902, 0.036261894, 0.026...  0.027635
#
#          tfidf     score closer#
# 2619  0.000533  1.024684     NaN
# 6528  0.000356  1.024934     NaN
# 5849  0.000356  1.025202     NaN
# 9611  0.002667  1.025522     NaN
# 6283  0.000533  1.025792     NaN
# 5280  0.000533  1.025980     NaN
# 5985  0.000533  1.026029     NaN
# 6870  0.000356  1.026231     NaN
# 5075  0.000178  1.026353     NaN
# 8838  0.000178  1.026414     NaN
# 7668  0.000356  1.026440     NaN
# 6662  0.000533  1.026470     NaN
# 7014  0.000533  1.026497     NaN
# 3116  0.000356  1.026503     NaN
# 9200  0.000178  1.026582     NaN
# 4828  0.000356  1.026587     NaN
# 7827  0.000356  1.026635     NaN
# 8984  0.000533  1.026676     NaN
# 8663  0.000178  1.026786     NaN
# 2852  0.000711  1.026806     NaN
# 3122  0.000356  1.026846     NaN
# 5215  0.000533  1.027009     NaN
# 8130  0.000178  1.027080     NaN
# 6772  0.000889  1.027143     NaN
# 4523  0.000533  1.027158     NaN
# 6551  0.000533  1.027181     NaN
# 4610  0.000356  1.027250     NaN
# 9413  0.000356  1.027260     NaN
# 1670  0.000356  1.027266     NaN
# 1016  0.000356  1.027280     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') # 긍정적 현상
# Out:
#                                                raw_data              word  \
# 145   [-0.3182448148727417, 0.5050870180130005, 0.95...             great
# 1915  [-0.31575194001197815, 0.5037618279457092, 0.9...              home
# 1080  [-0.3253692090511322, 0.5030497312545776, 0.95...              name
# 270   [-0.31824591755867004, 0.4966776967048645, 0.9...            wallet
# 364   [-0.319792777299881, 0.5010750889778137, 0.941...  cryptocurrencies
# 1842  [-0.3199319541454315, 0.5044077634811401, 0.95...           feature
# 660   [-0.3253099322319031, 0.5004242062568665, 0.95...              keep
# 555   [-0.31543704867362976, 0.49723032116889954, 0....              code
# 1002  [-0.32006457448005676, 0.4940251410007477, 0.9...              wave
# 340   [-0.31216350197792053, 0.48886868357658386, 0....              turn
# 1623  [-0.3215320110321045, 0.5151290893554688, 0.95...            access
# 1176  [-0.32292723655700684, 0.5044846534729004, 0.9...            amount
# 51    [-0.305873841047287, 0.48329785466194153, 0.93...             place
# 117   [-0.33137938380241394, 0.519640326499939, 0.97...             major
# 166   [-0.3077368438243866, 0.49404552578926086, 0.9...         statement
# 962   [-0.3157697916030884, 0.4853251576423645, 0.92...              form
# 421   [-0.3173416256904602, 0.5024194121360779, 0.92...           control
# 335   [-0.3131965100765228, 0.499565452337265, 0.929...            invest
# 322   [-0.31796884536743164, 0.4823707044124603, 0.9...             store
# 460   [-0.3293740451335907, 0.5156056880950928, 0.97...            happen
#
#       cluster                                           centroid  distance  \
# 145         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.062959
# 1915        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.051267
# 1080        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.056351
# 270         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.076173
# 364         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.088596
# 1842        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.076916
# 660         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.081015
# 555         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.079156
# 1002        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.074986
# 340         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.086079
# 1623        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.097064
# 1176        1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.102611
# 51          1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.101342
# 117         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.117936
# 166         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.113034
# 962         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.119326
# 421         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.121530
# 335         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.126881
# 322         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.132718
# 460         1  [-0.31962526, 0.5014286, 0.94909626, 0.6811933...  0.123894
#
#          tfidf     score closer#
# 145   0.028267  1.034691     NaN
# 1915  0.014578  1.036688     NaN
# 1080  0.017423  1.038928     NaN
# 270   0.035023  1.041149     NaN
# 364   0.042490  1.046106     NaN
# 1842  0.023467  1.053449     NaN
# 660   0.027023  1.053992     NaN
# 555   0.023467  1.055689     NaN
# 1002  0.016889  1.058097     NaN
# 340   0.020445  1.065635     NaN
# 1623  0.029690  1.067375     NaN
# 1176  0.028267  1.074344     NaN
# 51    0.025956  1.075386     NaN
# 117   0.032356  1.085579     NaN
# 166   0.021334  1.091700     NaN
# 962   0.026667  1.092659     NaN
# 421   0.027734  1.093796     NaN
# 335   0.030934  1.095947     NaN
# 322   0.035023  1.097695     NaN
# 460   0.026134  1.097760     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 비용,한계
# Out:
#                                                raw_data              word  \
# 58    [-0.28474849462509155, 0.7329626679420471, 1.2...              cost
# 66    [-0.2852664887905121, 0.7343748211860657, 1.22...             power
# 553   [-0.2846664488315582, 0.7421175241470337, 1.22...          software
# 1611  [-0.2795720100402832, 0.7392390966415405, 1.21...              plan
# 216   [-0.28180211782455444, 0.744627058506012, 1.21...          customer
# 143   [-0.2844253480434418, 0.7274585962295532, 1.21...              show
# 400   [-0.2898816168308258, 0.74361652135849, 1.2326...  cryptocurrencies
# 93    [-0.2965559661388397, 0.7323348522186279, 1.24...             level
# 1448  [-0.2922765910625458, 0.7500787377357483, 1.23...            design
# 84    [-0.2827581763267517, 0.7228019833564758, 1.22...            record
# 155   [-0.27982425689697266, 0.730026125907898, 1.20...             great
# 743   [-0.2848002314567566, 0.722486138343811, 1.208...              keep
# 246   [-0.2871595323085785, 0.7482261061668396, 1.25...          continue
# 873   [-0.2829371690750122, 0.7376783490180969, 1.21...          research
# 248   [-0.29015859961509705, 0.7577797174453735, 1.2...           capital
# 1022  [-0.28031590580940247, 0.7295610308647156, 1.1...            launch
# 81    [-0.2865109443664551, 0.7257009148597717, 1.20...             today
# 289   [-0.28390398621559143, 0.7297692894935608, 1.2...              fact
# 200   [-0.2809479236602783, 0.7290683388710022, 1.21...             legal
# 1220  [-0.28682592511177063, 0.7178727388381958, 1.2...           current
#
#       cluster                                           centroid  distance  \
# 58          2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.053508
# 66          2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.078151
# 553         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.081763
# 1611        2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.078717
# 216         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.086225
# 143         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.084926
# 400         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.099780
# 93          2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.091114
# 1448        2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.090361
# 84          2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.095394
# 155         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.100825
# 743         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.106940
# 246         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.112319
# 873         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.105947
# 248         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.117785
# 1022        2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.120281
# 81          2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.135589
# 289         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.124919
# 200         2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.127984
# 1220        2  [-0.28886858, 0.7430031, 1.2322576, 0.82592905...  0.132113
#
#          tfidf     score closer#
# 58    0.028441  1.025067     NaN
# 66    0.031444  1.046706     NaN
# 553   0.031974  1.049789     NaN
# 1611  0.028795  1.049922     NaN
# 216   0.033564  1.052660     NaN
# 143   0.028265  1.056662     NaN
# 400   0.043104  1.056676     NaN
# 93    0.029325  1.061789     NaN
# 1448  0.027911  1.062449     NaN
# 84    0.025968  1.069426     NaN
# 155   0.028265  1.072560     NaN
# 743   0.026851  1.080089     NaN
# 246   0.031091  1.081228     NaN
# 873   0.022435  1.083512     NaN
# 248   0.033564  1.084221     NaN
# 1022  0.036037  1.084243     NaN
# 81    0.037274  1.098315     NaN
# 289   0.025438  1.099481     NaN
# 200   0.023495  1.104489     NaN
# 1220  0.027558  1.104555     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 기술, 시도 , business
# Out:
#                                                raw_data              word  \
# 1665  [-0.06952891498804092, 0.11628390103578568, 0....             guess
# 4710  [-0.06681576371192932, 0.11380297690629959, 0....          algorand
# 2018  [-0.07647533714771271, 0.11526669561862946, 0....             theme
# 1108  [-0.07591962069272995, 0.10898017883300781, 0....  decentralization
# 710   [-0.07407992333173752, 0.11291287839412689, 0....           respect
# 9599  [-0.07385680824518204, 0.11373753100633621, 0....              kent
# 7074  [-0.07516471296548843, 0.11614187806844711, 0....     supercomputer
# 1008  [-0.06749153137207031, 0.11463598161935806, 0....              clue
# 7320  [-0.07133897393941879, 0.11251162737607956, 0....             brain
# 1406  [-0.07037435472011566, 0.11241963505744934, 0....            suffer
# 4706  [-0.07361714541912079, 0.11658291518688202, 0....            micali
# 967   [-0.06593292951583862, 0.11129283159971237, 0....           careful
# 2768  [-0.06771451979875565, 0.11760969460010529, 0....          conflict
# 2714  [-0.06932732462882996, 0.11910273134708405, 0....         expertise
# 2145  [-0.06747151166200638, 0.11137021332979202, 0....             peter
# 2498  [-0.07389987260103226, 0.11194595694541931, 0....             novel
# 22    [-0.07554636150598526, 0.1124984547495842, 0.2...              edge
# 9665  [-0.07260118424892426, 0.11957534402608871, 0....             cuban
# 479   [-0.07043137401342392, 0.12020806968212128, 0....           clarify
# 123   [-0.07253991067409515, 0.11536724865436554, 0....           caution
#
#       cluster                                           centroid  distance  \
# 1665        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.028909
# 4710        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.029346
# 2018        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.030844
# 1108        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.030338
# 710         3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.031001
# 9599        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.028807
# 7074        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.030976
# 1008        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.030477
# 7320        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.030380
# 1406        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.031828
# 4706        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032326
# 967         3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032698
# 2768        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032430
# 2714        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.033017
# 2145        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032339
# 2498        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032343
# 22          3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.033060
# 9665        3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.031284
# 479         3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.032971
# 123         3  [-0.07237445, 0.113511354, 0.21534914, 0.15428...  0.033496
#
#          tfidf     score closer#
# 1665  0.002845  1.026064     NaN
# 4710  0.003200  1.026146     NaN
# 2018  0.003911  1.026933     NaN
# 1108  0.003022  1.027316     NaN
# 710   0.003556  1.027445     NaN
# 9599  0.001244  1.027563     NaN
# 7074  0.002845  1.028131     NaN
# 1008  0.002133  1.028344     NaN
# 7320  0.001778  1.028602     NaN
# 1406  0.003022  1.028806     NaN
# 4706  0.003200  1.029126     NaN
# 967   0.003022  1.029675     NaN
# 2768  0.002667  1.029763     NaN
# 2714  0.003200  1.029817     NaN
# 2145  0.002489  1.029850     NaN
# 2498  0.002489  1.029854     NaN
# 22    0.003200  1.029860     NaN
# 9665  0.001422  1.029862     NaN
# 479   0.002845  1.030127     NaN
# 123   0.003200  1.030296     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #진영, 세력다툼
# Out:
# 8087

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #긍정적 현상
# Out:
# 353

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #비용 한계
# Out:
# 560

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #기술,시도,비즈니스
# Out:
# 1334

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.9999163

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[ 4.77489328e+00, -2.31475759e-02],
#        [ 4.81304469e+00, -2.15928144e-02],
#        [ 4.93466167e+00, -3.72915342e-02],
#        ...,
#        [-4.46580640e-01,  1.34810186e-03],
#        [-4.74973487e-01,  8.75028427e-04],
#        [-4.50633660e-01,  1.62948765e-03]])

# %%
xys[:,0]
# Out:
# array([ 4.77489328,  4.81304469,  4.93466167, ..., -0.44658064,
#        -0.47497349, -0.45063366])

# %%
xys[:,1]
# Out:
# array([-0.02314758, -0.02159281, -0.03729153, ...,  0.0013481 ,
#         0.00087503,  0.00162949])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
