# %%
import pandas as pd
import urllib.request

#data = pd.read_csv('../../news/scraping_result/kr/2019_down2/2019_down2_(KR)Hankyung.csv', error_bad_lines=False)
data = pd.read_csv('../../news/scraping_result/kr/2019_down2/2019_down2_(KR)Tokenpost.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/kr/2019_down2/2019_down2_(KR)BlockMedia.csv', error_bad_lines=False))

# %%
data.loc[data['main article']=="Provided by Coinness",'main article'] = data.loc[data['main article']=="Provided by Coinness",'abstract']
data.loc[data['main article']=="Provided by 코인니스",'main article'] = data.loc[data['main article']=="Provided by 코인니스",'abstract']
# data.loc[data['main article']=='Provided by 코인니스','abstract']

# %%
text = data[['main article']].astype(str)
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\xa0",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)

# %%
from konlpy.tag import Mecab
mecab = Mecab()
text['main token article'] = text.apply(lambda row: mecab.morphs(row['main article']), axis=1)

# %%
text['main article']
# Out:
# 0     최근 암호화폐 전문 매체 더블록은 뉴욕 금융서비스부(NYDFS)의 승인 지연으로 백...
# 1     12일(현지시간) 암호화폐 전문 매체 비인크립토(BeInCrypto) 보도에 따르면...
# 2     뉴질랜드 국세청은 국가 조세행정법(1994) s91D 아래, 암호화폐를 유사 화폐(...
# 3     세계 최대 재무설계자문기업 드비어 그룹의 니겔 그린(Nigel Green) CEO는...
# 4     상장 검토 대상인 주요 암호화폐는 비트코인, 이오스, 이더리움, 카르다노, 코스모스...
# 5     미국 무역대표부(USTR)는 13일(현지시간) 성명을 통해 "9월 1일부터 미국에 ...
# 6     13일(현지시간) 코인데스크 보도에 따르면 미국 뉴욕동부 지방법원은 SEC가 기소한...
# 7     이와 함께 스테이블 코인 USDP를 개발, 암호화폐 실생활 응용 수준을 높인다는 방...
# 8     10일(현지시간) 더블록 보도에 따르면 중국금융40인포럼(中國金融四十人論壇) 행사에...
# 9     암호화폐 전문 미디어 코인텔레그래프가 걸프뉴스(Gulf News) 11일(현지시간)...
# 10    이번 행사는 코인인(Coinin), 블록글로벌(BLOCK GLOBAL), 비트보이(...
# 11    매일 출석하고 비트코인 획득! 무료가입하고 매일 1시간 광고보고 16000원고정수입...
# 12    지난 11일 찰리 리는 자신의 트위터를 통해 "많은 이들이 올해 라이트코인이 사실상...
# 13    코인원은 프로젝트가 속한 기업이나 재단 정보, 비즈니스 모델, 시장성, 기술 등으로...
# 14    매일 출석하고 비트코인 획득! 무료가입하고 매일 1시간 광고보고 16000원고정수입...
# 15    카카오 클레이튼에서 통용되는 암호화폐 클레이를 비록해 클레이튼 기반 코스모코인, 힌...
# 16    10일(현지시간) 코인데스크 보도에 따르면 IBM은 P2P 네트워크로 지원되는 웹브...
# 17    11일(현지시간) UAE 매체 걸프뉴스(Gulf News) 보도에 따르면 UAE 국...
# 18    경기도와 경제과학진흥원 공동주최로 열리는 이번 대회는 블록체인을 기반으로 한 창업,...
# 19    국회 입법조사처는 최근 발간한 '2019 국감 이슈 분석보고서'에서 "블록체인과 암...
# 20    13일(현지시간) 코인데스크 보도에 따르면 호주 커먼웰스은행 소유의 뉴질랜드 ASB...
# 21    13일(현지시간) 코인텔레그래프에 따르면, 타이슨은 블록체인 기반 엔터테인먼트 플랫...
# 22    12일(현지시간) 코인텔레그래프 보도에 따르면 42차 정기 주주총회에서 스리 무케시...
# 23    12일 카카오는 카카오톡 내 '더보기' 탭에 카카오 암호화폐 지갑 '클립'의 티징 ...
# 24    이들은 블록체인을 활용해 기존 마일리지 서비스를 확대해 건강기능식부터 운동까지 통합...
# 0     미 SEC는 12일(현지시간) 3개 비트코인 상장지수펀드(ETF) 승인에 관한 결정...
# 1     미국의 중국에 대한 환율조작국 지정, 일본의 경제보복 조치, 북한의 단거리 탄도미사...
# 2     인민은행은 최근 다양한 경로를 통해 법정 디지털 화폐 출시와 관련 정보를 제공하고 ...
# 3     12일(현지시간) 코인데스크는 비트코인 단기 챠트의 경우 약세론자들(bears)이 ...
# 4     출처: Coindesk. Created with TradingView13일(현지시간...
# 5     CNBC에 따르면 BOA의 미국 경제 헤드 미셸 마이어는 지난 9일자 고객 노트에서...
# 6     이 둘의 가장 큰 차이점은 퍼블리과 프라이빗, 단어의 의미처럼 얼마나 열려 있는가에...
# 7     온톨로지는 네오, 퀀텀과 함께 중국을 대표하는 퍼블릭 블록체인 중 하나로 신뢰 기반...
# 8     코인원이 밝힌 상장심사 기준은 프로젝트가 속한 기업이나 재단 정보, 비즈니스 모델,...
# 9     사진=카카오톡 캡처안드로이드 최신 버전 카카오톡에는 ‘더보기’에서 ‘전체 서비스’를...
# 10    12일(현지시간) 코인텔레그래프에 따르면, 선은 지난 9일 트위터를 통해 미국인들이...
# 11    이번 강좌에는 블록체인 업계 종사자 및 일반인 등 약 200여명이 참석했다.1부 주...
# 12    업비트는 12일부터 특정 조건의 로그인이 발생할 경우 고객들에게 카카오톡 메시지를 ...
# 13    13일(현지시간) 코인데스크에 따르면 XRP 가격 챠트에서 50일 이동평균(MA)이...
# 14    신한은행은 카카오의 블록체인 기술 계열사 그라운드X, 블록체인 기술연구소 헥슬란트와...
# 15    블록체인 핀테크 기업인 테라는 벅스를 운영하는 NHN벅스와 블록체인 기반 결제 시스...
# 16    헤데라 해시그래프는 소프트웨어 회사인 스월즈사(Swirlds. Inc.)의 공동창립...
# 17    현재 국회는 여야간 정쟁으로 대부분의 법들이 장기 계류 중이다. 금융혁신의 초석이라...
# Name: main article, dtype: object

# %%
# 소문자 적용 , - 문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word.replace("-","") for word in x])
# 공백문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word for word in x if word])

# %%
text['pos tag'] = text.apply(lambda row: mecab.pos(row['main article']), axis=1)

# %%
text['pos tag']
# Out:
# 0     [(최근, NNG), (암호, NNG), (화폐, NNG), (전문, NNG), (...
# 1     [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 2     [(뉴질랜드, NNP), (국세청, NNG), (은, JX), (국가, NNG), ...
# 3     [(세계, NNG), (최대, NNG), (재무, NNG), (설계, NNG), (...
# 4     [(상장, NNG), (검토, NNG), (대상, NNG), (인, VCP+ETM)...
# 5     [(미국, NNP), (무역, NNG), (대표부, NNG), ((, SSO), (...
# 6     [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 7     [(이, NP), (와, JKB), (함께, MAG), (스테이, NNG), (블,...
# 8     [(10, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 9     [(암호, NNG), (화폐, NNG), (전문, NNG), (미디어, NNG), ...
# 10    [(이번, NNG), (행사, NNG), (는, JX), (코인, NNG), (인,...
# 11    [(매일, MAG), (출석, NNG), (하, XSV), (고, EC), (비트코...
# 12    [(지난, VV+ETM), (11, SN), (일, NNBC), (찰리, NNP),...
# 13    [(코, NNG), (인원, NNG), (은, JX), (프로젝트, NNG), (가...
# 14    [(매일, MAG), (출석, NNG), (하, XSV), (고, EC), (비트코...
# 15    [(카카오, NNP), (클레이튼, NNP), (에서, JKB), (통용, NNG)...
# 16    [(10, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 17    [(11, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 18    [(경기도, NNP), (와, JC), (경제, NNG), (과학, NNG), (진...
# 19    [(국회, NNG), (입, NNG), (법조, NNG), (사처, NNG), (는...
# 20    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 21    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 22    [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 23    [(12, SN), (일, NNBC), (카카오, NNP), (는, JX), (카카...
# 24    [(이, NP), (들, XSN), (은, JX), (블록체인, NNG), (을, ...
# 0     [(미, NNG), (SEC, SL), (는, JX), (12, SN), (일, N...
# 1     [(미국, NNP), (의, JKG), (중국, NNP), (에, JKB), (대한...
# 2     [(인민, NNG), (은행, NNG), (은, JX), (최근, NNG), (다양...
# 3     [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 4     [(출처, NNG), (:, SC), (Coindesk, SL), (., SY), ...
# 5     [(CNBC, SL), (에, JKB), (따르, VV), (면, EC), (BOA...
# 6     [(이, NR), (둘, NR), (의, JKG), (가장, MAG), (큰, VA...
# 7     [(온톨로지, NNG), (는, JX), (네오, NNP), (,, SC), (퀀텀...
# 8     [(코, NNG), (인원, NNG), (이, JKS), (밝힌, VV+ETM), ...
# 9     [(사진, NNG), (=, SY), (카카오톡, NNP), (캡처, NNP), (...
# 10    [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 11    [(이번, NNG), (강좌, NNG), (에, JKB), (는, JX), (블록체...
# 12    [(업, NNG), (비트, VV), (는, ETM), (12, SN), (일, N...
# 13    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 14    [(신한은행, NNP), (은, JX), (카카오, NNG), (의, JKG), (...
# 15    [(블록체인, NNG), (핀테크, NNG), (기업, NNG), (인, VCP+E...
# 16    [(헤, IC), (데, VV), (라, EC), (해시, NNG), (그래프, N...
# 17    [(현재, MAG), (국회, NNG), (는, JX), (여야, NNG), (간,...
# Name: pos tag, dtype: object

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('JKS','JX','JKO','JKB','EC','EP','SN','EP+EC')])

# %%
text['main article']
# Out:
# 0     [최근, 암호, 화폐, 전문, 매체, 더, 블록, 뉴욕, 금융, 서비스, 부, (,...
# 1     [일, (, 현지, 시간, ), 암호, 화폐, 전문, 매체, 비인, 크, 립, 토,...
# 2     [뉴질랜드, 국세청, 국가, 조세, 행정법, (, ), s, D, 아래, ,, 암호...
# 3     [세계, 최대, 재무, 설계, 자문, 기업, 드비어, 그룹, 의, 니겔, 그린, (...
# 4     [상장, 검토, 대상, 인, 주요, 암호, 화폐, 비트코인, ,, 이, 오스, ,,...
# 5     [미국, 무역, 대표부, (, USTR, ), 일, (, 현지, 시간, ), 성명,...
# 6     [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, 미국, 뉴욕, 동부,...
# 7     [이, 함께, 스테이, 블, 코인, USDP, 개발, ,, 암호, 화폐, 실생활, ...
# 8     [일, (, 현지, 시간, ), 더, 블록, 보도, 따르, 중국, 금융, 인, 포럼...
# 9     [암호, 화폐, 전문, 미디어, 코인, 텔레, 그래프, 걸프, 뉴스, (, Gulf...
# 10    [이번, 행사, 코인, 인, (, Coinin, ), ,, 블록, 글로벌, (, B...
# 11    [매일, 출석, 하, 비트코인, 획득, !, 무료, 가입, 하, 매일, 시간, 광고...
# 12    [지난, 일, 찰리, 리, 자신, 의, 트위터, 통해, ", 많, 은, 이, 들, ...
# 13    [코, 인원, 프로젝트, 속한, 기업, 이나, 재단, 정보, ,, 비즈니스, 모델,...
# 14    [매일, 출석, 하, 비트코인, 획득, !, 무료, 가입, 하, 매일, 시간, 광고...
# 15    [카카오, 클레이튼, 통용, 되, 는, 암호, 화폐, 클레이, 비록, 해, 클레이튼...
# 16    [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, IBM, P, P, ...
# 17    [일, (, 현지, 시간, ), UAE, 매체, 걸프, 뉴스, (, Gulf, Ne...
# 18    [경기도, 와, 경제, 과학, 진, 흥원, 공동, 주최, 열리, 는, 이번, 대회,...
# 19    [국회, 입, 법조, 사처, 최근, 발간, 한, ', 국감, 이, 분석, 보고서, ...
# 20    [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, 호주, 커먼, 웰스,...
# 21    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 따르, ,, 타이슨, 블록체...
# 22    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 보도, 따르, 차, 정기, ...
# 23    [일, 카카오, 카카오톡, 내, ', 더, 보, 기, ', 탭, 카카오, 암호, 화...
# 24    [이, 들, 블록체인, 활용, 해, 기존, 마일리지, 서비스, 확대, 해, 건강, ...
# 0     [미, SEC, 일, (, 현지, 시간, ), 개, 비트코인, 상장지수, 펀드, (...
# 1     [미국, 의, 중국, 대한, 환율, 조, 작국, 지정, ,, 일본, 의, 경제, 보...
# 2     [인민, 은행, 최근, 다양, 한, 경로, 통해, 법정, 디지털, 화폐, 출시, 와...
# 3     [일, (, 현지, 시간, ), 코인, 데스크, 비트코인, 단기, 챠트, 의, 경우...
# 4     [출처, :, Coindesk, ., Created, with, TradingVie...
# 5     [CNBC, 따르, BOA, 의, 미국, 경제, 헤드, 미셸, 마이어, 지난, 일자...
# 6     [이, 둘, 의, 가장, 큰, 차이점, 퍼블, 리, 과, 프라이빗, ,, 단어, 의...
# 7     [온톨로지, 네오, ,, 퀀텀, 함께, 중국, 대표, 하, 는, 퍼블릭, 블록체인,...
# 8     [코, 인원, 밝힌, 상장, 심사, 기준, 프로젝트, 속한, 기업, 이나, 재단, ...
# 9     [사진, =, 카카오톡, 캡처, 안드로이드, 최신, 버전, 카카오톡, ‘, 더, 보...
# 10    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 따르, ,, 선, 지난, 일...
# 11    [이번, 강좌, 블록체인, 업계, 종사자, 및, 일반인, 등, 약, 여, 명, 참석...
# 12    [업, 비트, 는, 일, 특정, 조건, 의, 로그인, 발생, 할, 경우, 고객, 들...
# 13    [일, (, 현지, 시간, ), 코인, 데스크, 따르, XRP, 가격, 챠트, 일,...
# 14    [신한은행, 카카오, 의, 블록체인, 기술, 계열사, 그라운드, X, ,, 블록체인...
# 15    [블록체인, 핀테크, 기업, 인, 테, 라는, 벅스, 운영, 하, 는, NHN, 벅...
# 16    [헤, 데, 해시, 그래프, 소프트웨어, 회사, 인, 스, 월즈, 사, (, Swi...
# 17    [현재, 국회, 여야, 간, 정쟁, 대부분, 의, 법, 들, 장기, 계류, 중, 이...
# Name: main article, dtype: object

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_ko.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 1])
print(tokenized_doc)
#tokenized_doc = text['main article']
#tokenized_doc
# Out:
# 0     [최근, 암호, 화폐, 전문, 매체, 블록, 뉴욕, 금융, 서비스, NYDFS, 승...
# 1     [현지, 시간, 암호, 화폐, 전문, 매체, 비인, BeInCrypto, 보도, 골...
# 2     [뉴질랜드, 국세청, 국가, 조세, 행정법, 아래, 암호, 화폐, 유사, 화폐, m...
# 3     [세계, 최대, 재무, 설계, 자문, 기업, 드비어, 그룹, 니겔, 그린, Nige...
# 4     [상장, 검토, 대상, 암호, 화폐, 비트코인, 오스, 카르다노, 코스모스, 베이직...
# 5     [미국, 무역, 대표부, USTR, 현지, 시간, 성명, 통해, 미국, 수입, 중국...
# 6     [현지, 시간, 코인, 데스크, 보도, 미국, 뉴욕, 동부, 지방, 법원, SEC,...
# 7     [함께, 스테이, 코인, USDP, 개발, 암호, 화폐, 실생활, 응용, 수준, 높...
# 8     [현지, 시간, 블록, 보도, 중국, 금융, 포럼, 中國, 四十人論壇, 행사, 중국...
# 9     [암호, 화폐, 전문, 미디어, 코인, 텔레, 그래프, 걸프, 뉴스, Gulf, N...
# 10    [이번, 행사, 코인, Coinin, 블록, 글로벌, BLOCK, GLOBAL, 비...
# 11    [매일, 출석, 비트코인, 획득, 무료, 가입, 매일, 시간, 광고, 고정, 수입,...
# 12    [찰리, 자신, 트위터, 통해, 올해, 라이트, 코인, 사실상, 코드, 업데이트, ...
# 13    [인원, 프로젝트, 속한, 기업, 재단, 정보, 비즈니스, 모델, 시장, 기술, 평...
# 14    [매일, 출석, 비트코인, 획득, 무료, 가입, 매일, 시간, 광고, 고정, 수입,...
# 15    [카카오, 클레이튼, 통용, 암호, 화폐, 클레이, 비록, 클레이튼, 기반, 코스모...
# 16    [현지, 시간, 코인, 데스크, 보도, IBM, 네트워크, 지원, 브라우저, 관련,...
# 17    [현지, 시간, UAE, 매체, 걸프, 뉴스, Gulf, News, 보도, UAE,...
# 18    [경기도, 경제, 과학, 흥원, 공동, 주최, 열리, 이번, 대회, 블록체인, 기반...
# 19    [국회, 법조, 사처, 최근, 발간, 국감, 분석, 보고서, 블록체인, 암호, 화폐...
# 20    [현지, 시간, 코인, 데스크, 보도, 호주, 커먼, 웰스, 은행, 소유, 뉴질랜드...
# 21    [현지, 시간, 코인, 텔레, 그래프, 타이슨, 블록체인, 기반, 엔터, 플랫, 파...
# 22    [현지, 시간, 코인, 텔레, 그래프, 보도, 정기, 주주, 총회, 스리, 무케시,...
# 23    [카카오, 카카오톡, 카카오, 암호, 화폐, 지갑, 클립, 페이지, 공개, 클립, ...
# 24    [블록체인, 활용, 기존, 마일리지, 서비스, 확대, 건강, 기능, 운동, 통합, ...
# 0     [SEC, 현지, 시간, 비트코인, 상장지수, 펀드, ETF, 승인, 관한, 결정,...
# 1     [미국, 중국, 환율, 작국, 지정, 일본, 경제, 보복, 조치, 북한, 단거리, ...
# 2     [인민, 은행, 최근, 다양, 경로, 통해, 법정, 디지털, 화폐, 출시, 관련, ...
# 3     [현지, 시간, 코인, 데스크, 비트코인, 단기, 챠트, 약세, bears, 상황,...
# 4     [출처, Coindesk, Created, with, TradingView, 현지,...
# 5     [CNBC, BOA, 미국, 경제, 헤드, 미셸, 마이어, 일자, 고객, 노트, 내...
# 6     [가장, 차이점, 퍼블, 프라이빗, 단어, 의미, 열려, 퍼블릭, 블록체인, 모두,...
# 7     [온톨로지, 네오, 퀀텀, 함께, 중국, 대표, 퍼블릭, 블록체인, 하나, 신뢰, ...
# 8     [인원, 밝힌, 상장, 심사, 기준, 프로젝트, 속한, 기업, 재단, 정보, 비즈니...
# 9     [사진, 카카오톡, 캡처, 안드로이드, 최신, 버전, 카카오톡, 전체, 서비스, 클...
# 10    [현지, 시간, 코인, 텔레, 그래프, 트위터, 통해, 미국인, 바이, 낸스, 트론...
# 11    [이번, 강좌, 블록체인, 업계, 종사자, 일반인, 참석, 주제, 블록체인, 개념,...
# 12    [비트, 특정, 조건, 로그인, 발생, 고객, 카카오톡, 메시지, 발송, 비트, 계...
# 13    [현지, 시간, 코인, 데스크, XRP, 가격, 챠트, 이동, 평균, MA, MA,...
# 14    [신한은행, 카카오, 블록체인, 기술, 계열사, 그라운드, 블록체인, 기술, 연구소...
# 15    [블록체인, 핀테크, 기업, 벅스, 운영, NHN, 벅스, 블록체인, 기반, 결제,...
# 16    [해시, 그래프, 소프트웨어, 회사, 월즈, Swirlds, Inc, 공동, 창립자...
# 17    [현재, 국회, 여야, 정쟁, 대부분, 장기, 계류, 금융, 혁신, 초석, 불리, ...
# Name: main article, dtype: object

# %%
article_contents = tokenized_doc.values.tolist()

# %%
len(tokenized_doc)
# Out:
# 43

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
# article_contents_tfidf

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 2262

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 2262

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.004*"부리" + 0.004*"피싱" + 0.004*"경향" + 0.004*"안내" + 0.004*"늘려" + 0.004*"계열사" + 0.004*"디바이스" + 0.004*"로그아웃"')
# (1, '0.005*"보인다" + 0.005*"교묘" + 0.005*"효용" + 0.005*"담당" + 0.005*"System" + 0.005*"노무라" + 0.005*"미래" + 0.005*"대학"')
# (2, '0.005*"봉착" + 0.005*"유행" + 0.005*"진다" + 0.005*"대처" + 0.005*"로그인" + 0.005*"행사장" + 0.005*"CHAI" + 0.005*"주제"')
# (3, '0.004*"본인" + 0.004*"즉시" + 0.004*"기승" + 0.004*"상세" + 0.004*"즉각" + 0.004*"IP" + 0.004*"버튼" + 0.004*"조건"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1208140535547278672893358397"></div>
# <script type="text/javascript">
#
# var ldavis_el1208140535547278672893358397_data = {"mdsDat": {"x": [0.1439549616209663, -0.11574382681095037, -0.014717571532458047, -0.013493563277557841], "y": [0.05291114167212093, 0.08235469638674942, -0.07353561663089553, -0.061730221427974734], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [25.681533813476562, 25.202564239501953, 24.68933868408203, 24.426565170288086]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 2.050360679626465, 2.0503602027893066, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.05 ...

# %%
sentences = article_contents

# %%
length1 = 0
for setence in sentences :
    length1 += len(setence) 
length1
# Out:
# 4203

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 1460

# %%
# model.wv.vocab

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: ""
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/lm/counter.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence, defaultdict

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 1460

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 1309.1309596963831

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.738680516990997

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 0.02670196994142861

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
len(tf_idf_value)
# Out:
# 1460

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 거래소
# Out:
#                                               raw_data  word  cluster  \
# 26   [-0.006278167013078928, -0.007625259924679995,...    암호        0
# 27   [0.0002995020186062902, -0.0018469240749254823...    화폐        0
# 67   [0.0024996125139296055, -0.0006193954031914473...    달러        0
# 6    [-0.0005467821029014885, -0.004708655644208193...  비트코인        0
# 112  [-0.0068267518654465675, -0.005776440724730492...  블록체인        0
# 82   [-0.00549675477668643, -0.005018734373152256, ...    코인        0
# 621  [-0.0016370409866794944, -0.003931205254048109...    토큰        0
# 382  [-0.006358831189572811, -0.005795827601104975,...    비트        0
# 307  [-0.006975102238357067, -0.007287073880434036,...    통해        0
# 241  [-0.0030143060721457005, -0.003919984679669142...    위해        0
# 61   [-0.002043821383267641, -0.0019509915728121996...    세계        0
# 44   [0.0004609568859450519, -0.005696465261280537,...    금융        0
# 384  [0.002073882846161723, -0.004913286305963993, ...   거래소        0
# 87   [0.0033147826325148344, -0.0013430946273729205...    기준        0
# 96   [-0.003291712375357747, -0.0008686057408340275...    기업        0
# 23   [-0.000868085422553122, -0.002037814585492015,...    시간        0
# 668  [-0.0024880755227059126, -0.00571946008130908,...    지원        0
# 432  [0.0023958031088113785, 0.0010224503930658102,...    낸스        0
# 15   [-0.005642951000481844, -0.005859591998159885,...    의장        0
# 46   [0.0003980896435678005, -0.000633487303275615,...    결제        0
#
#                                               centroid  distance     tfidf  \
# 26   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.462199  0.442105
# 27   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.629786  0.491228
# 67   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.435608  0.188934
# 6    [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.569714  0.283400
# 112  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.477221  0.154926
# 82   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.526809  0.196491
# 621  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.488149  0.102024
# 382  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.517398  0.068016
# 307  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.546420  0.090688
# 241  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.547379  0.056680
# 61   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.572931  0.060459
# 44   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.590413  0.075573
# 384  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.670939  0.151147
# 87   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.572776  0.052901
# 96   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.608920  0.083131
# 23   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.653604  0.120918
# 668  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.615298  0.064237
# 432  [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.600121  0.041565
# 15   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.619728  0.060459
# 46   [-0.00030426448, -0.0011200143, 0.0005937362, ...  0.625205  0.056680
#
#         score closer#
# 26   1.020094     NaN
# 27   1.138559     NaN
# 67   1.246674     NaN
# 6    1.286313     NaN
# 112  1.322295     NaN
# 82   1.330318     NaN
# 621  1.386125     NaN
# 382  1.449382     NaN
# 307  1.455731     NaN
# 241  1.490699     NaN
# 61   1.512472     NaN
# 44   1.514840     NaN
# 384  1.519792     NaN
# 87   1.519875     NaN
# 96   1.525789     NaN
# 23   1.532686     NaN
# 668  1.551061     NaN
# 432  1.558555     NaN
# 15   1.559269     NaN
# 46   1.568525     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회이슈
# Out:
#                                                raw_data      word  cluster  \
# 1410  [0.0002958131080958992, -0.001731512020342052,...      아티스트        1
# 988   [-0.0023638696875423193, 0.00410047871991992, ...        비해        1
# 527   [0.0017404297832399607, -0.005024120677262545,...       최고가        1
# 53    [-0.0018581593176349998, -0.002178434049710631...       이라고        1
# 1454  [-0.004567151889204979, 0.0007271569920703769,...        데이        1
# 1320  [0.0006204621167853475, -0.004299809690564871,...        필두        1
# 563   [-0.002839356428012252, 0.00020355431479401886...       솔루션        1
# 248   [-0.0009420998394489288, 0.0028704660944640636...        신화        1
# 493   [-0.0028076814487576485, 0.0005293055437505245...       분기점        1
[-0.00097444095, 0.0003291991, -0.0002690597, ...  0.773530  0.018893
# 301   [-0.00097444095, 0.0003291991, -0.0002690597, ...  0.792481  0.037787
#
#          score closer#
# 790   1.584323     NaN
# 1073  1.624968     NaN
# 335   1.638696     NaN
# 380   1.659129     NaN
# 25    1.660713     NaN
# 452   1.675854     NaN
# 19    1.679413     NaN
# 1441  1.681536     NaN
# 1458  1.681764     NaN
# 819   1.683856     NaN
# 1453  1.690238     NaN
# 637   1.695949     NaN
# 797   1.696029     NaN
# 623   1.700122     NaN
# 1099  1.700781     NaN
# 752   1.702913     NaN
# 183   1.714196     NaN
# 672   1.716329     NaN
# 1430  1.717775     NaN
# 152   1.721559     NaN
# 253   1.723308     NaN
# 886   1.726415     NaN
# 1355  1.736503     NaN
# 781   1.738882     NaN
# 143   1.742968     NaN
# 1354  1.751802     NaN
# 801   1.751863     NaN
# 379   1.753768     NaN
# 100   1.754637     NaN
# 301   1.754695     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(30)  # 투자
# Out:
#                                                raw_data   word  cluster  \
# 426   [0.0030936310067772865, 0.0012937060091644526,...     안전        3
# 473   [-0.0010030103148892522, -0.000445458485046401...    조정장        3
# 626   [-0.004978825803846121, 4.71448693133425e-05, ...     블록        3
# 833   [0.0028917219024151564, 0.0008249752572737634,...    캐나다        3
# 533   [0.0011924359714612365, -0.0033296518959105015...     펀드        3
# 129   [0.0022154084872454405, -0.004611441865563393,...     주도        3
# 667   [-0.0015894387615844607, -0.004722548648715019...     워크        3
# 1263  [-0.004088202025741339, -0.002341264160349965,...    Top        3
# 1038  [-0.0021383471321314573, -0.002450186293572187...  Adham        3
# 769   [0.002692172769457102, 0.0034820770379155874, ...     변화        3
# 1406  [-0.0016963888192549348, -0.003652650630101561...     낙서        3
# 855   [0.003908309619873762, 0.004143967758864164, 0...     매주        3
# 1085  [0.0027710592839866877, 0.0012060092994943261,...     분야        3
# 77    [0.0019973646849393845, -0.005510170944035053,...   페이스북        3
# 874   [-0.003126026364043355, -0.0021569374948740005...     퍼스        3
# 702   [0.0012622361537069082, 0.0008126637549139559,...     +)        3
# 1248  [-0.005641672294586897, -0.0036464123986661434...     리플        3
# 851   [0.00210623349994421, -0.004081189166754484, -...    가포르        3
# 610   [-0.004699216224253178, -0.002354829804971814,...     역할        3
# 131   [-0.001904673408716917, -0.0027349123265594244...     통계        3
# 860   [-0.004664180334657431, -0.005072218831628561,...     전략        3
# 578   [-0.004745209123939276, -0.002519437577575445,...    코스미        3
# 1325  [-0.0023401558864861727, -0.002398509532213211...     단순        3
# 285   [-0.0034420813899487257, -0.002194540575146675...     kW        3
# 755   [0.0024607074446976185, -0.0028386644553393126...     특허        3
# 762   [0.0019190928433090448, -0.0037981062196195126...   알리바바        3
# 190   [-0.0029754601418972015, 0.002086293650791049,...     비교        3
# 1380  [-0.0005162424640730023, -0.00521816173568368,...     GT        3
# 1171  [-0.004396047443151474, 0.0027624741196632385,...     협업        3
# 655   [0.003502332605421543, -0.0034698282834142447,...     표준        3
#
#                                                centroid  distance     tfidf  \
# 426   [0.00020907927, -0.00037250595, 0.00026755824,...  0.532585  0.003779
# 473   [0.00020907927, -0.00037250595, 0.00026755824,...  0.622932  0.003779
# 626   [0.00020907927, -0.00037250595, 0.00026755824,...  0.686455  0.060459
[-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031813  0.491228
# 26    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.034757  0.442105
# 6     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030799  0.283400
# 82    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.033669  0.196491
# 67    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031642  0.188934
# 112   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.032122  0.154926
# 384   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029193  0.151147
# 23    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030676  0.120918
# 2     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029551  0.109582
# 35    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029976  0.102024
# 621   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.033187  0.102024
# 37    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028239  0.094467
# 307   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031410  0.090688
# 96    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027859  0.083131
# 1     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028333  0.079352
# 165   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028058  0.075573
# 3     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028089  0.075573
# 321   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028303  0.075573
# 234   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031177  0.075573
# 44    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031444  0.075573
# 196   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028420  0.071795
# 136   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.033124  0.075573
# 128   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031887  0.071795
# 382   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029659  0.068016
# 15    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.025095  0.060459
# 12    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.026967  0.060459
# 184   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030929  0.064237
# 668   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031186  0.064237
# 97    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027464  0.060459
# 61    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028278  0.060459
# 626   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028483  0.060459
# 81    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030149  0.060459
# 360   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031412  0.060459
# 77    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028045  0.056680
# 241   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028791  0.056680
# 181   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030066  0.056680
# 46    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031744  0.056680
# 87    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030254  0.052901
# 560   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027130  0.049123
# 122   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027694  0.045344
# 53    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028224  0.045344
# 1162  [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029408  0.045344
# 45    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027840  0.041565
# 1161  [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.032481  0.045344
# 48    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029005  0.041565
# 57    [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.025315  0.037787
# 432   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029911  0.041565
# 629   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.030226  0.041565
# 889   [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.027339  0.037787
# 1154  [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.031634  0.041565
#
#          score closer#
# 27    0.540585     NaN
# 26    0.592653     NaN
# 6     0.747398     NaN
# 82    0.837178     NaN
# 67    0.842708     NaN
# 112   0.877196     NaN
# 384   0.878046     NaN
# 23    0.909759     NaN
# 2     0.919969     NaN
# 35    0.927952     NaN
# 621   0.931163     NaN
# 37    0.933773     NaN
# 307   0.940722     NaN
# 96    0.944728     NaN
# 1     0.948981     NaN
# 165   0.952485     NaN
# 3     0.952515     NaN
# 321   0.952729     NaN
# 234   0.955604     NaN
# 44    0.955870     NaN
# 196   0.956626     NaN
# 136   0.957550     NaN
# 128   0.960093     NaN
# 382   0.961643     NaN
# 15    0.964637     NaN
# 12    0.966508     NaN
# 184   0.966691     NaN
# 668   0.966948     NaN
# 97    0.967005     NaN
# 61    0.967820     NaN
# 626   0.968025     NaN
# 81    0.969690     NaN
# 360   0.970954     NaN
# 77    0.971365     NaN
# 241   0.972111     NaN
# 181   0.973386     NaN
# 46    0.975064     NaN
# 87    0.977352     NaN
# 560   0.978007     NaN
# 122   0.982350     NaN
# 53    0.982880     NaN
# 1162  0.984064     NaN
# 45    0.986274     NaN
# 1161  0.987137     NaN
# 48    0.987439     NaN
# 57    0.987528     NaN
# 432   0.988345     NaN
# 629   0.988660     NaN
# 889   0.989552     NaN
# 1154  0.990069     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') #
NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 제도
# Out:
#                                                raw_data  word  cluster  \
# 134   [0.0010708161862567067, -0.005630856845527887,...    현재        2
# 301   [-0.005980706308037043, -0.004074279684573412,...    가능        2
# 32    [-0.0021860424894839525, -0.005770431831479073...    가치        2
# 80    [-0.0022637848742306232, 0.0019268542528152466...    예정        2
# 1058  [0.0041857510805130005, -0.0057147410698235035...  플래티넘        2
# 1153  [0.004015960730612278, -0.004207099322229624, ...  산토리니        2
# 380   [-0.005086101125925779, -0.0008562857401557267...    공식        2
# 1373  [-0.004613639321178198, -0.0033098103012889624...    비중        2
# 11    [-0.0013821008615195751, -0.002647912595421076...    제롬        2
# 500   [0.002297400962561369, 0.00020093689090572298,...    검찰        2
# 634   [-0.0027549422811716795, 0.0012344681890681386...   프롭스        2
# 316   [-0.004316417500376701, -0.0012697732308879495...    신뢰        2
# 100   [-0.0038453510496765375, -0.003267688443884253...    모두        2
# 594   [0.001996227540075779, 0.003953670617192984, -...    전공        2
# 546   [-0.0036693098954856396, -0.005124560091644525...    설명        2
# 630   [-0.004665077198296785, -0.005163994152098894,...    허가        2
# 25    [2.056739140243735e-05, -0.0007280355202965438...    가상        2
# 455   [-0.001649582525715232, -0.0013527973787859082...    회의        2
# 312   [0.0037026701029390097, -0.004890114068984985,...    비난        2
# 1285  [-0.002432044595479965, 0.003475767560303211, ...   nan        2
#
#                                                centroid  distance     tfidf  \
# 134   [0.00021455312, -0.0005461599, -0.00072119606,...  0.030032  0.068016
# 301   [0.00021455312, -0.0005461599, -0.00072119606,...  0.029908  0.037787
# 32    [0.00021455312, -0.0005461599, -0.00072119606,...  0.030140  0.030229
# 80    [0.00021455312, -0.0005461599, -0.00072119606,...  0.026603  0.026451
# 1058  [0.00021455312, -0.0005461599, -0.00072119606,...  0.029015  0.026451
# 1153  [0.00021455312, -0.0005461599, -0.00072119606,...  0.029268  0.026451
# 380   [0.00021455312, -0.0005461599, -0.00072119606,...  0.026905  0.022672
# 1373  [0.00021455312, -0.0005461599, -0.00072119606,...  0.031056  0.026451
# 11    [0.00021455312, -0.0005461599, -0.00072119606,...  0.027127  0.018893
# 500   [0.00021455312, -0.0005461599, -0.00072119606,...  0.027204  0.018893
# 634   [0.00021455312, -0.0005461599, -0.00072119606,...  0.027484  0.018893
# 316   [0.00021455312, -0.0005461599, -0.00072119606,...  0.029722  0.018893
# 100   [0.00021455312, -0.0005461599, -0.00072119606,...  0.029765  0.018893
# 594   [0.00021455312, -0.0005461599, -0.00072119606,...  0.026142  0.015115
# 546   [0.00021455312, -0.0005461599, -0.00072119606,...  0.030497  0.018893
# 630   [0.00021455312, -0.0005461599, -0.00072119606,...  0.030603  0.018893
# 25    [0.00021455312, -0.0005461599, -0.00072119606,...  0.026824  0.015115
# 455   [0.00021455312, -0.0005461599, -0.00072119606,...  0.026975  0.015115
# 312   [0.00021455312, -0.0005461599, -0.00072119606,...  0.027207  0.015115
# 1285  [0.00021455312, -0.0005461599, -0.00072119606,...  0.027801  0.015115
#
#          score closer#
# 134   0.962016     NaN
# 301   0.992121     NaN
# 32    0.999910     NaN
# 80    1.000153     NaN
# 1058  1.002564     NaN
# 1153  1.002818     NaN
# 380   1.004233     NaN
# 1373  1.004605     NaN
# 11    1.008234     NaN
# 500   1.008310     NaN
# 634   1.008591     NaN
# 316   1.010829     NaN
# 100   1.010872     NaN
# 594   1.011028     NaN
# 546   1.011604     NaN
# 630   1.011709     NaN
# 25    1.011710     NaN
# 455   1.011860     NaN
# 312   1.012092     NaN
# 1285  1.012687     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 투자
# Out:
#                                                raw_data word  cluster  \
# 368   [0.0004336003039497882, 0.0034138767514377832,...   개발        3
# 531   [-0.004733704496175051, -0.0031791208311915398...   투자        3
# 89    [-0.0005717012681998312, -0.003058464266359806...   기관        3
# 86    [-0.005408767610788345, -0.0005681378534063697...   당국        3
# 7     [0.000780029222369194, -0.003987439442425966, ...   대해        3
# 1434  [-0.003697160864248872, 0.0021633899305015802,...   모드        3
# 224   [0.0006724677514284849, -0.0001331747625954449...   중국        3
# 71    [-0.0026686941273510456, -0.000354546529706567...  글로벌        3
# 581   [-0.0016953673912212253, -5.014292037230916e-0...   이번        3
# 113   [-0.004665107931941748, -0.0021704398095607758...   업계        3
# 93    [-0.005216262303292751, -0.0003918467264156788...   필요        3
# 231   [0.0029501200187951326, -0.004275977611541748,...   상당        3
# 182   [-0.005024311598390341, 0.0013654254144057631,...  데스크        3
# 284   [-0.004397846292704344, -0.004073212388902903,...   매일        3
# 170   [-0.0009775875369086862, -0.003466412425041198...   대표        3
# 979   [0.000932783295866102, -0.0014505044091492891,...   마켓        3
# 34    [0.001570838037878275, -0.0052466848865151405,...   거의        3
# 573   [-0.0022126524709165096, -0.000395608250983059...   체인        3
# 986   [-0.0011969375191256404, 0.003499259240925312,...   배포        3
# 1267  [-0.0017942019039765, 0.0027422558050602674, 0...   주중        3
#
#                                                centroid  distance     tfidf  \
# 368   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.031220  0.041565
# 531   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028619  0.037787
# 89    [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.030068  0.037787
# 86    [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028657  0.034008
# 7     [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.029140  0.030229
# 1434  [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.029941  0.030229
# 224   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.027897  0.026451
# 71    [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.026499  0.022672
# 581   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.031600  0.026451
# 113   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028088  0.022672
# 93    [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028125  0.022672
# 231   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028943  0.022672
# 182   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.029414  0.022672
# 284   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.025984  0.018893
# 170   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.026799  0.018893
# 979   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.027903  0.018893
# 34    [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028176  0.018893
# 573   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.028948  0.018893
# 986   [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.026535  0.015115
# 1267  [-0.00014957649, 0.0002665805, 0.0009097392, -...  0.026612  0.015115
#
#          score closer#
# 368   0.989655     NaN
# 531   0.990832     NaN
# 89    0.992281     NaN
# 86    0.994649     NaN
# 7     0.998910     NaN
# 1434  0.999712     NaN
# 224   1.001446     NaN
# 71    1.003827     NaN
# 581   1.005150     NaN
# 113   1.005416     NaN
# 93    1.005453     NaN
# 231   1.006271     NaN
# 182   1.006742     NaN
# 284   1.007090     NaN
# 170   1.007906     NaN
# 979   1.009010     NaN
# 34    1.009283     NaN
# 573   1.010055     NaN
# 986   1.011421     NaN
# 1267  1.011497     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #사회이슈
# Out:
# 372

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #사회이슈
# Out:
# 372

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #제도
# Out:
# 366

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #투자시도
# Out:
# 350

# %%
temp_cluster_result1['category'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 5 # 사회이슈

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 5 # 사회이슈

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 10 # 제도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 11 # 투자

# %%
temp_cluster_result1
# Out:
#                                                raw_data word  cluster  \
# 0     [0.0035222647711634636, 0.0014556820970028639,...  도널드        0
# 1     [-0.006308514159172773, 0.001307432889007032, ...  트럼프        0
# 2     [-0.00031530080013908446, -0.00457141408696770...   미국        0
# 3     [0.0008505438454449177, -0.0008341940701939166...  대통령        0
# 4     [-0.0022626605350524187, -0.00235651433467865,...   사진        0
# ...                                                 ...  ...      ...
# 1455  [-0.0037585925310850143, -0.000204967625904828...   변경        1
# 1456  [0.004288170952349901, -0.00232287822291255, 0...   주의        2
# 1457  [0.004538406617939472, 0.003644506447017193, 0...   최적        2
# 1458  [-0.0024594245478510857, -0.003246051725000143...   만족        2
# 1459  [-0.004992215894162655, -0.0013923392398282886...   노력        2
#
#                                                centroid  distance     tfidf  \
# 0     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.026589  0.018893
# 1     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028333  0.079352
# 2     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029551  0.109582
# 3     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.028089  0.075573
# 4     [-0.00056437775, -0.0010099222, 0.0010558446, ...  0.029355  0.007557
# ...                                                 ...       ...       ...
# 1455  [-0.00077619066, -0.0001063924, -0.00020684209...  0.030559  0.007557
# 1456  [0.00021455312, -0.0005461599, -0.00072119606,...  0.028345  0.003779
# 1457  [0.00021455312, -0.0005461599, -0.00072119606,...  0.028720  0.003779
# 1458  [0.00021455312, -0.0005461599, -0.00072119606,...  0.031219  0.003779
# 1459  [0.00021455312, -0.0005461599, -0.00072119606,...  0.027029  0.003779
#
#          score closer#  Silhouette  result  category  label
# 0     1.007695     NaN    0.008649       2         2    5.0
# 1     0.948981     NaN    0.008649       2         2    5.0
# 2     0.919969     NaN    0.008649       2         2    5.0
# 3     0.952515     NaN    0.008649       2         2    5.0
# 4     1.021798     NaN    0.008649       2         2    5.0
# ...        ...     ...         ...     ...       ...    ...
# 1455  1.023002     NaN    0.008649       2         2    5.0
# 1456  1.024566     NaN    0.008649       2         2   10.0
# 1457  1.024941     NaN    0.008649       2         2   10.0
# 1458  1.027441     NaN    0.008649       2         2   10.0
# 1459  1.023250     NaN    0.008649       2         2   10.0
#
# [1460 rows x 12 columns]

# %%
temp_cluster_result1['Silhouette'] = 0.00864853
temp_cluster_result['Silhouette'] = 0.00864853

# %%
#temp_cluster_result1.to_csv("../cluster/ko_news/2018_down1/ko_news_2018_down1_euclidean.csv")
#temp_cluster_result.to_csv("../cluster/ko_news/2018_down1/ko_news_2018_down1_cosine.csv")

# %%
len(temp_cluster_result1)
# Out:
# 1460

# %%
len(temp_cluster_result)
# Out:
# 1460

# %%
temp_cluster_result1['result'] = 2
temp_cluster_result['result'] = 2

# %%
temp_cluster_result1.to_csv("../cluster/ko_news/2019_down1/ko_news_2019_down1_euclidean.csv")
temp_cluster_result.to_csv("../cluster/ko_news/2019_down1/ko_news_2019_down1_cosine.csv")
