# %%
import pandas as pd
import urllib.request

data = pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)Hankyung.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)Tokenpost.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)BlockMedia.csv', error_bad_lines=False))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x95 in position 15: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-ba071b500df8> in <module>
#       4 data = pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)Hankyung.csv', error_bad_lines=False)
#       5 data = data.append(pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)Tokenpost.csv', error_bad_lines=False))
# ----> 6 data = data.append(pd.read_csv('../../news/scraping_result/kr/2019_down3/2019_down3_(KR)BlockMedia.csv', error_bad_lines=False))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x95 in position 15: invalid start byte

# %%
data.loc[data['main article']=="Provided by Coinness",'main article'] = data.loc[data['main article']=="Provided by Coinness",'abstract']
data.loc[data['main article']=="Provided by 코인니스",'main article'] = data.loc[data['main article']=="Provided by 코인니스",'abstract']
# data.loc[data['main article']=='Provided by 코인니스','abstract']

# %%
text = data[['main article']].astype(str)
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\xa0",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)

# %%
from konlpy.tag import Mecab
mecab = Mecab()
text['main token article'] = text.apply(lambda row: mecab.morphs(row['main article']), axis=1)

# %%
text['main article']
# Out:
# 0     최근 암호화폐 전문 매체 더블록은 뉴욕 금융서비스부(NYDFS)의 승인 지연으로 백...
# 1     12일(현지시간) 암호화폐 전문 매체 비인크립토(BeInCrypto) 보도에 따르면...
# 2     뉴질랜드 국세청은 국가 조세행정법(1994) s91D 아래, 암호화폐를 유사 화폐(...
# 3     세계 최대 재무설계자문기업 드비어 그룹의 니겔 그린(Nigel Green) CEO는...
# 4     상장 검토 대상인 주요 암호화폐는 비트코인, 이오스, 이더리움, 카르다노, 코스모스...
# 5     미국 무역대표부(USTR)는 13일(현지시간) 성명을 통해 "9월 1일부터 미국에 ...
# 6     13일(현지시간) 코인데스크 보도에 따르면 미국 뉴욕동부 지방법원은 SEC가 기소한...
# 7     이와 함께 스테이블 코인 USDP를 개발, 암호화폐 실생활 응용 수준을 높인다는 방...
# 8     10일(현지시간) 더블록 보도에 따르면 중국금융40인포럼(中國金融四十人論壇) 행사에...
# 9     암호화폐 전문 미디어 코인텔레그래프가 걸프뉴스(Gulf News) 11일(현지시간)...
# 10    이번 행사는 코인인(Coinin), 블록글로벌(BLOCK GLOBAL), 비트보이(...
# 11    매일 출석하고 비트코인 획득! 무료가입하고 매일 1시간 광고보고 16000원고정수입...
# 12    지난 11일 찰리 리는 자신의 트위터를 통해 "많은 이들이 올해 라이트코인이 사실상...
# 13    코인원은 프로젝트가 속한 기업이나 재단 정보, 비즈니스 모델, 시장성, 기술 등으로...
# 14    매일 출석하고 비트코인 획득! 무료가입하고 매일 1시간 광고보고 16000원고정수입...
# 15    카카오 클레이튼에서 통용되는 암호화폐 클레이를 비록해 클레이튼 기반 코스모코인, 힌...
# 16    10일(현지시간) 코인데스크 보도에 따르면 IBM은 P2P 네트워크로 지원되는 웹브...
# 17    11일(현지시간) UAE 매체 걸프뉴스(Gulf News) 보도에 따르면 UAE 국...
# 18    경기도와 경제과학진흥원 공동주최로 열리는 이번 대회는 블록체인을 기반으로 한 창업,...
# 19    국회 입법조사처는 최근 발간한 '2019 국감 이슈 분석보고서'에서 "블록체인과 암...
# 20    13일(현지시간) 코인데스크 보도에 따르면 호주 커먼웰스은행 소유의 뉴질랜드 ASB...
# 21    13일(현지시간) 코인텔레그래프에 따르면, 타이슨은 블록체인 기반 엔터테인먼트 플랫...
# 22    12일(현지시간) 코인텔레그래프 보도에 따르면 42차 정기 주주총회에서 스리 무케시...
# 23    12일 카카오는 카카오톡 내 '더보기' 탭에 카카오 암호화폐 지갑 '클립'의 티징 ...
# 24    이들은 블록체인을 활용해 기존 마일리지 서비스를 확대해 건강기능식부터 운동까지 통합...
# 0     미 SEC는 12일(현지시간) 3개 비트코인 상장지수펀드(ETF) 승인에 관한 결정...
# 1     미국의 중국에 대한 환율조작국 지정, 일본의 경제보복 조치, 북한의 단거리 탄도미사...
# 2     인민은행은 최근 다양한 경로를 통해 법정 디지털 화폐 출시와 관련 정보를 제공하고 ...
# 3     12일(현지시간) 코인데스크는 비트코인 단기 챠트의 경우 약세론자들(bears)이 ...
# 4     출처: Coindesk. Created with TradingView13일(현지시간...
# 5     CNBC에 따르면 BOA의 미국 경제 헤드 미셸 마이어는 지난 9일자 고객 노트에서...
# 6     이 둘의 가장 큰 차이점은 퍼블리과 프라이빗, 단어의 의미처럼 얼마나 열려 있는가에...
# 7     온톨로지는 네오, 퀀텀과 함께 중국을 대표하는 퍼블릭 블록체인 중 하나로 신뢰 기반...
# 8     코인원이 밝힌 상장심사 기준은 프로젝트가 속한 기업이나 재단 정보, 비즈니스 모델,...
# 9     사진=카카오톡 캡처안드로이드 최신 버전 카카오톡에는 ‘더보기’에서 ‘전체 서비스’를...
# 10    12일(현지시간) 코인텔레그래프에 따르면, 선은 지난 9일 트위터를 통해 미국인들이...
# 11    이번 강좌에는 블록체인 업계 종사자 및 일반인 등 약 200여명이 참석했다.1부 주...
# 12    업비트는 12일부터 특정 조건의 로그인이 발생할 경우 고객들에게 카카오톡 메시지를 ...
# 13    13일(현지시간) 코인데스크에 따르면 XRP 가격 챠트에서 50일 이동평균(MA)이...
# 14    신한은행은 카카오의 블록체인 기술 계열사 그라운드X, 블록체인 기술연구소 헥슬란트와...
# 15    블록체인 핀테크 기업인 테라는 벅스를 운영하는 NHN벅스와 블록체인 기반 결제 시스...
# 16    헤데라 해시그래프는 소프트웨어 회사인 스월즈사(Swirlds. Inc.)의 공동창립...
# 17    현재 국회는 여야간 정쟁으로 대부분의 법들이 장기 계류 중이다. 금융혁신의 초석이라...
# Name: main article, dtype: object

# %%
# 소문자 적용 , - 문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word.replace("-","") for word in x])
# 공백문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word for word in x if word])

# %%
text['pos tag'] = text.apply(lambda row: mecab.pos(row['main article']), axis=1)

# %%
text['pos tag']
# Out:
# 0     [(최근, NNG), (암호, NNG), (화폐, NNG), (전문, NNG), (...
# 1     [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 2     [(뉴질랜드, NNP), (국세청, NNG), (은, JX), (국가, NNG), ...
# 3     [(세계, NNG), (최대, NNG), (재무, NNG), (설계, NNG), (...
# 4     [(상장, NNG), (검토, NNG), (대상, NNG), (인, VCP+ETM)...
# 5     [(미국, NNP), (무역, NNG), (대표부, NNG), ((, SSO), (...
# 6     [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 7     [(이, NP), (와, JKB), (함께, MAG), (스테이, NNG), (블,...
# 8     [(10, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 9     [(암호, NNG), (화폐, NNG), (전문, NNG), (미디어, NNG), ...
# 10    [(이번, NNG), (행사, NNG), (는, JX), (코인, NNG), (인,...
# 11    [(매일, MAG), (출석, NNG), (하, XSV), (고, EC), (비트코...
# 12    [(지난, VV+ETM), (11, SN), (일, NNBC), (찰리, NNP),...
# 13    [(코, NNG), (인원, NNG), (은, JX), (프로젝트, NNG), (가...
# 14    [(매일, MAG), (출석, NNG), (하, XSV), (고, EC), (비트코...
# 15    [(카카오, NNP), (클레이튼, NNP), (에서, JKB), (통용, NNG)...
# 16    [(10, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 17    [(11, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 18    [(경기도, NNP), (와, JC), (경제, NNG), (과학, NNG), (진...
# 19    [(국회, NNG), (입, NNG), (법조, NNG), (사처, NNG), (는...
# 20    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 21    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 22    [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 23    [(12, SN), (일, NNBC), (카카오, NNP), (는, JX), (카카...
# 24    [(이, NP), (들, XSN), (은, JX), (블록체인, NNG), (을, ...
# 0     [(미, NNG), (SEC, SL), (는, JX), (12, SN), (일, N...
# 1     [(미국, NNP), (의, JKG), (중국, NNP), (에, JKB), (대한...
# 2     [(인민, NNG), (은행, NNG), (은, JX), (최근, NNG), (다양...
# 3     [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 4     [(출처, NNG), (:, SC), (Coindesk, SL), (., SY), ...
# 5     [(CNBC, SL), (에, JKB), (따르, VV), (면, EC), (BOA...
# 6     [(이, NR), (둘, NR), (의, JKG), (가장, MAG), (큰, VA...
# 7     [(온톨로지, NNG), (는, JX), (네오, NNP), (,, SC), (퀀텀...
# 8     [(코, NNG), (인원, NNG), (이, JKS), (밝힌, VV+ETM), ...
# 9     [(사진, NNG), (=, SY), (카카오톡, NNP), (캡처, NNP), (...
# 10    [(12, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 11    [(이번, NNG), (강좌, NNG), (에, JKB), (는, JX), (블록체...
# 12    [(업, NNG), (비트, VV), (는, ETM), (12, SN), (일, N...
# 13    [(13, SN), (일, NNBC), ((, SSO), (현지, NNG), (시간...
# 14    [(신한은행, NNP), (은, JX), (카카오, NNG), (의, JKG), (...
# 15    [(블록체인, NNG), (핀테크, NNG), (기업, NNG), (인, VCP+E...
# 16    [(헤, IC), (데, VV), (라, EC), (해시, NNG), (그래프, N...
# 17    [(현재, MAG), (국회, NNG), (는, JX), (여야, NNG), (간,...
# Name: pos tag, dtype: object

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('JKS','JX','JKO','JKB','EC','EP','SN','EP+EC')])

# %%
text['main article']
# Out:
# 0     [최근, 암호, 화폐, 전문, 매체, 더, 블록, 뉴욕, 금융, 서비스, 부, (,...
# 1     [일, (, 현지, 시간, ), 암호, 화폐, 전문, 매체, 비인, 크, 립, 토,...
# 2     [뉴질랜드, 국세청, 국가, 조세, 행정법, (, ), s, D, 아래, ,, 암호...
# 3     [세계, 최대, 재무, 설계, 자문, 기업, 드비어, 그룹, 의, 니겔, 그린, (...
# 4     [상장, 검토, 대상, 인, 주요, 암호, 화폐, 비트코인, ,, 이, 오스, ,,...
# 5     [미국, 무역, 대표부, (, USTR, ), 일, (, 현지, 시간, ), 성명,...
# 6     [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, 미국, 뉴욕, 동부,...
# 7     [이, 함께, 스테이, 블, 코인, USDP, 개발, ,, 암호, 화폐, 실생활, ...
# 8     [일, (, 현지, 시간, ), 더, 블록, 보도, 따르, 중국, 금융, 인, 포럼...
# 9     [암호, 화폐, 전문, 미디어, 코인, 텔레, 그래프, 걸프, 뉴스, (, Gulf...
# 10    [이번, 행사, 코인, 인, (, Coinin, ), ,, 블록, 글로벌, (, B...
# 11    [매일, 출석, 하, 비트코인, 획득, !, 무료, 가입, 하, 매일, 시간, 광고...
# 12    [지난, 일, 찰리, 리, 자신, 의, 트위터, 통해, ", 많, 은, 이, 들, ...
# 13    [코, 인원, 프로젝트, 속한, 기업, 이나, 재단, 정보, ,, 비즈니스, 모델,...
# 14    [매일, 출석, 하, 비트코인, 획득, !, 무료, 가입, 하, 매일, 시간, 광고...
# 15    [카카오, 클레이튼, 통용, 되, 는, 암호, 화폐, 클레이, 비록, 해, 클레이튼...
# 16    [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, IBM, P, P, ...
# 17    [일, (, 현지, 시간, ), UAE, 매체, 걸프, 뉴스, (, Gulf, Ne...
# 18    [경기도, 와, 경제, 과학, 진, 흥원, 공동, 주최, 열리, 는, 이번, 대회,...
# 19    [국회, 입, 법조, 사처, 최근, 발간, 한, ', 국감, 이, 분석, 보고서, ...
# 20    [일, (, 현지, 시간, ), 코인, 데스크, 보도, 따르, 호주, 커먼, 웰스,...
# 21    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 따르, ,, 타이슨, 블록체...
# 22    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 보도, 따르, 차, 정기, ...
# 23    [일, 카카오, 카카오톡, 내, ', 더, 보, 기, ', 탭, 카카오, 암호, 화...
# 24    [이, 들, 블록체인, 활용, 해, 기존, 마일리지, 서비스, 확대, 해, 건강, ...
# 0     [미, SEC, 일, (, 현지, 시간, ), 개, 비트코인, 상장지수, 펀드, (...
# 1     [미국, 의, 중국, 대한, 환율, 조, 작국, 지정, ,, 일본, 의, 경제, 보...
# 2     [인민, 은행, 최근, 다양, 한, 경로, 통해, 법정, 디지털, 화폐, 출시, 와...
# 3     [일, (, 현지, 시간, ), 코인, 데스크, 비트코인, 단기, 챠트, 의, 경우...
# 4     [출처, :, Coindesk, ., Created, with, TradingVie...
# 5     [CNBC, 따르, BOA, 의, 미국, 경제, 헤드, 미셸, 마이어, 지난, 일자...
# 6     [이, 둘, 의, 가장, 큰, 차이점, 퍼블, 리, 과, 프라이빗, ,, 단어, 의...
# 7     [온톨로지, 네오, ,, 퀀텀, 함께, 중국, 대표, 하, 는, 퍼블릭, 블록체인,...
# 8     [코, 인원, 밝힌, 상장, 심사, 기준, 프로젝트, 속한, 기업, 이나, 재단, ...
# 9     [사진, =, 카카오톡, 캡처, 안드로이드, 최신, 버전, 카카오톡, ‘, 더, 보...
# 10    [일, (, 현지, 시간, ), 코인, 텔레, 그래프, 따르, ,, 선, 지난, 일...
# 11    [이번, 강좌, 블록체인, 업계, 종사자, 및, 일반인, 등, 약, 여, 명, 참석...
# 12    [업, 비트, 는, 일, 특정, 조건, 의, 로그인, 발생, 할, 경우, 고객, 들...
# 13    [일, (, 현지, 시간, ), 코인, 데스크, 따르, XRP, 가격, 챠트, 일,...
# 14    [신한은행, 카카오, 의, 블록체인, 기술, 계열사, 그라운드, X, ,, 블록체인...
# 15    [블록체인, 핀테크, 기업, 인, 테, 라는, 벅스, 운영, 하, 는, NHN, 벅...
# 16    [헤, 데, 해시, 그래프, 소프트웨어, 회사, 인, 스, 월즈, 사, (, Swi...
# 17    [현재, 국회, 여야, 간, 정쟁, 대부분, 의, 법, 들, 장기, 계류, 중, 이...
# Name: main article, dtype: object

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_ko.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 1])
print(tokenized_doc)
#tokenized_doc = text['main article']
#tokenized_doc
# Out:
# 0     [최근, 암호, 화폐, 전문, 매체, 블록, 뉴욕, 금융, 서비스, NYDFS, 승...
# 1     [현지, 시간, 암호, 화폐, 전문, 매체, 비인, BeInCrypto, 보도, 골...
# 2     [뉴질랜드, 국세청, 국가, 조세, 행정법, 아래, 암호, 화폐, 유사, 화폐, m...
# 3     [세계, 최대, 재무, 설계, 자문, 기업, 드비어, 그룹, 니겔, 그린, Nige...
# 4     [상장, 검토, 대상, 암호, 화폐, 비트코인, 오스, 카르다노, 코스모스, 베이직...
# 5     [미국, 무역, 대표부, USTR, 현지, 시간, 성명, 통해, 미국, 수입, 중국...
# 6     [현지, 시간, 코인, 데스크, 보도, 미국, 뉴욕, 동부, 지방, 법원, SEC,...
# 7     [함께, 스테이, 코인, USDP, 개발, 암호, 화폐, 실생활, 응용, 수준, 높...
# 8     [현지, 시간, 블록, 보도, 중국, 금융, 포럼, 中國, 四十人論壇, 행사, 중국...
# 9     [암호, 화폐, 전문, 미디어, 코인, 텔레, 그래프, 걸프, 뉴스, Gulf, N...
# 10    [이번, 행사, 코인, Coinin, 블록, 글로벌, BLOCK, GLOBAL, 비...
# 11    [매일, 출석, 비트코인, 획득, 무료, 가입, 매일, 시간, 광고, 고정, 수입,...
# 12    [찰리, 자신, 트위터, 통해, 올해, 라이트, 코인, 사실상, 코드, 업데이트, ...
# 13    [인원, 프로젝트, 속한, 기업, 재단, 정보, 비즈니스, 모델, 시장, 기술, 평...
# 14    [매일, 출석, 비트코인, 획득, 무료, 가입, 매일, 시간, 광고, 고정, 수입,...
# 15    [카카오, 클레이튼, 통용, 암호, 화폐, 클레이, 비록, 클레이튼, 기반, 코스모...
# 16    [현지, 시간, 코인, 데스크, 보도, IBM, 네트워크, 지원, 브라우저, 관련,...
# 17    [현지, 시간, UAE, 매체, 걸프, 뉴스, Gulf, News, 보도, UAE,...
# 18    [경기도, 경제, 과학, 흥원, 공동, 주최, 열리, 이번, 대회, 블록체인, 기반...
# 19    [국회, 법조, 사처, 최근, 발간, 국감, 분석, 보고서, 블록체인, 암호, 화폐...
# 20    [현지, 시간, 코인, 데스크, 보도, 호주, 커먼, 웰스, 은행, 소유, 뉴질랜드...
# 21    [현지, 시간, 코인, 텔레, 그래프, 타이슨, 블록체인, 기반, 엔터, 플랫, 파...
# 22    [현지, 시간, 코인, 텔레, 그래프, 보도, 정기, 주주, 총회, 스리, 무케시,...
# 23    [카카오, 카카오톡, 카카오, 암호, 화폐, 지갑, 클립, 페이지, 공개, 클립, ...
# 24    [블록체인, 활용, 기존, 마일리지, 서비스, 확대, 건강, 기능, 운동, 통합, ...
# 0     [SEC, 현지, 시간, 비트코인, 상장지수, 펀드, ETF, 승인, 관한, 결정,...
# 1     [미국, 중국, 환율, 작국, 지정, 일본, 경제, 보복, 조치, 북한, 단거리, ...
# 2     [인민, 은행, 최근, 다양, 경로, 통해, 법정, 디지털, 화폐, 출시, 관련, ...
# 3     [현지, 시간, 코인, 데스크, 비트코인, 단기, 챠트, 약세, bears, 상황,...
# 4     [출처, Coindesk, Created, with, TradingView, 현지,...
# 5     [CNBC, BOA, 미국, 경제, 헤드, 미셸, 마이어, 일자, 고객, 노트, 내...
# 6     [가장, 차이점, 퍼블, 프라이빗, 단어, 의미, 열려, 퍼블릭, 블록체인, 모두,...
# 7     [온톨로지, 네오, 퀀텀, 함께, 중국, 대표, 퍼블릭, 블록체인, 하나, 신뢰, ...
# 8     [인원, 밝힌, 상장, 심사, 기준, 프로젝트, 속한, 기업, 재단, 정보, 비즈니...
# 9     [사진, 카카오톡, 캡처, 안드로이드, 최신, 버전, 카카오톡, 전체, 서비스, 클...
# 10    [현지, 시간, 코인, 텔레, 그래프, 트위터, 통해, 미국인, 바이, 낸스, 트론...
# 11    [이번, 강좌, 블록체인, 업계, 종사자, 일반인, 참석, 주제, 블록체인, 개념,...
# 12    [비트, 특정, 조건, 로그인, 발생, 고객, 카카오톡, 메시지, 발송, 비트, 계...
# 13    [현지, 시간, 코인, 데스크, XRP, 가격, 챠트, 이동, 평균, MA, MA,...
# 14    [신한은행, 카카오, 블록체인, 기술, 계열사, 그라운드, 블록체인, 기술, 연구소...
# 15    [블록체인, 핀테크, 기업, 벅스, 운영, NHN, 벅스, 블록체인, 기반, 결제,...
# 16    [해시, 그래프, 소프트웨어, 회사, 월즈, Swirlds, Inc, 공동, 창립자...
# 17    [현재, 국회, 여야, 정쟁, 대부분, 장기, 계류, 금융, 혁신, 초석, 불리, ...
# Name: main article, dtype: object

# %%
article_contents = tokenized_doc.values.tolist()

# %%
len(tokenized_doc)
# Out:
# 43

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
# article_contents_tfidf

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 2262

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 2262

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.004*"부리" + 0.004*"피싱" + 0.004*"경향" + 0.004*"안내" + 0.004*"늘려" + 0.004*"계열사" + 0.004*"디바이스" + 0.004*"로그아웃"')
# (1, '0.005*"보인다" + 0.005*"교묘" + 0.005*"효용" + 0.005*"담당" + 0.005*"System" + 0.005*"노무라" + 0.005*"미래" + 0.005*"대학"')
# (2, '0.005*"봉착" + 0.005*"유행" + 0.005*"진다" + 0.005*"대처" + 0.005*"로그인" + 0.005*"행사장" + 0.005*"CHAI" + 0.005*"주제"')
# (3, '0.004*"본인" + 0.004*"즉시" + 0.004*"기승" + 0.004*"상세" + 0.004*"즉각" + 0.004*"IP" + 0.004*"버튼" + 0.004*"조건"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1208140535547278672893358397"></div>
# <script type="text/javascript">
#
# var ldavis_el1208140535547278672893358397_data = {"mdsDat": {"x": [0.1439549616209663, -0.11574382681095037, -0.014717571532458047, -0.013493563277557841], "y": [0.05291114167212093, 0.08235469638674942, -0.07353561663089553, -0.061730221427974734], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [25.681533813476562, 25.202564239501953, 24.68933868408203, 24.426565170288086]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 2.050360679626465, 2.0503602027893066, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.0503602027893066, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.050360679626465, 2.05 ...

# %%
sentences = article_contents

# %%
length1 = 0
for setence in sentences :
    length1 += len(setence) 
length1
# Out:
# 7704

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 2262

# %%
# model.wv.vocab

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: ""
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/lm/counter.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence, defaultdict

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 2262

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 1992.3301697254408

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.44679618482615224

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 0.03197921737733942

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
len(tf_idf_value)
# Out:
# 2262

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 기타
# Out:
#                                                raw_data  word  cluster  \
# 1218  [0.004267056938260794, 0.0013245641021057963, ...    터치        0
# 500   [-0.0007784839253872633, -0.001096494495868682...   리오넬        0
# 1626  [0.002437293529510498, -0.004921742249280214, ...    훨씬        0
# 1934  [-6.503444456029683e-05, -0.001809066627174615...   스러운        0
# 76    [0.002266909461468458, -0.0033422387205064297,...    판단        0
# 598   [0.00125649303663522, -0.0021715860348194838, ...    준비        0
# 412   [0.002044907072558999, -0.00045403395779430866...    조치        0
# 372   [0.0027401235420256853, 0.0013300632126629353,...    요율        0
# 2209  [-0.001710758893750608, -0.004165462218225002,...    타타        0
# 1896  [0.0019310289062559605, -0.0032531365286558867...    신규        0
# 287   [-0.0011200313456356525, -0.002674084855243563...    쓰리        0
# 1535  [0.0032256038393825293, -0.0030466909520328045...    쿠폰        0
# 811   [-0.001565841375850141, -0.004712445195764303,...    요인        0
# 343   [0.0044808583334088326, -0.002351596252992749,...    작년        0
# 31    [0.00126910419203341, -0.0019034530268982053, ...    강력        0
# 1601  [-0.0007965738186612725, 0.002195470267906785,...  데이비드        0
# 1154  [0.0032412190921604633, 0.0003640947979874909,...    달성        0
# 228   [-0.002407793654128909, 0.0026877743657678366,...  트레이딩        0
# 1361  [0.0026339024771004915, 0.00017085984291043133...    돼야        0
# 358   [5.176119157113135e-05, 0.0021673673763871193,...    국가        0
#
#                                                centroid  distance     tfidf  \
# 1218  [0.00026335637, -0.0003926025, -0.00014132285,...  0.536675  0.005119
# 500   [0.00026335637, -0.0003926025, -0.00014132285,...  0.556305  0.002560
# 1626  [0.00026335637, -0.0003926025, -0.00014132285,...  0.618068  0.002560
# 1934  [0.00026335637, -0.0003926025, -0.00014132285,...  0.628917  0.005119
# 76    [0.00026335637, -0.0003926025, -0.00014132285,...  0.641835  0.012798
# 598   [0.00026335637, -0.0003926025, -0.00014132285,...  0.651510  0.017918
# 412   [0.00026335637, -0.0003926025, -0.00014132285,...  0.650388  0.015358
# 372   [0.00026335637, -0.0003926025, -0.00014132285,...  0.641388  0.002560
# 2209  [0.00026335637, -0.0003926025, -0.00014132285,...  0.653397  0.007679
# 1896  [0.00026335637, -0.0003926025, -0.00014132285,...  0.655280  0.002560
# 287   [0.00026335637, -0.0003926025, -0.00014132285,...  0.659316  0.002560
# 1535  [0.00026335637, -0.0003926025, -0.00014132285,...  0.659402  0.002560
# 811   [0.00026335637, -0.0003926025, -0.00014132285,...  0.664749  0.005119
# 343   [0.00026335637, -0.0003926025, -0.00014132285,...  0.684505  0.007679
# 31    [0.00026335637, -0.0003926025, -0.00014132285,...  0.684151  0.005119
# 1601  [0.00026335637, -0.0003926025, -0.00014132285,...  0.682890  0.002560
# 1154  [0.00026335637, -0.0003926025, -0.00014132285,...  0.690298  0.005119
# 228   [0.00026335637, -0.0003926025, -0.00014132285,...  0.693263  0.007679
# 1361  [0.00026335637, -0.0003926025, -0.00014132285,...  0.690335  0.002560
# 358   [0.00026335637, -0.0003926025, -0.00014132285,...  0.707191  0.015358
#
#          score closer#
# 1218  1.531555     NaN
# 500   1.553745     NaN
# 1626  1.615509     NaN
# 1934  1.623798     NaN
# 76    1.629036     NaN
# 598   1.633593     NaN
# 412   1.635030     NaN
# 372   1.638829     NaN
# 2209  1.645718     NaN
# 1896  1.652720     NaN
# 287   1.656756     NaN
# 1535  1.656842     NaN
# 811   1.659629     NaN
# 343   1.676826     NaN
# 31    1.679031     NaN
# 1601  1.680330     NaN
# 1154  1.685179     NaN
# 228   1.685584     NaN
# 1361  1.687776     NaN
# 358   1.691833     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회이슈
# Out:
#                                                raw_data  word  cluster  \
# 615   [-0.00472745718434453, 0.003162353066727519, 0...    무역        1
# 1548  [0.004684587940573692, -0.0008593099191784859,...    여기        1
# 1943  [0.000990679836831987, -0.0034024897031486034,...    열람        1
# 2164  [0.0005830375012010336, 0.00312401307746768, -...   수수료        1
# 1850  [0.0007244447479024529, -0.003497963771224022,...   가리켰        1
# 1299  [0.003714198712259531, -0.0018526569474488497,...    연수        1
# 241   [-0.0048242127522826195, 0.0029784238431602716...    성과        1
# 2084  [0.00020651673548854887, 0.0015619593905285, 0...   UDC        1
# 523   [0.0029965799767524004, -0.0032494980841875076...   신봉자        1
# 1083  [-0.0043656728230416775, 0.0004521497758105397...    장기        1
# 985   [0.000660031451843679, 0.0012836555251851678, ...    한국        1
# 1946  [-0.0001977887295652181, -0.003135361475870013...   유튜브        1
# 2045  [-0.0031904135830700397, 0.0028627098072320223...   강연자        1
# 1092  [-0.002639765152707696, -0.006050275173038244,...  비즈니스        1
# 769   [-0.0023449482396245003, -0.002587544033303857...    접근        1
# 2189  [0.0040591442957520485, -0.002007900271564722,...   루이자        1
# 1137  [0.003521499689668417, 0.0002713321300689131, ...  Case        1
# 1725  [0.001572471228428185, 0.0026152783539146185, ...    유통        1
# 1402  [0.004876280669122934, -0.0008005964918993413,...    여자        1
# 68    [-0.001720751286484301, -0.003552447073161602,...    수요        1
# 263   [-0.0006104659987613559, -0.002047167159616947...    이득        1
# 2048  [-0.0013949796557426453, 0.00299152173101902, ...    경영        1
# 1270  [0.00189197005238384, 0.0014825636753812432, -...    흥원        1
# 468   [0.0026693325489759445, 0.0013220502296462655,...    우려        1
# 1987  [-8.633280958747491e-05, 0.0029563193675130606...    철저        1
# 180   [0.004008573479950428, 0.004123594146221876, -...    산하        1
# 52    [-0.0008421241655014455, 0.002943147672340274,...   트위터        1
# 1213  [-0.0014923264971002936, -0.003245985601097345...    일괄        1
# 249   [-0.0002734362496994436, 0.002196570159867406,...   활발히        1
# 310   [-0.002376729156821966, -0.0005656731082126498...    고려        1
#
#                                                centroid  distance     tfidf  \
# 615   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.641005  0.023037
# 1548  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.642926  0.005119
# 1943  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.649265  0.002560
# 2164  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.659272  0.005119
# 1850  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.670701  0.010239
# 1299  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.663676  0.002560
# 241   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.668112  0.002560
# 2084  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.682910  0.002560
# 523   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.686670  0.002560
# 1083  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.702584  0.015358
# 985   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.700449  0.012798
# 1946  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.704061  0.015358
# 2045  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.698024  0.002560
# 1092  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.732459  0.028156
# 769   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.725365  0.020477
# 2189  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.707700  0.002560
# 1137  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.708185  0.002560
# 1725  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.713716  0.007679
# 1402  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.711203  0.005119
# 68    [0.00043404114, -6.052582e-05, -0.00033216184,...  0.725075  0.017918
# 263   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.714136  0.002560
# 2048  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.714418  0.002560
# 1270  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.714942  0.002560
# 468   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.725924  0.012798
# 1987  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.716935  0.002560
# 180   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.726501  0.007679
# 52    [0.00043404114, -6.052582e-05, -0.00033216184,...  0.736475  0.015358
# 1213  [0.00043404114, -6.052582e-05, -0.00033216184,...  0.727586  0.002560
# 249   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.728055  0.002560
# 310   [0.00043404114, -6.052582e-05, -0.00033216184,...  0.731013  0.005119
#
#          score closer#
# 615   1.617968     NaN
# 1548  1.637807     NaN
# 1943  1.646705     NaN
# 2164  1.654153     NaN
# 1850  1.660463     NaN
# 1299  1.661116     NaN
# 241   1.665552     NaN
# 2084  1.680350     NaN
# 523   1.684111     NaN
# 1083  1.687226     NaN
# 985   1.687651     NaN
# 1946  1.688703     NaN
# 2045  1.695464     NaN
# 1092  1.704303     NaN
# 769   1.704888     NaN
# 2189  1.705140     NaN
# 1137  1.705625     NaN
# 1725  1.706037     NaN
# 1402  1.706084     NaN
# 68    1.707157     NaN
# 263   1.711577     NaN
# 2048  1.711858     NaN
# 1270  1.712383     NaN
# 468   1.713125     NaN
# 1987  1.714375     NaN
# 180   1.718822     NaN
# 52    1.721117     NaN
# 1213  1.725026     NaN
# 249   1.725496     NaN
# 310   1.725894     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(30)   # 제도
# Out:
#                                                raw_data    word  cluster  \
# 809   [-0.003247638698667288, -0.0013298643752932549...     벌금형        2
# 1707  [0.002045474713668227, -0.0001319990260526538,...      경로        2
# 1663  [0.0005791726289317012, -0.003703431226313114,...  Brexit        2
# 2054  [0.004063463769853115, -0.0007452203426510096,...     뛰어넘        2
# 359   [-0.0005394151667132974, 0.0013203826965764165...      조세        2
# 356   [-0.000379768549464643, -0.004621398635208607,...    뉴질랜드        2
# 2161  [0.0024482770822942257, 0.003424575552344322, ...    CHAI        2
# 2027  [4.096093471162021e-05, 0.0023503012489527464,...      로고        2
# 890   [0.0022765514440834522, 0.00250716763548553, 0...      체계        2
# 1861  [-0.0013085603713989258, 0.0030430699698626995...      에선        2
# 481   [0.0009484397596679628, 0.003706997726112604, ...     피난처        2
# 1920  [-0.0023443419486284256, -0.000412609253544360...      단점        2
# 154   [-0.0003598806797526777, 0.0010365834459662437...     분위기        2
# 146   [0.004946800414472818, -0.0048714373260736465,...     올려놓        2
# 846   [5.3063933592056856e-05, 0.0005227860528975725...      장춘        2
# 1797  [0.003768508555367589, 0.00220934278331697, 0....      능력        2
# 450   [-0.003234782023355365, 0.0035882722586393356,...      향후        2
# 396   [-0.0034583541564643383, 0.0042511168867349625...      많이        2
# 1689  [-0.0031738418620079756, 0.0003282385878264904...      재산        2
# 2065  [0.000935661606490612, -0.0045751240104436874,...      고란        2
# 2237  [-0.0008663902408443391, -0.003614560700953006...      맞춰        2
# 1373  [0.0029666165355592966, 3.741517139133066e-05,...      호주        2
# 403   [0.0009324673446826637, 0.0020450230222195387,...     상품권        2
# 1834  [0.004800944123417139, 0.0033532034140080214, ...      안착        2
# 2169  [-0.0026997963432222605, -0.000696285918820649...     신현성        2
# 506   [0.0009240043582394719, 0.0021850704215466976,...      생각        2
# 1055  [-0.003871628548949957, -0.004746288992464542,...     개발자        2
# 1034  [-0.004101122263818979, -0.0036202529445290565...     사실상        2
# 1892  [-0.0016704326262697577, -0.001163906417787075...     자동차        2
# 1241  [-0.0003693742910400033, -0.004816809669137001...   Basil        2
#
#                                                centroid  distance     tfidf  \
# 809   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.551437  0.002560
# 1707  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.641178  0.005119
# 1663  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.640533  0.002560
# 2054  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.662631  0.002560
# 359   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.666334  0.005119
# 356   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.677695  0.015358
# 2161  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.669273  0.002560
# 2027  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.670420  0.002560
# 890   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.695275  0.015358
# 1861  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.686670  0.005119
# 481   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.685989  0.002560
# 1920  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.686772  0.002560
# 154   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.698545  0.010239
# 146   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.691304  0.002560
# 846   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.702428  0.010239
# 1797  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.704428  0.007679
# 450   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.710288  0.010239
# 396   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.707876  0.005119
# 1689  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.707000  0.002560
# 2065  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.711998  0.005119
# 2237  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.709456  0.002560
# 1373  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.710615  0.002560
# 403   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.712051  0.002560
# 1834  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.713846  0.002560
# 2169  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.714701  0.002560
# 506   [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.728544  0.015358
# 1055  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.718938  0.005119
# 1034  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.718483  0.002560
# 1892  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.723009  0.002560
# 1241  [-0.00020182069, 0.00027401865, 0.0010298939, ...  0.724201  0.002560
#
#          score closer#
# 809   1.548878     NaN
# 1707  1.636059     NaN
# 1663  1.637973     NaN
# 2054  1.660071     NaN
# 359   1.661214     NaN
# 356   1.662337     NaN
# 2161  1.666713     NaN
# 2027  1.667860     NaN
# 890   1.679917     NaN
# 1861  1.681550     NaN
# 481   1.683430     NaN
# 1920  1.684213     NaN
# 154   1.688307     NaN
# 146   1.688745     NaN
# 846   1.692189     NaN
# 1797  1.696749     NaN
# 450   1.700049     NaN
# 396   1.702756     NaN
# 1689  1.704440     NaN
# 2065  1.706879     NaN
# 2237  1.706896     NaN
# 1373  1.708055     NaN
# 403   1.709492     NaN
# 1834  1.711287     NaN
# 2169  1.712142     NaN
# 506   1.713186     NaN
# 1055  1.713819     NaN
# 1034  1.715923     NaN
# 1892  1.720449     NaN
# 1241  1.721642     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(30)  # 비즈시도
# Out:
#                                                raw_data  word  cluster  \
# 2     [0.0008067922317422926, -0.006732206791639328,...    화폐        3
# 113   [-0.0023295623250305653, -0.008116278797388077...  블록체인        3
# 13    [0.0026376850437372923, -0.004822050221264362,...  비트코인        3
# 1     [-0.00101062236353755, -0.008688279427587986, ...    암호        3
# 8     [-0.0003814241208601743, -0.007905741222202778...   서비스        3
# 79    [-0.0010307886404916644, -0.001418926054611802...    기술        3
# 53    [0.0017234169645234942, -0.0025488317478448153...    통해        3
# 95    [-7.921516225906089e-05, -0.001674899947829544...    코인        3
# 44    [-0.004038866143673658, -0.007657797075808048,...   디지털        3
# 151   [0.0022172594908624887, -0.0028320348355919123...    거래        3
# 425   [-0.0020790270064026117, -0.007372395601123571...    기업        3
# 514   [0.0010561742819845676, -6.779255636502057e-05...    대표        3
# 29    [-0.002076873555779457, -0.006178220734000206,...    참여        3
# 230   [0.0015655518509447575, -0.004581556189805269,...    달러        3
# 585   [-0.00042911982745863497, -0.00196943455375731...    개발        3
# 620   [-0.001044536242261529, -0.003956585191190243,...    중국        3
# 82    [0.0018344609998166561, -0.0051891678012907505...    가치        3
# 1106  [-0.0005809866706840694, -0.00530267832800746,...    사업        3
# 45    [0.0011228857329115272, -0.005158654414117336,...    자산        3
# 999   [0.001097563887014985, -0.002499041613191366, ...  프로젝트        3
# 50    [0.0002618625294417143, -0.0031187913846224546...    시간        3
# 1091  [0.002716474235057831, -0.0023205610923469067,...    정보        3
# 315   [-0.003860041033476591, -0.006605139933526516,...    가능        3
# 126   [-0.0006593645666725934, -0.001308672712184488...    플랫        3
# 736   [-0.0039931656792759895, -0.004267282783985138...    기존        3
# 162   [0.0019637751393020153, -0.0007502514054067433...    운영        3
# 647   [-0.005169025622308254, -0.0047469851560890675...    산업        3
# 7     [-0.0006415399839170277, -0.000458178197732195...    금융        3
# 933   [-0.0018918794812634587, 0.0019681043922901154...   그래프        3
# 250   [-0.004849207121878862, -0.0044496203772723675...    토큰        3
#
#                                                centroid  distance     tfidf  \
# 2     [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.221220  0.401866
# 113   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.171557  0.309718
# 13    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.202070  0.330196
# 1     [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.263048  0.302039
# 8     [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.224089  0.120304
# 79    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.284257  0.135662
# 53    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.280194  0.117744
# 95    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.297708  0.130542
# 44    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.271843  0.099827
# 151   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.264803  0.089588
# 425   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.290406  0.089588
# 514   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.260521  0.053753
# 29    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.281654  0.063991
# 230   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.324298  0.097267
# 585   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.317007  0.087028
# 620   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.310847  0.079349
# 82    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.328304  0.079349
# 1106  [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.311539  0.056312
# 45    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.351508  0.089588
# 999   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.345685  0.081909
# 50    [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.361353  0.089588
# 1091  [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.325836  0.053753
# 315   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.344440  0.066551
# 126   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.358884  0.076790
# 736   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.332363  0.046074
# 162   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.367287  0.076790
# 647   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.347326  0.056312
# 7     [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.391898  0.097267
# 933   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.335880  0.040954
# 250   [-0.0002880071, -0.00083038455, 0.0005815058, ...  0.427063  0.117744
#
#          score closer#
# 2     0.819355     NaN
# 113   0.861839     NaN
# 13    0.871874     NaN
# 1     0.961008     NaN
# 8     1.103785     NaN
# 79    1.148596     NaN
# 53    1.162449     NaN
# 95    1.167165     NaN
# 44    1.172016     NaN
# 151   1.175215     NaN
# 425   1.200818     NaN
# 514   1.206768     NaN
# 29    1.217662     NaN
# 230   1.227031     NaN
# 585   1.229979     NaN
# 620   1.231498     NaN
# 82    1.248955     NaN
# 1106  1.255227     NaN
# 45    1.261920     NaN
# 999   1.263776     NaN
# 50    1.271765     NaN
# 1091  1.272083     NaN
# 315   1.277889     NaN
# 126   1.282095     NaN
# 736   1.286290     NaN
# 162   1.290497     NaN
# 647   1.291013     NaN
# 7     1.294631     NaN
# 933   1.294926     NaN
# 250   1.309319     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 기타
# Out:
# 479

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 사회이슈
# Out:
# 459

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 제도
# Out:
# 451

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 비즈시도
# Out:
# 873

# %%
temp_cluster_result['category'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result['label'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 13 # 기타

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 5 #  사회이슈

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label'] = 10 #  제도

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 7 # 비즈

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 1.869465378943944

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [2 2 2 ... 1 1 3]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -1.8694654

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.0101779

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(50,'score') # 부정적
# Out:
#                                                raw_data  word  cluster  \
# 112   [0.004886589478701353, 0.0018809057073667645, ...    전망        0
# 168   [0.003974522929638624, -0.0033552669920027256,...    계약        0
# 71    [-0.0005851259338669479, -0.001908532343804836...    상태        0
# 1046  [-0.002394989365711808, -0.0011024263221770525...    방식        0
# 1914  [0.002445179969072342, 0.0007983360555954278, ...   퍼블릭        0
# 55    [-0.0027275686152279377, -0.002356827259063720...    행사        0
# 1947  [-0.0019369262736290693, -0.00329321576282382,...  http        0
# 70    [0.0005302094505168498, 0.0010050128912553191,...    관심        0
# 56    [-0.004037856124341488, 0.0020300138276070356,...   지난달        0
# 78    [-0.0037697514053434134, 0.0001661753340158611...    수석        0
# 930   [0.002623668871819973, -0.003162636887282133, ...    밝힌        0
# 849   [0.0022271445486694574, -0.005512059200555086,...    발행        0
# 1323  [0.0014525499427691102, -0.0014771054266020656...    추진        0
# 1196  [0.0045332107692956924, 0.0001258574629900977,...    노드        0
# 333   [-0.0005849156295880675, 0.0025620998349040747...   지난해        0
# 922   [3.065133569180034e-06, -0.0018904624739661813...    결과        0
# 868   [0.0032310206443071365, -0.003471486736088991,...    민간        0
# 397   [-0.002583505818620324, -0.0005169971263967454...    도입        0
# 270   [0.0029529142193496227, 0.0019755943212658167,...    전날        0
# 1259  [-0.002630944363772869, 0.00025193183682858944...    기회        0
# 2232  [-0.004597164690494537, -0.0003426164330448955...    법안        0
# 1363  [0.0017526274314150214, -0.0012153235729783773...    선정        0
# 621   [-0.0021335245110094547, -0.002482196083292365...    제품        0
# 1013  [0.002954144263640046, 0.0005029199528507888, ...    이어        0
# 204   [-0.003971219062805176, 0.0007715685642324388,...    헤지        0
# 1066  [-0.0037323650903999805, -0.005118846893310547...    실제        0
# 530   [-0.004020220134407282, 0.000406737148296088, ...    유지        0
# 815   [0.0007029575062915683, -0.005288410000503063,...    차례        0
# 1083  [-0.0043656728230416775, 0.0004521497758105397...    장기        0
# 154   [-0.0003598806797526777, 0.0010365834459662437...   분위기        0
# 875   [-0.002516689710319042, 0.001476400881074369, ...    향상        0
# 361   [-0.0029541964177042246, -0.00504173943772912,...    유사        0
# 1581  [-0.002848660573363304, -0.0021742493845522404...    전쟁        0
# 416   [0.001116580213420093, 0.0033473640214651823, ...    영국        0
# 900   [0.001423518406227231, -0.0035164118744432926,...    회장        0
# 1130  [0.0014137355610728264, -0.0031197103671729565...    범위        0
# 906   [-0.0005908341845497489, -0.003487611887976527...  프로세스        0
# 1931  [0.0014227527426555753, -0.004121127538383007,...  대한민국        0
# 1417  [0.0022549296263605356, 0.0008170066284947097,...   타이슨        0
# 1300  [-0.0034572796430438757, -0.000228922915994189...  프로그램        0
# 1037  [-0.003265773644670844, 0.003331260522827506, ...    허브        0
# 1145  [-0.004027719609439373, -0.004301055334508419,...  아이디어        0
# 1115  [-0.0037833561655133963, 0.0003757835656870156...    분배        0
# 178   [0.00211261841468513, -0.0041954778134822845, ...    최고        0
# 392   [0.002295076148584485, 0.00021300985827110708,...    환전        0
# 518   [-0.0019359601428732276, 0.000383711070753634,...    투기        0
# 1383  [-0.0005914077628403902, 0.0037814986426383257...    신뢰        0
# 1004  [0.0039615570567548275, -0.001064903917722404,...    지역        0
# 925   [0.0002294537698617205, 0.00036239204928278923...   하반기        0
# 366   [0.0018050179351121187, -0.0008750035194680095...    마련        0
#
#                                                centroid  distance     tfidf  \
# 112   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029754  0.025597
# 168   [-0.00042663293, -0.00076728466, 0.00044175063...  0.026755  0.020477
# 71    [-0.00042663293, -0.00076728466, 0.00044175063...  0.028953  0.020477
# 1046  [-0.00042663293, -0.00076728466, 0.00044175063...  0.030695  0.020477
# 1914  [-0.00042663293, -0.00076728466, 0.00044175063...  0.028434  0.017918
# 55    [-0.00042663293, -0.00076728466, 0.00044175063...  0.028665  0.017918
# 1947  [-0.00042663293, -0.00076728466, 0.00044175063...  0.026946  0.015358
# 70    [-0.00042663293, -0.00076728466, 0.00044175063...  0.030187  0.017918
# 56    [-0.00042663293, -0.00076728466, 0.00044175063...  0.027787  0.015358
# 78    [-0.00042663293, -0.00076728466, 0.00044175063...  0.028166  0.015358
# 930   [-0.00042663293, -0.00076728466, 0.00044175063...  0.030789  0.017918
# 849   [-0.00042663293, -0.00076728466, 0.00044175063...  0.025935  0.012798
# 1323  [-0.00042663293, -0.00076728466, 0.00044175063...  0.028547  0.015358
# 1196  [-0.00042663293, -0.00076728466, 0.00044175063...  0.029025  0.015358
# 333   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029111  0.015358
# 922   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029179  0.015358
# 868   [-0.00042663293, -0.00076728466, 0.00044175063...  0.026973  0.012798
# 397   [-0.00042663293, -0.00076728466, 0.00044175063...  0.027003  0.012798
# 270   [-0.00042663293, -0.00076728466, 0.00044175063...  0.027012  0.012798
# 1259  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027143  0.012798
# 2232  [-0.00042663293, -0.00076728466, 0.00044175063...  0.029742  0.015358
# 1363  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027361  0.012798
# 621   [-0.00042663293, -0.00076728466, 0.00044175063...  0.027626  0.012798
# 1013  [-0.00042663293, -0.00076728466, 0.00044175063...  0.030817  0.015358
# 204   [-0.00042663293, -0.00076728466, 0.00044175063...  0.028574  0.012798
# 1066  [-0.00042663293, -0.00076728466, 0.00044175063...  0.028790  0.012798
# 530   [-0.00042663293, -0.00076728466, 0.00044175063...  0.028805  0.012798
# 815   [-0.00042663293, -0.00076728466, 0.00044175063...  0.026347  0.010239
# 1083  [-0.00042663293, -0.00076728466, 0.00044175063...  0.031561  0.015358
# 154   [-0.00042663293, -0.00076728466, 0.00044175063...  0.026456  0.010239
# 875   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029239  0.012798
# 361   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029259  0.012798
# 1581  [-0.00042663293, -0.00076728466, 0.00044175063...  0.026748  0.010239
# 416   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029406  0.012798
# 900   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029457  0.012798
# 1130  [-0.00042663293, -0.00076728466, 0.00044175063...  0.029597  0.012798
# 906   [-0.00042663293, -0.00076728466, 0.00044175063...  0.027240  0.010239
# 1931  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027436  0.010239
# 1417  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027643  0.010239
# 1300  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027911  0.010239
# 1037  [-0.00042663293, -0.00076728466, 0.00044175063...  0.027943  0.010239
# 1145  [-0.00042663293, -0.00076728466, 0.00044175063...  0.028290  0.010239
# 1115  [-0.00042663293, -0.00076728466, 0.00044175063...  0.030926  0.012798
# 178   [-0.00042663293, -0.00076728466, 0.00044175063...  0.028429  0.010239
# 392   [-0.00042663293, -0.00076728466, 0.00044175063...  0.025938  0.007679
# 518   [-0.00042663293, -0.00076728466, 0.00044175063...  0.028652  0.010239
# 1383  [-0.00042663293, -0.00076728466, 0.00044175063...  0.028899  0.010239
# 1004  [-0.00042663293, -0.00076728466, 0.00044175063...  0.026393  0.007679
# 925   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029038  0.010239
# 366   [-0.00042663293, -0.00076728466, 0.00044175063...  0.029068  0.010239
#
#          score closer#
# 112   1.004157     NaN
# 168   1.006278     NaN
# 71    1.008476     NaN
# 1046  1.010218     NaN
# 1914  1.010517     NaN
# 55    1.010747     NaN
# 1947  1.011588     NaN
# 70    1.012269     NaN
# 56    1.012429     NaN
# 78    1.012808     NaN
# 930   1.012871     NaN
# 849   1.013136     NaN
# 1323  1.013190     NaN
# 1196  1.013667     NaN
# 333   1.013753     NaN
# 922   1.013821     NaN
# 868   1.014175     NaN
# 397   1.014205     NaN
# 270   1.014214     NaN
# 1259  1.014345     NaN
# 2232  1.014384     NaN
# 1363  1.014563     NaN
# 621   1.014828     NaN
# 1013  1.015459     NaN
# 204   1.015776     NaN
# 1066  1.015991     NaN
# 530   1.016007     NaN
# 815   1.016109     NaN
# 1083  1.016204     NaN
# 154   1.016218     NaN
# 875   1.016441     NaN
# 361   1.016461     NaN
# 1581  1.016509     NaN
# 416   1.016607     NaN
# 900   1.016659     NaN
# 1130  1.016799     NaN
# 906   1.017002     NaN
# 1931  1.017197     NaN
# 1417  1.017405     NaN
# 1300  1.017672     NaN
# 1037  1.017704     NaN
# 1145  1.018051     NaN
# 1115  1.018127     NaN
# 178   1.018190     NaN
# 392   1.018259     NaN
# 518   1.018413     NaN
# 1383  1.018660     NaN
# 1004  1.018715     NaN
# 925   1.018799     NaN
# 366   1.018829     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') # 사회이슈
# Out:
#                                                raw_data   word  cluster  \
# 10    [0.003783297259360552, 0.0028174007311463356, ...     승인        1
# 1175  [-0.001212209346704185, 0.00032608446781523526...    카카오        1
# 578   [-0.003995397128164768, -0.004990849178284407,...     출처        1
# 222   [-0.00470410380512476, -0.00538172572851181, 0...     지속        1
# 256   [-0.0017476801294833422, 0.003004365600645542,...    골드만        1
# 398   [-0.004086816217750311, 0.0012229131534695625,...     상황        1
# 406   [0.004128047730773687, -0.0035685983020812273,...     증권        1
# 140   [0.002077403711155057, -0.001966493669897318, ...     상당        1
# 553   [0.0009310445748269558, 0.002946206135675311, ...     모든        1
# 1337  [0.0010496387258172035, 0.0012170894769951701,...     통화        1
# 81    [0.004210507031530142, -0.0022927240934222937,...     핵심        1
# 1378  [-0.0024859511759132147, 0.0024760242085903883...    윈도우        1
# 1204  [-0.0013900004560127854, -8.439911471214145e-0...     보안        1
# 355   [0.004087589215487242, -0.003242119448259473, ...     주목        1
# 282   [-0.0002117351978085935, -0.000951434776652604...     아래        1
# 557   [0.004036109894514084, -0.0011093757348135114,...     모두        1
# 814   [-0.0038162553682923317, -0.000213339240872301...     여러        1
# 1946  [-0.0001977887295652181, -0.003135361475870013...    유튜브        1
# 1948  [0.003948627505451441, 0.0005198015714995563, ...  bitly        1
# 293   [-0.0030829233583062887, -0.000583416840527206...     공동        1
#
#                                                centroid  distance     tfidf  \
# 10    [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.029715  0.028156
# 1175  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.025876  0.023037
# 578   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.026895  0.023037
# 222   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.025896  0.020477
# 256   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028619  0.023037
# 398   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.027064  0.020477
# 406   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.027212  0.020477
# 140   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.030103  0.023037
# 553   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.026929  0.017918
# 1337  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.030028  0.020477
# 81    [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.027569  0.017918
# 1378  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.030537  0.020477
# 1204  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028198  0.017918
# 355   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028232  0.017918
# 282   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028324  0.017918
# 557   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028572  0.017918
# 814   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.031421  0.020477
# 1946  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028120  0.015358
# 1948  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028169  0.015358
# 293   [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028237  0.015358
#
#          score closer#
# 10    1.001558     NaN
# 1175  1.002839     NaN
# 578   1.003858     NaN
# 222   1.005419     NaN
# 256   1.005582     NaN
# 398   1.006586     NaN
# 406   1.006735     NaN
# 140   1.007066     NaN
# 553   1.009011     NaN
# 1337  1.009551     NaN
# 81    1.009652     NaN
# 1378  1.010060     NaN
# 1204  1.010280     NaN
# 355   1.010314     NaN
# 282   1.010406     NaN
# 557   1.010655     NaN
# 814   1.010944     NaN
# 1946  1.012762     NaN
# 1948  1.012811     NaN
# 293   1.012879     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 투자
# Out:
#                                               raw_data  word  cluster  \
# 2    [0.0008067922317422926, -0.006732206791639328,...    화폐        2
# 13   [0.0026376850437372923, -0.004822050221264362,...  비트코인        2
# 113  [-0.0023295623250305653, -0.008116278797388077...  블록체인        2
# 1    [-0.00101062236353755, -0.008688279427587986, ...    암호        2
# 79   [-0.0010307886404916644, -0.001418926054611802...    기술        2
# 95   [-7.921516225906089e-05, -0.001674899947829544...    코인        2
# 8    [-0.0003814241208601743, -0.007905741222202778...   서비스        2
# 250  [-0.004849207121878862, -0.0044496203772723675...    토큰        2
# 53   [0.0017234169645234942, -0.0025488317478448153...    통해        2
# 21   [0.0021426542662084103, -0.002758860122412443,...    시장        2
# 108  [0.0031070797704160213, -0.0012035948457196355...    관련        2
# 44   [-0.004038866143673658, -0.007657797075808048,...   디지털        2
# 7    [-0.0006415399839170277, -0.000458178197732195...    금융        2
# 230  [0.0015655518509447575, -0.004581556189805269,...    달러        2
# 156  [0.0023265425115823746, -0.0034525664523243904...    가격        2
# 258  [-0.0022650007158517838, -0.003233117749914527...    은행        2
# 151  [0.0022172594908624887, -0.0028320348355919123...    거래        2
# 45   [0.0011228857329115272, -0.005158654414117336,...    자산        2
# 425  [-0.0020790270064026117, -0.007372395601123571...    기업        2
# 50   [0.0002618625294417143, -0.0031187913846224546...    시간        2
#
#                                               centroid  distance     tfidf  \
# 2    [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.036873  0.401866
# 13   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.036293  0.330196
# 113  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.036415  0.309718
# 1    [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.033197  0.302039
# 79   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.029778  0.135662
# 95   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.033132  0.130542
# 8    [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.031214  0.120304
# 250  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.032927  0.117744
# 53   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.034370  0.117744
# 21   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.026831  0.110065
# 108  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.030638  0.102386
# 44   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.030538  0.099827
# 7    [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.030812  0.097267
# 230  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.031553  0.097267
# 156  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.029259  0.092148
# 258  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.027473  0.089588
# 151  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.028457  0.089588
# 45   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.029675  0.089588
# 425  [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.031240  0.089588
# 50   [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.031508  0.089588
#
#         score closer#
# 2    0.635007     NaN
# 13   0.706098     NaN
# 113  0.726696     NaN
# 1    0.731157     NaN
# 79   0.894116     NaN
# 95   0.902589     NaN
# 8    0.910910     NaN
# 250  0.915183     NaN
# 53   0.916626     NaN
# 21   0.916766     NaN
# 108  0.928252     NaN
# 44   0.930712     NaN
# 7    0.933545     NaN
# 230  0.934286     NaN
# 156  0.937112     NaN
# 258  0.937885     NaN
# 151  0.938869     NaN
# 45   0.940087     NaN
# 425  0.941652     NaN
# 50   0.941920     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 제도
# Out:
#                                                raw_data            word  \
# 252   [-0.0047745481133461, -0.003271420719102025, 0...  emailprotected
# 36    [-0.004030425101518631, -0.0001549128210172057...              업체
# 408   [-0.004668946843594313, 0.0020120402332395315,...              기능
# 444   [0.004544039256870747, -0.0010244391160085797,...              저장
# 1062  [-0.0027618829626590014, -0.001214552554301917...              작업
# 1176  [-0.004464234225451946, 0.0003769258037209511,...            클레이튼
# 12    [-0.0013124772813171148, 0.002103555714711547,...              백트
# 231   [-0.004661197308450937, -0.0018196195596829057...              규모
# 320   [-0.004789374768733978, 0.000668381224386394, ...              더욱
# 269   [-0.004676738753914833, 0.0006664841785095632,...              마켓
# 466   [0.002695543924346566, 0.0013548682909458876, ...              지적
# 1494  [0.0028718183748424053, 0.0023515447974205017,...              차이
# 570   [-0.000566290516871959, -0.0021002425346523523...              검토
# 60    [0.004237642511725426, -0.004220239818096161, ...             관계자
# 1500  [-0.00012034289829898626, -0.00518280453979969...              지갑
# 1092  [-0.002639765152707696, -0.006050275173038244,...            비즈니스
# 1187  [0.0015473610255867243, 0.003491163020953536, ...            브라우저
# 6     [0.0020970881450921297, -0.0035690998192876577...              뉴욕
# 136   [0.0039051834028214216, -0.0026423055678606033...              직접
# 37    [-0.004782404750585556, -2.1978850782033987e-0...              펀드
#
#       cluster                                           centroid  distance  \
# 252         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.035191
# 36          3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.027049
# 408         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.029267
# 444         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.027555
# 1062        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028371
# 1176        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.029340
# 12          3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.030519
# 231         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.029998
# 320         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.030802
# 269         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028393
# 466         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028471
# 1494        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.026247
# 570         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028891
# 60          3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.030130
# 1500        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.030386
# 1092        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.030891
# 1187        3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028562
# 6           3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028813
# 136         3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.026302
# 37          3  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.026615
#
#          tfidf     score closer#
# 252   0.051193  0.983998     NaN
# 36    0.038395  0.988654     NaN
# 408   0.035835  0.993432     NaN
# 444   0.033276  0.994279     NaN
# 1062  0.033276  0.995095     NaN
# 1176  0.033276  0.996065     NaN
# 12    0.033276  0.997243     NaN
# 231   0.030716  0.999282     NaN
# 320   0.030716  1.000086     NaN
# 269   0.028156  1.000237     NaN
# 466   0.028156  1.000314     NaN
# 1494  0.025597  1.000650     NaN
# 570   0.028156  1.000735     NaN
# 60    0.028156  1.001974     NaN
# 1500  0.028156  1.002230     NaN
# 1092  0.028156  1.002735     NaN
# 1187  0.025597  1.002966     NaN
# 6     0.025597  1.003216     NaN
# 136   0.023037  1.003265     NaN
# 37    0.023037  1.003578     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #부정적
# Out:
# 372

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #사회이슈
# Out:
# 372

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #투자
# Out:
# 366

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #제도
# Out:
# 350

# %%
temp_cluster_result1['category'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 2 # 부정적

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 5 # 사회이슈

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 11 # 투자

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 10 # 제도

# %%
temp_cluster_result1
# Out:
#                                                raw_data word  cluster  \
# 0     [-0.004866092465817928, -0.005518927238881588,...   최근        2
# 1     [-0.00101062236353755, -0.008688279427587986, ...   암호        2
# 2     [0.0008067922317422926, -0.006732206791639328,...   화폐        2
# 3     [0.004555738531053066, -0.0030954002868384123,...   전문        3
# 4     [0.000570414587855339, -0.0031863132026046515,...   매체        1
# ...                                                 ...  ...      ...
# 2257  [-0.001378706656396389, -0.003764946013689041,...  김병욱        1
# 2258  [7.055130845401436e-05, 0.0005977491964586079,...   의원        3
# 2259  [0.0007675183587707579, -0.0008845218108035624...   발의        1
# 2260  [0.003057453315705061, 0.0011040342506021261, ...  흩어진        1
# 2261  [-0.0026723064947873354, -0.00116132537368685,...   중점        3
#
#                                                centroid  distance     tfidf  \
# 0     [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.029310  0.071670
# 1     [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.033197  0.302039
# 2     [0.00011552463, -0.0022046645, 0.0012688885, 0...  0.036873  0.401866
# 3     [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.025593  0.020477
# 4     [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028417  0.007679
# ...                                                 ...       ...       ...
# 2257  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028983  0.002560
# 2258  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.026203  0.002560
# 2259  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028657  0.002560
# 2260  [0.00039137297, 0.0001678337, -0.0003709259, 0...  0.028735  0.002560
# 2261  [-9.096461e-05, -0.00013699812, 0.0008135314, ...  0.028422  0.002560
#
#          score closer#  category  label
# 0     0.957640     NaN         2   11.0
# 1     0.731157     NaN         2   11.0
# 2     0.635007     NaN         2   11.0
# 3     1.005116     NaN         2   10.0
# 4     1.020738     NaN         2    5.0
# ...        ...     ...       ...    ...
# 2257  1.026424     NaN         2    5.0
# 2258  1.023643     NaN         2   10.0
# 2259  1.026097     NaN         2    5.0
# 2260  1.026176     NaN         2    5.0
# 2261  1.025863     NaN         2   10.0
#
# [2262 rows x 10 columns]

# %%
temp_cluster_result1['Silhouette'] = 0.0101779
temp_cluster_result['Silhouette'] = 0.0101779

# %%
#temp_cluster_result1.to_csv("../cluster/ko_news/2018_down1/ko_news_2018_down1_euclidean.csv")
#temp_cluster_result.to_csv("../cluster/ko_news/2018_down1/ko_news_2018_down1_cosine.csv")

# %%
len(temp_cluster_result1)
# Out:
# 2262

# %%
len(temp_cluster_result)
# Out:
# 2262

# %%
temp_cluster_result1['result'] = 2
temp_cluster_result['result'] = 2

# %%
temp_cluster_result1.to_csv("../cluster/ko_news/2019_down2/ko_news_2019_down2_euclidean.csv")
temp_cluster_result.to_csv("../cluster/ko_news/2019_down2/ko_news_2019_down2_cosine.csv")
