# %%
import pandas as pd
import urllib.request

data = pd.read_csv('../../news/scraping_result/kr/2017_up1/2017_up1_(KR)Hankyung.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/kr/2017_up1/2017_up1_(KR)Tokenpost.csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()
text['main token article'] = text.apply(lambda row: mecab.morphs(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
text['main article']
# Out:
# 0     \n\n\n\n\n일본에서 최초로 설치된 비트코인 ATM. \n\n         ...
# 1     \n\n\n\n\n이더리움 로고. (자료 = Ethereum logo 2014)\n...
# 2     \n\n\n\n\n\n\n                            비트코인...
# 0     스포티파이는 지난 4월 26일 공식 홈페이지를 통해 블록체인 전문 업체인 미디어체인...
# 1     세계 130개국의 은행 및 보험 회사를 회원으로 둔 글로벌 비영리 재단인 Efma와...
# 2     가짜 음식 판매 근절 프로젝트에는 호주 체신부(Australia Post)를 비롯해...
# 3     블록체인 분야는 블로코가 사물인터넷 기기 인증에 블록체인 기술을 활용하는 서비스를 ...
# 4     카카오페이의 이진 사업총괄 이사는 25일 더블록체인과 만나 “내달 첫 선을 보이는 ...
# 5     컨피덴셜 에셋(Confidential Assets)이라고 불리는 새로운 기능은 비트...
# 6     셀런트의 공경순 애널리스트는 지난 3월 20일 서울 포스코P&S타워에서 열린 ‘2회...
# 7     록히드마틴은 블록체인 기술을 개발 프로세스에 적용해 연방 정부에 보다 효율적이고 확...
# 8     소라미츠는 자신들의 주도하는 하이퍼레저 이로하(Hyperledger Iroha) 프...
# 9     국내 물류 및 IT 서비스 업체, 정부 및 국책 연구기관이 함께 물류 산업 발전을 ...
# 10    EY 옵스 체인은 EY와 산업 협력체들이 함께 개발한 블록체인 기반의 서비스와 EY...
# 11    코스콤 기술연구소의 이상기 R&D 부서장은 18일 한국거래소 국제회의실에서 열린 ‘...
# 12    마이크로소프트는 인도내 은행들이 블록체인 기술을 도입, 구축하기 위한 플랫폼인 뱅크...
# 13    블록체인 솔루션 전문업체인 블로코의 김종환 대표는 최근 열린 한 컨퍼런스의 패널토의...
# ...

# %%
# 소문자 적용 , - 문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word.replace("-","") for word in x])
# 공백문자 삭제
text['main token article'] = text['main token article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
text['pos tag'] = text.apply(lambda row: mecab.pos(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
text['pos tag']
# Out:
# 0     [(일본, NNP), (에서, JKB), (최초, NNG), (로, JKB), (설...
# 1     [(이, MM), (더리, VA), (움, EC), (로고, NNG), (., SY...
# 2     [(비트코인, NNP), (투기, NNG), (광풍, NNG), (이, JKS), ...
# 0     [(스포티파이, NNP), (는, JX), (지난, VV+ETM), (4, SN),...
# 1     [(세계, NNG), (130, SN), (개국, NNBC), (의, JKG), (...
# 2     [(가짜, NNG), (음식, NNG), (판매, NNG), (근절, NNG), (...
# 3     [(블록체인, NNG), (분야, NNG), (는, JX), (블로, NNG), (...
# 4     [(카카오, NNP), (페이, NNP), (의, JKG), (이진, NNG), (...
# 5     [(컨피덴셜, NNG), (에, JKB), (셋, NR), ((, SSO), (Co...
# 6     [(셀, NNG), (런, VCP+ETM), (트, NNG), (의, JKG), (...
# 7     [(록히드, NNP), (마틴, NNP), (은, JX), (블록체인, NNG), ...
# 8     [(소라미, NNP), (츠, NNP), (는, JX), (자신, NNG), (들,...
# 9     [(국내, NNG), (물류, NNP), (및, MAJ), (IT, SL), (서비...
# 10    [(EY, SL), (옵스, NNG), (체인, NNG), (은, JX), (EY,...
# 11    [(코스콤, NNP), (기술, NNG), (연구소, NNG), (의, JKG), ...
# 12    [(마이크, NNG), (로, JKB), (소프트, NNG), (는, JX), (인...
# 13    [(블록체인, NNG), (솔루션, NNP), (전문, NNG), (업체, NNG)...
# ...

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('JKS','JX','JKO','JKB','EC','EP','SN','EP+EC')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# from nltk.corpus import stopwords
# stop = stopwords.words('english')
# text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])

# %%
text['main article']
# Out:
# 0     [일본, 최초, 설치, 된, 비트코인, ATM, ., 일본, 산업, 계, 와, 금융...
# 1     [이, 더리, 로고, ., (, 자료, =, Ethereum, logo, ), 비트...
# 2     [비트코인, 투기, 광풍, 불, 있, 다, ., 공식, 화폐, 아닌, 비트코인, 가...
# 0     [스포티파이, 지난, 월, 일, 공식, 홈페이지, 통해, 블록체인, 전문, 업체, ...
# 1     [세계, 개국, 의, 은행, 및, 보험, 회사, 회원, 둔, 글로벌, 비, 영리, ...
# 2     [가짜, 음식, 판매, 근절, 프로젝트, 호주, 체신부, (, Australia, ...
# 3     [블록체인, 분야, 블로, 코, 사물, 인터넷, 기기, 인증, 블록체인, 기술, 활...
# 4     [카카오, 페이, 의, 이진, 사업, 총괄, 사, 는, 일, 더, 블록체인, 과, ...
# 5     [컨피덴셜, 셋, (, Confidential, Assets, ), 이, 불리, 는...
# 6     [셀, 런, 트, 의, 공, 경순, 애널리스트, 지난, 월, 일, 서울, 포스코, ...
# 7     [록히드, 마틴, 블록체인, 기술, 개발, 프로세스, 적용, 해, 연방, 정부, 보...
# 8     [소라미, 츠, 자신, 들, 의, 주도, 하, 는, 하이퍼, 레저, 이로하, (, ...
# 9     [국내, 물류, 및, IT, 서비스, 업체, ,, 정부, 및, 국책, 연구, 기관,...
# 10    [EY, 옵스, 체인, EY, 와, 산업, 협력체, 들, 함께, 개발, 한, 블록체...
# 11    [코스콤, 기술, 연구소, 의, 이상기, R, &, D, 부서장, 일, 한국, 거래...
# 12    [마이크, 소프트, 인도, 내, 은행, 들, 블록체인, 기술, 도입, ,, 구축, ...
# 13    [블록체인, 솔루션, 전문, 업체, 인, 블로, 코, 의, 김종환, 대표, 최근, ...
# ...

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_ko.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 1])
print(tokenized_doc)
#tokenized_doc = text['main article']
#tokenized_doc
# Out:
# 0     [일본, 최초, 설치, 비트코인, ATM, 일본, 산업, 금융, 비트코인, 가상, ...
# 1     [로고, 자료, Ethereum, logo, 비트코인, 디지털, 통화, Ethere...
# 2     [비트코인, 투기, 광풍, 공식, 화폐, 아닌, 비트코인, 가격, 이달, 이상, 치...
# 0     [스포티파이, 공식, 홈페이지, 통해, 블록체인, 전문, 업체, 미디어, 체인, 랩...
# 1     [세계, 개국, 은행, 보험, 회사, 회원, 글로벌, 영리, 재단, Efma, 컨설...
# 2     [가짜, 음식, 판매, 근절, 프로젝트, 호주, 체신부, Australia, Pos...
# 3     [블록체인, 분야, 블로, 사물, 인터넷, 기기, 인증, 블록체인, 기술, 활용, ...
# 4     [카카오, 페이, 이진, 사업, 총괄, 블록체인, 만나, 내달, 보이, 카카오, 공...
# 5     [컨피덴셜, Confidential, Assets, 불리, 새로운, 기능, 비트코인...
# 6     [경순, 애널리스트, 서울, 포스코, 타워, 열린, 슈어, 테크, 블록체인, 컨퍼런...
# 7     [록히드, 마틴, 블록체인, 기술, 개발, 프로세스, 적용, 연방, 정부, 효율, ...
# 8     [소라미, 자신, 주도, 하이퍼, 레저, 이로하, Hyperledger, Iroha...
# 9     [국내, 물류, IT, 서비스, 업체, 정부, 국책, 연구, 기관, 함께, 물류, ...
# 10    [EY, 옵스, 체인, EY, 산업, 협력체, 함께, 개발, 블록체인, 기반, 서비...
# 11    [코스콤, 기술, 연구소, 이상기, 부서장, 한국, 거래소, 국제, 회의실, 열린,...
# 12    [마이크, 소프트, 인도, 은행, 블록체인, 기술, 도입, 구축, 플랫, 뱅크, 체...
# 13    [블록체인, 솔루션, 전문, 업체, 블로, 김종환, 대표, 최근, 열린, 컨퍼런스,...
# ...

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 2112

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 2112

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.009*"판도" + 0.009*"는다" + 0.009*"재력" + 0.009*"실행" + 0.009*"일곱" + 0.009*"스왑" + 0.009*"불록" + 0.009*"질문"')
# (1, '0.011*"걸리" + 0.011*"시큐어" + 0.011*"여섯" + 0.011*"똑같" + 0.011*"영수증" + 0.011*"지문" + 0.011*"성향" + 0.011*"기다릴"')
# (2, '0.010*"대시보드" + 0.010*"서명" + 0.010*"선천" + 0.010*"고가" + 0.010*"거버넌스" + 0.010*"SAP" + 0.010*"소매" + 0.010*"도모"')
# (3, '0.011*"Nexsign" + 0.011*"응용" + 0.011*"바꿀" + 0.011*"문제점" + 0.011*"판매자" + 0.011*"역량" + 0.011*"역사" + 0.011*"Payment"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el929801406609924999204919117901"></div>
# <script type="text/javascript">
#
# ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 2112

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: ""
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/nltk/lm/counter.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence, defaultdict

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 2112

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 1572.7509593706843

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.5201155922447772

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 0.02989619450857937

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 사회이슈
# Out:
#                                                raw_data       word  cluster  \
# 1074  [-0.0021131890825927258, -0.003762339008972048...         제품        0
# 1201  [0.0008107236353680491, -0.0019227458396926522...         요구        0
# 507   [-0.00037001914461143315, -0.00019397716096136...         권력        0
# 188   [-0.0013289239723235369, -0.003540684701874852...         비중        0
# 1602  [-0.003685627831146121, -0.0032977655064314604...  biometric        0
# 2036  [-0.002029834780842066, 0.0009858406847342849,...        귀중품        0
# 1553  [-0.003356743138283491, -0.004821134731173515,...        내비친        0
# 480   [1.9661027181427926e-05, -0.000673031958285719...         심하        0
# 374   [-0.0030768190044909716, -0.003909427206963301...        의외로        0
# 1442  [-0.0005419707740657032, -0.00325451185926795,...         융합        0
# 1357  [-0.004456752445548773, -0.003275982802733779,...        프랑스        0
# ...

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 사회적 적용
# Out:
#                                                raw_data  word  cluster  \
# 142   [-0.004027992486953735, 0.0030908016487956047,...  블록체인        1
# 87    [0.0014252690598368645, 0.005937409587204456, ...    기술        1
# 89    [0.004121521487832069, 0.005388923920691013, -...   서비스        1
# 766   [0.001461594831198454, 0.0012465539621189237, ...    개발        1
# 1040  [0.0031115012243390083, 0.0025813125539571047,...    물류        1
# 51    [0.004302904009819031, 0.0023163219448179007, ...    거래        1
# 47    [0.004540193825960159, 0.008482745848596096, 0...    기업        1
# 75    [-0.002570162294432521, 0.003319142386317253, ...    회사        1
# 5     [0.004034396260976791, 0.0071904296055436134, ...    산업        1
# 143   [-0.003706692485138774, 0.006251267623156309, ...    활용        1
# 72    [-0.004522137809544802, 0.008117293938994408, ...    통해        1
# 648   [-0.005035046022385359, 0.0011581364087760448,...    적용        1
# ...

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 제도
# Out:
#                                                raw_data       word  cluster  \
# 848   [0.0034243494737893343, -0.0002086856256937608...       업데이트        2
# 36    [0.0031747054308652878, -0.003356497036293149,...         편리        2
# 1155  [0.002746035810559988, 0.0011901881080120802, ...        자동차        2
# 1943  [0.0023982070852071047, 0.004412111360579729, ...         포키        2
# 458   [-0.00270854658447206, 8.091958443401381e-05, ...        완전히        2
# 1886  [0.0010066652903333306, 0.003924780525267124, ...         머신        2
# 344   [0.0045682284981012344, 0.0020896857604384422,...       누그러지        2
# 253   [-0.0038125321734696627, 0.004477635957300663,...         시행        2
# 1726  [-0.004347877111285925, -0.0008351203869096935...   Personal        2
# 2027  [0.003960081841796637, -0.0008866525022312999,...        문제점        2
# 1349  [-0.0013261744752526283, -0.001069699181243777...        위원회        2
# ...

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 기타
# Out:
#                                                raw_data  word  cluster  \
# 1197  [-0.0028943479992449284, 0.004017374943941832,...  트랜잭션        3
# 1377  [-0.001190058421343565, 0.003060501767322421, ...    구현        3
# 563   [-0.0014611511724069715, 0.004093758296221495,...    미디        3
# 1578  [-0.0018368232995271683, -0.003121592104434967...   목소리        3
# 1036  [0.002757173962891102, 0.00298547325655818, -0...    표준        3
# 1172  [-0.0030236411839723587, -0.001278052921406924...    개설        3
# 1922  [0.003100026398897171, 0.004184497054666281, -...    요금        3
# 1225  [0.004060018807649612, -0.001323710661381483, ...    감안        3
# 523   [-0.00492500327527523, 0.0002540792338550091, ...    급진        3
# 864   [-0.004005656577646732, 0.005097721237689257, ...    트림        3
# 647   [0.001170522766187787, 0.0016226136358454823, ...    마린        3
# 812   [-0.0029639671556651592, 0.002946071559563279,...    내달        3
# ...

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 이슈
# Out:
# 416

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 사회적용
# Out:
# 843

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 제도
# Out:
# 433

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 기타
# Out:
# 420

# %%
temp_cluster_result['category'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result['label'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 5 # 5 : 사회 이슈 문제점

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 7 # 7 : 비즈 발전

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label']  = 10 # 제도한계

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 13 # 기타

# %%
temp_cluster_result
# Out:
#                                                raw_data  word  cluster  \
# 0     [0.00021432801440823823, -0.001941892434842884...    일본        1
# 1     [0.0012961274478584528, 0.001383977709338069, ...    최초        1
# 2     [0.003956063184887171, 0.0012802776182070374, ...    설치        0
# 3     [-0.0019664710853248835, -0.001186903100460767...  비트코인        1
# 4     [0.0010761411394923925, 0.002418451476842165, ...   ATM        3
# ...                                                 ...   ...      ...
# 2107  [-0.004585069604218006, -0.0037742857821285725...    누릴        0
# 2108  [-0.004319499246776104, -0.0009349715546704829...    힘쓸        0
# 2109  [-0.0012235557660460472, -0.001273399451747536...    예탁        2
# 2110  [0.0008405667613260448, 0.0029103290289640427,...    제원        1
# 2111  [-0.004291215445846319, -0.004488183185458183,...   플러그        0
#
#                                                centroid  distance     tfidf  \
# ...

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 1.7447875351122644

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [3 2 2 ... 1 1 1]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -1.7447875

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.010797439

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(50,'score') # 비즈 적용
# Out:
#                                                raw_data       word  cluster  \
# 630   [0.002737133065238595, -0.003063715063035488, ...  protected        0
# 313   [-0.0011630150256678462, 0.004582669120281935,...         방식        0
# 1089  [-0.0038011856377124786, 0.004088972695171833,...         문서        0
# 801   [-0.0005044221179559827, -0.001033154316246509...         과정        0
# 764   [-0.0028152207378298044, -0.000517741020303219...         사물        0
# 367   [0.004939500242471695, 0.0021984654013067484, ...         개혁        0
# 568   [0.0012140680337324739, -0.003372759325429797,...       프로젝트        0
# 109   [0.004669766873121262, -0.0016945633105933666,...         준비        0
# 373   [0.0032746423967182636, 0.006191479042172432, ...         국가        0
# 182   [-0.004594416357576847, 0.0041688596829771996,...         달러        0
# 118   [0.0002585428883321583, 0.0045776707120239735,...         고객        0
# ...

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') # 사회적용
# Out:
#                                                raw_data   word  cluster  \
# 307   [0.0033459642436355352, -0.0012500715674832463...     협력        1
# 211   [-0.004047212656587362, 0.002757524373009801, ...     국민        1
# 569   [0.004662335850298405, 0.0005649562808685005, ...     주도        1
# 119   [-0.004496993497014046, 0.002609794493764639, ...     자산        1
# 1135  [-0.001627461751922965, 0.004821623209863901, ...     결합        1
# 35    [0.003456690115854144, -0.0029313191771507263,...     송금        1
# 565   [-5.743871952290647e-05, 0.002147331601008773,...     향상        1
# 113   [0.004434566013514996, -0.003710780758410692, ...     이후        1
# 948   [-0.0037167847622185946, 0.0031231169123202562...    페더럴        1
# 28    [-0.004678060300648212, 0.0028489432297647, -0...     빠르        1
# 997   [-0.004112228285521269, -0.0034690429456532, 0...   bank        1
# 188   [-0.0013289239723235369, -0.003540684701874852...     비중        1
# ...

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 협업
# Out:
#                                                raw_data   word  cluster  \
# 46    [0.0032359843607991934, 0.004773404449224472, ...     강화        2
# 290   [-0.0028338467236608267, 0.0014561909483745694...     우리        2
# 869   [0.003232198301702738, 0.0011919264215976, 0.0...     가치        2
# 1464  [0.002428228035569191, 0.0016302954172715545, ...    에너지        2
# 1390  [-0.0004272834921721369, 0.0016373273683711886...    로그인        2
# 449   [0.0038849678821861744, -0.0015580311883240938...     목적        2
# 666   [0.0035946383140981197, -0.0030143349431455135...     차별        2
# 715   [-0.0015693396562710404, 0.003965539857745171,...     도움        2
# 940   [-0.004446841776371002, -0.002582263434305787,...     마틴        2
# 1320  [-0.0008280640468001366, 0.004572432953864336,...  다이아몬드        2
# 1079  [0.0022893946152180433, 0.0033664789516478777,...     제조        2
# 981   [0.003313315100967884, 0.0022342540323734283, ...     설계        2
# ...

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 협업
# Out:
#                                                raw_data  word  cluster  \
# 142   [-0.004027992486953735, 0.0030908016487956047,...  블록체인        3
# 87    [0.0014252690598368645, 0.005937409587204456, ...    기술        3
# 89    [0.004121521487832069, 0.005388923920691013, -...   서비스        3
# 1040  [0.0031115012243390083, 0.0025813125539571047,...    물류        3
# 766   [0.001461594831198454, 0.0012465539621189237, ...    개발        3
# 8     [0.004525761120021343, 0.0027420760598033667, ...    화폐        3
# 5     [0.004034396260976791, 0.0071904296055436134, ...    산업        3
# 75    [-0.002570162294432521, 0.003319142386317253, ...    회사        3
# 72    [-0.004522137809544802, 0.008117293938994408, ...    통해        3
# 130   [0.001592943212017417, 0.004465888720005751, -...    분야        3
# 6     [0.004237061366438866, 0.004110568668693304, -...    금융        3
# 120   [-0.0026451777666807175, 0.004754259251058102,...    관리        3
# ...

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #사회시도
# Out:
# 660

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #사회시도
# Out:
# 628

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #협업
# Out:
# 706

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #협업
# Out:
# 118

# %%
temp_cluster_result1['category'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 7 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 7 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 8 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 8 # 7 : biz 시도

# %%
temp_cluster_result1
# Out:
#                                                raw_data  word  cluster  \
# 0     [0.00021432801440823823, -0.001941892434842884...    일본        3
# 1     [0.0012961274478584528, 0.001383977709338069, ...    최초        2
# 2     [0.003956063184887171, 0.0012802776182070374, ...    설치        2
# 3     [-0.0019664710853248835, -0.001186903100460767...  비트코인        3
# 4     [0.0010761411394923925, 0.002418451476842165, ...   ATM        2
# ...                                                 ...   ...      ...
# 2107  [-0.004585069604218006, -0.0037742857821285725...    누릴        2
# 2108  [-0.004319499246776104, -0.0009349715546704829...    힘쓸        1
# 2109  [-0.0012235557660460472, -0.001273399451747536...    예탁        1
# 2110  [0.0008405667613260448, 0.0029103290289640427,...    제원        1
# 2111  [-0.004291215445846319, -0.004488183185458183,...   플러그        1
#
#                                                centroid  distance     tfidf  \
# ...

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 7 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 7 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 8 # 7 : biz 시도

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 8 # 7 : biz 시도

# %%
temp_cluster_result1
# Out:
#                                                raw_data  word  cluster  \
# 0     [0.00021432801440823823, -0.001941892434842884...    일본        3
# 1     [0.0012961274478584528, 0.001383977709338069, ...    최초        2
# 2     [0.003956063184887171, 0.0012802776182070374, ...    설치        2
# 3     [-0.0019664710853248835, -0.001186903100460767...  비트코인        3
# 4     [0.0010761411394923925, 0.002418451476842165, ...   ATM        2
# ...                                                 ...   ...      ...
# 2107  [-0.004585069604218006, -0.0037742857821285725...    누릴        2
# 2108  [-0.004319499246776104, -0.0009349715546704829...    힘쓸        1
# 2109  [-0.0012235557660460472, -0.001273399451747536...    예탁        1
# 2110  [0.0008405667613260448, 0.0029103290289640427,...    제원        1
# 2111  [-0.004291215445846319, -0.004488183185458183,...   플러그        1
#
#                                                centroid  distance     tfidf  \
# ...

# %%
temp_cluster_result1['Silhouette'] = 0.010797439
temp_cluster_result['Silhouette'] = 0.010797439

# %%
temp_cluster_result1.to_csv("../cluster/ko_news/2017_up1/ko_news_2017_up1_euclidean.csv")
temp_cluster_result.to_csv("../cluster/ko_news/2017_up1/ko_news_2017_up1_cosine.csv")

# %%
temp_cluster_result1['result'] = 1
temp_cluster_result['result'] = 1

# %%
temp_cluster_result1.to_csv("../cluster/ko_news/2017_up1/ko_news_2017_up1_euclidean.csv")
temp_cluster_result.to_csv("../cluster/ko_news/2017_up1/ko_news_2017_up1_cosine.csv")
