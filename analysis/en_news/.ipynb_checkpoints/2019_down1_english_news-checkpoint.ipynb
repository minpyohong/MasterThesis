# %%
import chardet
import pandas as pd
import urllib.request

    
#print(encoding_result)
data = pd.read_csv('../../news/scraping_result/en/2019_down1/2019_down1_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/en/2019_down1/2019_down1_Cointelegraph.csv',error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/en/2019_down1/2019_down1_CryptoNews.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/en/2019_down1/2019_down1_Forbes.csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 4954

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 4954

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.001*"paranoid" + 0.001*"matthew" + 0.001*"impossible" + 0.001*"aggregate" + 0.001*"aramco" + 0.001*"obvious" + 0.001*"arabian" + 0.001*"operative"')
# (1, '0.001*"honorable" + 0.001*"blatant" + 0.001*"nexo" + 0.001*"financialization" + 0.001*"goldman" + 0.001*"sachs" + 0.001*"render" + 0.001*"anyways"')
# (2, '0.001*"christmas" + 0.001*"empower" + 0.001*"photocredit" + 0.001*"universal" + 0.001*"nourish" + 0.001*"mortar" + 0.001*"gettythis" + 0.001*"gordon"')
# (3, '0.001*"griffith" + 0.001*"spearhead" + 0.001*"relation" + 0.001*"abstract" + 0.001*"engagement" + 0.001*"chris" + 0.001*"attest" + 0.001*"percentage"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el68541404829788722724934971485"></div>
# <script type="text/javascript">
#
# var ldavis_el68541404829788722724934971485_data = {"mdsDat": {"x": [-0.1406231964369176, 0.05155958919314387, 0.045151852490476554, 0.043911754753297116], "y": [0.0028169385689340077, 0.07534879032465747, -0.04550564897407732, -0.03266007991951421], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [29.385692596435547, 24.17103385925293, 23.30706024169922, 23.136219024658203]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 4954

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 4954

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 16.825644603268543

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 7.935978928275134e-05

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 2.181990085396693

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 기술
# Out:
#                                                raw_data           word  \
# 3967  [0.00201299786567688, -0.001496657496318221, 0...           peru
# 3950  [-0.0006681770319119096, -0.004814984276890755...        webpage
# 3691  [-0.002380566205829382, 0.003047100268304348, ...        omisego
# 1885  [-0.0072139548137784, -0.003568533807992935, -...       istanbul
# 2880  [-0.0025851980317384005, -0.004973364528268576...  unconditional
# 3151  [-0.0020301572512835264, -0.000651277077849954...       overseas
# 3701  [-0.0020476900972425938, 0.00053640257101506, ...     population
# 1264  [0.002698971424251795, -0.0005953463260084391,...        liberty
# 2459  [0.0024024054873734713, 0.0014746764209121466,...    consultancy
# 2810  [-0.003968849312514067, -0.004184702876955271,...         winter
# 3702  [-0.004719781223684549, -0.0005886011058464646...      bezantium
# 4630  [0.004705512430518866, 0.0038391321431845427, ...           bold
#
#       cluster                                           centroid  distance  \
# 3967        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.380495
# 3950        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.479569
# 3691        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.492785
# 1885        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.539946
# 2880        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.593340
# 3151        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.611981
# 3701        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.616827
# 1264        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.628790
# 2459        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.651412
# 2810        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.741035
# 3702        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.851538
# 4630        0  [-0.0011495404, -0.000998013, 0.00011272327, 0...  0.999206
#
#          tfidf     score closer#
# 3967  0.000708  1.379787     NaN
# 3950  0.000708  1.478862     NaN
# 3691  0.000708  1.492077     NaN
# 1885  0.000708  1.539239     NaN
# 2880  0.000708  1.592633     NaN
# 3151  0.000708  1.611274     NaN
# 3701  0.000708  1.616120     NaN
# 1264  0.000708  1.628082     NaN
# 2459  0.000708  1.650704     NaN
# 2810  0.000708  1.740327     NaN
# 3702  0.000708  1.850831     NaN
# 4630  0.000708  1.998499     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 기타
# Out:
#                                                raw_data        word  cluster  \
# 894   [-0.01788894273340702, -0.00815619621425867, -...      viable        1
# 725   [-0.016624189913272858, -0.007084827870130539,...      domino        1
# 4211  [-0.011572923511266708, -0.007088228594511747,...  commentary        1
# 2083  [-0.014325570315122604, -0.005914507433772087,...  comparable        1
# 3386  [-0.015142733231186867, -0.012006687931716442,...      freeze        1
# 729   [-0.015454752370715141, -0.001924605225212872,...     archive        1
# 2339  [-0.008640551008284092, -0.004356421530246735,...    spacious        1
# 1225  [-0.01678050123155117, -0.006161401513963938, ...       tough        1
# 1915  [-0.009234696626663208, -0.005606220569461584,...  repurchase        1
# 2759  [-0.010577580891549587, -0.002382072154432535,...   megaphone        1
# 3405  [-0.010802559554576874, -0.004992242902517319,...  fieldhouse        1
# 2368  [-0.007129651494324207, -0.008684365078806877,...    backfire        1
# 1993  [-0.009310206398367882, -0.009716625325381756,...    coinlist        1
# 4214  [-0.007116551510989666, -0.006999795325100422,...    stranger        1
# 2148  [-0.010619093663990498, -0.010584120638668537,...  graduation        1
# 3893  [-0.01668880507349968, -0.005246270447969437, ...      krüger        1
# 1874  [-0.014305047690868378, -0.006747260224074125,...       kenan        1
# 4416  [-0.012632236815989017, -0.0015480758156627417...     consume        1
# 4278  [-0.00887786503881216, -0.003101210342720151, ...     forwith        1
# 2019  [-0.010041333734989166, -0.0017546163871884346...    overlook        1
# 3104  [-0.011948001570999622, -0.00297501590102911, ...       climb        1
# 2519  [-0.007741086184978485, -0.0029531039763242006...      uptake        1
# 4808  [-0.01323589775711298, -0.007955354638397694, ...       query        1
# 2469  [-0.0142119275406003, -0.0021424032747745514, ...    ordinary        1
# 2299  [-0.010285744443535805, -0.009426667355000973,...   modernize        1
# 2133  [-0.004293347243219614, -0.002796486020088196,...   christine        1
# 1483  [-0.011716839857399464, -0.0039228713139891624...     rollout        1
# 3201  [-0.009160791523754597, -0.0027998245786875486...       ruble        1
# 4152  [-0.010005306452512741, -0.0030752511229366064...       sandy        1
# 3753  [-0.01228833757340908, -0.003794829361140728, ...       sheer        1
#
#                                                centroid  distance     tfidf  \
# 894   [-0.005736918, -0.002889609, -0.0043392195, 0....  0.033448  0.001415
# 725   [-0.005736918, -0.002889609, -0.0043392195, 0....  0.036873  0.002123
# 4211  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.047595  0.001415
# 2083  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.048026  0.001415
# 3386  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.048462  0.001415
# 729   [-0.005736918, -0.002889609, -0.0043392195, 0....  0.049832  0.002123
# 2339  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.050596  0.000708
# 1225  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.052428  0.001415
# 1915  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.053038  0.001415
# 2759  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.055103  0.001415
# 3405  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.056595  0.000708
# 2368  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.057295  0.000708
# 1993  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.058333  0.001415
# 4214  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.058666  0.000708
# 2148  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.060014  0.000708
# 3893  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.060915  0.001415
# 1874  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.061163  0.000708
# 4416  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.063821  0.001415
# 4278  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.068136  0.000708
# 2019  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.071054  0.000708
# 3104  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.073591  0.002830
# 2519  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.075422  0.001415
# 4808  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.080337  0.000708
# 2469  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.081183  0.001415
# 2299  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.081857  0.001415
# 2133  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.082103  0.000708
# 1483  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.083515  0.001415
# 3201  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.083139  0.000708
# 4152  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.083925  0.000708
# 3753  [-0.005736918, -0.002889609, -0.0043392195, 0....  0.084642  0.001415
#
#          score closer#
# 894   1.032033     NaN
# 725   1.034750     NaN
# 4211  1.046180     NaN
# 2083  1.046610     NaN
# 3386  1.047047     NaN
# 729   1.047709     NaN
# 2339  1.049888     NaN
# 1225  1.051013     NaN
# 1915  1.051623     NaN
# 2759  1.053688     NaN
# 3405  1.055888     NaN
# 2368  1.056588     NaN
# 1993  1.056918     NaN
# 4214  1.057959     NaN
# 2148  1.059307     NaN
# 3893  1.059500     NaN
# 1874  1.060455     NaN
# 4416  1.062406     NaN
# 4278  1.067428     NaN
# 2019  1.070346     NaN
# 3104  1.070760     NaN
# 2519  1.074007     NaN
# 4808  1.079629     NaN
# 2469  1.079768     NaN
# 2299  1.080442     NaN
# 2133  1.081396     NaN
# 1483  1.082100     NaN
# 3201  1.082432     NaN
# 4152  1.083218     NaN
# 3753  1.083227     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(30)   # 사회적 시도
# Out:
#                                                raw_data          word  \
# 1291  [-0.012861165218055248, -0.008785524405539036,...      transmit
# 610   [-0.012917649932205677, -0.005975031293928623,...       certify
# 4543  [-0.01667483150959015, -0.007965575903654099, ...  cryptoleague
# 2322  [-0.020086973905563354, -0.006922946777194738,...      traction
# 3899  [-0.021675383672118187, -0.0075232828967273235...         crash
# 2700  [-0.019360609352588654, -0.004757910966873169,...   probability
# 1120  [-0.01575608178973198, -0.01043129712343216, -...        invent
# 479   [-0.014695847406983376, -0.005978461354970932,...        adjust
# 4938  [-0.01781054399907589, -0.0043776752427220345,...       larceny
# 2939  [-0.012426006607711315, -0.008748779073357582,...        barack
# 2559  [-0.013109972700476646, -0.007050692569464445,...       perfect
# 2337  [-0.009950636886060238, -0.004335245117545128,...          posh
# 1881  [-0.014739780686795712, -0.006129100453108549,...       erdogan
# 1418  [-0.011664960533380508, -0.00900882389396429, ...         faith
# 2163  [-0.009621425531804562, -0.006259812042117119,...   translation
# 1996  [-0.011897712014615536, -0.004695400595664978,...    relinquish
# 3079  [-0.009481196291744709, -0.004658082500100136,...    corrective
# 2503  [-0.010094537399709225, -0.0028129848651587963...         ricky
# 586   [-0.012075035832822323, -0.003195359604433179,...       silbert
# 845   [-0.012411791831254959, -0.005228023510426283,...       turmoil
# 500   [-0.011572534218430519, -0.011463519185781479,...       execute
# 1737  [-0.015884170308709145, -0.005743346642702818,...     procedure
# 3402  [-0.012898777611553669, -0.0014884650008752942...       signage
# 2520  [-0.010810053907334805, -0.007274428382515907,...    capitalist
# 4105  [-0.011801185086369514, -0.0047756582498550415...    confluence
# 1573  [-0.012464743107557297, -0.008821412920951843,...         arena
# 2732  [-0.00954454019665718, -0.0024635514710098505,...       anthony
# 3084  [-0.014218436554074287, -0.0011627685744315386...  considerable
# 4194  [-0.01020205207169056, -0.009090335108339787, ...          long
# 2871  [-0.009670980274677277, -0.005775702651590109,...     voluntary
#
#       cluster                                           centroid  distance  \
# 1291        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.024174
# 610         2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.026069
# 4543        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.026319
# 2322        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.029493
# 3899        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.030831
# 2700        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.031758
# 1120        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.033751
# 479         2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.036106
# 4938        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.036803
# 2939        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.037634
# 2559        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.039641
# 2337        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.039795
# 1881        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.040673
# 1418        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.041889
# 2163        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.043059
# 1996        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.043424
# 3079        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.043901
# 2503        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.045771
# 586         2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.045969
# 845         2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.047643
# 500         2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.048602
# 1737        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.048259
# 3402        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.048126
# 2520        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.049433
# 4105        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.050418
# 1573        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.050122
# 2732        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.051669
# 3084        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.052178
# 4194        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.051522
# 2871        2  [-0.0057467273, -0.0025310297, -0.0041259318, ...  0.053294
#
#          tfidf     score closer#
# 1291  0.001415  1.022758     NaN
# 610   0.002123  1.023946     NaN
# 4543  0.002123  1.024197     NaN
# 2322  0.002123  1.027370     NaN
# 3899  0.002123  1.028709     NaN
# 2700  0.002123  1.029636     NaN
# 1120  0.002123  1.031629     NaN
# 479   0.002123  1.033983     NaN
# 4938  0.001415  1.035388     NaN
# 2939  0.001415  1.036219     NaN
# 2559  0.002123  1.037518     NaN
# 2337  0.000708  1.039088     NaN
# 1881  0.001415  1.039258     NaN
# 1418  0.001415  1.040474     NaN
# 2163  0.001415  1.041644     NaN
# 1996  0.001415  1.042009     NaN
# 3079  0.001415  1.042486     NaN
# 2503  0.001415  1.044356     NaN
# 586   0.001415  1.044554     NaN
# 845   0.001415  1.046228     NaN
# 500   0.002123  1.046479     NaN
# 1737  0.001415  1.046844     NaN
# 3402  0.000708  1.047418     NaN
# 2520  0.001415  1.048017     NaN
# 4105  0.002123  1.048296     NaN
# 1573  0.001415  1.048707     NaN
# 2732  0.001415  1.050254     NaN
# 3084  0.001415  1.050763     NaN
# 4194  0.000708  1.050814     NaN
# 2871  0.001415  1.051879     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 가격, 거래소, 돈
# Out:
#                                                raw_data            word  \
# 80    [-0.7101580500602722, -0.3775424063205719, -0....         bitcoin
# 153   [-0.6245093941688538, -0.3348443806171417, -0....      blockchain
# 39    [-0.603091835975647, -0.3316136300563812, -0.4...          crypto
# 28    [-0.5301133990287781, -0.28578901290893555, -0...           trade
# 334   [-0.5935318470001221, -0.32291701436042786, -0...         company
# 36    [-0.5143488645553589, -0.27828022837638855, -0...          market
# 76    [-0.5295115113258362, -0.28329232335090637, -0...  cryptocurrency
# 213   [-0.5308007597923279, -0.28092139959335327, -0...        exchange
# 167   [-0.5450255870819092, -0.2973203957080841, -0....         digital
# 168   [-0.5219272375106812, -0.2867794334888458, -0....        currency
# 49    [-0.49411335587501526, -0.2704966962337494, -0...            time
# 187   [-0.5174499154090881, -0.28071892261505127, -0...            bank
# 191   [-0.538543701171875, -0.292013019323349, -0.38...       financial
# 192   [-0.4769710898399353, -0.257256418466568, -0.3...         service
# 1615  [-0.5127851366996765, -0.2789623737335205, -0....           token
# 570   [-0.4863392412662506, -0.2639530301094055, -0....         payment
# 117   [-0.4828590154647827, -0.26270583271980286, -0...            year
# 2     [-0.49286332726478577, -0.27447766065597534, -...           price
# 709   [-0.4846138060092926, -0.26471683382987976, -0...            make
# 151   [-0.487413227558136, -0.2701534032821655, -0.3...           asset
#
#       cluster                                           centroid  distance  \
# 80          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000029
# 153         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000034
# 39          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000033
# 28          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000049
# 334         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000028
# 36          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000036
# 76          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000036
# 213         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000046
# 167         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000060
# 168         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000051
# 49          3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000052
# 187         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000050
# 191         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000040
# 192         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000051
# 1615        3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000042
# 570         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000049
# 117         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000059
# 2           3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000058
# 709         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000048
# 151         3  [-0.04635532, -0.025003495, -0.03304099, 0.052...  0.000062
#
#          tfidf     score closer#
# 80    0.352365  0.647664     NaN
# 153   0.254014  0.746020     NaN
# 39    0.204485  0.795548     NaN
# 28    0.162031  0.838018     NaN
# 334   0.154248  0.845780     NaN
# 36    0.154248  0.845788     NaN
# 76    0.147173  0.852864     NaN
# 213   0.137267  0.862780     NaN
# 167   0.135852  0.864208     NaN
# 168   0.126653  0.873398     NaN
# 49    0.124531  0.875521     NaN
# 187   0.123823  0.876227     NaN
# 191   0.118163  0.881877     NaN
# 192   0.112502  0.887549     NaN
# 1615  0.103304  0.896739     NaN
# 570   0.103304  0.896746     NaN
# 117   0.103304  0.896755     NaN
# 2     0.099058  0.901000     NaN
# 709   0.098351  0.901697     NaN
# 151   0.095521  0.904541     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 기술
# Out:
# 12

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 기타
# Out:
# 453

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 사회적 시도
# Out:
# 656

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 가격,거래소,암호화폐
# Out:
# 3833

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 89.0205217550677

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [1 0 1 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -89.02052

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.74025154

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # 부정적 감정
# Out:
#                                                raw_data          word  \
# 3196  [-0.012170852161943913, -0.006741114426404238,...     adversary
# 3207  [-0.008442231453955173, -0.004142323508858681,...       nervous
# 3356  [-0.01020715944468975, -0.007272389717400074, ...        silver
# 2836  [-0.015407855622470379, -0.006412138231098652,...      coincide
# 1173  [-0.011385854333639145, -0.009295852854847908,...        accuse
# 3307  [-0.01350449863821268, -0.007601525168865919, ...        prompt
# 2313  [-0.01657322607934475, -0.007256656419485807, ...   feasibility
# 1521  [-0.012083616107702255, -0.008700771257281303,...       michael
# 1125  [-0.009704668074846268, -0.0022051031701266766...     podcaster
# 3264  [-0.01101705338805914, -0.011663383804261684, ...        george
# 3383  [-0.011504463851451874, -0.009796717204153538,...       cieslik
# 2190  [-0.00967596285045147, -0.0074728322215378284,...       offline
# 1306  [-0.015247908420860767, -0.007242161780595779,...         forum
# 1124  [-0.014154421165585518, -0.011286299675703049,...         roger
# 3614  [-0.012462464161217213, -0.0030076836701482534...          city
# 1246  [-0.01208098977804184, -0.005449960939586163, ...   explanation
# 4140  [-0.008882518857717514, -0.009025358594954014,...       extreme
# 2183  [-0.013000448234379292, -0.006837298162281513,...     segregate
# 3171  [-0.011277732439339161, -0.006810404825955629,...         rupee
# 1555  [-0.009927812032401562, -0.012288221158087254,...         risky
# 3219  [-0.012883305549621582, -0.00769902765750885, ...         malta
# 914   [-0.009618375450372696, -0.0027829566970467567...    bitcoiners
# 496   [-0.018666086718440056, -0.007781559135764837,...         guard
# 411   [-0.019194817170500755, -0.009651897475123405,...    collection
# 2401  [-0.01792033389210701, -0.006003693211823702, ...         table
# 3283  [-0.011281096376478672, -0.008102442137897015,...         tight
# 4938  [-0.01781054399907589, -0.0043776752427220345,...       larceny
# 2803  [-0.017421960830688477, -0.0047126635909080505...  verification
# 2945  [-0.013522496446967125, -0.005973185878247023,...      november
# 4619  [-0.012871150858700275, -0.009950125589966774,...          sofi
#
#       cluster                                           centroid  distance  \
# 3196        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.025414
# 3207        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.025409
# 3356        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.025657
# 2836        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026366
# 1173        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026465
# 3307        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026566
# 2313        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026091
# 1521        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026092
# 1125        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026101
# 3264        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026189
# 3383        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026248
# 2190        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026269
# 1306        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027084
# 1124        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026443
# 3614        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027245
# 1246        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026547
# 4140        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026566
# 2183        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026574
# 3171        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026639
# 1555        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027408
# 3219        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027435
# 914         0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026741
# 496         0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027481
# 411         0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.028280
# 2401        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027593
# 3283        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026919
# 4938        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.026993
# 2803        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027720
# 2945        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027724
# 4619        0  [-0.013618102, -0.007255393, -0.0097477455, 0....  0.027741
#
#          tfidf     score closer#
# 3196  0.002123  1.023291     NaN
# 3207  0.001415  1.023994     NaN
# 3356  0.001415  1.024242     NaN
# 2836  0.002123  1.024244     NaN
# 1173  0.002123  1.024342     NaN
# 3307  0.002123  1.024443     NaN
# 2313  0.001415  1.024676     NaN
# 1521  0.001415  1.024676     NaN
# 1125  0.001415  1.024686     NaN
# 3264  0.001415  1.024773     NaN
# 3383  0.001415  1.024833     NaN
# 2190  0.001415  1.024854     NaN
# 1306  0.002123  1.024961     NaN
# 1124  0.001415  1.025028     NaN
# 3614  0.002123  1.025122     NaN
# 1246  0.001415  1.025132     NaN
# 4140  0.001415  1.025151     NaN
# 2183  0.001415  1.025158     NaN
# 3171  0.001415  1.025224     NaN
# 1555  0.002123  1.025285     NaN
# 3219  0.002123  1.025312     NaN
# 914   0.001415  1.025326     NaN
# 496   0.002123  1.025358     NaN
# 411   0.002830  1.025450     NaN
# 2401  0.002123  1.025471     NaN
# 3283  0.001415  1.025504     NaN
# 4938  0.001415  1.025578     NaN
# 2803  0.002123  1.025598     NaN
# 2945  0.002123  1.025601     NaN
# 4619  0.002123  1.025618     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(30,'score') # 사업적 시도
# Out:
#                                               raw_data              word  \
# 195  [-0.44476479291915894, -0.24573510885238647, -...             libra
# 271  [-0.4520327150821686, -0.24814827740192413, -0...            report
# 236  [-0.4478165805339813, -0.24433021247386932, -0...          facebook
# 503  [-0.44426465034484863, -0.2362499088048935, -0...           provide
# 53   [-0.4488469362258911, -0.23745983839035034, -0...  cryptocurrencies
# 85   [-0.44308236241340637, -0.24325673282146454, -...              high
# 181  [-0.44226881861686707, -0.23942287266254425, -...           project
# 41   [-0.45783060789108276, -0.24695779383182526, -...            accord
# 23   [-0.45483067631721497, -0.2513512372970581, -0...              move
# 471  [-0.46571531891822815, -0.24474886059761047, -...          platform
# 302  [-0.46042105555534363, -0.24631544947624207, -...              base
# 742  [-0.43255043029785156, -0.2358666956424713, -0...        technology
# 348  [-0.4296039044857025, -0.23029127717018127, -0...           network
# 518  [-0.46250441670417786, -0.25534847378730774, -...              fund
# 246  [-0.4706283509731293, -0.25123289227485657, -0...              work
# 192  [-0.4769710898399353, -0.257256418466568, -0.3...           service
# 345  [-0.4218531548976898, -0.22898554801940918, -0...          business
# 666  [-0.4169880151748657, -0.22726985812187195, -0...       transaction
# 436  [-0.4174624979496002, -0.22262968122959137, -0...            people
# 315  [-0.4174172282218933, -0.2221037894487381, -0....              mine
# 395  [-0.41461125016212463, -0.21899449825286865, -...             state
# 709  [-0.4846138060092926, -0.26471683382987976, -0...              make
# 621  [-0.40962842106819153, -0.22756074368953705, -...             offer
# 117  [-0.4828590154647827, -0.26270583271980286, -0...              year
# 7    [-0.4862447679042816, -0.2573097050189972, -0....           support
# 470  [-0.4123513102531433, -0.2241235077381134, -0....        investment
# 353  [-0.4082803726196289, -0.2256251871585846, -0....              plan
# 570  [-0.4863392412662506, -0.2639530301094055, -0....           payment
# 652  [-0.4080270826816559, -0.222834050655365, -0.2...            system
# 387  [-0.4836491048336029, -0.2635568380355835, -0....           include
#
#      cluster                                           centroid  distance  \
# 195        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.034450
# 271        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.039520
# 236        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.036320
# 503        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.028880
# 53         1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.039952
# 85         1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.032867
# 181        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.059507
# 41         1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.067110
# 23         1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.074360
# 471        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.104151
# 302        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.120585
# 742        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.114499
# 348        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.123450
# 518        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.132363
# 246        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.153924
# 192        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.229780
# 345        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.186440
# 666        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.199420
# 436        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.206042
# 315        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.209013
# 395        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.222294
# 709        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.271703
# 621        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.240546
# 117        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.279752
# 7          1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.258206
# 470        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.243477
# 353        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.244748
# 570        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.294168
# 652        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.279772
# 387        1  [-0.44568098, -0.24108754, -0.31718254, 0.5096...  0.285975
#
#         tfidf     score closer#
# 195  0.087030  0.947420     NaN
# 271  0.084907  0.954613     NaN
# 236  0.078539  0.957781     NaN
# 503  0.067926  0.960954     NaN
# 53   0.078539  0.961413     NaN
# 85   0.067218  0.965648     NaN
# 181  0.075709  0.983799     NaN
# 41   0.067218  0.999892     NaN
# 23   0.065803  1.008557     NaN
# 471  0.087030  1.017122     NaN
# 302  0.091983  1.028602     NaN
# 742  0.073586  1.040912     NaN
# 348  0.072171  1.051279     NaN
# 518  0.080662  1.051701     NaN
# 246  0.062973  1.090951     NaN
# 192  0.112502  1.117278     NaN
# 345  0.056605  1.129835     NaN
# 666  0.061558  1.137862     NaN
# 436  0.059435  1.146607     NaN
# 315  0.054482  1.154531     NaN
# 395  0.056605  1.165690     NaN
# 709  0.098351  1.173352     NaN
# 621  0.065096  1.175450     NaN
# 117  0.103304  1.176449     NaN
# 7    0.077832  1.180374     NaN
# 470  0.062265  1.181212     NaN
# 353  0.057312  1.187436     NaN
# 570  0.103304  1.190864     NaN
# 652  0.073586  1.206186     NaN
# 387  0.072879  1.213096     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(30,'score')  # 사회적 이슈
# Out:
#                                                raw_data           word  \
# 439   [-0.08792015165090561, -0.05168677121400833, -...         donald
# 1901  [-0.09154566377401352, -0.04918396845459938, -...        version
# 295   [-0.08429004997015, -0.04367191344499588, -0.0...          cross
# 929   [-0.08904848247766495, -0.04818849265575409, -...        deposit
# 2122  [-0.08721598982810974, -0.05005655437707901, -...        analyst
# 1009  [-0.08414668589830399, -0.047828309237957, -0....        creator
# 2206  [-0.09057693928480148, -0.04800359159708023, -...      advantage
# 2768  [-0.08933553099632263, -0.04843853414058685, -...         monero
# 2918  [-0.08874255418777466, -0.04669201374053955, -...       retailer
# 1301  [-0.08975085616111755, -0.0465526208281517, -0...           unit
# 166   [-0.08352469652891159, -0.04311119019985199, -...     subsidiary
# 143   [-0.08853679150342941, -0.04946815222501755, -...        mention
# 695   [-0.08753012120723724, -0.04534660279750824, -...           shop
# 1085  [-0.0878436490893364, -0.044566813856363297, -...  investigation
# 2073  [-0.0874134749174118, -0.04350524768233299, -0...    requirement
# 1405  [-0.08887026458978653, -0.05287647992372513, -...         intend
# 788   [-0.0873659998178482, -0.04481910541653633, -0...         anyone
# 346   [-0.08406060189008713, -0.04559142887592316, -...          crime
# 475   [-0.09346327930688858, -0.05117649957537651, -...     difficulty
# 642   [-0.08854810893535614, -0.045013438910245895, ...         choose
# 667   [-0.08631473034620285, -0.04379731044173241, -...        balance
# 4293  [-0.09048484265804291, -0.049445126205682755, ...         exonum
# 161   [-0.08963236212730408, -0.050648920238018036, ...         strict
# 216   [-0.09169474244117737, -0.0502963550388813, -0...      commodity
# 1337  [-0.08851633220911026, -0.04814164713025093, -...           tool
# 136   [-0.08631950616836548, -0.046836983412504196, ...          buyer
# 880   [-0.08545107394456863, -0.05004335939884186, -...           apps
# 1468  [-0.09008219838142395, -0.04520484432578087, -...     innovation
# 17    [-0.08975813537836075, -0.0457056500017643, -0...       momentum
# 1469  [-0.09339617192745209, -0.05097854509949684, -...         target
#
#       cluster                                           centroid  distance  \
# 439         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.028221
# 1901        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.027552
# 295         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.028390
# 929         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.030024
# 2122        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.027729
# 1009        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.026812
# 2206        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.028799
# 2768        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.030257
# 2918        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031003
# 1301        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.028981
# 166         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031969
# 143         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.029249
# 695         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031477
# 1085        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.028028
# 2073        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.029460
# 1405        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.030305
# 788         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.032244
# 346         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.030169
# 475         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.033782
# 642         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031287
# 667         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.029258
# 4293        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.032306
# 161         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.030190
# 216         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.032428
# 1337        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.033920
# 136         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031525
# 880         2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.031753
# 1468        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.034603
# 17          2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.033407
# 1469        2  [-0.08752902, -0.04688398, -0.062449593, 0.099...  0.033425
#
#          tfidf     score closer#
# 439   0.012736  1.015485     NaN
# 1901  0.011321  1.016231     NaN
# 295   0.012029  1.016362     NaN
# 929   0.013444  1.016580     NaN
# 2122  0.010613  1.017115     NaN
# 1009  0.009198  1.017614     NaN
# 2206  0.010613  1.018186     NaN
# 2768  0.012029  1.018229     NaN
# 2918  0.012736  1.018267     NaN
# 1301  0.010613  1.018367     NaN
# 166   0.013444  1.018525     NaN
# 143   0.010613  1.018636     NaN
# 695   0.012736  1.018741     NaN
# 1085  0.008491  1.019537     NaN
# 2073  0.009906  1.019555     NaN
# 1405  0.010613  1.019691     NaN
# 788   0.012029  1.020215     NaN
# 346   0.009906  1.020263     NaN
# 475   0.013444  1.020338     NaN
# 642   0.010613  1.020673     NaN
# 667   0.008491  1.020767     NaN
# 4293  0.011321  1.020985     NaN
# 161   0.009198  1.020992     NaN
# 216   0.011321  1.021107     NaN
# 1337  0.012736  1.021184     NaN
# 136   0.009906  1.021619     NaN
# 880   0.009906  1.021847     NaN
# 1468  0.012736  1.021867     NaN
# 17    0.011321  1.022086     NaN
# 1469  0.011321  1.022104     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 투자
# Out:
#                                                raw_data         word  cluster  \
# 71    [-0.2159121185541153, -0.11832716315984726, -0...        order        3
# 657   [-0.21756622195243835, -0.11705002188682556, -...         card        3
# 554   [-0.21185950934886932, -0.11932887881994247, -...       credit        3
# 644   [-0.20955869555473328, -0.11109127104282379, -...         risk        3
# 1893  [-0.21208630502223969, -0.11474347114562988, -...     solution        3
# 40    [-0.21324491500854492, -0.11538714915513992, -...        board        3
# 300   [-0.2114277482032776, -0.11338192969560623, -0...         bull        3
# 1060  [-0.21436867117881775, -0.10900604724884033, -...  development        3
# 600   [-0.2180527001619339, -0.11459420621395111, -0...         deal        3
# 1093  [-0.22018522024154663, -0.11309171468019485, -...        block        3
# 78    [-0.210684135556221, -0.11448995023965836, -0....        image        3
# 73    [-0.21211004257202148, -0.11354757845401764, -...         sell        3
# 1014  [-0.21472229063510895, -0.12058111280202866, -...      private        3
# 257   [-0.22077161073684692, -0.11953515559434891, -...      concern        3
# 99    [-0.2046140432357788, -0.11674002557992935, -0...      average        3
# 871   [-0.21807004511356354, -0.1156022772192955, -0...       online        3
# 154   [-0.21725811064243317, -0.12299253046512604, -...         news        3
# 58    [-0.21770517528057098, -0.1194879412651062, -0...         june        3
# 911   [-0.20222210884094238, -0.10762926191091537, -...        place        3
# 133   [-0.22164420783519745, -0.12408236414194107, -...        close        3
#
#                                                centroid  distance     tfidf  \
# 71    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.028338  0.029010
# 657   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.031421  0.031133
# 554   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.030666  0.029718
# 644   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.029224  0.027595
# 1893  [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.029846  0.027595
# 40    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.033260  0.029718
# 300   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.036223  0.032548
# 1060  [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.032927  0.027595
# 600   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.032366  0.025472
# 1093  [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.036870  0.029718
# 78    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.042725  0.031840
# 73    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.038971  0.026887
# 1014  [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.043569  0.027595
# 257   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.045405  0.029010
# 99    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.047828  0.029718
# 871   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.048391  0.027595
# 154   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.050837  0.029718
# 58    [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.055371  0.028302
# 911   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.056376  0.027595
# 133   [-0.21340604, -0.11533346, -0.15188998, 0.2435...  0.058155  0.028302
#
#          score closer#
# 71    0.999328     NaN
# 657   1.000289     NaN
# 554   1.000948     NaN
# 644   1.001629     NaN
# 1893  1.002251     NaN
# 40    1.003542     NaN
# 300   1.003676     NaN
# 1060  1.005332     NaN
# 600   1.006894     NaN
# 1093  1.007153     NaN
# 78    1.010884     NaN
# 73    1.012084     NaN
# 1014  1.015974     NaN
# 257   1.016395     NaN
# 99    1.018110     NaN
# 871   1.020796     NaN
# 154   1.021119     NaN
# 58    1.027069     NaN
# 911   1.028781     NaN
# 133   1.029852     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #부정적 감정, 공포
# Out:
# 4091

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #사업적 시도
# Out:
# 76

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #사회적 이슈
# Out:
# 584

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #투자
# Out:
# 203

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.99707365

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[ 2.24330861e+00, -2.91459688e-03],
#        [-7.56573932e-03, -9.89105840e-04],
#        [ 3.12589504e+00, -9.26186556e-04],
#        ...,
#        [-2.18023903e-01, -3.92772352e-03],
#        [-2.15767586e-01,  4.01767498e-04],
#        [-2.29725685e-01,  2.08064777e-03]])

# %%
xys[:,0]
# Out:
# array([ 2.24330861, -0.00756574,  3.12589504, ..., -0.2180239 ,
#        -0.21576759, -0.22972569])

# %%
xys[:,1]
# Out:
# array([-0.0029146 , -0.00098911, -0.00092619, ..., -0.00392772,
#         0.00040177,  0.00208065])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128556 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
