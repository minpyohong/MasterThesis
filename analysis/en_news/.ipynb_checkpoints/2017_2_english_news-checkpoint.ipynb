# %%
import pandas as pd
import urllib.request


data = pd.read_csv('../../news/scraping_result/en/2017_up2/2017_up2_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/en/2017_up2/2017_up2_Cointelegraph.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/en/2017_up2/2017_up2_Forbes.csv', error_bad_lines=False))

# %%
text = data[['main article']]
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("-"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
#text['main article'] = text.apply(lambda row: row['main article'].replace("",""), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 13239

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 13239

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.000*"wechat" + 0.000*"bloombergchina" + 0.000*"warfare" + 0.000*"evidentiary" + 0.000*"unsolicited" + 0.000*"fragment" + 0.000*"paththis" + 0.000*"matterone"')
# (1, '0.000*"dulce" + 0.000*"toothpaste" + 0.000*"bitwage" + 0.000*"reitzig" + 0.000*"unreliable" + 0.000*"regulationsbut" + 0.000*"leapfrog" + 0.000*"transferability"')
# (2, '0.000*"playstations" + 0.000*"unearth" + 0.000*"compulsive" + 0.000*"schmidt" + 0.000*"matterport" + 0.000*"urinate" + 0.000*"crumb" + 0.000*"animation"')
# (3, '0.000*"haley" + 0.000*"learnif" + 0.000*"scramble" + 0.000*"hoggard" + 0.000*"brainchild" + 0.000*"markey" + 0.000*"franco" + 0.000*"peninsula"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el77941405979546896168880679703"></div>
# <script type="text/javascript">
#
# var ldavis_el77941405979546896168880679703_data = {"mdsDat": {"x": [-0.13488181554081424, 0.0462952749519228, 0.050750210083768954, 0.037836330505122376], "y": [0.0031741252380443515, -0.06946967062063912, 0.08795723268384288, -0.021661687301248126], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [27.463314056396484, 25.069416046142578, 23.787933349609375, 23.67933464050293]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3 ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 13239

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 13239

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 228.04108827825925

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.003953702832056982

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 3.834150922966717

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 기술
# Out:
#                                                 raw_data              word  \
# 12625  [-0.002003998029977083, -0.00832841731607914, ...         worldcoin
# 12016  [-0.001836403738707304, -0.00489966431632638, ...       logarithmic
# 12373  [-0.004009316209703684, -0.007637400180101395,...             cough
# 10992  [0.0008189690997824073, -0.001263445825316012,...          daedalus
# 9087   [-0.00845691654831171, -0.009029094129800797, ...  interestinvestor
# 12596  [-0.0054933661594986916, -0.000568090938031673...       underweight
# 2808   [-0.004749033600091934, 0.0021839472465217113,...        eurodollar
# 9425   [-0.004959698300808668, -0.000131133827380836,...        conceptual
# 12017  [-0.004550261422991753, -0.002467281650751829,...             eagle
# 11463  [-0.0014866241253912449, -0.002420569304376840...             garza
# 12406  [-0.002079685917124152, -0.006943177431821823,...        unanswered
# 10971  [-0.006449515465646982, -0.006354751996695995,...      simultaneous
# 6348   [-0.004293966572731733, -0.003920187707990408,...        jeopardize
# 10689  [-0.003418809035792947, -0.0037299408577382565...        systemsthe
# 11732  [-0.0011633281828835607, 0.000744318007491529,...             dcoin
# 12935  [0.0033326586708426476, -0.0021909954957664013...              dyke
# 10017  [-0.002896802267059684, -0.007059898227453232,...         solarcoin
# 1625   [-0.006016836501657963, 0.0008538728579878807,...  disintermediated
# 6652   [0.002442379016429186, -0.00074474309803918, -...       seigniorage
# 9136   [-0.004383717197924852, -0.0008646576898172498...     uncompetitive
#
#        cluster                                           centroid  distance  \
# 12625        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.110194
# 12016        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.117316
# 12373        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.240231
# 10992        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.246052
# 9087         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.246988
# 12596        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.306157
# 2808         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.320153
# 9425         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.331032
# 12017        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.341545
# 11463        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.351161
# 12406        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.351746
# 10971        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.362974
# 6348         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.384910
# 10689        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.442048
# 11732        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.463915
# 12935        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.471291
# 10017        0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.516546
# 1625         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.522775
# 6652         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.524029
# 9136         0  [-0.0014056425, -0.0011539371, -0.0017511756, ...  0.529822
#
#           tfidf     score closer#
# 12625  0.000099  1.110094     NaN
# 12016  0.000099  1.117217     NaN
# 12373  0.000099  1.240132     NaN
# 10992  0.000099  1.245952     NaN
# 9087   0.000099  1.246889     NaN
# 12596  0.000099  1.306058     NaN
# 2808   0.000099  1.320054     NaN
# 9425   0.000199  1.330834     NaN
# 12017  0.000099  1.341446     NaN
# 11463  0.000099  1.351062     NaN
# 12406  0.000099  1.351647     NaN
# 10971  0.000099  1.362875     NaN
# 6348   0.000099  1.384811     NaN
# 10689  0.000099  1.441949     NaN
# 11732  0.000199  1.463717     NaN
# 12935  0.000099  1.471192     NaN
# 10017  0.000099  1.516447     NaN
# 1625   0.000099  1.522676     NaN
# 6652   0.000099  1.523930     NaN
# 9136   0.000099  1.529723     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 가격 거래소 돈
# Out:
#                                                raw_data            word  \
# 4     [0.24468933045864105, 0.69664466381073, 0.8615...  cryptocurrency
# 12    [0.19470010697841644, 0.7494246959686279, 0.79...        exchange
# 112   [0.22486652433872223, 0.6098896265029907, 0.75...           money
# 15    [0.16625629365444183, 0.7523308396339417, 1.01...           trade
# 114   [0.10867360234260559, 0.7209967374801636, 0.85...        investor
# 81    [0.1317329853773117, 0.6920264959335327, 0.773...          crypto
# 2     [0.34228211641311646, 0.5746796727180481, 0.78...           world
# 52    [0.08218546956777573, 0.7557743191719055, 0.69...            fund
# 235   [0.1411200761795044, 0.7377999424934387, 0.813...      investment
# 290   [0.29992756247520447, 0.8077536225318909, 0.83...           token
# 733   [0.37108302116394043, 0.7621320486068726, 0.77...        security
# 364   [0.22292742133140564, 0.6862010955810547, 0.87...            hold
# 961   [0.48034054040908813, 0.5227594375610352, 0.71...        platform
# 82    [0.17402693629264832, 0.6807669401168823, 0.90...           asset
# 165   [0.3310142159461975, 0.6761243343353271, 0.875...          global
# 61    [0.18569156527519226, 0.7210904359817505, 0.90...          invest
# 1175  [0.35880184173583984, 0.677120566368103, 0.767...           issue
# 1109  [0.2744293510913849, 0.6957706212997437, 0.820...         country
# 1078  [0.26528677344322205, 0.6574971675872803, 0.70...      government
# 205   [0.29566678404808044, 0.6137567162513733, 0.64...         account
# 916   [0.1355336606502533, 0.7075735330581665, 0.938...          dollar
# 826   [0.4481324553489685, 0.5678457617759705, 0.588...         service
# 298   [0.2797044813632965, 0.6945421099662781, 0.911...          launch
# 306   [0.2366010993719101, 0.7895134091377258, 0.812...         capital
# 436   [0.27500611543655396, 0.7117068767547607, 0.87...           group
# 89    [0.2283795028924942, 0.5621629953384399, 0.651...     traditional
# 648   [0.31253737211227417, 0.7377665042877197, 0.91...        consider
# 198   [0.23636727035045624, 0.7579594254493713, 0.82...        currency
# 227   [0.4305965304374695, 0.545553982257843, 0.5246...       financial
# 833   [0.24285338819026947, 0.6615685224533081, 0.78...           china
#
#       cluster                                           centroid  distance  \
# 4           1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.008615
# 12          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.019801
# 112         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.002713
# 15          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.030512
# 114         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.013369
# 81          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.007931
# 2           1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.010601
# 52          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.022975
# 235         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.012261
# 290         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.053524
# 733         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.010548
# 364         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.004827
# 961         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.016140
# 82          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.033569
# 165         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.004678
# 61          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.010448
# 1175        1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.006037
# 1109        1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.004232
# 1078        1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.011992
# 205         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.011973
# 916         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.010419
# 826         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.028407
# 298         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.014321
# 306         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.009392
# 436         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.007234
# 89          1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.002469
# 648         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.003851
# 198         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.130819
# 227         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.046771
# 833         1  [0.020103367, 0.05187383, 0.06076143, 0.037539...  0.003587
#
#          tfidf     score closer#
# 4     0.140692  0.867923     NaN
# 12    0.122310  0.897491     NaN
# 112   0.096477  0.906236     NaN
# 15    0.117740  0.912772     NaN
# 114   0.094689  0.918680     NaN
# 81    0.073525  0.934406     NaN
# 2     0.069253  0.941348     NaN
# 52    0.081076  0.941899     NaN
# 235   0.064086  0.948175     NaN
# 290   0.102836  0.950688     NaN
# 733   0.051964  0.958584     NaN
# 364   0.044910  0.959917     NaN
# 961   0.055144  0.960996     NaN
# 82    0.071538  0.962031     NaN
# 165   0.040439  0.964239     NaN
# 61    0.044413  0.966035     NaN
# 1175  0.038352  0.967684     NaN
# 1109  0.035471  0.968761     NaN
# 1078  0.043022  0.968970     NaN
# 205   0.042525  0.969448     NaN
# 916   0.039843  0.970577     NaN
# 826   0.055541  0.972866     NaN
# 298   0.041333  0.972988     NaN
# 306   0.036166  0.973225     NaN
# 436   0.033484  0.973750     NaN
# 89    0.027025  0.975444     NaN
# 648   0.027423  0.976428     NaN
# 198   0.152813  0.978006     NaN
# 227   0.067862  0.978909     NaN
# 833   0.024542  0.979046     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(40)   # 가능성, 희망
# Out:
#                                               raw_data        word  cluster  \
# 31   [0.23950064182281494, 0.6819129586219788, 1.38...     bitcoin        2
# 5    [0.08959338068962097, 0.7672187089920044, 1.10...      market        2
# 21   [0.25587862730026245, 0.6682595610618591, 1.18...        time        2
# 33   [0.06760698556900024, 0.8081602454185486, 1.26...        year        2
# 41   [0.12250039726495743, 0.6944298148155212, 1.16...       value        2
# 30   [-0.02178839221596718, 0.8354238271713257, 1.6...       price        2
# 7    [0.14608806371688843, 0.722930371761322, 1.328...        high        2
# 702  [0.21824397146701813, 0.7315053939819336, 0.99...        sell        2
# 160  [0.2378389984369278, 0.759429931640625, 1.0483...       early        2
# 187  [0.32350829243659973, 0.7231131792068481, 1.25...    increase        2
# 124  [0.22767402231693268, 0.6701136827468872, 0.93...      accord        2
# 175  [0.12085679918527603, 0.7345901727676392, 1.11...       month        2
# 18   [0.22182343900203705, 0.6221742033958435, 0.95...       today        2
# 183  [0.2782050669193268, 0.6489428281784058, 0.993...    continue        2
# 718  [0.20688097178936005, 0.6891611218452454, 1.15...        gold        2
# 333  [0.26304182410240173, 0.614185094833374, 1.007...      future        2
# 257  [0.12004183977842331, 0.8272543549537659, 1.20...        last        2
# 342  [0.22231538593769073, 0.6962053179740906, 0.94...        gain        2
# 50   [0.14726999402046204, 0.6872267723083496, 1.03...        week        2
# 38   [0.11374993622303009, 0.738175094127655, 1.237...        rise        2
# 579  [0.3574255704879761, 0.6341376304626465, 1.253...        cash        2
# 213  [0.22165632247924805, 0.667152464389801, 1.011...      bubble        2
# 400  [0.18891380727291107, 0.5881045460700989, 0.87...       worth        2
# 176  [0.312438428401947, 0.6502431035041809, 1.0262...     current        2
# 911  [0.18790042400360107, 0.6838935613632202, 0.93...       stock        2
# 443  [0.21767792105674744, 0.5784459710121155, 0.92...       reach        2
# 344  [0.19364982843399048, 0.6367974281311035, 0.94...        past        2
# 307  [0.1930217295885086, 0.6605513691902161, 0.886...      return        2
# 569  [0.24960598349571228, 0.5925773978233337, 0.88...       short        2
# 32   [0.004021278582513332, 0.868641197681427, 1.36...     percent        2
# 123  [0.1650114208459854, 0.6050717234611511, 0.942...        drop        2
# 129  [0.1864396333694458, 0.5527554750442505, 0.867...  volatility        2
# 828  [0.20749066770076752, 0.49113455414772034, 0.7...    litecoin        2
# 347  [0.20087911188602448, 0.5094473361968994, 0.75...       total        2
# 345  [0.2089657336473465, 0.5469352006912231, 0.848...        hour        2
# 608  [0.16511879861354828, 0.558840274810791, 0.851...       index        2
# 132  [0.19769291579723358, 0.4842846095561981, 0.71...      volume        2
# 327  [0.11246784031391144, 0.3823901414871216, 0.61...       surge        2
# 20   [0.1441461145877838, 0.39568471908569336, 0.60...       press        2
# 845  [0.192605122923851, 0.4962349534034729, 0.7527...     average        2
#
#                                               centroid  distance     tfidf  \
# 31   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.021559  0.561773
# 5    [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.024749  0.184310
# 21   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.008001  0.114063
# 33   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.010084  0.115256
# 41   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.018944  0.096080
# 30   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.064160  0.121813
# 7    [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.020834  0.060907
# 702  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.010795  0.048288
# 160  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.004776  0.040340
# 187  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.011089  0.046301
# 124  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.004223  0.036862
# 175  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.003954  0.036564
# 18   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.002733  0.035173
# 183  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.005591  0.035372
# 718  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.014847  0.043420
# 333  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.035735  0.064186
# 257  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.007055  0.034676
# 342  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.004367  0.030205
# 50   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.002443  0.028118
# 38   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.007959  0.031000
# 579  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.038422  0.060311
# 213  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.004943  0.026231
# 400  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.000833  0.020567
# 176  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.005183  0.024144
# 911  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.009560  0.026926
# 443  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.002421  0.019276
# 344  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.002687  0.019176
# 307  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.006299  0.021561
# 569  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.005668  0.020667
# 32   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.033768  0.047593
# 123  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.000996  0.013910
# 129  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.003157  0.015401
# 828  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.001733  0.013811
# 347  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.003289  0.014904
# 345  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.001696  0.013115
# 608  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.001331  0.012519
# 132  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.004495  0.013016
# 327  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.001091  0.009538
# 20   [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.001996  0.010035
# 845  [0.018747238, 0.055108618, 0.08512635, 0.04301...  0.003626  0.011526
#
#         score closer#
# 31   0.459786     NaN
# 5    0.840439     NaN
# 21   0.893938     NaN
# 33   0.894829     NaN
# 41   0.922864     NaN
# 30   0.942347     NaN
# 7    0.959927     NaN
# 702  0.962507     NaN
# 160  0.964436     NaN
# 187  0.964788     NaN
# 124  0.967361     NaN
# 175  0.967390     NaN
# 18   0.967560     NaN
# 183  0.970220     NaN
# 718  0.971427     NaN
# 333  0.971549     NaN
# 257  0.972379     NaN
# 342  0.974162     NaN
# 50   0.974324     NaN
# 38   0.976959     NaN
# 579  0.978111     NaN
# 213  0.978712     NaN
# 400  0.980266     NaN
# 176  0.981039     NaN
# 911  0.982633     NaN
# 443  0.983145     NaN
# 344  0.983511     NaN
# 307  0.984739     NaN
# 569  0.985002     NaN
# 32   0.986175     NaN
# 123  0.987086     NaN
# 129  0.987757     NaN
# 828  0.987922     NaN
# 347  0.988385     NaN
# 345  0.988580     NaN
# 608  0.988812     NaN
# 132  0.991479     NaN
# 327  0.991552     NaN
# 20   0.991961     NaN
# 845  0.992100     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 사회적용
# Out:
#                                                raw_data              word  \
# 810   [0.7028860449790955, 0.3898661732673645, 0.582...        blockchain
# 145   [0.41320034861564636, 0.576363742351532, 0.910...              make
# 158   [0.36788254976272583, 0.599152147769928, 0.659...           company
# 543   [0.3137415945529938, 0.5587363839149475, 0.840...            people
# 148   [0.3172328770160675, 0.6618658900260925, 0.925...              take
# 424   [0.308273047208786, 0.6447147727012634, 0.8910...              many
# 42    [0.231806218624115, 0.5856281518936157, 0.8444...  cryptocurrencies
# 170   [0.5781941413879395, 0.5298962593078613, 0.770...              user
# 11    [0.2714637517929077, 0.7200011014938354, 1.024...              come
# 399   [0.307839959859848, 0.6074270606040955, 0.9510...             think
# 353   [0.3554913401603699, 0.5865853428840637, 0.883...              good
# 1180  [0.4452367126941681, 0.5880020260810852, 0.749...              base
# 79    [0.5509294867515564, 0.5598520040512085, 0.779...              work
# 162   [0.37482786178588867, 0.606534481048584, 0.945...            become
# 848   [0.4371083080768585, 0.5448451042175293, 0.694...          business
# 248   [0.5132458806037903, 0.5391258001327515, 0.828...            create
# 212   [0.42001816630363464, 0.6750799417495728, 0.89...              call
# 23    [0.3877655267715454, 0.701127827167511, 0.8471...           include
# 98    [0.27660635113716125, 0.6738896369934082, 0.96...             first
# 409   [0.3870948553085327, 0.6375716924667358, 0.960...              know
#
#       cluster                                           centroid  distance  \
# 810         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.078749
# 145         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.002731
# 158         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.010005
# 543         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.005369
# 148         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.001997
# 424         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.001619
# 42          3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.005956
# 170         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.021446
# 11          3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.004688
# 399         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.003238
# 353         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.002202
# 1180        3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.008558
# 79          3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.018846
# 162         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.001653
# 848         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.014761
# 248         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.007617
# 212         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.002318
# 23          3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.003722
# 98          3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.004366
# 409         3  [0.03868922, 0.07069596, 0.098781265, 0.064205...  0.001806
#
#          tfidf     score closer#
# 810   0.200505  0.878243     NaN
# 145   0.119429  0.883302     NaN
# 158   0.114560  0.895445     NaN
# 543   0.093397  0.911973     NaN
# 148   0.078096  0.923902     NaN
# 424   0.071538  0.930081     NaN
# 42    0.074519  0.931437     NaN
# 170   0.083064  0.938383     NaN
# 11    0.064583  0.940105     NaN
# 399   0.060211  0.943027     NaN
# 353   0.054846  0.947356     NaN
# 1180  0.060807  0.947751     NaN
# 79    0.070843  0.948004     NaN
# 162   0.052561  0.949092     NaN
# 848   0.065477  0.949284     NaN
# 248   0.057429  0.950188     NaN
# 212   0.051368  0.950949     NaN
# 23    0.052660  0.951062     NaN
# 98    0.052561  0.951805     NaN
# 409   0.048984  0.952822     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 기술
# Out:
# 77

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 가격, 거래소, 돈
# Out:
# 1008

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 가능성 희망
# Out:
# 739

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 사회적용
# Out:
# 11415

# %%
temp_cluster_result['category'] = 1 # 1 영문뉴스, 2 국문뉴스 , 3 twitter
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 9 # 기술
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 12 #  가격, 거래소, 돈
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label'] = 1 # 가능성 희망
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 7 # 사회적용

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 1003.2674757952256

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [3 2 3 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -1003.26746

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.7473078

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # 인플
# Out:
#                                                 raw_data           word  \
# 10712  [0.010918861255049706, 0.024155694991350174, 0...     backstreet
# 10447  [0.009872589260339737, 0.016635118052363396, 0...     incomplete
# 13085  [0.008993147872388363, 0.023521961644291878, 0...    winterstein
# 8793   [0.010095588862895966, 0.018612971529364586, 0...       derision
# 9210   [0.009628473781049252, 0.020020948722958565, 0...         bigold
# 8922   [0.009887698106467724, 0.016430610790848732, 0...        audrius
# 6290   [0.011603220365941525, 0.015572621487081051, 0...         rajesh
# 10119  [0.015628213062882423, 0.020720794796943665, 0...      homeowner
# 4444   [0.012903217226266861, 0.01742364838719368, 0....          vivid
# 13203  [0.010437102057039738, 0.01768776960670948, 0....        eveline
# 12605  [0.008762809447944164, 0.018911117687821388, 0...       datasets
# 4441   [0.010052194818854332, 0.022223109379410744, 0...  idiosyncratic
# 983    [0.01165839470922947, 0.023971566930413246, 0....           hilt
# 5743   [0.014458361081779003, 0.023833343759179115, 0...      defensive
# 9874   [0.01421582605689764, 0.02196498215198517, 0.0...         allure
# 10385  [0.007049245294183493, 0.01722363568842411, 0....      holocaust
# 8785   [0.008156001567840576, 0.01751141995191574, 0....      boyfriend
# 4507   [0.011302320286631584, 0.023197241127490997, 0...        empathy
# 10059  [0.006754178553819656, 0.016088243573904037, 0...        bombard
# 8672   [0.012001309543848038, 0.017634112387895584, 0...      downright
# 11682  [0.007964827120304108, 0.023547034710645676, 0...         zaneis
# 9385   [0.012368488125503063, 0.02047787979245186, 0....      mccaffrey
# 4576   [0.009655975736677647, 0.01594490557909012, 0....          arbor
# 6750   [0.011880163103342056, 0.023306122049689293, 0...      vanuatuan
# 12031  [0.011191296391189098, 0.020074088126420975, 0...     missionary
# 7381   [0.00839624647051096, 0.020918384194374084, 0....         finman
# 8931   [0.009934935718774796, 0.018345605581998825, 0...   vilniusemail
# 11917  [0.013545298017561436, 0.015761923044919968, 0...       finucane
# 7452   [0.011536815203726292, 0.025414936244487762, 0...       mlnsteem
# 12047  [0.0058604395017027855, 0.02334221825003624, 0...       slovakia
#
#        cluster                                           centroid  distance  \
# 10712        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.025088
# 10447        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026274
# 13085        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026289
# 8793         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026531
# 9210         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026597
# 8922         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026727
# 6290         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026890
# 10119        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026916
# 4444         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026957
# 13203        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026878
# 12605        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.026982
# 4441         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027032
# 983          0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027063
# 5743         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027222
# 9874         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027131
# 10385        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027144
# 8785         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027158
# 4507         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027166
# 10059        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027277
# 8672         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027288
# 11682        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027279
# 9385         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027478
# 4576         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027484
# 6750         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027584
# 12031        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027493
# 7381         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027667
# 8931         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027474
# 11917        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027475
# 7452         0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027495
# 12047        0  [0.010803064, 0.020373747, 0.028255329, 0.0183...  0.027508
#
#           tfidf     score closer#
# 10712  0.000099  1.024988     NaN
# 10447  0.000199  1.026075     NaN
# 13085  0.000199  1.026091     NaN
# 8793   0.000099  1.026432     NaN
# 9210   0.000099  1.026497     NaN
# 8922   0.000099  1.026628     NaN
# 6290   0.000199  1.026691     NaN
# 10119  0.000199  1.026717     NaN
# 4444   0.000199  1.026758     NaN
# 13203  0.000099  1.026779     NaN
# 12605  0.000199  1.026784     NaN
# 4441   0.000199  1.026833     NaN
# 983    0.000199  1.026864     NaN
# 5743   0.000199  1.027024     NaN
# 9874   0.000099  1.027031     NaN
# 10385  0.000099  1.027045     NaN
# 8785   0.000099  1.027058     NaN
# 4507   0.000099  1.027067     NaN
# 10059  0.000199  1.027078     NaN
# 8672   0.000199  1.027089     NaN
# 11682  0.000099  1.027180     NaN
# 9385   0.000199  1.027279     NaN
# 4576   0.000199  1.027285     NaN
# 6750   0.000298  1.027286     NaN
# 12031  0.000199  1.027294     NaN
# 7381   0.000298  1.027369     NaN
# 8931   0.000099  1.027374     NaN
# 11917  0.000099  1.027376     NaN
# 7452   0.000099  1.027396     NaN
# 12047  0.000099  1.027409     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(40,'score') # 기타
# Out:
#                                                raw_data          word  \
# 413   [0.17248143255710602, 0.32280075550079346, 0.4...        friend
# 1428  [0.16671976447105408, 0.3352118730545044, 0.46...        school
# 1730  [0.1719045341014862, 0.333190381526947, 0.4559...    discussion
# 3159  [0.1783115565776825, 0.32661139965057373, 0.45...       insight
# 988   [0.16239318251609802, 0.33991697430610657, 0.4...       respond
# 1820  [0.16654953360557556, 0.3347886800765991, 0.46...          gift
# 1276  [0.18244050443172455, 0.325442910194397, 0.466...        seller
# 2966  [0.17509686946868896, 0.339383989572525, 0.479...         steal
# 668   [0.1756628304719925, 0.3187555968761444, 0.455...        define
# 3566  [0.18946900963783264, 0.3180287182331085, 0.45...          farm
# 1350  [0.1769155114889145, 0.3288562595844269, 0.436...        center
# 707   [0.19026613235473633, 0.33085569739341736, 0.4...          sort
# 49    [0.16105131804943085, 0.32832205295562744, 0.4...       opinion
# 924   [0.16052468121051788, 0.3318554759025574, 0.45...         catch
# 3475  [0.1729128211736679, 0.32126858830451965, 0.45...     emphasize
# 1831  [0.18336206674575806, 0.3295036554336548, 0.44...         carry
# 1897  [0.1715131402015686, 0.3369625210762024, 0.447...        senior
# 3252  [0.1852312982082367, 0.3397504687309265, 0.478...       contain
# 3046  [0.18347547948360443, 0.3152487874031067, 0.44...  relationship
# 341   [0.1865844428539276, 0.33931025862693787, 0.46...          wide
# 3605  [0.19359000027179718, 0.3089764714241028, 0.44...     condition
# 461   [0.17804504930973053, 0.31260156631469727, 0.4...      powerful
# 1098  [0.17922541499137878, 0.3434275984764099, 0.46...       request
# 368   [0.15874145925045013, 0.32857608795166016, 0.4...        decade
# 1718  [0.18005937337875366, 0.3145332336425781, 0.45...          pick
# 2008  [0.19418852031230927, 0.3225986957550049, 0.46...          wave
# 1537  [0.18295502662658691, 0.3202725648880005, 0.44...     knowledge
# 1057  [0.18292929232120514, 0.3435796797275543, 0.46...       balance
# 381   [0.18258632719516754, 0.3276211619377136, 0.46...         apple
# 1386  [0.16457822918891907, 0.3234957158565521, 0.43...       failure
# 288   [0.18088945746421814, 0.31880515813827515, 0.4...        useful
# 2544  [0.1807880699634552, 0.3130650818347931, 0.445...    researcher
# 614   [0.15780293941497803, 0.32531458139419556, 0.4...      evidence
# 697   [0.16894155740737915, 0.33452308177948, 0.4807...        chance
# 2211  [0.18082383275032043, 0.33565038442611694, 0.4...     guarantee
# 3065  [0.20038674771785736, 0.31924834847450256, 0.4...     incentive
# 1741  [0.17064881324768066, 0.3192138373851776, 0.44...       express
# 1609  [0.16497643291950226, 0.34550541639328003, 0.4...          debt
# 667   [0.16640672087669373, 0.339320570230484, 0.459...         cover
# 1623  [0.1731833517551422, 0.3490363657474518, 0.468...       russian
#
#       cluster                                           centroid  distance  \
# 413         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.056576
# 1428        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.055838
# 1730        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.059073
# 3159        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.059969
# 988         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.061832
# 1820        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.062107
# 1276        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.071680
# 2966        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.080298
# 668         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.082429
# 3566        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.082317
# 1350        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.083772
# 707         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.087349
# 49          1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.088619
# 924         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.087180
# 3475        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.087981
# 1831        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.088199
# 1897        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.091656
# 3252        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.096279
# 3046        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.098703
# 341         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.101474
# 3605        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.099595
# 461         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.101265
# 1098        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.102338
# 368         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.102043
# 1718        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.102503
# 2008        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.104042
# 1537        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.105409
# 1057        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.106306
# 381         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.107581
# 1386        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.106133
# 288         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.108096
# 2544        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.106073
# 614         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.108090
# 697         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.110944
# 2211        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.109243
# 3065        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.113442
# 1741        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.113162
# 1609        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.112414
# 667         1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.113240
# 1623        1  [0.17562433, 0.33059734, 0.4610273, 0.29625303...  0.114013
#
#          tfidf     score closer#
# 413   0.004968  1.051608     NaN
# 1428  0.003875  1.051963     NaN
# 1730  0.004670  1.054403     NaN
# 3159  0.005564  1.054405     NaN
# 988   0.005167  1.056665     NaN
# 1820  0.004074  1.058033     NaN
# 1276  0.006061  1.065619     NaN
# 2966  0.005862  1.074436     NaN
# 668   0.006160  1.076269     NaN
# 3566  0.003974  1.078343     NaN
# 1350  0.005067  1.078705     NaN
# 707   0.006657  1.080692     NaN
# 49    0.007651  1.080969     NaN
# 924   0.005465  1.081715     NaN
# 3475  0.005365  1.082616     NaN
# 1831  0.005365  1.082833     NaN
# 1897  0.003974  1.087681     NaN
# 3252  0.005365  1.090913     NaN
# 3046  0.005067  1.093636     NaN
# 341   0.007750  1.093724     NaN
# 3605  0.004968  1.094627     NaN
# 461   0.005266  1.095999     NaN
# 1098  0.005962  1.096377     NaN
# 368   0.005465  1.096578     NaN
# 1718  0.005266  1.097237     NaN
# 2008  0.005962  1.098081     NaN
# 1537  0.006657  1.098752     NaN
# 1057  0.006657  1.099649     NaN
# 381   0.006260  1.101322     NaN
# 1386  0.004570  1.101563     NaN
# 288   0.006458  1.101638     NaN
# 2544  0.004372  1.101701     NaN
# 614   0.005067  1.103023     NaN
# 697   0.007154  1.103790     NaN
# 2211  0.004471  1.104772     NaN
# 3065  0.007353  1.106089     NaN
# 1741  0.006260  1.106903     NaN
# 1609  0.005365  1.107049     NaN
# 667   0.004769  1.108470     NaN
# 1623  0.004471  1.109542     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(30,'score')  # 비즈
# Out:
#                                                 raw_data          word  \
# 2525   [0.07339799404144287, 0.13654357194900513, 0.1...         truth
# 2039   [0.07329288125038147, 0.1391071230173111, 0.19...        guilty
# 1806   [0.06732415407896042, 0.1364186704158783, 0.18...      recovery
# 2189   [0.06809137761592865, 0.13948304951190948, 0.1...      neighbor
# 3695   [0.07795393466949463, 0.13577502965927124, 0.1...       college
# 3382   [0.07631929963827133, 0.13875506818294525, 0.1...          camp
# 5628   [0.07283705472946167, 0.14324623346328735, 0.1...      graduate
# 4882   [0.07414662092924118, 0.13832543790340424, 0.1...        origin
# 6417   [0.07061715424060822, 0.13390536606311798, 0.1...       dispute
# 2940   [0.06664397567510605, 0.1338956207036972, 0.18...        narrow
# 2495   [0.07746511697769165, 0.1339154690504074, 0.19...      accurate
# 2247   [0.07838425785303116, 0.13190069794654846, 0.1...        vendor
# 2823   [0.07740487158298492, 0.1382102519273758, 0.18...   maintenance
# 1816   [0.07778442651033401, 0.1357625275850296, 0.19...      follower
# 11786  [0.07005368173122406, 0.14116233587265015, 0.1...          msci
# 3317   [0.06774544715881348, 0.13629761338233948, 0.1...    excitement
# 3655   [0.0728994607925415, 0.14353641867637634, 0.18...   legislation
# 2469   [0.07462747395038605, 0.13252750039100647, 0.1...       defense
# 2176   [0.0710483267903328, 0.14332181215286255, 0.19...    consistent
# 5893   [0.07704463601112366, 0.13174891471862793, 0.1...          ddos
# 3106   [0.07260145246982574, 0.13551054894924164, 0.1...      restrict
# 8881   [0.073575459420681, 0.1328447163105011, 0.1829...      robotics
# 2471   [0.07790852338075638, 0.13775479793548584, 0.1...  manufacturer
# 3024   [0.06552010029554367, 0.1410045027732849, 0.18...  spokesperson
# 2872   [0.07607116550207138, 0.13142706453800201, 0.1...          suit
# 3523   [0.0683504119515419, 0.134306862950325, 0.1939...         venmo
# 2309   [0.0682758167386055, 0.13465675711631775, 0.18...    obligation
# 504    [0.07718294858932495, 0.1342804878950119, 0.19...        notion
# 4858   [0.06969185918569565, 0.14091555774211884, 0.1...       default
# 2242   [0.06553003937005997, 0.1375850886106491, 0.19...         jones
#
#        cluster                                           centroid  distance  \
# 2525         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.030809
# 2039         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.033246
# 1806         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.034005
# 2189         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.033536
# 3695         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.034103
# 3382         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.035368
# 5628         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.037754
# 4882         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.037646
# 6417         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.038076
# 2940         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.038793
# 2495         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.039767
# 2247         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040036
# 2823         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.039982
# 1816         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040039
# 11786        2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.039433
# 3317         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040217
# 3655         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040711
# 2469         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040755
# 2176         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.041399
# 5893         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.040789
# 3106         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.042017
# 8881         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.041847
# 2471         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.042467
# 3024         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.043306
# 2872         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.043876
# 3523         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.043784
# 2309         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.045334
# 504          2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.045449
# 4858         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.045730
# 2242         2  [0.072307914, 0.13745528, 0.19084063, 0.123358...  0.044994
#
#           tfidf     score closer#
# 2525   0.001490  1.029318     NaN
# 2039   0.001788  1.031457     NaN
# 1806   0.001888  1.032117     NaN
# 2189   0.001192  1.032344     NaN
# 3695   0.001391  1.032712     NaN
# 3382   0.001391  1.033977     NaN
# 5628   0.001490  1.036264     NaN
# 4882   0.001292  1.036355     NaN
# 6417   0.001590  1.036486     NaN
# 2940   0.001888  1.036905     NaN
# 2495   0.002186  1.037581     NaN
# 2247   0.001788  1.038248     NaN
# 2823   0.001689  1.038293     NaN
# 1816   0.001689  1.038350     NaN
# 11786  0.000894  1.038539     NaN
# 3317   0.001590  1.038628     NaN
# 3655   0.001987  1.038723     NaN
# 2469   0.001590  1.039165     NaN
# 2176   0.002087  1.039312     NaN
# 5893   0.001391  1.039398     NaN
# 3106   0.001987  1.040030     NaN
# 8881   0.001391  1.040456     NaN
# 2471   0.001590  1.040877     NaN
# 3024   0.001987  1.041319     NaN
# 2872   0.001987  1.041889     NaN
# 3523   0.001788  1.041996     NaN
# 2309   0.001987  1.043347     NaN
# 504    0.002087  1.043363     NaN
# 4858   0.002186  1.043544     NaN
# 2242   0.001391  1.043603     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 긍정적
# Out:
#                                                raw_data         word  cluster  \
# 576   [0.3129846155643463, 0.5524970293045044, 0.772...        clear        3
# 991   [0.30010247230529785, 0.5535451769828796, 0.80...         hand        3
# 1508  [0.2916697561740875, 0.5713896751403809, 0.805...         best        3
# 375   [0.30391252040863037, 0.5608403086662292, 0.78...        leave        3
# 549   [0.29650425910949707, 0.5674994587898254, 0.77...        bring        3
# 119   [0.3017546236515045, 0.5479187369346619, 0.765...  opportunity        3
# 1252  [0.30015167593955994, 0.5478704571723938, 0.78...   experience        3
# 1209  [0.3005844056606293, 0.5582118630409241, 0.796...       others        3
# 939   [0.2862669825553894, 0.5671881437301636, 0.829...        place        3
# 355   [0.2878476679325104, 0.5766236782073975, 0.846...       course        3
# 700   [0.30747324228286743, 0.5668104887008667, 0.80...        right        3
# 1757  [0.2952534258365631, 0.5627489686012268, 0.768...     approach        3
# 258   [0.2827114164829254, 0.5497802495956421, 0.795...         sign        3
# 685   [0.3290419578552246, 0.5721281170845032, 0.772...         rule        3
# 310   [0.312438040971756, 0.5480915307998657, 0.7627...      involve        3
# 1458  [0.31461772322654724, 0.5711974501609802, 0.81...         full        3
# 343   [0.29091620445251465, 0.5778742432594299, 0.78...      several        3
# 392   [0.2859061360359192, 0.574701189994812, 0.8202...        least        3
# 1149  [0.30806124210357666, 0.5602141618728638, 0.74...         test        3
# 1368  [0.2889268398284912, 0.5646470189094543, 0.767...         hack        3
#
#                                                centroid  distance     tfidf  \
# 576   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.108319  0.018183
# 991   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.126444  0.013314
# 1508  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.145203  0.018779
# 375   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.140510  0.014010
# 549   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.145955  0.018083
# 119   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.148004  0.019375
# 1252  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.159554  0.016593
# 1209  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.160896  0.016692
# 939   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.168263  0.021263
# 355   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.164067  0.015997
# 700   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.172918  0.019276
# 1757  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.168917  0.011724
# 258   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.171516  0.013612
# 685   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.181437  0.018580
# 310   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.182767  0.018977
# 1458  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.180761  0.015500
# 343   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.185855  0.017487
# 392   [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.189037  0.018580
# 1149  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.186198  0.015301
# 1368  [0.30053467, 0.5699195, 0.7939829, 0.4984231, ...  0.185161  0.013811
#
#          score closer#
# 576   1.090136     NaN
# 991   1.113130     NaN
# 1508  1.126424     NaN
# 375   1.126500     NaN
# 549   1.127871     NaN
# 119   1.128629     NaN
# 1252  1.142961     NaN
# 1209  1.144204     NaN
# 939   1.147000     NaN
# 355   1.148071     NaN
# 700   1.153643     NaN
# 1757  1.157193     NaN
# 258   1.157904     NaN
# 685   1.162857     NaN
# 310   1.163790     NaN
# 1458  1.165261     NaN
# 343   1.168368     NaN
# 392   1.170457     NaN
# 1149  1.170897     NaN
# 1368  1.171350     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) # 인플
# Out:
# 10576

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) # 기타
# Out:
# 612

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) # 비즈
# Out:
# 1589

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) # 긍정
# Out:
# 462

# %%
temp_cluster_result1['category'] = 1 # 1 영문뉴스, 2 국문뉴스 , 3 twitter
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 6 # 인플루언서
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 13 # 기타
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 7 # 비즈
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 1 # 긍정

# %%
temp_cluster_result1['result'] = 1 # 1 상승 2 하락 3 보합
temp_cluster_result['result'] = 1
temp_cluster_result1['Silhouette'] = 0.7473078 # 1 상승 2 하락 3 보합
temp_cluster_result['Silhouette'] = 0.7473078
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f2159d2735e5> in <module>
# ----> 1 temp_cluster_result1['result'] = 1 # 1 상승 2 하락 3 보합
#       2 temp_cluster_result['result'] = 1
#       3 temp_cluster_result1['Silhouette'] = 0.7473078 # 1 상승 2 하락 3 보합
#       4 temp_cluster_result['Silhouette'] = 0.7473078
#       5
#
# NameError: name 'temp_cluster_result1' is not defined

# %%
temp_cluster_result1.to_csv("../cluster/en_news/2017_up2/en_news_2017_up2_euclidean.csv")
temp_cluster_result.to_csv("../cluster/en_news/2017_up2/en_news_2017_up2_cosine.csv")

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.9987334

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[ 3.82690269e+00, -2.90646219e-01],
#        [ 1.16795381e+00,  1.02395030e-01],
#        [ 4.56931911e+00, -3.30550804e-01],
#        ...,
#        [-4.97246333e-01,  1.94170338e-03],
#        [-5.18756994e-01,  4.09361507e-03],
#        [-5.30824012e-01,  2.28347844e-03]])

# %%
xys[:,0]
# Out:
# array([ 3.82690269,  1.16795381,  4.56931911, ..., -0.49724633,
#        -0.51875699, -0.53082401])

# %%
xys[:,1]
# Out:
# array([-0.29064622,  0.10239503, -0.3305508 , ...,  0.0019417 ,
#         0.00409362,  0.00228348])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
