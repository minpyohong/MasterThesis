# %%
import chardet
import pandas as pd
import urllib.request

data = pd.read_csv('../../news/scraping_result/en/2020_up2/2020_up2_Coindesk.csv', error_bad_lines=False)
data = data.append(pd.read_csv('../../news/scraping_result/en/2020_up2/2020_up2_Cointelegraph.csv',error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/en/2020_up2/2020_up2_CryptoNews.csv', error_bad_lines=False))
data = data.append(pd.read_csv('../../news/scraping_result/en/2020_up2/2020_up2_Forbes.csv', error_bad_lines=False))

# %%
text = data[['main article']]
#print(text)

# %%
text['main article'] = text['main article'].astype(str)
text['main article'] = text.apply(lambda row: row['main article'].replace("/"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("—"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("*"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("…"," "), axis=1)
text['main article'] = text.apply(lambda row: row['main article'].replace("\\"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
import nltk
text['main article'] = text.apply(lambda row: nltk.word_tokenize(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 소문자 적용 , - 문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word.lower().replace("-","") for word in x])
# 공백문자 삭제
text['main article'] = text['main article'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['main article']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['main article'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['main article'] = text['main article'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import re
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['main article'] = text['main article'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['main article'] = text['main article'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['main article'] = text['main article'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
#print(text)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['main article'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 11100

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 11100

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
import gensim
NUM_TOPICS = 4 #20개의 토픽, k=20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50) 
# passes is similar with epoch , iterarion : loop per document
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.000*"absurdity" + 0.000*"bloombergmashinsky" + 0.000*"rebuying" + 0.000*"platinum" + 0.000*"spreadsheet" + 0.000*"steroid" + 0.000*"rehypothecating" + 0.000*"flatlining"')
# (1, '0.000*"administrate" + 0.000*"definitive" + 0.000*"shadowbanned" + 0.000*"criticise" + 0.000*"supplydemand" + 0.000*"assange" + 0.000*"blockchainfocused" + 0.000*"hyphenate"')
# (2, '0.000*"onslaught" + 0.000*"captain" + 0.000*"shortsighted" + 0.000*"valencia" + 0.000*"nixon" + 0.000*"visavis" + 0.000*"reckless" + 0.000*"theorize"')
# (3, '0.000*"distillery" + 0.000*"variant" + 0.000*"roommate" + 0.000*"russell" + 0.000*"soto" + 0.000*"scmp" + 0.000*"closedend" + 0.000*"borderline"')

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el116521403136028299041427196233"></div>
# <script type="text/javascript">
#
# var ldavis_el116521403136028299041427196233_data = {"mdsDat": {"x": [0.031981849342607366, 0.0035002458225072736, -0.10886647725050388, 0.07338438208538924], "y": [0.10412337474584116, -6.302403641888969e-06, -0.02365163604646858, -0.0804654362957307], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [27.33469009399414, 26.0218448638916, 23.348661422729492, 23.294809341430664]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2 ...

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 11100

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 11100

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 224.0211385523265

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.0018544200023898894

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 2.035759579084344

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 기술
# Out:
#                                                raw_data              word  \
# 146   [0.4711167514324188, 0.6833639144897461, -0.28...        blockchain
# 159   [0.44660794734954834, 1.0624674558639526, -0.0...           digital
# 157   [0.7707160711288452, 0.9535629749298096, -0.24...           operate
# 208   [0.30085626244544983, 0.728122889995575, -0.22...        technology
# 155   [1.1041336059570312, 0.9495468139648438, -0.22...            policy
# 161   [0.490011602640152, 1.080665111541748, -0.2190...             group
# 160   [0.35362058877944946, 1.0716100931167603, -0.0...          currency
# 163   [0.23881082236766815, 0.9021839499473572, -0.1...  cryptocurrencies
# 156   [0.8723975419998169, 0.8239145874977112, -0.15...       independent
# 158   [0.6527471542358398, 0.9152029156684875, -0.13...        subsidiary
# 215   [0.3943004012107849, 0.48915576934814453, -0.1...          monetary
# 164   [0.2620618939399719, 0.7628659009933472, -0.17...           startup
# 162   [0.33804553747177124, 0.9400200843811035, -0.1...            invest
# 8393  [0.010859564878046513, 0.022082017734646797, -...              icbc
# 4870  [0.03485874831676483, 0.04619905352592468, -0....           zhanhua
# 3210  [0.02355094999074936, 0.02322317101061344, -0....         stringent
# 4869  [0.04051705449819565, 0.060967378318309784, -0...            fujian
# 154   [1.0059611797332764, 0.6569007635116577, -0.23...         editorial
# 996   [0.023018522188067436, 0.028022445738315582, -...            twoday
# 6213  [0.016500890254974365, 0.018741358071565628, -...            duncan
#
#       cluster                                           centroid  distance  \
# 146         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.034409
# 159         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.102933
# 157         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.026452
# 208         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.042977
# 155         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.037317
# 161         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.042143
# 160         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.108693
# 163         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.067567
# 156         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.032314
# 158         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.032928
# 215         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.027751
# 164         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.051012
# 162         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.051390
# 8393        0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.015742
# 4870        0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.021517
# 3210        0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.021577
# 4869        0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.022204
# 154         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.047001
# 996         0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.024077
# 6213        0  [0.03986177, 0.04261149, -0.01400231, 0.010169...  0.027561
#
#          tfidf     score closer#
# 146   0.191486  0.842923     NaN
# 159   0.124084  0.978849     NaN
# 157   0.042694  0.983759     NaN
# 208   0.056501  0.986476     NaN
# 155   0.044329  0.992988     NaN
# 161   0.043420  0.998723     NaN
# 160   0.107188  1.001505     NaN
# 163   0.065766  1.001801     NaN
# 156   0.029795  1.002519     NaN
# 158   0.028160  1.004768     NaN
# 215   0.019621  1.008130     NaN
# 164   0.040877  1.010135     NaN
# 162   0.040332  1.011058     NaN
# 8393  0.000363  1.015378     NaN
# 4870  0.001090  1.020427     NaN
# 3210  0.000545  1.021032     NaN
# 4869  0.001090  1.021114     NaN
# 154   0.024344  1.022656     NaN
# 996   0.000908  1.023169     NaN
# 6213  0.000545  1.027016     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 비즈
# Out:
#                                                raw_data       word  cluster  \
# 9     [0.269368439912796, 0.7339116930961609, -0.329...     crypto        1
# 336   [0.3260185718536377, 0.6639740467071533, -0.37...   exchange        1
# 422   [0.3044511377811432, 0.7133076786994934, -0.37...    company        1
# 86    [0.3564906120300293, 0.7675235867500305, -0.43...       make        1
# 414   [0.2861108183860779, 0.7087077498435974, -0.37...       user        1
# 376   [0.3302368223667145, 0.6592748761177063, -0.42...    network        1
# 1110  [0.3278198540210724, 0.7048673629760742, -0.40...      token        1
# 222   [0.3479985296726227, 0.7382375001907349, -0.44...       many        1
# 233   [0.32439807057380676, 0.8554901480674744, -0.3...      money        1
# 101   [0.4058472812175751, 0.8006916046142578, -0.43...    include        1
# 655   [0.374870628118515, 0.7095893621444702, -0.384...       need        1
# 371   [0.30266499519348145, 0.8099890351295471, -0.3...     people        1
# 1169  [0.37555238604545593, 0.7692740559577942, -0.3...       work        1
# 549   [0.38693562150001526, 0.7821394801139832, -0.3...     system        1
# 188   [0.29917293787002563, 0.7456686496734619, -0.3...       fund        1
# 718   [0.4124615788459778, 0.7437859773635864, -0.40...   business        1
# 213   [0.38705939054489136, 0.6676697134971619, -0.3...   platform        1
# 12    [0.3249049186706543, 0.7251870036125183, -0.38...       firm        1
# 982   [0.3509387671947479, 0.7306037545204163, -0.44...       know        1
# 768   [0.3055650293827057, 0.7453753352165222, -0.28...      world        1
# 515   [0.31439322233200073, 0.8065134286880493, -0.2...  financial        1
# 421   [0.3659129738807678, 0.6691363453865051, -0.37...   security        1
# 693   [0.4094077944755554, 0.7618862986564636, -0.40...      state        1
# 404   [0.2812073528766632, 0.7668356895446777, -0.31...    service        1
# 898   [0.32146427035331726, 0.6863125562667847, -0.4...      offer        1
# 1970  [0.3630363643169403, 0.708834707736969, -0.385...     create        1
# 237   [0.3299754858016968, 0.7638534307479858, -0.36...     global        1
# 643   [0.41557031869888306, 0.7859896421432495, -0.4...       tell        1
# 394   [0.3106946051120758, 0.6536677479743958, -0.36...    provide        1
# 36    [0.21418587863445282, 0.8225209712982178, -0.2...      asset        1
#
#                                                centroid  distance     tfidf  \
# 9     [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.012836  0.184764
# 336   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.004006  0.127718
# 422   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.004155  0.116272
# 86    [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.005525  0.106462
# 414   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.006385  0.099376
# 376   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.007072  0.084842
# 1110  [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.003559  0.068310
# 222   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.004931  0.068128
# 233   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.029134  0.086296
# 101   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.001418  0.058499
# 655   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.000584  0.054684
# 371   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.018825  0.072488
# 1169  [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.008424  0.060680
# 549   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.013302  0.063586
# 188   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.009180  0.058499
# 718   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.000519  0.049234
# 213   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.023308  0.071762
# 12    [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.005710  0.052868
# 982   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.004220  0.049052
# 768   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.023296  0.067038
# 515   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.028900  0.072488
# 421   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.000363  0.043420
# 693   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.001325  0.044147
# 404   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.015269  0.057954
# 898   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.003046  0.045601
# 1970  [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.001235  0.043602
# 237   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.011784  0.053958
# 643   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.002800  0.044147
# 394   [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.002759  0.043965
# 36    [0.041862015, 0.072425395, -0.0416846, 0.01116...  0.065564  0.106643
#
#          score closer#
# 9     0.828072     NaN
# 336   0.876289     NaN
# 422   0.887883     NaN
# 86    0.899063     NaN
# 414   0.907009     NaN
# 376   0.922229     NaN
# 1110  0.935249     NaN
# 222   0.936803     NaN
# 233   0.942838     NaN
# 101   0.942918     NaN
# 655   0.945900     NaN
# 371   0.946336     NaN
# 1169  0.947745     NaN
# 549   0.949715     NaN
# 188   0.950680     NaN
# 718   0.951285     NaN
# 213   0.951547     NaN
# 12    0.952843     NaN
# 982   0.955168     NaN
# 768   0.956257     NaN
# 515   0.956411     NaN
# 421   0.956943     NaN
# 693   0.957178     NaN
# 404   0.957315     NaN
# 898   0.957445     NaN
# 1970  0.957633     NaN
# 237   0.957826     NaN
# 643   0.958653     NaN
# 394   0.958793     NaN
# 36    0.958920     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(50)   # 투자
# Out:
#                                                raw_data            word  \
# 32    [0.42545872926712036, 0.74234938621521, -0.581...          market
# 185   [0.3159934878349304, 0.6597476005554199, -0.45...  cryptocurrency
# 308   [0.42212873697280884, 0.6467623710632324, -0.5...           trade
# 16    [0.36556893587112427, 0.7078716158866882, -0.4...            data
# 39    [0.3834993541240692, 0.7502890229225159, -0.51...            take
# 311   [0.4360218346118927, 0.6087679862976074, -0.54...          report
# 91    [0.36281460523605347, 0.7664507627487183, -0.5...        investor
# 122   [0.23003320395946503, 0.6930062770843506, -0.5...            mine
# 112   [0.36650240421295166, 0.6888969540596008, -0.5...            come
# 373   [0.2979477345943451, 0.6792733073234558, -0.44...     transaction
# 189   [0.36972910165786743, 0.6811088919639587, -0.4...        interest
# 37    [0.3254769742488861, 0.6928730607032776, -0.46...          future
# 255   [0.3658050000667572, 0.6933836936950684, -0.46...            look
# 95    [0.38288819789886475, 0.6502353549003601, -0.4...            hold
# 21    [0.3960394263267517, 0.6246436834335327, -0.46...        continue
# 285   [0.42033863067626953, 0.7323529124259949, -0.6...           first
# 171   [0.3968711197376251, 0.623079240322113, -0.491...          accord
# 865   [0.39578327536582947, 0.7174987196922302, -0.4...            give
# 190   [0.3315350413322449, 0.6713955402374268, -0.44...           large
# 2986  [0.3140048384666443, 0.6445697546005249, -0.45...   cointelegraph
# 167   [0.3237411379814148, 0.5908266305923462, -0.43...          number
# 214   [0.3791089653968811, 0.6550872921943665, -0.50...          supply
# 67    [0.34617099165916443, 0.6550803780555725, -0.4...            mean
# 102   [0.42587172985076904, 0.7145912051200867, -0.5...           point
# 59    [0.41974419355392456, 0.7317547798156738, -0.4...            call
# 823   [0.45648983120918274, 0.6921374201774597, -0.5...            find
# 55    [0.37972110509872437, 0.6684314012527466, -0.4...            lead
# 416   [0.37554892897605896, 0.6388756632804871, -0.4...            open
# 492   [0.3899659514427185, 0.6538839340209961, -0.51...           start
# 1089  [0.3180111348628998, 0.5857680439949036, -0.38...           major
# 666   [0.3562111556529999, 0.6889382600784302, -0.41...            cash
# 202   [0.3866024315357208, 0.692835807800293, -0.428...     coronavirus
# 1121  [0.2781708836555481, 0.5563408136367798, -0.38...        ethereum
# 590   [0.35703083872795105, 0.6026058197021484, -0.4...            risk
# 377   [0.33328112959861755, 0.6200587749481201, -0.4...           share
# 89    [0.4038478434085846, 0.6307218074798584, -0.51...            sell
# 77    [0.35365352034568787, 0.5989682674407959, -0.3...          change
# 58    [0.4111633598804474, 0.6156002283096313, -0.52...          demand
# 1157  [0.3470933139324188, 0.6085724830627441, -0.40...         binance
# 287   [0.3190905749797821, 0.5951207280158997, -0.47...            coin
# 1068  [0.32995739579200745, 0.6365174651145935, -0.3...        contract
# 556   [0.3771144151687622, 0.6319088935852051, -0.41...        protocol
# 11    [0.31097614765167236, 0.5490742921829224, -0.3...        research
# 76    [0.37918198108673096, 0.5506085157394409, -0.4...            keep
# 14    [0.379983127117157, 0.6190404891967773, -0.418...           begin
# 470   [0.3542759120464325, 0.5634210705757141, -0.41...            term
# 931   [0.41136500239372253, 0.5714743733406067, -0.4...            view
# 307   [0.3616275191307068, 0.5974264740943909, -0.40...            cost
# 633   [0.3265584409236908, 0.5347778797149658, -0.38...          return
# 3393  [0.42285385727882385, 0.6474077701568604, -0.4...          attack
#
#       cluster                                           centroid  distance  \
# 32          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.017949
# 185         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.005298
# 308         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.010098
# 16          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.004384
# 39          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.004022
# 311         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.009527
# 91          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.014306
# 122         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.020541
# 112         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003832
# 373         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.006806
# 189         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003672
# 37          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.008832
# 255         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002496
# 95          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003250
# 21          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000679
# 285         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.009586
# 171         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003406
# 865         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002567
# 190         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.006263
# 2986        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.005293
# 167         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002381
# 214         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.005004
# 67          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003184
# 102         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000887
# 59          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002460
# 823         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000767
# 55          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000902
# 416         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000471
# 492         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.007236
# 1089        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.001926
# 666         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.005912
# 202         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.003774
# 1121        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.006571
# 590         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.001652
# 377         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.001543
# 89          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.010154
# 77          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.001543
# 58          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.009813
# 1157        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002850
# 287         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.010716
# 1068        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.004180
# 556         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000900
# 11          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002941
# 76          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002681
# 14          2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.001119
# 470         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000408
# 931         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.002208
# 307         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000375
# 633         2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000457
# 3393        2  [0.04116668, 0.06433133, -0.045606505, 0.01165...  0.000161
#
#          tfidf     score closer#
# 32    0.190032  0.827917     NaN
# 185   0.111549  0.893750     NaN
# 308   0.100830  0.909268     NaN
# 16    0.076849  0.927535     NaN
# 39    0.076304  0.927718     NaN
# 311   0.077939  0.931588     NaN
# 91    0.081027  0.933279     NaN
# 122   0.086659  0.933882     NaN
# 112   0.064131  0.939700     NaN
# 373   0.060498  0.946308     NaN
# 189   0.056319  0.947353     NaN
# 37    0.061406  0.947426     NaN
# 255   0.053413  0.949083     NaN
# 95    0.053594  0.949656     NaN
# 21    0.049961  0.950718     NaN
# 285   0.058681  0.950905     NaN
# 171   0.052323  0.951083     NaN
# 865   0.045782  0.956785     NaN
# 190   0.048326  0.957938     NaN
# 2986  0.046872  0.958421     NaN
# 167   0.043784  0.958597     NaN
# 214   0.045782  0.959222     NaN
# 67    0.043602  0.959582     NaN
# 102   0.040150  0.960737     NaN
# 59    0.039424  0.963036     NaN
# 823   0.037062  0.963706     NaN
# 55    0.037062  0.963840     NaN
# 416   0.036153  0.964317     NaN
# 492   0.042512  0.964724     NaN
# 1089  0.037062  0.964864     NaN
# 666   0.040695  0.965217     NaN
# 202   0.035063  0.968711     NaN
# 1121  0.037788  0.968783     NaN
# 590   0.032702  0.968951     NaN
# 377   0.031975  0.969568     NaN
# 89    0.040332  0.969822     NaN
# 77    0.031430  0.970113     NaN
# 58    0.039424  0.970390     NaN
# 1157  0.032157  0.970694     NaN
# 287   0.039424  0.971292     NaN
# 1068  0.032702  0.971479     NaN
# 556   0.028341  0.972559     NaN
# 11    0.029613  0.973328     NaN
# 76    0.029068  0.973613     NaN
# 14    0.026706  0.974412     NaN
# 470   0.025798  0.974610     NaN
# 931   0.027433  0.974775     NaN
# 307   0.025435  0.974940     NaN
# 633   0.025253  0.975204     NaN
# 3393  0.024890  0.975271     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 거래소, 돈
# Out:
#                                                raw_data      word  cluster  \
# 1     [0.3067438304424286, 0.6765769720077515, -0.66...   bitcoin        3
# 42    [0.6572409272193909, 0.6469507813453674, -0.98...     price        3
# 44    [0.3708641827106476, 0.6786584258079529, -0.60...      time        3
# 220   [0.3733411133289337, 0.6557844877243042, -0.61...      year        3
# 166   [0.6569512486457825, 0.6965705752372742, -0.76...      move        3
# 1095  [0.6844213008880615, 0.6565432548522949, -0.76...   support        3
# 204   [0.43434494733810425, 0.5883971452713013, -0.6...      week        3
# 20    [0.3989255428314209, 0.5903844237327576, -0.57...     march        3
# 23    [0.34354260563850403, 0.6047750115394592, -0.6...      last        3
# 175   [0.325013667345047, 0.6206688284873962, -0.566...  increase        3
# 17    [0.40350842475891113, 0.6177577972412109, -0.6...     month        3
# 118   [0.5318087935447693, 0.58433598279953, -0.5994...     april        3
# 75    [0.48096585273742676, 0.6532999277114868, -0.5...    trader        3
# 281   [0.525122344493866, 0.5926434993743896, -0.628...      show        3
# 833   [0.7322377562522888, 0.7051160335540771, -0.75...    source        3
# 97    [0.41497817635536194, 0.5750147700309753, -0.5...      next        3
# 219   [0.4958855211734772, 0.6049434542655945, -0.56...   percent        3
# 69    [0.43573784828186035, 0.5130431652069092, -0.5...      rise        3
# 284   [0.8092003464698792, 0.7583745718002319, -0.88...      bull        3
# 622   [0.6472011804580688, 0.5992771983146667, -0.65...     daily        3
#
#                                                centroid  distance     tfidf  \
# 1     [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.025012  0.463817
# 42    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.061801  0.193303
# 44    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.015027  0.116091
# 220   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.011582  0.090474
# 166   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.002431  0.063041
# 1095  [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.009249  0.061951
# 204   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.002240  0.051959
# 20    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.003259  0.051232
# 23    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.010966  0.058863
# 175   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.014477  0.061043
# 17    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.005058  0.050324
# 118   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.007027  0.051414
# 75    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.002219  0.045964
# 281   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.001201  0.044329
# 833   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.003302  0.042512
# 97    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.001027  0.035972
# 219   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.001746  0.035063
# 69    [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.001883  0.034882
# 284   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.006943  0.039060
# 622   [0.053729326, 0.06472077, -0.06554112, 0.01595...  0.005435  0.033428
#
#          score closer#
# 1     0.561195     NaN
# 42    0.868498     NaN
# 44    0.898936     NaN
# 220   0.921108     NaN
# 166   0.939389     NaN
# 1095  0.947298     NaN
# 204   0.950281     NaN
# 20    0.952026     NaN
# 23    0.952103     NaN
# 175   0.953435     NaN
# 17    0.954734     NaN
# 118   0.955613     NaN
# 75    0.956255     NaN
# 281   0.956872     NaN
# 833   0.960790     NaN
# 97    0.965055     NaN
# 219   0.966682     NaN
# 69    0.967002     NaN
# 284   0.967882     NaN
# 622   0.972006     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 기술
# Out:
# 508

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 비즈
# Out:
# 5040

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 투자
# Out:
# 4731

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 거래소 돈
# Out:
# 821

# %%
temp_cluster_result['category'] = 1 # 1 영문뉴스, 2 국문뉴스 , 3 twitter
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 9  # 기술
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 7  # 비즈
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label'] = 11 # 투자
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 12 # 거래소 돈

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 1677.6201171875

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [2 1 0 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -1677.6201171875

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.7236957

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(30,'score') # 인플
# Out:
#                                                 raw_data              word  \
# 8049   [0.0132444454357028, 0.0204877108335495, -0.01...          drawback
# 7234   [0.016481913626194, 0.018127622082829475, -0.0...        maximalist
# 7942   [0.013701875694096088, 0.02410077303647995, -0...        philippine
# 9156   [0.014857098460197449, 0.02178393490612507, -0...            county
# 4384   [0.01717185229063034, 0.01922483928501606, -0....         financier
# 7313   [0.014479799196124077, 0.024387795478105545, -...            siemer
# 5770   [0.013056449592113495, 0.019650479778647423, -...          loeffler
# 9027   [0.013454356230795383, 0.018326634541153908, -...          overhaul
# 5179   [0.009876450523734093, 0.020976105704903603, -...          hygienic
# 9059   [0.016154497861862183, 0.021589580923318863, -...        threadbare
# 7009   [0.009829412214457989, 0.0245643500238657, -0....          chamorro
# 9739   [0.010499801486730576, 0.0240811537951231, -0....             __and
# 9710   [0.009149418212473392, 0.017412977293133736, -...            barber
# 4690   [0.012029089964926243, 0.023377418518066406, -...           onpoint
# 8914   [0.018948068842291832, 0.01879018358886242, -0...          baseless
# 3907   [0.01183568686246872, 0.023649830371141434, -0...  cryptoconfidence
# 10724  [0.013843748718500137, 0.024579035118222237, -...           whoever
# 3489   [0.008527902886271477, 0.01902718096971512, -0...            tippin
# 10723  [0.016367098316550255, 0.019421732053160667, -...          screener
# 9657   [0.013070271350443363, 0.024638671427965164, -...       trustworthy
# 10356  [0.014083954505622387, 0.021402405574917793, -...              dish
# 3757   [0.011551998555660248, 0.018549786880612373, -...           concoct
# 8713   [0.013316803611814976, 0.01643586903810501, -0...          poloniex
# 10905  [0.011354165151715279, 0.022249441593885422, -...            docker
# 10025  [0.011047917418181896, 0.023129669949412346, -...              eink
# 9341   [0.01496098656207323, 0.019052138552069664, -0...          failsafe
# 5846   [0.011134804226458073, 0.018574263900518417, -...             repel
# 7282   [0.015987088903784752, 0.0225907601416111, -0....       procurement
# 10301  [0.019074594601988792, 0.02482481673359871, -0...       preparatory
# 2154   [0.010387329384684563, 0.02570142038166523, -0...              kpmg
#
#        cluster                                           centroid  distance  \
# 8049         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.025247
# 7234         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.025431
# 7942         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.026449
# 9156         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027011
# 4384         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027235
# 7313         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027130
# 5770         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027772
# 9027         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027911
# 5179         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028009
# 9059         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027901
# 7009         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028084
# 9739         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027925
# 9710         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027929
# 4690         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.027992
# 8914         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028217
# 3907         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028282
# 10724        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028123
# 3489         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028306
# 10723        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028132
# 9657         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028315
# 10356        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028164
# 3757         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028245
# 8713         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028709
# 10905        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028441
# 10025        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028634
# 9341         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028638
# 5846         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028459
# 7282         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028739
# 10301        0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028597
# 2154         0  [0.012976123, 0.020620044, -0.013239611, 0.003...  0.028618
#
#           tfidf     score closer#
# 8049   0.000545  1.024702     NaN
# 7234   0.000363  1.025068     NaN
# 7942   0.000363  1.026085     NaN
# 9156   0.000363  1.026647     NaN
# 4384   0.000363  1.026871     NaN
# 7313   0.000182  1.026949     NaN
# 5770   0.000363  1.027409     NaN
# 9027   0.000363  1.027548     NaN
# 5179   0.000363  1.027646     NaN
# 9059   0.000182  1.027719     NaN
# 7009   0.000363  1.027720     NaN
# 9739   0.000182  1.027743     NaN
# 9710   0.000182  1.027747     NaN
# 4690   0.000182  1.027810     NaN
# 8914   0.000363  1.027854     NaN
# 3907   0.000363  1.027919     NaN
# 10724  0.000182  1.027942     NaN
# 3489   0.000363  1.027943     NaN
# 10723  0.000182  1.027950     NaN
# 9657   0.000363  1.027951     NaN
# 10356  0.000182  1.027982     NaN
# 3757   0.000182  1.028064     NaN
# 8713   0.000545  1.028164     NaN
# 10905  0.000182  1.028259     NaN
# 10025  0.000363  1.028271     NaN
# 9341   0.000363  1.028275     NaN
# 5846   0.000182  1.028277     NaN
# 7282   0.000363  1.028375     NaN
# 10301  0.000182  1.028415     NaN
# 2154   0.000182  1.028437     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(20,'score') # 비즈
# Out:
#                                                raw_data       word  cluster  \
# 772   [0.36382976174354553, 0.5769352912902832, -0.3...       live        1
# 77    [0.35365352034568787, 0.5989682674407959, -0.3...     change        1
# 322   [0.37115955352783203, 0.5999478697776794, -0.3...  potential        1
# 27    [0.3496643304824829, 0.6079148650169373, -0.38...       note        1
# 14    [0.379983127117157, 0.6190404891967773, -0.418...      begin        1
# 948   [0.35323596000671387, 0.5635151267051697, -0.3...       team        1
# 392   [0.37879425287246704, 0.5783516764640808, -0.3...    release        1
# 702   [0.3461487293243408, 0.5811603665351868, -0.37...      focus        1
# 168   [0.3320976197719574, 0.5759674906730652, -0.36...    address        1
# 1536  [0.34376847743988037, 0.6035947799682617, -0.3...    receive        1
# 294   [0.35223057866096497, 0.5662901401519775, -0.3...       list        1
# 1608  [0.33614569902420044, 0.5823506712913513, -0.3...       able        1
# 307   [0.3616275191307068, 0.5974264740943909, -0.40...       cost        1
# 274   [0.33948662877082825, 0.557030439376831, -0.37...    explain        1
# 502   [0.3199191689491272, 0.6015257835388184, -0.36...  community        1
# 1157  [0.3470933139324188, 0.6085724830627441, -0.40...    binance        1
# 556   [0.3771144151687622, 0.6319088935852051, -0.41...   protocol        1
# 621   [0.3314684331417084, 0.5628156065940857, -0.35...      write        1
# 590   [0.35703083872795105, 0.6026058197021484, -0.4...       risk        1
# 460   [0.3378847539424896, 0.5567365288734436, -0.34...       name        1
#
#                                                centroid  distance     tfidf  \
# 772   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.129059  0.017441
# 77    [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.170709  0.031430
# 322   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.168489  0.023618
# 27    [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.186905  0.027615
# 14    [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.214451  0.026706
# 948   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.213282  0.022709
# 392   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.235274  0.020166
# 702   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.243333  0.023436
# 168   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.248914  0.024526
# 1536  [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.287858  0.023073
# 294   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.295464  0.024344
# 1608  [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.306476  0.024163
# 307   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.308398  0.025435
# 274   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.314800  0.020711
# 502   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.352709  0.027615
# 1157  [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.366360  0.032157
# 556   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.374530  0.028341
# 621   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.381029  0.024890
# 590   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.402241  0.032702
# 460   [0.38107428, 0.598354, -0.39430684, 0.10533272...  0.391662  0.017623
#
#          score closer#
# 772   1.111618     NaN
# 77    1.139279     NaN
# 322   1.144871     NaN
# 27    1.159290     NaN
# 14    1.187745     NaN
# 948   1.190572     NaN
# 392   1.215108     NaN
# 702   1.219897     NaN
# 168   1.224388     NaN
# 1536  1.264786     NaN
# 294   1.271119     NaN
# 1608  1.282313     NaN
# 307   1.282963     NaN
# 274   1.294089     NaN
# 502   1.325094     NaN
# 1157  1.334204     NaN
# 556   1.346188     NaN
# 621   1.356140     NaN
# 590   1.369539     NaN
# 460   1.374040     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(30,'score')  # 이슈
# Out:
#                                                raw_data         word  cluster  \
# 260   [0.19159181416034698, 0.3179664611816406, -0.2...       expert        2
# 2929  [0.19195900857448578, 0.3100903630256653, -0.1...       anyone        2
# 745   [0.20401079952716827, 0.3184181749820709, -0.2...      america        2
# 2680  [0.19818539917469025, 0.30537834763526917, -0....       letter        2
# 179   [0.18093803524971008, 0.31976062059402466, -0....       expand        2
# 29    [0.18723556399345398, 0.3286391496658325, -0.2...     resource        2
# 2131  [0.19991740584373474, 0.32455974817276, -0.209...      medical        2
# 2106  [0.2049940526485443, 0.3120289742946625, -0.20...     engineer        2
# 1769  [0.20085783302783966, 0.32270535826683044, -0....      present        2
# 3671  [0.1833527535200119, 0.30591341853141785, -0.2...     makerdao        2
# 923   [0.18814584612846375, 0.31213441491127014, -0....     official        2
# 3503  [0.2144821435213089, 0.30335330963134766, -0.2...       domain        2
# 1393  [0.2045276165008545, 0.31392163038253784, -0.2...      episode        2
# 405   [0.1841069906949997, 0.31134289503097534, -0.1...     operator        2
# 1125  [0.17677819728851318, 0.31409865617752075, -0....       liquid        2
# 2055  [0.19155457615852356, 0.32878124713897705, -0....       decide        2
# 2337  [0.1952558159828186, 0.2993184030056, -0.20628...      improve        2
# 447   [0.1998693197965622, 0.3342011868953705, -0.21...       matter        2
# 96    [0.2056615799665451, 0.3028293251991272, -0.21...     register        2
# 1018  [0.20539657771587372, 0.32410383224487305, -0....       office        2
# 2220  [0.21207113564014435, 0.30331167578697205, -0....      malware        2
# 868   [0.19440831243991852, 0.29458317160606384, -0....        fight        2
# 4319  [0.19165544211864471, 0.30397331714630127, -0....     document        2
# 0     [0.20984680950641632, 0.3081601858139038, -0.2...       spread        2
# 378   [0.1763080358505249, 0.30568912625312805, -0.1...      history        2
# 1407  [0.18694035708904266, 0.3019832372665405, -0.2...  electricity        2
# 2892  [0.17880834639072418, 0.3127359449863434, -0.1...      promise        2
# 380   [0.16990923881530762, 0.31699204444885254, -0....         rely        2
# 1359  [0.20119540393352509, 0.3221386969089508, -0.2...      speaker        2
# 615   [0.20572620630264282, 0.3017638623714447, -0.2...     critical        2
#
#                                                centroid  distance     tfidf  \
# 260   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.072201  0.007812
# 2929  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.076234  0.008902
# 745   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.075228  0.007085
# 2680  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.076105  0.006359
# 179   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.084994  0.008902
# 29    [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.089771  0.009629
# 2131  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.090605  0.007812
# 2106  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.092289  0.006359
# 1769  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.093698  0.007085
# 3671  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.094633  0.007630
# 923   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.100688  0.008539
# 3503  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.101657  0.007085
# 1393  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.105714  0.009084
# 405   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.105011  0.007812
# 1125  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.107022  0.008357
# 2055  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.118336  0.009084
# 2337  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.120653  0.008902
# 447   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.121933  0.009992
# 96    [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.121626  0.009084
# 1018  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.120275  0.007267
# 2220  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.125623  0.006177
# 868   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.130501  0.006904
# 4319  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.131504  0.006722
# 0     [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.134564  0.007994
# 378   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.138397  0.009265
# 1407  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.140761  0.007449
# 2892  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.140831  0.007449
# 380   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.145529  0.009629
# 1359  [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.143375  0.006177
# 615   [0.19574606, 0.31446296, -0.20685917, 0.054049...  0.147004  0.007812
#
#          score closer#
# 260   1.064389     NaN
# 2929  1.067332     NaN
# 745   1.068142     NaN
# 2680  1.069747     NaN
# 179   1.076092     NaN
# 29    1.080142     NaN
# 2131  1.082793     NaN
# 2106  1.085930     NaN
# 1769  1.086612     NaN
# 3671  1.087002     NaN
# 923   1.092150     NaN
# 3503  1.094571     NaN
# 1393  1.096631     NaN
# 405   1.097199     NaN
# 1125  1.098665     NaN
# 2055  1.109252     NaN
# 2337  1.111751     NaN
# 447   1.111940     NaN
# 96    1.112543     NaN
# 1018  1.113008     NaN
# 2220  1.119446     NaN
# 868   1.123598     NaN
# 4319  1.124782     NaN
# 0     1.126570     NaN
# 378   1.129131     NaN
# 1407  1.133313     NaN
# 2892  1.133382     NaN
# 380   1.135900     NaN
# 1359  1.137198     NaN
# 615   1.139192     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 긍정
# Out:
#                                                raw_data            word  \
# 7867  [0.08363021910190582, 0.12801110744476318, -0....           bonus
# 2048  [0.08516911417245865, 0.1318906992673874, -0.0...          evolve
# 3454  [0.08397036790847778, 0.12600453197956085, -0....           click
# 4492  [0.08600632101297379, 0.12808634340763092, -0....     implication
# 4439  [0.07780243456363678, 0.12390246987342834, -0....            film
# 1928  [0.07840791344642639, 0.12892073392868042, -0....           latin
# 1087  [0.07512491196393967, 0.12676069140434265, -0....            kong
# 5665  [0.07566437870264053, 0.12581820785999298, -0....       elaborate
# 407   [0.08432457596063614, 0.13713492453098297, -0....           cycle
# 552   [0.07855374366044998, 0.12899534404277802, -0....      resilience
# 9503  [0.08094543218612671, 0.12622815370559692, -0....          nascar
# 7722  [0.0797656923532486, 0.12580159306526184, -0.0...           shrem
# 3345  [0.0869724228978157, 0.12469427287578583, -0.0...       knowledge
# 5871  [0.07640671730041504, 0.12584900856018066, -0....            load
# 1479  [0.07230458408594131, 0.12723569571971893, -0....       brokerage
# 2444  [0.0858994573354721, 0.13159455358982086, -0.0...         goldman
# 8398  [0.08391766995191574, 0.12537628412246704, -0....            abra
# 1463  [0.07396173477172852, 0.1301334947347641, -0.0...      conclusion
# 5832  [0.07902225852012634, 0.12564221024513245, -0....           adapt
# 2385  [0.08718875050544739, 0.12912751734256744, -0....  responsibility
#
#       cluster                                           centroid  distance  \
# 7867        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.035887
# 2048        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.037415
# 3454        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.037539
# 4492        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.038929
# 4439        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.037599
# 1928        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.039556
# 1087        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.042387
# 5665        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.043163
# 407         3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.045730
# 552         3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.045512
# 9503        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.045732
# 7722        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.048362
# 3345        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.048970
# 5871        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.048155
# 1479        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.050208
# 2444        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.050651
# 8398        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.050385
# 1463        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.051292
# 5832        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.052174
# 2385        3  [0.08184683, 0.12853675, -0.084204525, 0.02246...  0.052045
#
#          tfidf     score closer#
# 7867  0.001635  1.034252     NaN
# 2048  0.002907  1.034508     NaN
# 3454  0.002907  1.034632     NaN
# 4492  0.003634  1.035296     NaN
# 4439  0.001998  1.035600     NaN
# 1928  0.002180  1.037376     NaN
# 1087  0.002725  1.039661     NaN
# 5665  0.002907  1.040256     NaN
# 407   0.003270  1.042460     NaN
# 552   0.002907  1.042606     NaN
# 9503  0.001272  1.044461     NaN
# 7722  0.002907  1.045455     NaN
# 3345  0.002907  1.046064     NaN
# 5871  0.001998  1.046157     NaN
# 1479  0.002725  1.047483     NaN
# 2444  0.002725  1.047926     NaN
# 8398  0.002362  1.048023     NaN
# 1463  0.002907  1.048385     NaN
# 5832  0.002725  1.049449     NaN
# 2385  0.002543  1.049502     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) #인플
# Out:
# 8816

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) #비즈
# Out:
# 346

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) #이슈
# Out:
# 572

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) #긍정
# Out:
# 1366

# %%
temp_cluster_result1['category'] = 1 # 1 영문뉴스, 2 국문뉴스 , 3 twitter
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 6 # 인플
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 7 # 비즈
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 5 # 이슈
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 1 # 긍정

# %%
temp_cluster_result1['result'] = 1 # 1 상승 2 하락 3 보합
temp_cluster_result['result'] = 1
temp_cluster_result1['Silhouette'] = 0.7236957
temp_cluster_result['Silhouette'] = 0.7236957

# %%
temp_cluster_result1.to_csv("../cluster/en_news/2020_up1/(test)_en_news_2020_up2_euclidean.csv")
temp_cluster_result.to_csv("../cluster/en_news/2020_up1/(test)_en_news_2020_up2_cosine.csv")

# %%
word_vectors = model.wv

# %%
vocabs = word_vectors.vocab.keys()

# %%
word_vector_list = [word_vectors[v]for v in vocabs]

# %%
print(word_vectors.similarity(w1='little',w2='push'))
# Out:
# 0.92550874

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
xys = pca.fit_transform(word_vector_list)

# %%
xys
# Out:
# array([[-0.5680961 ,  0.0545366 ],
#        [ 2.50050079,  0.29734324],
#        [ 6.55864352,  5.98708902],
#        ...,
#        [-0.48589998,  0.0281039 ],
#        [-0.44965773,  0.0346795 ],
#        [-0.52126418,  0.02389634]])

# %%
xys[:,0]
# Out:
# array([-0.5680961 ,  2.50050079,  6.55864352, ..., -0.48589998,
#        -0.44965773, -0.52126418])

# %%
xys[:,1]
# Out:
# array([0.0545366 , 0.29734324, 5.98708902, ..., 0.0281039 , 0.0346795 ,
#        0.02389634])

# %%
xs = xys[:,0]
ys = xys[:,1]

# %%
def plot_2d_graph(vocabs,xs,ys) :
    plt.figure(figsize=(8,6))
    plt.scatter(xs,ys,marker='o')
    for i,v in enumerate(vocabs) :
        plt.annotate(v,xy=(xs[i],ys[i]))

# %%
plot_2d_graph(vocabs,xs,ys)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 9975 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 9975 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127935 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127935 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 129301 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 129301 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
nltk.help.upenn_tagset
# Out:
# <function nltk.help.upenn_tagset(tagpattern=None)>
