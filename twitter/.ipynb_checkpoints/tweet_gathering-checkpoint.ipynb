# %%
import GetOldTweets3 as got
import datetime
import time
import pandas as pd

# %%
days_range = []

query = 'bitcoin'

#query = 'ethereum'

#start = datetime.datetime.strptime("2020-5-8", "%Y-%m-%d")
#end = datetime.datetime.strptime("2020-5-12", "%Y-%m-%d")

start = datetime.datetime.strptime("2020-4-21", "%Y-%m-%d")
end = datetime.datetime.strptime("2020-5-7", "%Y-%m-%d")

#start = datetime.datetime.strptime("2017-3-19", "%Y-%m-%d")
#end = datetime.datetime.strptime("2017-6-20", "%Y-%m-%d")
#start = datetime.datetime.strptime("2017-9-15", "%Y-%m-%d")
#end = datetime.datetime.strptime("2017-12-26", "%Y-%m-%d")
#start = datetime.datetime.strptime("2018-1-7", "%Y-%m-%d")
#end = datetime.datetime.strptime("2018-2-5", "%Y-%m-%d")
#start = datetime.datetime.strptime("2018-9-9", "%Y-%m-%d")
#end = datetime.datetime.strptime("2018-11-18", "%Y-%m-%d")
#start = datetime.datetime.strptime("2018-11-19", "%Y-%m-%d")
#end = datetime.datetime.strptime("2018-12-14", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-4-2", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-6-26", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-7-10", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-7-16", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-7-31", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-8-8", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-8-10", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-8-14", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-9-23", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-9-26", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-10-25", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-10-27", "%Y-%m-%d")
#start = datetime.datetime.strptime("2019-11-8", "%Y-%m-%d")
#end = datetime.datetime.strptime("2019-11-24", "%Y-%m-%d")
#start = datetime.datetime.strptime("2020-1-3", "%Y-%m-%d")
#end = datetime.datetime.strptime("2020-2-11", "%Y-%m-%d")
#start = datetime.datetime.strptime("2020-3-8", "%Y-%m-%d")
#end = datetime.datetime.strptime("2020-3-30", "%Y-%m-%d")
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]

for date in date_generated:
    days_range.append(date.strftime("%Y-%m-%d"))

print("=== 설정된 트윗 수집 기간은 {} 에서 {} 까지 입니다 ===".format(days_range[0], days_range[-1]))
print("=== 총 {}일 간의 데이터 수집 ===".format(len(days_range)))

# 수집 기간 맞추기
start_date = days_range[0]
end_date = (datetime.datetime.strptime(days_range[-1], "%Y-%m-%d")
            + datetime.timedelta(days=1)).strftime("%Y-%m-%d")
# Out:
# === 설정된 트윗 수집 기간은 2020-04-21 에서 2020-05-06 까지 입니다 ===
# === 총 16일 간의 데이터 수집 ===

# %%
header = ['period','username','date','retweets','favorites','hashtags','text']
tweetSet = pd.DataFrame(columns=header)

# %%
data = pd.read_csv('influencer.csv', error_bad_lines=False)

# %%
data['TweetAccount'] = data['TweetAccount'].apply(lambda x : x.replace('@',''))

# %%
data
# Out:
#     No                        Name Followers     TweetAccount  \
# 0    1                  Justin Sun        2M    justinsuntron
# 1    2                 John McAfee        1M   officialmcafee
# 2    3             Vitalic Buterin    892.7K   VitalikButerin
# 3    4                 Charlie Lee    831.3K      SatoshiLite
# 4    5                       Naval    776.3K            naval
# 5    6             Marc Andreeseen    735.9K           pmarca
# 6    7                 Fred Wilson    662.7K       fredwilson
# 7    8                   Roger Ver      597K        rogerkver
# 8    9                 Chris Dixon    574.2K           cdixon
# 9   10        Andreas Antonopoulos    507.4K         aantonop
# 10  11  Changpeng Zhao  CZ Binance    490.1K       cz_binance
# 11  12               Erik Voorhees    362.9K     ErikVoorhees
# 12  13                Peter Brandt    327.6K     PeterLBrandt
# 13  14             Brian Armstrong    323.6K  brian_armstrong
# 14  15                        Pomp    313.4K       Apompliano
# 15  16                  Nick Szabo    243.4K       NickSzabo4
# 16  17           Michael Arrington    239.6K        arrington
# 17  18                  Max Keiser    227.7K        maxkeiser
# 18  19                Jameson Lopp    216.1K             lopp
# 19  20                 Luke Martin    215.1K   VentureCoinist
# 20  21              Tuur Demeester    204.4K    TuurDemeester
# 21  22               Barry Silbert    200.6K     barrysilbert
# 22  23                   Tone Vays      197K         ToneVays
# 23  24                   Adam Back    187.7K          adam3us
# 24  25               Vinny Lingham    170.1K     VinnyLingham
# 25  26               Charlie Shrem      167K     CharlieShrem
# 26  27              Gavin Andresen    154.6K    gavinandresen
# 27  28           Balaji Srinivasan    149.5K          balajis
# 28  29                    Ari Paul    139.3K     AriDavidPaul
# 29  30           Michael Novograts    135.5K        novogratz
# 30  31                   Willy Woo    124.6K         woonomic
# 31  32              Chris Burniske    121.6K        cburniske
# 32  33                 Laura Shine    116.8K        laurashin
# 33  34                Joseph Lubin    112.8K   ethereumJoseph
# 34  35                  Ran Neuner      111K     cryptomanran
# 35  36                    Jihan Wu    110.1K          JihanWu
# 36  37           Dr Craig S Wright    110.1K     BotFaketoshi
#
#                               Desc
# 0                     Founder Tron
# 1            Security Compancy CEO
# 2                 Founder Ethereum
# 3                      Founder LTC
# 4         Called Angel Philosopher
# 5                         Investor
# 6    Union Square Ventures Founder
# 7             Bitcoin.com Chairman
# 8                         Investor
# 9              evangelist , Writer
# 10                 Binance Founder
# 11              Shapeshift founder
# 12   popular bitcoin chart analyst
# 13              Coinbase cofounder
# 14  Morgan Creek Digital cofounder
# 15  Smart Contract Concept Creator
# 16                 Capital founder
# 17           The RT talk show host
# 18          Bitcoin Core developer
# 19  Youtube show Venturecoinist.tv
# 20                 Adamant Capital
# 21    Digital Currency Group (DCG)
# 22                   crypto trader
# 23               Blockstream’s CEO
# 24                   Civic founder
# 25           former Bitinstant CEO
# 26     former Bitcoin Core develop
# 27                    Coinbase CTO
# 28            Blocktower Capital’s
# 29                Galaxy Digital’s
# 30        Adaptive Capital partner
# 31          Placeholder VC partner
# 32    host of Unchainedpodcast.com
# 33               Consensys founder
# 34         Crypto Trader show host
# 35             Bitmain’s cofounder
# 36                      bitcoin sv

# %%
i=0
for j in range(0,data['No'].count()):
    #print(data.loc[i,'TweetAccount'])
    tweet_account = data.loc[j,'TweetAccount']
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch(query)\
                                           .setSince(start_date)\
                                           .setUntil(end_date)\
                                           .setUsername(tweet_account)\
                                           .setMaxTweets(-1)
    print("Collecting data start.. from {} to {}".format(days_range[0], days_range[-1]))
    start_time = time.time()

    tweet = got.manager.TweetManager.getTweets(tweetCriteria)
    #print("Collecting data end.. {0:0.2f} Minutes".format((time.time() - start_time)/60))
    print(tweet_account,"=== Total num of tweets is {} ===".format(len(tweet))) 
    for tweet_contents in tweet :
        i = i+1
        
        #tweetSet.loc[i,'period'] = 202022
        tweetSet.loc[i,'period'] = 202012
        #tweetSet.loc[i,'period'] = 201711
        #tweetSet.loc[i,'period'] = 201712
        #tweetSet.loc[i,'period'] = 201821
        #tweetSet.loc[i,'period'] = 201831
        #tweetSet.loc[i,'period'] = 201822
        #tweetSet.loc[i,'period'] = 201911
        #tweetSet.loc[i,'period'] = 201921
        #tweetSet.loc[i,'period'] = 201912
        #tweetSet.loc[i,'period'] = 201922
        #tweetSet.loc[i,'period'] = 201923
        #tweetSet.loc[i,'period'] = 201913
        #tweetSet.loc[i,'period'] = 201924
        #tweetSet.loc[i,'period'] = 202011
        #tweetSet.loc[i,'period'] = 202021
        tweetSet.loc[i,'username'] = tweet_contents.username
        tweetSet.loc[i,'date'] = tweet_contents.date
        tweetSet.loc[i,'retweets'] = tweet_contents.retweets
        tweetSet.loc[i,'favorites'] = tweet_contents.favorites
        tweetSet.loc[i,'hashtags'] = tweet_contents.hashtags
        tweetSet.loc[i,'text'] = tweet_contents.text
        #print(str(i)+' '+tweet_contents.username+' '+str(tweet_contents.date) )
# Out:
# Collecting data start.. from 2020-04-21 to 2020-05-06
# justinsuntron === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# officialmcafee === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# VitalikButerin === Total num of tweets is 4 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# SatoshiLite === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# naval === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# pmarca === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# fredwilson === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# rogerkver === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# cdixon === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# aantonop === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# cz_binance === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# ErikVoorhees === Total num of tweets is 2 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# PeterLBrandt === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# brian_armstrong === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# Apompliano === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# NickSzabo4 === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# arrington === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# maxkeiser === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# lopp === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# VentureCoinist === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# TuurDemeester === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# barrysilbert === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# ToneVays === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# adam3us === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# VinnyLingham === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# CharlieShrem === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# gavinandresen === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# balajis === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# AriDavidPaul === Total num of tweets is 1 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# novogratz === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# woonomic === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# cburniske === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# laurashin === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# ethereumJoseph === Total num of tweets is 6 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# cryptomanran === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# JihanWu === Total num of tweets is 0 ===
# Collecting data start.. from 2020-04-21 to 2020-05-06
# BotFaketoshi === Total num of tweets is 0 ===

# %%
tweetSet
#temp_cluster_result1.to_csv("../cluster/ko_news/2017_up1/ko_news_2017_up1_euclidean.csv")
# Out:
#     period        username                       date retweets favorites  \
# 1   202012   justinsuntron  2020-04-24 00:21:29+00:00       50       194
# 2   202012  VitalikButerin  2020-05-03 18:26:23+00:00        0         0
# 3   202012  VitalikButerin  2020-04-30 15:21:34+00:00        0         3
# 4   202012  VitalikButerin  2020-04-23 19:54:55+00:00       75       278
# 5   202012  VitalikButerin  2020-04-22 12:06:39+00:00       33       164
# 6   202012        aantonop  2020-04-23 17:54:11+00:00       21        72
# 7   202012    ErikVoorhees  2020-04-30 20:29:57+00:00       29       134
# 8   202012    ErikVoorhees  2020-04-23 15:29:29+00:00        1        21
# 9   202012       arrington  2020-05-04 22:33:52+00:00        6        34
# 10  202012  VentureCoinist  2020-04-29 15:38:11+00:00        0         3
# 11  202012   TuurDemeester  2020-05-03 19:09:58+00:00        0         3
# 12  202012         adam3us  2020-05-03 19:41:30+00:00        0         2
# 13  202012    CharlieShrem  2020-04-28 17:08:01+00:00        0        14
# 14  202012    AriDavidPaul  2020-05-02 10:50:29+00:00        0         3
# 15  202012  ethereumJoseph  2020-05-06 19:30:35+00:00       14        76
# 16  202012  ethereumJoseph  2020-05-01 22:08:10+00:00       50       188
# 17  202012  ethereumJoseph  2020-04-28 15:15:00+00:00        6        42
# 18  202012  ethereumJoseph  2020-04-27 22:05:56+00:00      190       554
# 19  202012  ethereumJoseph  2020-04-27 18:09:04+00:00       39       101
# 20  202012  ethereumJoseph  2020-04-21 19:02:11+00:00       35       124
#
#                                              hashtags  \
# 1
# 2
# 3
# 4
# 5
# 6   #WorldBookDay #TheInternetofMoney #bitcoin #bi...
# 7                         #bitcoin #bitcoin #ethereum
# 8                         #bitcoin #bitcoin #ethereum
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# 17                         #HyperledgerBesu #Ethereum
# 18                                              #ETH2
# 19                       #Ethereum #DeFi #tachyonalum
# 20
#
#                                                  text
# 1   TRON is cuter than Ethereum! The Cutineers say...
# 2   Arguably they are starting to! Though even the...
# 3   That's up to the ethereum community and not me...
# 4   Bitfly @etherchain_org, mother company of http...
# 5   Unitimes continues to do excellent Chinese tra...
# 6   It’s #WorldBookDay! Check out Mastering Bitcoi...
# 7   Andreessen Horowitz doubles down on crypto wit...
# 8   Better UX for all cryptocurrencies: Learn more...
# 9   Congratulations to @NEARProtocol : NEAR Protoc...
# 10  blue horseshoe told me it runs on the ethereum...
# 11  In the past I've compared Ethereum with straw ...
# 12  It's on ethereum? Wut? BAT is an erc20? Lols a...
# 13  .@IOHK_Charles dishes on the Bitcoin Cash vs B...
# 14  Ethereum classic testnet? Sink for excess glob...
# 15  Huge congrats to Eris Clearing on getting thei...
# 16  Thanks to @pbrody &amp; @jwolpert for a great ...
# 17  I'm joining @brianbehlendorf for a webinar on ...
# 18  Ethereum 2.0 will bring improvements in scalab...
# 19  Our @TachyonAccel alums @Transak_Finance keep ...
# 20  We at ConsenSys are also extremely excited abo...

# %%
#tweetSet.to_csv("./tweetdata/2017_up2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2018_down1_tweet.csv")
#tweetSet.to_csv("./tweetdata/2018_complement1_tweet.csv")
#tweetSet.to_csv("./tweetdata/2018_down2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_up1_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_down1_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_up2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_down2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_down3_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_up3_tweet.csv")
#tweetSet.to_csv("./tweetdata/2019_down4_tweet.csv")
#tweetSet.to_csv("./tweetdata/2020_up1_tweet.csv")



#tweetSet.to_csv("./tweetdata/2020_down1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2020_up1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_down4_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_up3_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_down3_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_down2_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_up2_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_down1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2019_up1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2018_down2_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2018_complement1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2018_down1_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2017_up2_tweet(e).csv")
#tweetSet.to_csv("./tweetdata/2017_up1_tweet(e).csv")

tweetSet.to_csv("./tweetdata/2020_up2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2020_up2_tweet(e).csv")

#tweetSet.to_csv("./tweetdata/2020_down2_tweet.csv")
#tweetSet.to_csv("./tweetdata/2020_down2_tweet(e).csv")
