# %%
import pandas as pd
import urllib.request
import re

data = pd.read_csv('./data/split/after_up_BCH1.csv', error_bad_lines=False)
#data = data.append(pd.read_csv('../../news/scraping_result/kr/2017_up1/2017_up1_(KR)Tokenpost.csv', error_bad_lines=False))

# %%
data = data.drop('Unnamed: 0',axis = 1)

# %%
data
# Out:
#     crypto gubun             datetime         username  retweets  favorites  \
# 0      BCH    up  2018-02-08 19:00:00       CryptoGulp         0          0
# 1      BCH    up  2018-02-08 19:00:01         BchPulse         0          0
# 2      BCH    up  2018-02-08 19:00:02        ScrapeINT         0          0
# 3      BCH    up  2018-02-08 19:00:02       mister_zk0         0          0
# 4      BCH    up  2018-02-08 19:00:02  cryptcoin_trade         0          0
# ..     ...   ...                  ...              ...       ...        ...
# 862    BCH    up  2018-02-08 23:56:16       cryptow1re         0          0
# 863    BCH    up  2018-02-08 23:56:44         ToboRaki         0          0
# 864    BCH    up  2018-02-08 23:57:42         YoursOrg         2          7
# 865    BCH    up  2018-02-08 23:58:23      CryptoCody7         1          2
# 866    BCH    up  2018-02-08 23:59:56   CryptoStatsBot         0          0
#
#                                      hashtags  \
# 0                                         NaN
# 1                        #BCHUSD #BitcoinCash
# 2                                         NaN
# 3                              #OpenBazaarBCH
# 4                           #BCC #bitcoincash
# ..                                        ...
# 862                                       NaN
# 863                                       NaN
# 864                                       NaN
# 865  #Bitcoin #Bitcoin #BitcoinCash #Ethereum
# 866                                       NaN
#
#                                                   text
# 0    Top 5 Cryptocurrencies Prices $BTC: $8,193.55 ...
# 1    BCH / USD $1270.24 | +0.0507% #BCHUSD #Bitcoin...
# 2    Bitcoin:$8193.55 Ethereum:$802.019 Bitcoin Cas...
# 3    Hey @OpenBazaar, I want my $BCH! My Peer ID is...
# 4    Bitcoin Cash: $1,289.60 +27.81% (+$280.60) Hig...
# ..                                                 ...
# 862  @reddit : Crypto Watch: Bitcoin Cash (BCH) Pri...
# 863  Bitcoin Cash $BCH price: $1280.42 HURRY! Binan...
# 864  Campus Creations - Barpay To Accept Bitcoin Ca...
# 865  Current #Bitcoin #BitcoinCash &amp; #Ethereum....
# 866   Biggest Losers (1 hr) Bitcoin Cash $BCH -3.63...
#
# [867 rows x 8 columns]

# %%
pattern = '(http|ftp|https)://(?:[-\w.]|(?:%[\da-fA-F]{2}))+'

data['text'] = data['text'].apply(lambda x : re.sub(pattern=pattern, repl='', string=x ))
# text = re.sub(pattern=pattern, repl='', string=text)

# %%
text = data[['text']]
text['text'] = text.apply(lambda row: row['text'].replace("/"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("-"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("—"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("*"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("…"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("\\"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("#"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['text'] = text.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
text['text'] = text['text'].apply(lambda x : [word.lower().replace("-","") for word in x])
text['text'] = text['text'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
text['text']
# Out:
# 0      [top, 5, cryptocurrencies, prices, $, btc, :, ...
# 1      [bch, usd, $, 1270.24, |, +0.0507, %, bchusd, ...
# 2      [bitcoin, :, $, 8193.55, ethereum, :, $, 802.0...
# 3      [hey, @, openbazaar, ,, i, want, my, $, bch, !...
# 4      [bitcoin, cash, :, $, 1,289.60, +27.81, %, (, ...
#                              ...
# 862    [@, reddit, :, crypto, watch, :, bitcoin, cash...
# 863    [bitcoin, cash, $, bch, price, :, $, 1280.42, ...
# 864    [campus, creations, barpay, to, accept, bitcoi...
# 865    [current, bitcoin, bitcoincash, &, amp, ;, eth...
# 866    [biggest, losers, (, 1, hr, ), bitcoin, cash, ...
# Name: text, Length: 867, dtype: object

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['text']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['text'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['text'] = text['text'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['text'] = text['text'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
text['text']
# Out:
# 0      [top, cryptocurrencies, prices, $, btc, :, $, ...
# 1               [bch, usd, $, |, %, bchusd, bitcoincash]
# 2      [bitcoin, :, $, ethereum, :, $, bitcoin, cash,...
# 3      [hey, @, openbazaar, ,, want, $, bch, !, peer,...
# 4      [bitcoin, cash, :, $, +27.81, %, (, +, $, ), h...
#                              ...
# 862    [@, reddit, :, crypto, watch, :, bitcoin, cash...
# 863    [bitcoin, cash, $, bch, price, :, $, hurry, !,...
# 864    [campus, creations, barpay, accept, bitcoin, c...
# 865    [current, bitcoin, bitcoincash, amp, ;, ethere...
# 866    [biggest, losers, (, hr, ), bitcoin, cash, $, ...
# Name: text, Length: 867, dtype: object

# %%
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['text'] = text['text'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['text'] = text['text'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['text'] = text['text'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['text'] = text['text'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['text'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 2143

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 2143

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 2143

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 2143

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 33.209643536276424

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.0010492251565540345

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 0.5509528611114574

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 이슈
# Out:
#                                               raw_data              word  \
# 2    [-0.0061969151720404625, -0.3561863899230957, ...           bitcoin
# 5    [-0.0063504320569336414, -0.25817543268203735,...              cash
# 8    [-0.0006392124923877418, -0.20795823633670807,...       bitcoincash
# 1    [-0.002030894858762622, -0.12477204203605652, ...             price
# 20   [-0.006163403391838074, -0.17824408411979675, ...            crypto
# 3    [-0.002503280760720372, -0.19285379350185394, ...          ethereum
# 58   [-0.006455356255173683, -0.09577661752700806, ...             surge
# 26   [0.0006192619330249727, -0.10269203782081604, ...            market
# 9    [-0.005114039406180382, -0.14427079260349274, ...          litecoin
# 32   [-0.0037048282101750374, -0.12634623050689697,...    cryptocurrency
# 112  [-0.0006238693604245782, -0.12599533796310425,...        blockchain
# 4    [-0.004122412763535976, -0.10652074962854385, ...            ripple
# 59   [0.0017500739777460694, -0.1152082234621048, 0...              hour
# 354  [0.0011845248518511653, -0.07031157612800598, ...           rebound
# 423  [-0.006503581535071135, -0.06297419965267181, ...             close
# 18   [-0.005594433750957251, -0.09456261247396469, ...             today
# 33   [-0.004753522574901581, -0.1268954575061798, 0...              news
# 75   [0.0008051424520090222, -0.1346028447151184, 0...              coin
# 0    [0.0002563977614045143, -0.10486654192209244, ...  cryptocurrencies
# 796  [-0.0003154514415655285, -0.1145908460021019, ...      ecoinnetwork
#
#      cluster                                           centroid  distance  \
# 2          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000135
# 5          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000257
# 8          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000315
# 1          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001196
# 20         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000430
# 3          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000440
# 58         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.002811
# 26         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.002034
# 9          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000711
# 32         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000775
# 112        0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001030
# 4          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001159
# 59         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001610
# 354        0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.005457
# 423        0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.005593
# 18         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001529
# 33         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000886
# 75         0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.000686
# 0          0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.001049
# 796        0  [-0.00028740164, -0.01404472, 0.003683061, -0....  0.002318
#
#         tfidf     score closer#
# 2    0.777095  0.223040     NaN
# 5    0.471288  0.528970     NaN
# 8    0.232334  0.767981     NaN
# 1    0.125765  0.875431     NaN
# 20   0.120470  0.879960     NaN
# 3    0.113850  0.886590     NaN
# 58   0.088697  0.914114     NaN
# 26   0.087374  0.914660     NaN
# 9    0.082078  0.918633     NaN
# 32   0.078769  0.922007     NaN
# 112  0.068178  0.932852     NaN
# 4    0.064206  0.936952     NaN
# 59   0.055601  0.946009     NaN
# 354  0.057587  0.947870     NaN
# 423  0.056263  0.949329     NaN
# 18   0.048320  0.953209     NaN
# 33   0.036406  0.964481     NaN
# 75   0.034420  0.966266     NaN
# 0    0.033096  0.967953     NaN
# 796  0.030448  0.971870     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 거래소
# Out:
#                                                raw_data               word  \
# 1864  [-0.0043746093288064, -0.005833642557263374, -...         s'enflamme
# 407   [0.0036254553124308586, -0.0019764548633247614...             artist
# 1766  [-0.0016417419537901878, -0.009171295911073685...          втариться
# 1915  [0.0025942749343812466, -0.0013456038432195783...             работы
# 1218  [-0.004759225063025951, -0.000284034525975585,...           стартира
# 1457  [0.001357132918201387, -0.009127940982580185, ...         commentary
# 1938  [0.002093213377520442, -0.010653214529156685, ...     kriptoaktivami
# 722   [0.002406124956905842, -0.00413192855194211, 0...             разгон
# 71    [0.0037627369165420532, -0.0032467907294631004...       kiasanyrskoi
# 1646  [-0.0005531340138986707, -0.00589881744235754,...             форекс
# 896   [0.001932059763930738, -0.007842451333999634, ...           prepping
# 1317  [-0.002230983227491379, -0.0034155105240643024...  satoshiroundtable
# 1617  [-0.004372264724224806, -0.006248611956834793,...              focus
# 1580  [0.004071560688316822, -0.005904224701225758, ...             samson
# 1127  [-0.0006863173330202699, -0.002184273209422826...          piyasanın
# 115   [0.0034475347492843866, -0.000933223171159625,...           describe
# 1339  [0.004075890406966209, -0.00578649714589119, 0...              seosu
# 1619  [-0.0018084605690091848, -0.004905519541352987...        wachgeküsst
# 459   [-0.0019432646222412586, -0.006304101087152958...              logic
# 1197  [0.002174563007429242, -0.008909786120057106, ...              favor
# 832   [0.003868155414238572, -0.00672755716368556, -...           gethired
# 2064  [-0.003841601312160492, -0.004587838891893625,...              naaah
# 151   [0.0006038067513145506, -0.0026497822254896164...               pero
# 2056  [-0.0010562518145889044, -0.003435017773881554...  はそれらの問題を解決する改良版だ』
# 1518  [0.004863911774009466, -0.00040125413215719163...             kulhru
# 1731  [0.0010774709517136216, -0.007928362116217613,...             symbol
# 1460  [0.003485510591417551, -0.007350143976509571, ...            consume
# 911   [0.004403422120958567, -0.004268689081072807, ...             answer
# 1748  [-0.0008927310118451715, -0.007975390180945396...               wolf
# 801   [0.002653646981343627, -0.0027333449106663465,...               hire
#
#       cluster                                           centroid  distance  \
# 1864        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.143639
# 407         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.188475
# 1766        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.202260
# 1915        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.214637
# 1218        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.228749
# 1457        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.235787
# 1938        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.248068
# 722         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.260563
# 71          1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.275772
# 1646        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.280694
# 896         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.294427
# 1317        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.298242
# 1617        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.298557
# 1580        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.302134
# 1127        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.304640
# 115         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.306318
# 1339        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.307264
# 1619        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.309581
# 459         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.327510
# 1197        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.328473
# 832         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.329951
# 2064        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.330043
# 151         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.331837
# 2056        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.332837
# 1518        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.336253
# 1731        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.338977
# 1460        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.347176
# 911         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.349752
# 1748        1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.349816
# 801         1  [0.0004420581, -0.0030165785, 0.0008492873, -0...  0.351107
#
#          tfidf     score closer#
# 1864  0.000662  1.142977     NaN
# 407   0.001324  1.187152     NaN
# 1766  0.000662  1.201598     NaN
# 1915  0.000662  1.213976     NaN
# 1218  0.000662  1.228087     NaN
# 1457  0.000662  1.235125     NaN
# 1938  0.000662  1.247407     NaN
# 722   0.000662  1.259901     NaN
# 71    0.000662  1.275110     NaN
# 1646  0.000662  1.280032     NaN
# 896   0.000662  1.293765     NaN
# 1317  0.000662  1.297580     NaN
# 1617  0.000662  1.297895     NaN
# 1580  0.000662  1.301472     NaN
# 1127  0.000662  1.303978     NaN
# 115   0.000662  1.305656     NaN
# 1339  0.000662  1.306602     NaN
# 1619  0.000662  1.308919     NaN
# 459   0.000662  1.326848     NaN
# 1197  0.000662  1.327811     NaN
# 832   0.000662  1.329289     NaN
# 2064  0.000662  1.329381     NaN
# 151   0.000662  1.331175     NaN
# 2056  0.000662  1.332175     NaN
# 1518  0.000662  1.335591     NaN
# 1731  0.000662  1.338315     NaN
# 1460  0.000662  1.346514     NaN
# 911   0.000662  1.349090     NaN
# 1748  0.000662  1.349154     NaN
# 801   0.000662  1.350446     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 기술
# Out:
#                                                raw_data            word  \
# 842   [-0.003558169351890683, -0.0058074030093848705...           viral
# 180   [-0.0023476353380829096, -0.005671747960150242...     marketplace
# 2082  [0.0046729715541005135, -0.002965671243146062,...           legit
# 638   [-0.003254495095461607, -0.0032083848491311073...     musicvideos
# 1923  [0.004203802905976772, -0.00999138318002224, 0...      технически
# 517   [0.004762899596244097, -0.003936855588108301, ...        omawiamy
# 1692  [0.0022468003444373608, -0.007658475544303656,...           light
# 1110  [-0.003329857252538204, -0.000871800584718585,...           preds
# 2042  [0.0037851266097277403, -0.008850889280438423,...     cryptowatch
# 828   [-0.0036819521337747574, -0.006250320002436638...         edition
# 1605  [0.0034595816396176815, -0.0018637109315022826...            fall
# 668   [0.0003693206235766411, -0.0013290117494761944...      durdurunca
# 1951  [0.0004947002744302154, -0.0002316571190021932...        problemi
# 347   [0.0027781969401985407, -0.0005613520625047386...          ticket
# 1059  [-0.002352628391236067, -0.0019782823510468006...         обгонит
# 1456  [-0.003757379949092865, -0.0005816246848553419...        negative
# 682   [-0.0038670680951327085, -0.000319210521411150...            form
# 1591  [-0.00043984007788822055, -0.00978359952569007...  miningethereum
# 976   [0.0040551237761974335, -0.00238737347535789, ...         cultist
# 1683  [-0.00128646579105407, -0.00789736770093441, -...          needle
#
#       cluster                                           centroid  distance  \
# 842         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.120301
# 180         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.156349
# 2082        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.172485
# 638         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.188498
# 1923        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.198403
# 517         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.204425
# 1692        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.209379
# 1110        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.210087
# 2042        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.215435
# 828         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.224131
# 1605        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.232281
# 668         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.238424
# 1951        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.244471
# 347         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.246956
# 1059        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.247008
# 1456        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.251353
# 682         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.257167
# 1591        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.260066
# 976         2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.268311
# 1683        2  [1.8362975e-05, -0.0020465755, 0.0014610133, -...  0.281327
#
#          tfidf     score closer#
# 842   0.001324  1.118977     NaN
# 180   0.001986  1.154364     NaN
# 2082  0.000662  1.171823     NaN
# 638   0.000662  1.187836     NaN
# 1923  0.000662  1.197742     NaN
# 517   0.000662  1.203763     NaN
# 1692  0.000662  1.208717     NaN
# 1110  0.000662  1.209426     NaN
# 2042  0.000662  1.214773     NaN
# 828   0.000662  1.223469     NaN
# 1605  0.000662  1.231619     NaN
# 668   0.000662  1.237763     NaN
# 1951  0.000662  1.243809     NaN
# 347   0.000662  1.246294     NaN
# 1059  0.000662  1.246346     NaN
# 1456  0.000662  1.250692     NaN
# 682   0.000662  1.256505     NaN
# 1591  0.000662  1.259404     NaN
# 976   0.000662  1.267649     NaN
# 1683  0.000662  1.280665     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 기타
# Out:
#                                                raw_data                 word  \
# 2005  [0.0007543072570115328, -0.008016904816031456,...              handful
# 1075  [0.002942641032859683, -0.003946993965655565, ...                 copy
# 2046  [0.0017496149521321058, -0.008539468981325626,...               qfbxds
# 573   [-0.0032961973920464516, -0.006077205762267113...              coinpot
# 1778  [-0.004037770442664623, -0.005659907124936581,...            worldcore
# 128   [0.003834649920463562, -0.004768532235175371, ...             solltest
# 817   [-0.003023154567927122, -0.0072713918052613735...            dvonmusic
# 1267  [0.0011232915567234159, -0.006464335601776838,...                 pasa
# 689   [0.001556402537971735, -0.0074086617678403854,...             technews
# 917   [0.0007114124018698931, -0.002063980558887124,...                 imho
# 708   [0.001652087434194982, -0.007923583500087261, ...               trader
# 1141  [-0.004056505858898163, -0.00720628909766674, ...          diyebilirim
# 1503  [-0.002953740768134594, -0.003920532763004303,...  cryptorateconverter
# 737   [-0.0033510110806673765, -0.007371088024228811...       криптовалютных
# 1687  [-0.004760176409035921, 0.0008532755891792476,...               decent
# 1654  [0.0038639940321445465, -0.005090105347335339,...          cryptobulls
# 2073  [-0.002178370952606201, -0.000452884822152555,...             infoguru
# 1053  [-0.004222741816192865, -0.0010943521047011018...                видит
# 702   [-0.0023498162627220154, -0.000925771659240126...             торговле
# 1329  [0.003929127473384142, 0.0002765785320661962, ...              noipcom
#
#       cluster                                           centroid  distance  \
# 2005        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.175290
# 1075        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.259538
# 2046        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.329442
# 573         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.346938
# 1778        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.368582
# 128         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.375930
# 817         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.380455
# 1267        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.383601
# 689         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.385938
# 917         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.397645
# 708         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.402618
# 1141        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.407168
# 1503        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.411880
# 737         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.422618
# 1687        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.432488
# 1654        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.434246
# 2073        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.436685
# 1053        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.449584
# 702         3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.452464
# 1329        3  [9.3655566e-05, -0.0026411526, 0.00072321395, ...  0.454984
#
#          tfidf     score closer#
# 2005  0.000662  1.174628     NaN
# 1075  0.000662  1.258876     NaN
# 2046  0.000662  1.328780     NaN
# 573   0.000662  1.346276     NaN
# 1778  0.000662  1.367920     NaN
# 128   0.000662  1.375268     NaN
# 817   0.000662  1.379793     NaN
# 1267  0.000662  1.382939     NaN
# 689   0.000662  1.385276     NaN
# 917   0.000662  1.396983     NaN
# 708   0.001324  1.401294     NaN
# 1141  0.000662  1.406506     NaN
# 1503  0.000662  1.411218     NaN
# 737   0.000662  1.421956     NaN
# 1687  0.000662  1.431826     NaN
# 1654  0.000662  1.433584     NaN
# 2073  0.000662  1.436023     NaN
# 1053  0.000662  1.448922     NaN
# 702   0.000662  1.451802     NaN
# 1329  0.000662  1.454322     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 이슈
# Out:
# 1709

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 거래소
# Out:
# 167

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 기술
# Out:
# 160

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 기타
# Out:
# 107

# %%
temp_cluster_result['category'] = 3 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
#temp_cluster_result['label'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 5 # 이슈

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 12 # 거래소

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label'] = 9 # 기술

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 13 # 기타

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 5.4025397300720215

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [1 1 3 ... 0 0 0]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -5.40254020690918

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.6374751

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(50,'score') # 비즈
# Out:
#                                                raw_data                word  \
# 1655  [0.0025056730955839157, -0.0035667428746819496...              poucos
# 754   [0.0033875631634145975, -0.005874684080481529,...       синхронизации
# 1188  [-0.001376998028717935, -0.006129962857812643,...               broad
# 1553  [0.003551043337211013, -0.00440709013491869, 0...               игора
# 1934  [-0.0023704543709754944, -0.006481005344539881...            операции
# 516   [-0.0010830239625647664, -0.003776870202273130...             dzisiaj
# 1374  [0.0013553660828620195, -0.007802302483469248,...              btcusd
# 714   [-0.0037520267069339752, -0.005506798159331083...  децентрализованный
# 197   [-0.003939478658139706, -0.0044985925778746605...          aggressive
# 1945  [0.004921354353427887, -0.009087744168937206, ...            проблеми
# 1371  [-0.00134553131647408, -0.0025666411966085434,...          comparison
# 288   [-0.0034484046045690775, -0.006333509460091591...             aumentó
# 378   [0.0017579984851181507, -0.00970618985593319, ...              enrich
# 1540  [0.004763616248965263, -0.0014420252991840243,...     cryptocurrencie
# 906   [0.0047366139478981495, -0.008530550636351109,...               hater
# 27    [-0.001420253305695951, -0.010758117772638798,...                rank
# 330   [0.002668932545930147, -0.004089576657861471, ...                мені
# 472   [0.0026572684291750193, -0.008153288625180721,...              vuelve
# 1766  [-0.0016417419537901878, -0.009171295911073685...           втариться
# 749   [0.0001373454724671319, -0.0050879912450909615...             браузер
# 916   [-0.0014100566040724516, -0.005958408582955599...              clothe
# 1967  [-0.0030738471541553736, -0.006907521281391382...        kryptowaluty
# 1804  [-0.00460013747215271, -0.007162271998822689, ...        unbelievable
# 1961  [-0.003026676131412387, -0.00330347940325737, ...          księgowość
# 1352  [-0.0028642001561820507, -0.006285405717790127...               robot
# 1234  [-0.0009203113149851561, -0.00453083124011755,...              losinj
# 1386  [-0.0045539322309195995, -0.008072925731539726...          correction
# 2141  [-0.004190121777355671, -0.0006870398647151887...              barpay
# 2123  [-0.0014322914648801088, -0.004349031951278448...            unbanked
# 1818  [0.0006375563098117709, -0.008853351697325706,...      misinformation
# 1350  [-0.002284624148160219, -0.008064975030720234,...                kill
# 931   [0.003042025025933981, -0.008209322579205036, ...                fine
# 1052  [-0.00019682673155330122, -0.00278284121304750...              роджер
# 2061  [0.0037157018668949604, -0.0038301353342831135...            relevant
# 1978  [0.0016860546311363578, -0.004709804896265268,...              header
# 711   [-0.0010539527283981442, -0.006332193035632372...               гонят
# 1933  [-0.002098080702126026, -0.008953186683356762,...         арбитражные
# 344   [-0.0023081579711288214, -0.009433426894247532...     cryptocommunity
# 1112  [0.002718808362260461, -0.00480530085042119, 0...         bettingtips
# 598   [-0.0033295033499598503, -0.008746395818889141...              vision
# 346   [-0.004387600813060999, -0.010893426835536957,...           community
# 1931  [-0.00394654693081975, -0.0033146690111607313,...             borsata
# 1706  [-0.002747036051005125, -0.008914421312510967,...              moneda
# 1128  [-0.0007561662350781262, -0.007135452702641487...            anasıysa
# 873   [-0.0022947946563363075, -0.001432402641512453...                word
# 2080  [0.0030977714341133833, -0.0029102754779160023...            possible
# 2044  [-0.0028041498735547066, -0.006922545842826366...                sink
# 2129  [-0.0025314779486507177, -0.006497228983789682...          conversion
# 1531  [-0.004772360436618328, -0.010222423821687698,...           sentiment
# 767   [-0.002845723880454898, -0.008827075362205505,...                huge
#
#       cluster                                           centroid  distance  \
# 1655        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025749
# 754         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025320
# 1188        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026023
# 1553        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025460
# 1934        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025601
# 516         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025690
# 1374        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027692
# 714         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025812
# 197         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025827
# 1945        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.025848
# 1371        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.029269
# 288         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027415
# 378         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026806
# 1540        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026145
# 906         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026158
# 27          0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.028958
# 330         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026986
# 472         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026333
# 1766        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026390
# 749         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026483
# 916         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026495
# 1967        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026512
# 1804        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026542
# 1961        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026583
# 1352        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026590
# 1234        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026622
# 1386        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027304
# 2141        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026691
# 2123        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026718
# 1818        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026728
# 1350        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027400
# 931         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.028127
# 1052        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026860
# 2061        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026877
# 1978        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026891
# 711         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026898
# 1933        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026984
# 344         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.026987
# 1112        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027029
# 598         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027695
# 346         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027706
# 1931        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027070
# 1706        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027071
# 1128        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027126
# 873         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027799
# 2080        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027141
# 2044        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027142
# 2129        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027146
# 1531        0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027155
# 767         0  [-0.00010170282, -0.006132331, 0.0017212166, -...  0.027824
#
#          tfidf     score closer#
# 1655  0.001324  1.024425     NaN
# 754   0.000662  1.024658     NaN
# 1188  0.001324  1.024699     NaN
# 1553  0.000662  1.024798     NaN
# 1934  0.000662  1.024939     NaN
# 516   0.000662  1.025028     NaN
# 1374  0.002648  1.025045     NaN
# 714   0.000662  1.025150     NaN
# 197   0.000662  1.025165     NaN
# 1945  0.000662  1.025186     NaN
# 1371  0.003972  1.025297     NaN
# 288   0.001986  1.025429     NaN
# 378   0.001324  1.025482     NaN
# 1540  0.000662  1.025483     NaN
# 906   0.000662  1.025496     NaN
# 27    0.003310  1.025648     NaN
# 330   0.001324  1.025662     NaN
# 472   0.000662  1.025671     NaN
# 1766  0.000662  1.025728     NaN
# 749   0.000662  1.025821     NaN
# 916   0.000662  1.025833     NaN
# 1967  0.000662  1.025850     NaN
# 1804  0.000662  1.025880     NaN
# 1961  0.000662  1.025921     NaN
# 1352  0.000662  1.025928     NaN
# 1234  0.000662  1.025960     NaN
# 1386  0.001324  1.025980     NaN
# 2141  0.000662  1.026029     NaN
# 2123  0.000662  1.026056     NaN
# 1818  0.000662  1.026066     NaN
# 1350  0.001324  1.026076     NaN
# 931   0.001986  1.026141     NaN
# 1052  0.000662  1.026198     NaN
# 2061  0.000662  1.026215     NaN
# 1978  0.000662  1.026230     NaN
# 711   0.000662  1.026236     NaN
# 1933  0.000662  1.026322     NaN
# 344   0.000662  1.026325     NaN
# 1112  0.000662  1.026367     NaN
# 598   0.001324  1.026371     NaN
# 346   0.001324  1.026382     NaN
# 1931  0.000662  1.026408     NaN
# 1706  0.000662  1.026409     NaN
# 1128  0.000662  1.026464     NaN
# 873   0.001324  1.026475     NaN
# 2080  0.000662  1.026480     NaN
# 2044  0.000662  1.026480     NaN
# 2129  0.000662  1.026485     NaN
# 1531  0.000662  1.026493     NaN
# 767   0.001324  1.026501     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(50,'score') # 긍정
# Out:
#                                               raw_data              word  \
# 58   [-0.006455356255173683, -0.09577661752700806, ...             surge
# 26   [0.0006192619330249727, -0.10269203782081604, ...            market
# 57   [-0.0018753265030682087, -0.08570103347301483,...             watch
# 18   [-0.005594433750957251, -0.09456261247396469, ...             today
# 228  [-0.0004621703701559454, -0.0892985463142395, ...              core
# 14   [-0.003907391335815191, -0.09211781620979309, ...            wallet
# 165  [0.00221293605864048, -0.08453097939491272, 0....            ビットコイン
# 16   [-0.005142563953995705, -0.08736195415258408, ...              high
# 168  [0.0014729696558788419, -0.09221231937408447, ...             モナコイン
# 203  [-0.0030405004508793354, -0.08156104385852814,...             trade
# 166  [-0.005508182570338249, -0.08354194462299347, ...            イーサリアム
# 167  [-0.0058185807429254055, -0.08266719430685043,...              zaif
# 100  [0.003650213126093149, -0.08638794720172882, 0...          exchange
# 45   [-0.0039107478223741055, -0.09360496699810028,...              join
# 28   [-0.002133940579369664, -0.08348900824785233, ...             start
# 262  [0.003730912460014224, -0.08346496522426605, 0...              dash
# 325  [-0.002155443886294961, -0.07876797765493393, ...            gainer
# 6    [-0.00245222682133317, -0.07685783505439758, 0...           cardano
# 969  [0.001427547773346305, -0.08394946902990341, 0...             slump
# 303  [-0.00018340404494665563, -0.10381791740655899...              tron
# 138  [-0.003119601169601083, -0.10638188570737839, ...              djia
# 4    [-0.004122412763535976, -0.10652074962854385, ...            ripple
# 170  [-0.00016516870527993888, -0.07631678134202957...              仮想通貨
# 797  [0.00046086160000413656, -0.0822090283036232, ...     cryptocurency
# 0    [0.0002563977614045143, -0.10486654192209244, ...  cryptocurrencies
# 242  [-0.006439893040806055, -0.10481638461351395, ...             learn
# 12   [0.0012881356524303555, -0.0710175558924675, 0...              want
# 169  [0.002889803843572736, -0.07807523757219315, 0...              mona
# 106  [0.0016566565027460456, -0.07205822318792343, ...           support
# 798  [0.002120347460731864, -0.08092696219682693, 0...             ecoin
# 557  [-0.0009980096947401762, -0.08070353418588638,...           average
# 565  [-0.0006356688099913299, -0.07549087703227997,...             think
# 425  [-0.003331030486151576, -0.07477757334709167, ...              lead
# 209  [0.003146424191072583, -0.07846004515886307, 0...          bitcoins
# 98   [-0.004176036920398474, -0.10366500169038773, ...           binance
# 796  [-0.0003154514415655285, -0.1145908460021019, ...      ecoinnetwork
# 21   [-0.0026039257645606995, -0.10937206447124481,...          altcoins
# 1    [-0.002030894858762622, -0.12477204203605652, ...             price
# 59   [0.0017500739777460694, -0.1152082234621048, 0...              hour
# 423  [-0.006503581535071135, -0.06297419965267181, ...             close
# 354  [0.0011845248518511653, -0.07031157612800598, ...           rebound
# 109  [0.001297920709475875, -0.06780087202787399, 0...            dollar
# 60   [-0.003117581596598029, -0.07570652663707733, ...              bull
# 192  [-0.002434705849736929, -0.07416986674070358, ...              good
# 309  [-0.006140716373920441, -0.07138927280902863, ...              time
# 198  [-0.004341179504990578, -0.0685739740729332, 0...              real
# 112  [-0.0006238693604245782, -0.12599533796310425,...        blockchain
# 116  [-0.005093310959637165, -0.11087628453969955, ...             bcash
# 137  [0.0023859648499637842, -0.06569365411996841, ...   machinelearning
# 11   [0.0004579283995553851, -0.06362076103687286, ...        openbazaar
#
#      cluster                                           centroid  distance  \
# 58         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.045797
# 26         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.077861
# 57         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.033902
# 18         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.058710
# 228        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.029599
# 14         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.036627
# 165        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.038977
# 16         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.046262
# 168        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.036757
# 203        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.040179
# 166        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.039331
# 167        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.042631
# 100        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.049575
# 45         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.055954
# 28         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.059107
# 262        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.053725
# 325        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.062803
# 6          1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.062348
# 969        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.065611
# 303        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.075545
# 138        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.073086
# 4          1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.118839
# 170        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.076005
# 797        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.076759
# 0          1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.099390
# 242        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.087082
# 12         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.091181
# 169        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.085848
# 106        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.085754
# 798        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.091006
# 557        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.095573
# 565        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.088100
# 425        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.100675
# 209        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.091104
# 98         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.108631
# 796        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.117878
# 21         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.109275
# 1          1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.219183
# 59         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.150385
# 423        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.151859
# 354        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.161302
# 109        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.120213
# 60         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.129139
# 192        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.122794
# 309        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.127794
# 198        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.133649
# 112        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.191145
# 116        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.142437
# 137        1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.142509
# 11         1  [-0.0014689956, -0.09018123, 0.023553958, -0.0...  0.152042
#
#         tfidf     score closer#
# 58   0.088697  0.957099     NaN
# 26   0.087374  0.990487     NaN
# 57   0.029786  1.004116     NaN
# 18   0.048320  1.010390     NaN
# 228  0.014562  1.015037     NaN
# 14   0.016548  1.020079     NaN
# 165  0.016548  1.022429     NaN
# 16   0.023167  1.023094     NaN
# 168  0.013238  1.023519     NaN
# 203  0.016548  1.023631     NaN
# 166  0.013238  1.026092     NaN
# 167  0.013238  1.029393     NaN
# 100  0.014562  1.035013     NaN
# 45   0.019196  1.036759     NaN
# 28   0.021843  1.037263     NaN
# 262  0.011915  1.041810     NaN
# 325  0.020520  1.042283     NaN
# 6    0.019196  1.043153     NaN
# 969  0.015886  1.049725     NaN
# 303  0.023829  1.051716     NaN
# 138  0.018534  1.054552     NaN
# 4    0.064206  1.054633     NaN
# 170  0.018534  1.057471     NaN
# 797  0.015224  1.061535     NaN
# 0    0.033096  1.066294     NaN
# 242  0.017210  1.069872     NaN
# 12   0.021181  1.069999     NaN
# 169  0.013238  1.072609     NaN
# 106  0.011915  1.073839     NaN
# 798  0.015224  1.075782     NaN
# 557  0.018534  1.077039     NaN
# 565  0.009929  1.078171     NaN
# 425  0.021843  1.078832     NaN
# 209  0.011915  1.079189     NaN
# 98   0.021843  1.086787     NaN
# 796  0.030448  1.087430     NaN
# 21   0.018534  1.090741     NaN
# 1    0.125765  1.093418     NaN
# 59   0.055601  1.094784     NaN
# 423  0.056263  1.095596     NaN
# 354  0.057587  1.103715     NaN
# 109  0.010591  1.109622     NaN
# 60   0.019196  1.109944     NaN
# 192  0.011915  1.110880     NaN
# 309  0.010591  1.117203     NaN
# 198  0.015224  1.118425     NaN
# 112  0.068178  1.122967     NaN
# 116  0.017872  1.124565     NaN
# 137  0.009267  1.133242     NaN
# 11   0.015224  1.136817     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 인플
# Out:
#                                                raw_data             word  \
# 29    [0.002119014970958233, -0.034165602177381516, ...           growth
# 23    [-0.0021727767307311296, -0.03144397959113121,...           kraken
# 934   [0.001483036088757217, -0.03246040642261505, 0...           domain
# 221   [0.0035830936394631863, -0.03182072937488556, ...            value
# 127   [-0.004500668495893478, -0.03295639902353287, ...            tweet
# 1466  [-0.0020650792866945267, -0.035549651831388474...          similar
# 376   [-0.002678170334547758, -0.02995423786342144, ...            chart
# 786   [-0.0027064066380262375, -0.03225410357117653,...     criptomoedas
# 555   [0.0002762678195722401, -0.03347346931695938, ...            trend
# 273   [-0.0021533172111958265, -0.036197394132614136...  bitcoinexchange
# 144   [-0.0022833955008536577, -0.02718239836394787,...            world
# 1354  [-0.0019965926185250282, -0.030000414699316025...            shame
# 246   [0.00020489591406658292, -0.02740863524377346,...           subido
# 333   [-0.003396645886823535, -0.03450383245944977, ...          receive
# 318   [0.0001168034941656515, -0.03295635059475899, ...           simple
# 1208  [-0.0009678140049800277, -0.029768144711852074...         tipprbot
# 279   [-0.0015855086967349052, -0.03619573637843132,...             devs
# 179   [-6.69876390020363e-05, -0.026862148195505142,...     decentralize
# 276   [0.0009094685665331781, -0.032849837094545364,...          express
# 334   [-0.00019798621360678226, -0.03509588167071342...            major
#
#       cluster                                           centroid  distance  \
# 29          2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.030565
# 23          2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.029391
# 934         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.027598
# 221         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.026514
# 127         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.027290
# 1466        2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.026824
# 376         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.028329
# 786         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.026652
# 555         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.029391
# 273         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.026805
# 144         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.029934
# 1354        2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.032620
# 246         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.030032
# 333         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.028892
# 318         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.027018
# 1208        2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.032320
# 279         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.029290
# 179         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.029039
# 276         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.030391
# 334         2  [-0.00048130332, -0.032402582, 0.008358383, -0...  0.028540
#
#          tfidf     score closer#
# 29    0.009267  1.021298     NaN
# 23    0.007943  1.021448     NaN
# 934   0.005957  1.021641     NaN
# 221   0.004633  1.021881     NaN
# 127   0.005295  1.021995     NaN
# 1466  0.004633  1.022190     NaN
# 376   0.005957  1.022371     NaN
# 786   0.003310  1.023343     NaN
# 555   0.005957  1.023434     NaN
# 273   0.003310  1.023495     NaN
# 144   0.005957  1.023977     NaN
# 1354  0.008605  1.024015     NaN
# 246   0.005957  1.024074     NaN
# 333   0.004633  1.024259     NaN
# 318   0.002648  1.024370     NaN
# 1208  0.007943  1.024377     NaN
# 279   0.004633  1.024657     NaN
# 179   0.003972  1.025068     NaN
# 276   0.005295  1.025096     NaN
# 334   0.003310  1.025230     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 거래소
# Out:
#                                              raw_data         word  cluster  \
# 5   [-0.0063504320569336414, -0.25817543268203735,...         cash        3
# 2   [-0.0061969151720404625, -0.3561863899230957, ...      bitcoin        3
# 8   [-0.0006392124923877418, -0.20795823633670807,...  bitcoincash        3
# 3   [-0.002503280760720372, -0.19285379350185394, ...     ethereum        3
# 20  [-0.006163403391838074, -0.17824408411979675, ...       crypto        3
#
#                                              centroid  distance     tfidf  \
# 5   [-0.004370649, -0.23868358, 0.060214654, -0.10...  0.124408  0.471288
# 2   [-0.004370649, -0.23868358, 0.060214654, -0.10...  0.703028  0.777095
# 8   [-0.004370649, -0.23868358, 0.060214654, -0.10...  0.184756  0.232334
# 3   [-0.004370649, -0.23868358, 0.060214654, -0.10...  0.285208  0.113850
# 20  [-0.004370649, -0.23868358, 0.060214654, -0.10...  0.357753  0.120470
#
#        score closer#
# 5   0.653120     NaN
# 2   0.925932     NaN
# 8   0.952422     NaN
# 3   1.171358     NaN
# 20  1.237283     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) # 비즈
# Out:
# 1854

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) # 긍정
# Out:
# 58

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) # 인플
# Out:
# 226

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) # 거래소
# Out:
# 5

# %%
temp_cluster_result1['category'] = 3 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 7 # 비즈

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 2 # 긍정

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 6 # 인플

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 5 # 거래소

# %%
temp_cluster_result1['Silhouette'] = 0.6406296
temp_cluster_result['Silhouette'] = 0.6406296
temp_cluster_result1['result'] = 1
temp_cluster_result['result'] = 1

# %%
temp_cluster_result1.to_csv("../analysis/cluster/causeanalysis/BTC/after_up_BCH0_euclidean.csv")
temp_cluster_result.to_csv("../analysis/cluster/causeanalysis/BTC/after_up_BCH0_cosine")
