# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import ast
from datetime import datetime , timedelta
import time
import pandas as pd
import numpy as np
import GetOldTweets3 as got
from cause_analysis import ConcurrentTweetManager


header = ['crypto','gubun','datetime','username','retweets','favorites','hashtags','text']
# cryptoprice_set = pd.DataFrame(columns=headername)
# total_cryptoprice_set = pd.DataFrame(columns=headername)

tweetSet = pd.DataFrame(columns=header)

#data = pd.read_csv('./data/BTC_up_period.csv', error_bad_lines=False)
data = pd.read_csv('./data/BTC_down_period.csv', error_bad_lines=False)
#data = pd.read_csv('./data/BCH_up_period.csv', error_bad_lines=False)
#data = pd.read_csv('./data/BCH_down_period.csv', error_bad_lines=False)

query = 'bitcoin'

symbol = 'BTC'

# %%
import os 
os.getcwd()
# Out:
# '/Users/hongminpyo/PycharmProjects/MasterThesis/cause_analysis'

# %%
data
# Out:
#    Unnamed: 0 crypto        date                 time     high      low  \
# 0           1    BCH  2017-08-18  2017-08-18 00:00:00   395.72   316.42
# 1          45    BCH  2018-02-08  2018-02-08 19:00:00  1254.62  1086.78
# 2          68    BCH  2018-12-20  2018-12-20 17:00:00   154.01   148.37
# 3          89    BCH  2019-04-02  2019-04-02 13:00:00   204.84   181.00
# 4         102    BCH  2019-10-25  2019-10-25 01:00:00   217.66   214.04
# 5         149    BCH  2020-01-14  2020-01-14 23:00:00   338.38   298.28
#
#       open    close        gap            from_time              to_time gubun
# 0   325.38   395.59  21.577847  2017-08-17 18:00:00  2017-08-18 06:00:00    up
# 1  1087.50  1251.59  15.088736  2018-02-08 13:00:00  2018-02-09 01:00:00    up
# 2   140.25   153.08   9.147950  2018-12-20 11:00:00  2018-12-20 23:00:00    up
# 3   168.05   196.96  17.203213  2019-04-02 07:00:00  2019-04-02 19:00:00    up
# 4   214.13   217.23   1.447719  2019-10-24 19:00:00  2019-10-25 07:00:00    up
# 5   299.68   327.95   9.433396  2020-01-14 17:00:00  2020-01-15 05:00:00    up

# %%
#for i in data.index :
i = 2
gubun = data.loc[i,'gubun']
if gubun =='up' :
    #start_time = "2017-01-04"
    #end_time = "2017-01-05"
    start_time = datetime.strptime(data.loc[i,'from_time'],"%Y-%m-%d %H:%M:%S")
    end_time = datetime.strptime(data.loc[i,'time'],"%Y-%m-%d %H:%M:%S")
    start_date = data.loc[i,'from_time'][0:10]
    end_date  = start_time + timedelta(days=1)
    end_date  = str(end_date)[0:10] 
else :
    start_time = datetime.strptime(data.loc[i,'time'],"%Y-%m-%d %H:%M:%S")
    end_time = datetime.strptime(data.loc[i,'to_time'],"%Y-%m-%d %H:%M:%S")
    start_date = data.loc[i,'time'][0:10]
    end_date  = start_time + timedelta(days=1)
    end_date  = str(end_date)[0:10]

print(start_time,' ',type(start_time))
print(end_time,' ',type(end_time))
print(end_date,' ',type(end_date))

tweetCriteria = got.manager.TweetCriteria().setQuerySearch(query)\
                                       .setSince(start_date)\
                                       .setUntil(end_date)\
                                       .setMaxTweets(-1)

tweet = ConcurrentTweetManager.getTweets(tweetCriteria)

num = 0

for tweet_contents in tweet :

    #if start_time <= tweet_contents.date.replace(tzinfo=None) and end_time >= tweet_contents.date.replace(tzinfo=None) :

    num = num+1
    tweetSet.loc[num,'gubun'] = gubun
    tweetSet.loc[num,'crypto'] = symbol
    tweetSet.loc[num,'username'] = tweet_contents.username
    tweetSet.loc[num,'datetime'] = tweet_contents.date
    tweetSet.loc[num,'retweets'] = tweet_contents.retweets
    tweetSet.loc[num,'favorites'] = tweet_contents.favorites
    tweetSet.loc[num,'hashtags'] = tweet_contents.hashtags
    tweetSet.loc[num,'text'] = tweet_contents.text
# Out:
# 2020-01-14 17:00:00   <class 'datetime.datetime'>
# 2020-01-14 23:00:00   <class 'datetime.datetime'>
# 2020-01-15   <class 'str'>

# %%
tweetSet
# Out:
#     crypto gubun                   datetime         username retweets  \
# 1      BCH    up  2020-01-14 00:00:00+00:00         BchPulse        0
# 2      BCH    up  2020-01-14 00:00:01+00:00   BitcoinCash_ES        0
# 3      BCH    up  2020-01-14 00:00:07+00:00  TrackThatCrypto        0
# 4      BCH    up  2020-01-14 00:00:20+00:00       CryptoGulp        0
# 5      BCH    up  2020-01-14 00:01:00+00:00  CasinosandGames        0
# ..     ...   ...                        ...              ...      ...
# 969    BCH    up  2020-01-14 23:50:54+00:00         CoinhubN        0
# 970    BCH    up  2020-01-14 23:52:05+00:00     Bdjx36809823        0
# 971    BCH    up  2020-01-14 23:52:06+00:00     altcoinsscom        0
# 972    BCH    up  2020-01-14 23:52:19+00:00      TradecoinJP        0
# 973    BCH    up  2020-01-14 23:55:52+00:00  RhythmicAnalyst        1
#
#     favorites                                           hashtags  \
# 1           0                               #BCHUSD #BitcoinCash
# 2           0                       #BitcoinCash #Kraken #BCHEUR
# 3           0  #crypto #bitcoin #bitcoin #luna #ethereum #zca...
# 4           1
# 5           1  #Crypto #Bitcoin #Bitcoin #Litecoin #BitcoinCa...
# ..        ...                                                ...
# 969         0
# 970         0   #Bitcoin #Bitcoin #bitcoin #bitcoin #BitcoinCash
# 971         0
# 972         0                 #BitcoinCash #HODL #Cryptocurrency
# 973         7   #BitcoinCash #cryptocurrency #blockchain #crypto
#
#                                                   text
# 1    BCH / USD $267.41 | +0.0004% #BCHUSD #BitcoinCash
# 2    Cotización del Bitcoin Cash: 240 30.€ | -0.12%...
# 3    TOP-12 most-mentioned #crypto this hour: 1. #b...
# 4    Top 5 Cryptocurrencies Prices Bitcoin $BTC: $8...
# 5    Grande Vegas Casino - 50 Spins Sign Up Bonus a...
# ..                                                 ...
# 969  Bitcoin SV Goes Parabolic, Flippens Bitcoin Cash
# 970  #Bitcoin #bitcoin #BitcoinCash I love how ever...
# 971  BSV Soars 95% Challenging Its Original Fork Bi...
# 972  crypto_goat_: #BitcoinCash Up over 37% in the ...
# 973  $BCH is heading for higher target. Join my dis...
#
# [973 rows x 8 columns]

# %%
tweetSet.to_csv('./data/tweet_'+gubun+'_'+symbol+str(i)+'.csv')
