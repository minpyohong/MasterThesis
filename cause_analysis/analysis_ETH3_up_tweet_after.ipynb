# %%
import pandas as pd
import urllib.request
import re

data = pd.read_csv('./data/split/after_up_ETH3.csv', error_bad_lines=False)
#data = data.append(pd.read_csv('../../news/scraping_result/kr/2017_up1/2017_up1_(KR)Tokenpost.csv', error_bad_lines=False))

# %%
data = data.drop('Unnamed: 0',axis = 1)

# %%
data.head(50)
# Out:
#    crypto gubun             datetime         username  retweets  favorites  \
# 0     ETH    up  2018-12-28 16:00:00       eth_hourly         0          0
# 1     ETH    up  2018-12-28 16:00:01       sebasrizzo         0          0
# 2     ETH    up  2018-12-28 16:00:01     CryptoHourly         0          0
# 3     ETH    up  2018-12-28 16:00:02    StackEthereum         0          0
# 4     ETH    up  2018-12-28 16:00:02        asens_inc         0          0
# 5     ETH    up  2018-12-28 16:00:02  CryptoPressNews         2          3
# 6     ETH    up  2018-12-28 16:00:03        foroether         0          0
# 7     ETH    up  2018-12-28 16:00:03     CryptoShopUK         0          0
# 8     ETH    up  2018-12-28 16:00:04  cryptcoin_trade         0          0
# 9     ETH    up  2018-12-28 16:00:08     Ethereum_MXN         1          0
# 10    ETH    up  2018-12-28 16:00:12        coinstats         0          0
# 11    ETH    up  2018-12-28 16:00:19       CryptoGulp         0          0
# 12    ETH    up  2018-12-28 16:00:19  TrackThatCrypto         0          0
# 13    ETH    up  2018-12-28 16:00:39     ICObello_com         0          0
# 14    ETH    up  2018-12-28 16:00:39    SuperInfoKali         0          0
# 15    ETH    up  2018-12-28 16:00:50        NeeYoComp         0          1
# 16    ETH    up  2018-12-28 16:01:02   EarlyAdopter23         0          0
# 17    ETH    up  2018-12-28 16:01:10  TokensArbitrage         0          0
# 18    ETH    up  2018-12-28 16:01:22    ArulmaniShiva         0          1
# 19    ETH    up  2018-12-28 16:01:46       GURrrrrMAN         0          0
# 20    ETH    up  2018-12-28 16:01:57       indicomvll         0          0
# 21    ETH    up  2018-12-28 16:02:00     BossLadiesOC         0          0
# 22    ETH    up  2018-12-28 16:02:01       iliuha1977         0          0
# 23    ETH    up  2018-12-28 16:02:04      erkancamli4         0          0
# 24    ETH    up  2018-12-28 16:02:10          DaoLan5         0          0
# 25    ETH    up  2018-12-28 16:02:12  eth_ethereumbot         0          0
# 26    ETH    up  2018-12-28 16:02:13     HitCoin_News         0          0
# 27    ETH    up  2018-12-28 16:02:30      CryptJoMoon         0          0
# 28    ETH    up  2018-12-28 16:02:39      erkancamli4         0          0
# 29    ETH    up  2018-12-28 16:03:03   finvestmonitor         0          0
# 30    ETH    up  2018-12-28 16:03:15    TuurDemeester       835       2358
# 31    ETH    up  2018-12-28 16:03:16    TuurDemeester        11        240
# 32    ETH    up  2018-12-28 16:03:16    TuurDemeester        33        340
# 33    ETH    up  2018-12-28 16:03:16    TuurDemeester        27        341
# 34    ETH    up  2018-12-28 16:03:17    TuurDemeester        17        226
# 35    ETH    up  2018-12-28 16:03:18    TuurDemeester         9        169
# 36    ETH    up  2018-12-28 16:03:19    TuurDemeester        32        312
# 37    ETH    up  2018-12-28 16:03:20    TuurDemeester         8        151
# 38    ETH    up  2018-12-28 16:03:20    TuurDemeester        15        264
# 39    ETH    up  2018-12-28 16:03:21    TuurDemeester         9        137
# 40    ETH    up  2018-12-28 16:03:41     sinaga_arnol         0          0
# 41    ETH    up  2018-12-28 16:04:03     bravenewcoin         1          3
# 42    ETH    up  2018-12-28 16:04:06      Bitcoin_Win         0          0
# 43    ETH    up  2018-12-28 16:04:18  OmerFar33312718         0          1
# 44    ETH    up  2018-12-28 16:04:25       theBCStory         3          3
# 45    ETH    up  2018-12-28 16:04:37         admsbot1         0          0
# 46    ETH    up  2018-12-28 16:04:43       alanna_eve         0          1
# 47    ETH    up  2018-12-28 16:04:54         admsbot1         0          0
# 48    ETH    up  2018-12-28 16:05:00     ESPACIOBITVE         0          0
# 49    ETH    up  2018-12-28 16:05:02     crypto4_good         0          2
#
#                                              hashtags  \
# 0                                           #ethereum
# 1   #Crypto #Cryptocurreny #signal #telegram #BTC ...
# 2                                                 NaN
# 3                        #ethereum #solidity #ganache
# 4   #Bitcoin #Bitcoin #NEM #XEM #Monacoin #Ethereu...
# 5                                                #ETH
# 6                                           #Ethereum
# 7                                                 NaN
# 8                                      #ETH #ethereum
# 9                                 #ETH #Bitso #ETHMXN
# 10                                     #Ethereum #ETH
# 11                                                NaN
# 12  #crypto #bitcoin #bitcoin #ethereum #litecoin ...
# 13  #bitcoin #bitcoin #crypto #blockchain #btc #bt...
# 14  #GenesisMining #BTC #BTC #ETH #LTC #Dash #XMR ...
# 15  #AirWallet #AIR #ethereum #blockchain #wallet ...
# 16  #ethereum #price #analysis #december #instabit...
# 17               #TokensNet #Hitbtc #Ethereum #Stasis
# 18  #crowdfunding #BiPS #investments #ethereum #Mo...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  #QuarkChain #Blockchain #sharding #Crypto #eth...
# 24  #freecoins #Airdropster #bitcoin #bitcoin #Eth...
# 25          #ETH #Ethereum #ZAIF #coincheck #bitFlyer
# 26  #Huobi #altcoin #hitcoinnews #bitcoin #bitcoin...
# 27                                                NaN
# 28  #QuarkChain #Blockchain #sharding #Crypto #eth...
# 29                                          #Ethereum
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  #freecoins #Airdropster #bitcoin #bitcoin #Eth...
# 41                                          #Ethereum
# 42                                                NaN
# 43  #Crypto #Blockchain #BetInReal #BIR #ether #et...
# 44  #nvidia #crypto #Mining #blockchain #cryptocur...
# 45          #SmartContract #blockchain #ethereum #eth
# 46  #FSTNetwork #FST #Blockchain #Ethereum #Interc...
# 47                         #eth #ethereum #blockchain
# 48  #Criptomonedas #Bitcoin #Bitcoin #BTC #BTC #Et...
# 49                   #HoryouToken #BTC #BTC #ETH #HYT
#
#                                                  text
# 0   Current #ethereum price is $127.57, an increas...
# 1   Receive a 10% discount for the first deposit. ...
# 2   @#3, Ethereum with unit price of $127.58, mark...
# 3   How to use the EVENTS tab in ganache win 2.00?...
# 4   12/29 01:00現在 #Bitcoin : 421,005円↑ #NEM #XEM :...
# 5   $ETH | #ETH - ethereum's Current Price: ▲ $127...
# 6            El precio actual de #Ethereum es 127.58$
# 7   Bitcoin @£3,265.57 | Ethereum @£110.64 | Litec...
# 8   Ethereum: $126.58 +3.67% (+$4.48) High: $126.9...
# 9   Precio #ETH: $2,510.00 Fuente: Bitso #Bitso #E...
# 10  Ethereum - ETH Price: $127.55 Change in 1h: +8...
# 11  Top 5 Cryptocurrencies Prices $BTC: $3,851.51 ...
# 12  TOP-12 most-mentioned #crypto this hour: 1. #b...
# 13  Italian Financial Regulator Issues Cease and D...
# 14  #GenesisMining Exclusive Discount qrpvG9 #BTC ...
# 15  AIR WALLET is creating a much needed bridge be...
# 16  #ethereum #(eth) #price #analysis #– #december...
# 17  Buy ETH/EURS at #TokensNet, sell at #Hitbtc; e...
# 18  the BiPS Token holders can influence this glob...
# 19  I liked a @YouTube video http://youtu.be/SAc4U...
# 20  Мне понравилось видео " ТЕХНИЧЕСКИЙ АНАЛИЗ КРИ...
# 21  Check this out http://youtu.be/PxmOl0BBu50 NEO...
# 22  Мне понравилось видео " ТЕХНИЧЕСКИЙ АНАЛИЗ КРИ...
# 23  #QuarkChain #Blockchain #sharding #Crypto #eth...
# 24  550$Airdrop Join Join Airdrop: https://gleam.i...
# 25  ETH-JPYが＋15％に到達。上昇中。 現在の価格 「0.03431409(+6.88) ...
# 26  #Huobi türev pazarı genişliyor... İşte yeni ek...
# 27  New post in CryptJoMoon Alerts: New BitCoinTal...
# 28  #QuarkChain #Blockchain #sharding #Crypto #eth...
# 29  #Ethereum $ETH last info: Price: $127.56829889...
# 30  1/ People often ask me why I’m so “against” Et...
# 31  6/ Despite strong optimism that on-chain scali...
# 32  4/ I agree with Ethereum developer Vlad Zamfir...
# 33  3/ I've followed Ethereum since 2014 &amp; fee...
# 34  8/ On the 2nd layer front, devs are now trying...
# 35  11/ In 2017, more Ethereum scaling buzz was cr...
# 36  17/ Over the years, this has become a pattern ...
# 37  20/ A few days ago, I shared a critical tweet ...
# 38  18/ One of my big concerns is that sophistry a...
# 39  21/ I was very serious about my criticism. In ...
# 40  550$Airdrop Join Join Airdrop: https://gleam.i...
# 41  #Ethereum Price: USD $129.41 $ETH http://ow.ly...
# 42  Bitcoin [BTC] and Ethereum [ETH] face off the ...
# 43  Join soon here my friends ! A very friendly pr...
# 44  #nvidia: Why low #crypto #Mining demand didn't...
# 45  Gandhiji #SmartContract Is Mooning #blockchain...
# 46  #FSTNetwork #FST #Blockchain #Ethereum #Interc...
# 47  Gandhiji Smart Contract Stands Against The Ind...
# 48  Bitcoin sigue en su lucha por mantenerse encim...
# 49  . @HoryouToken (HYT) is starting its listing o...

# %%
pattern = '(http|ftp|https)://(?:[-\w.]|(?:%[\da-fA-F]{2}))+'

data['text'] = data['text'].apply(lambda x : re.sub(pattern=pattern, repl='', string=x ))
# text = re.sub(pattern=pattern, repl='', string=text)

# %%
text = data[['text']]
text['text'] = text.apply(lambda row: row['text'].replace("/"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("-"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("—"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("*"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("…"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("\\"," "), axis=1)
text['text'] = text.apply(lambda row: row['text'].replace("#"," "), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import nltk
text['text'] = text.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
text['text'] = text['text'].apply(lambda x : [word.lower().replace("-","") for word in x])
text['text'] = text['text'].apply(lambda x : [word for word in x if word])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
text['text']
# Out:
# 0       [current, ethereum, price, is, $, 127.57, ,, a...
# 1       [receive, a, 10, %, discount, for, the, first,...
# 2       [@, 3, ,, ethereum, with, unit, price, of, $, ...
# 3       [how, to, use, the, events, tab, in, ganache, ...
# 4       [12, 29, 01:00現在, bitcoin, :, 421,005円↑, nem, ...
#                               ...
# 1556    [bitcoin, and, ethereum, daily, price, forecas...
# 1557    [news, bitcoin, ripple, ethereum, bitcoin, cas...
# 1558    [so, ethereum, has, no, flaws, or, shortcoming...
# 1559    [ethereum, (, eth, ), ,, eos, ,, and, litecoin...
# 1560    [the, ethereum, outlook, for, early, 2019, btc...
# Name: text, Length: 1561, dtype: object

# %%
from nltk.tag import pos_tag

text['pos tag'] = text.apply(lambda row: pos_tag(row['text']), axis=1)
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 불용어 품사 제거
text['text'] = text['pos tag'].apply(lambda x: [word[0] for word in x if word[1] not in ('CC','CD','DT','EX','IN','LS','MD','PRP','PRP$','RB','TO','UH','WDT','WP','WP$','WRB')])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
text['text'] = text['text'].apply(lambda x: [word for word in x if word not in (stop)])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import csv
stopword_list =[]
f = open('../stopword/stop_en.txt', 'r')
reader = csv.reader(f)
for row in reader:
    #print(row[0])
    stopword_list.append(row[0])
    #pass
f.close()

text['text'] = text['text'].apply(lambda x: [word for word in x if word not in stopword_list])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
text['text']
# Out:
# 0       [current, ethereum, price, $, ,, increase, +8....
# 1       [receive, %, discount, first, deposit, ., ?, c...
# 2       [,, ethereum, unit, price, $, ,, market, cap, ...
# 3       [use, events, tab, ganache, win, ?, questions,...
# 4       [bitcoin, :, nem, xem, :, monacoin, :, ethereu...
#                               ...
# 1556    [bitcoin, ethereum, daily, price, forecast, bt...
# 1557    [news, bitcoin, ripple, ethereum, bitcoin, cas...
# 1558                   [ethereum, flaws, shortcomings, ?]
# 1559    [ethereum, (, eth, ), ,, ,, litecoin, (, ltc, ...
# 1560           [ethereum, outlook, early, btcusd, ethusd]
# Name: text, Length: 1561, dtype: object

# %%
pattern=re.compile(r'\.')
print(pattern.search('abc.de'))

text['text'] = text['text'].apply(lambda x: [word for word in x if pattern.search(word)== None])
# Out:
# <re.Match object; span=(3, 4), match='.'>
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
number_pattern=re.compile(r'[0-9]\,[0-9]')
text['text'] = text['text'].apply(lambda x: [word for word in x if number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
native_number_pattern=re.compile(r'[0-9]')
text['text'] = text['text'].apply(lambda x: [word for word in x if native_number_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
star_pattern=re.compile(r'[a-z0-9*]\*[a-z0-9*]')
text['text'] = text['text'].apply(lambda x: [word for word in x if star_pattern.search(word)== None])
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from nltk.stem import WordNetLemmatizer
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x]) # 동사 
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='a') for word in x]) # 형용사
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='n') for word in x]) # 명사
text['text'] = text['text'].apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='r') for word in x]) # 부사
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tokenized_doc = text['text'].apply(lambda x: [word for word in x if len(word) > 3])
#print(tokenized_doc)

# %%
article_contents = tokenized_doc.values.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

# %%
tokenized_doc_tfidf = tokenized_doc.apply(lambda x : ' '.join(x))

# %%
article_contents_tfidf = tokenized_doc_tfidf.values.tolist()

# %%
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform([ " ".join(article_contents_tfidf) ])

# %%
word2id = defaultdict(lambda: 0)

# %%
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx

# %%
tf_idf_result = []
token_list = []
for i, sent in enumerate([" ".join(article_contents_tfidf)]):
    for token in sent.split() :
        if token not in token_list :
            temp=[]
            temp.append(token)
            temp.append(sp_matrix[i, word2id[token]])
            token_list.append(token)
            tf_idf_result.append(temp)

# %%
len(tf_idf_result)
# Out:
# 3663

# %%
tf_idf_value =[]
for tf_idf_element in tf_idf_result :
    tf_idf_value.append(tf_idf_element[1])
print(len(tf_idf_value))  ## tf-idf 값을 배열에 담음
# Out:
# 3663

# %%
from gensim import corpora
tokenized_doc = [d.split() for d in token_list]
dictionary = corpora.Dictionary(tokenized_doc)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]
print(corpus[1])
# Out:
# [(1, 1)]

# %%
sentences = article_contents

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 3663

# %%
X = model[model.wv.vocab]
# Out:
# /Users/hongminpyo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=4
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
#kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.euclidean_distance, repeats=25)
#euclidean_distance
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
#print(X)
#print(assigned_clusters)

# %%
import pandas as pd
import numpy as np
temp_heder = ['raw_data','word','cluster','centroid','distance','tfidf','score','closer#']
temp_cluster_result = pd.DataFrame(columns=temp_heder)

# %%
temp_cluster_result['word'] = list(model.wv.vocab)

# %%
temp_cluster_result['cluster'] = assigned_clusters

# %%
temp_cluster_result['raw_data'] = X.tolist()

# %%
#temp_cluster_result['raw_data']
temp_cluster_result['centroid'] = temp_cluster_result['cluster'].apply(lambda x : kclusterer.means()[x])

# %%
from sklearn.metrics import pairwise_distances

# %%
cosine_centroid_list = []
for cosine_centroid in temp_cluster_result['centroid'] :
    cosine_centroid_list.append(cosine_centroid.tolist())

# %%
len(cosine_centroid_list)
# Out:
# 3663

# %%
temp_distance = pairwise_distances(X,cosine_centroid_list, metric='cosine')

# %%
sum(temp_distance[3])
# Out:
# 98.88534726176601

# %%
import scipy.spatial.distance as dist

# %%
dist.cosine(X[0],cosine_centroid_list[0])
# Out:
# 0.019894204161797435

# %%
dist.euclidean(X[0],cosine_centroid_list[0])
# Out:
# 0.05901992965111324

# %%
temp_cluster_result['distance'] = temp_cluster_result.apply(lambda x : dist.cosine(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result['tfidf'] = tf_idf_value
temp_cluster_result['score'] = temp_cluster_result.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result

# %%
temp_cluster_result[temp_cluster_result['cluster']==0].sort_values(by=['score']).head(20)  # 투자
# Out:
#                                                raw_data              word  \
# 1     [0.3086147606372833, 0.09587284922599792, 0.10...          ethereum
# 13    [0.21774178743362427, 0.07257799804210663, 0.0...           bitcoin
# 9     [0.21751555800437927, 0.06787705421447754, 0.0...            crypto
# 51    [0.21175901591777802, 0.07389391958713531, 0.0...        blockchain
# 49    [0.16832438111305237, 0.05322611331939697, 0.0...    cryptocurrency
# 17    [0.08485402166843414, 0.0280442014336586, 0.03...          litecoin
# 2     [0.10274725407361984, 0.030679825693368912, 0....             price
# 14    [0.07261882722377777, 0.026392212137579918, 0....            ripple
# 4     [0.14748261868953705, 0.05388098210096359, 0.0...            market
# 64    [0.14764909446239471, 0.05353055149316788, 0.0...             trade
# 44    [0.09256453067064285, 0.033816199749708176, 0....              tron
# 52    [0.13606487214565277, 0.04307685047388077, 0.0...              news
# 75    [0.1612396538257599, 0.053474485874176025, 0.0...           airdrop
# 209   [0.18499860167503357, 0.06513142585754395, 0.0...             token
# 1314  [0.08630599081516266, 0.02373126707971096, -0....            minute
# 32    [0.11883600056171417, 0.03655896335840225, 0.0...              high
# 15    [0.08509161323308945, 0.03494764491915703, 0.0...       bitcoincash
# 360   [0.10655330121517181, 0.03468979522585869, 0.0...        cryptonews
# 43    [0.06665079295635223, 0.019300546497106552, 0....              hour
# 40    [0.08376667648553848, 0.028343209996819496, 0....  cryptocurrencies
#
#       cluster                                           centroid  distance  \
# 1           0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000088
# 13          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000255
# 9           0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000074
# 51          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000067
# 49          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000152
# 17          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.001531
# 2           0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000789
# 14          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.001890
# 4           0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000146
# 64          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000118
# 44          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.001749
# 52          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000188
# 75          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000411
# 209         0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000077
# 1314        0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.018236
# 32          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000432
# 15          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000385
# 360         0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000272
# 43          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000829
# 40          0  [0.014547066, 0.0049926694, 0.0050986353, -0.0...  0.000352
#
#          tfidf     score closer#
# 1     0.736498  0.263590     NaN
# 13    0.515388  0.484867     NaN
# 9     0.203823  0.796251     NaN
# 51    0.156787  0.843280     NaN
# 49    0.133872  0.866280     NaN
# 17    0.119801  0.881730     NaN
# 2     0.114173  0.886616     NaN
# 14    0.101711  0.900179     NaN
# 4     0.061509  0.938637     NaN
# 64    0.060303  0.939815     NaN
# 44    0.061911  0.939839     NaN
# 52    0.056283  0.943906     NaN
# 75    0.052262  0.948148     NaN
# 209   0.042212  0.957866     NaN
# 1314  0.055077  0.963159     NaN
# 32    0.030151  0.970281     NaN
# 15    0.028945  0.971439     NaN
# 360   0.028543  0.971729     NaN
# 43    0.028945  0.971883     NaN
# 40    0.027337  0.973015     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==1].sort_values(by=['score']).head(30)  # 거래소 돈
# Out:
#                                                raw_data               word  \
# 41    [0.030534492805600166, 0.0007691369974054396, ...               cash
# 624   [0.041829824447631836, 0.010710901580750942, 0...            stellar
# 114   [0.03701088950037956, 0.012604066170752048, 0....            cardano
# 83    [0.041008591651916504, 0.006191730033606291, 0...           analysis
# 404   [0.017567092552781105, 0.006214178632944822, 0...         ripplenews
# 2352  [0.019029054790735245, 0.001686663250438869, 0...            freitag
# 562   [0.009439905174076557, 0.008896571584045887, 0...        fundamental
# 869   [0.009318024851381779, 0.008836229331791401, 0...              audit
# 970   [0.008144289255142212, 0.003594702575355768, 0...            cadenas
# 2565  [0.007852485403418541, 0.0068506342358887196, ...            sequoia
# 1389  [0.0104483338072896, 0.00661793677136302, 0.00...             cripto
# 3454  [0.006883841939270496, 0.002958768280223012, 0...              clone
# 339   [0.0083391685038805, -0.0007901647477410734, 0...      international
# 2223  [0.007634684443473816, 0.008599034510552883, 0...           youtuber
# 2089  [0.011666471138596535, 0.0032759136520326138, ...           follower
# 2027  [0.010882806032896042, 0.004628499038517475, 0...        cryptopunks
# 2955  [0.014565372839570045, 0.0009884441969916224, ...              unite
# 3653  [0.011606989428400993, 0.0033179554156959057, ...             volumi
# 2000  [0.0055073332041502, 0.006777687929570675, 0.0...  newcryptocurrency
# 1062  [0.00686559546738863, 0.0009816819801926613, -...               sein
# 3360  [0.01183252315968275, 0.006088658235967159, 0....              final
# 1477  [0.012431197799742222, 0.003935979213565588, 0...               book
# 1916  [0.012412872165441513, -0.0007045698584988713,...              hedef
# 2265  [0.007553889881819487, 0.0025895892176777124, ...          ethstatus
# 350   [0.011299020610749722, 0.004828438628464937, 0...              habit
# 2315  [0.009138667955994606, 0.007414382882416248, 0...              orası
# 2407  [0.007026977837085724, 0.004909281153231859, 0...               alım
# 1112  [0.00336037902161479, 0.0032835223246365786, -...            octobot
# 1729  [0.010485888458788395, -0.0009919131407514215,...           universe
# 1678  [0.008610392920672894, 0.007694889325648546, 0...           struggle
#
#       cluster                                           centroid  distance  \
# 41          1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.015296
# 624         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.009174
# 114         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.009128
# 83          1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.006880
# 404         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.008430
# 2352        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.009314
# 562         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.011525
# 869         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.013204
# 970         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.013163
# 2565        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.014419
# 1389        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.014729
# 3454        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.014814
# 339         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.016478
# 2223        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.018004
# 2089        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.018373
# 2027        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.018493
# 2955        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.019108
# 3653        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.020019
# 2000        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.021121
# 1062        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.021674
# 3360        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.021311
# 1477        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.021758
# 1916        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.022200
# 2265        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.021860
# 350         1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.023381
# 2315        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.023324
# 2407        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.024366
# 1112        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.025509
# 1729        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.024883
# 1678        1  [0.004525882, 0.0015175426, 0.0020703434, -0.0...  0.025298
#
#          tfidf     score closer#
# 41    0.073971  0.941325     NaN
# 624   0.050252  0.958921     NaN
# 114   0.047438  0.961690     NaN
# 83    0.041810  0.965070     NaN
# 404   0.002814  1.005616     NaN
# 2352  0.000804  1.008510     NaN
# 562   0.001206  1.010319     NaN
# 869   0.001608  1.011596     NaN
# 970   0.000804  1.012359     NaN
# 2565  0.001206  1.013212     NaN
# 1389  0.000804  1.013925     NaN
# 3454  0.000804  1.014010     NaN
# 339   0.001206  1.015272     NaN
# 2223  0.000804  1.017200     NaN
# 2089  0.000804  1.017569     NaN
# 2027  0.000804  1.017689     NaN
# 2955  0.000804  1.018304     NaN
# 3653  0.000804  1.019215     NaN
# 2000  0.001206  1.019915     NaN
# 1062  0.001206  1.020467     NaN
# 3360  0.000804  1.020507     NaN
# 1477  0.001206  1.020552     NaN
# 1916  0.000804  1.021396     NaN
# 2265  0.000402  1.021458     NaN
# 350   0.000804  1.022577     NaN
# 2315  0.000402  1.022922     NaN
# 2407  0.000402  1.023964     NaN
# 1112  0.001206  1.024303     NaN
# 1729  0.000402  1.024481     NaN
# 1678  0.000804  1.024494     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==2].sort_values(by=['score']).head(20)   # 인플
# Out:
#                                                raw_data  \
# 3079  [0.0036049545742571354, 0.005220532882958651, ...
# 2766  [0.0019413731060922146, 0.0058807372115552425,...
# 66    [0.002148496452718973, 0.0037717996165156364, ...
# 1772  [0.0012985399225726724, 0.0019544963724911213,...
# 746   [0.0030282940715551376, -0.0006753266789019108...
# 1987  [0.0050884452648460865, -0.0007381983450613916...
# 2762  [0.00579654797911644, 0.004231052007526159, 0....
# 738   [0.004480438772588968, -0.0015221810899674892,...
# 2886  [0.006193399894982576, 0.0012388337636366487, ...
# 2542  [0.0005186766502447426, -0.0010358256986364722...
# 2080  [-0.0002894431818276644, 0.005335740279406309,...
# 3254  [0.0010096044279634953, 0.004061871208250523, ...
# 3554  [0.004371011629700661, -0.0017010781448334455,...
# 2718  [0.0015202586073428392, -0.0031371715012937784...
# 3555  [-0.0009155484731309116, -0.003532300470396876...
# 994   [0.006794532295316458, 0.0032658036798238754, ...
# 2713  [0.003104092553257942, 0.004322335124015808, 0...
# 2628  [0.0017472414765506983, -0.000650366535410285,...
# 1309  [0.0004000484477728605, 0.004523600917309523, ...
# 3307  [0.001000932534225285, 0.003880968550220132, 0...
#
#                           word  cluster  \
# 3079                    olmali        2
# 2766                     dense        2
# 66               genesismining        2
# 1772               desarrollar        2
# 746                  accessory        2
# 1987                      caen        2
# 2762                     стань        2
# 738                  alcoholic        2
# 2886                 messenger        2
# 2542  【既存の暗号通貨の詐欺かどうかを見分ける方法３】        2
# 2080                   western        2
# 3254                  roulette        2
# 3554                  upadhyay        2
# 2718                   optimal        2
# 3555                 aggregate        2
# 994                      puppy        2
# 2713                retweeting        2
# 2628                 turbulent        2
# 1309                 ¿contiene        2
# 3307                  database        2
#
#                                                centroid  distance     tfidf  \
# 3079  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.066693  0.000402
# 2766  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.146236  0.000402
# 66    [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.150392  0.000402
# 1772  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.167071  0.000402
# 746   [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.168731  0.000402
# 1987  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.184853  0.000804
# 2762  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.185768  0.000402
# 738   [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.190412  0.000402
# 2886  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.194535  0.000402
# 2542  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.205040  0.000402
# 2080  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.212388  0.000402
# 3254  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.220068  0.000402
# 3554  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.223552  0.000402
# 2718  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.229937  0.000402
# 3555  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.233931  0.000402
# 994   [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.238457  0.000402
# 2713  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.243837  0.000402
# 2628  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.247940  0.000402
# 1309  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.248946  0.000402
# 3307  [0.0012783464, 0.0014817456, 5.4189022e-05, -0...  0.260823  0.000402
#
#          score closer#
# 3079  1.066291     NaN
# 2766  1.145834     NaN
# 66    1.149990     NaN
# 1772  1.166669     NaN
# 746   1.168329     NaN
# 1987  1.184049     NaN
# 2762  1.185366     NaN
# 738   1.190010     NaN
# 2886  1.194133     NaN
# 2542  1.204638     NaN
# 2080  1.211986     NaN
# 3254  1.219666     NaN
# 3554  1.223150     NaN
# 2718  1.229535     NaN
# 3555  1.233529     NaN
# 994   1.238055     NaN
# 2713  1.243435     NaN
# 2628  1.247538     NaN
# 1309  1.248544     NaN
# 3307  1.260421     NaN

# %%
temp_cluster_result[temp_cluster_result['cluster']==3].sort_values(by=['score']).head(20)  # 비즈
# Out:
#                                                raw_data              word  \
# 120   [-0.0005814467440359294, 0.0030126869678497314...        quarkchain
# 3152  [-6.707091233693063e-05, 0.0003173914737999439...      happynewyear
# 3515  [-0.0037209689617156982, -0.002554575679823756...         alttradex
# 296   [-0.004589972551912069, 0.0019489624537527561,...       vitaliksays
# 3647  [1.5182769857347012e-05, 0.00411493144929409, ...            topple
# 2454  [0.00037867174251005054, -0.002895806217566132...         situation
# 811   [0.0014266420621424913, -0.004396005067974329,...            xblock
# 3551  [0.0039668092504143715, -0.004362180829048157,...        bearmarket
# 2427  [0.0018444072920829058, 0.0021502841264009476,...    romansventures
# 2320  [0.0034275439102202654, -0.0028952276334166527...       oraclechain
# 1264  [-0.0019368426874279976, -0.000745711673516780...  cryptocotización
# 21    [-0.004587728530168533, -0.0026707183569669724...              unit
# 3055  [-0.005740279797464609, -0.0004337505088187754...     willywonkaxrp
# 1986  [-0.005453200079500675, -0.003526640124619007,...     christmasgift
# 3365  [-0.0004682045546360314, -0.004688335582613945...           tribute
# 3566  [0.0029567452147603035, 0.0046477895230054855,...            qvykvs
# 3557  [0.0014929677126929164, -0.0025753704831004143...    weekinethereum
# 1739  [0.0021436247043311596, -0.0035830724518746138...              food
# 3063  [-0.0016343118622899055, -0.001492104260250926...   cryptocentralai
# 2033  [0.004031068179756403, -0.002497934503480792, ...   paywithlitecoin
#
#       cluster                                           centroid  distance  \
# 120         3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.317467
# 3152        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.389967
# 3515        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.447305
# 296         3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.508247
# 3647        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.530488
# 2454        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.532758
# 811         3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.593220
# 3551        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.626889
# 2427        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.627890
# 2320        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.643871
# 1264        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.649398
# 21          3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.676367
# 3055        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.681711
# 1986        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.687516
# 3365        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.710937
# 3566        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.715730
# 3557        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.715851
# 1739        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.734155
# 3063        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.748257
# 2033        3  [-0.00030460797, -0.00048434045, 5.8034217e-05...  0.749094
#
#          tfidf     score closer#
# 120   0.004020  1.313447     NaN
# 3152  0.000402  1.389565     NaN
# 3515  0.000402  1.446903     NaN
# 296   0.000402  1.507845     NaN
# 3647  0.000402  1.530086     NaN
# 2454  0.000402  1.532356     NaN
# 811   0.000804  1.592416     NaN
# 3551  0.000402  1.626487     NaN
# 2427  0.000402  1.627488     NaN
# 2320  0.000402  1.643469     NaN
# 1264  0.000804  1.648594     NaN
# 21    0.002412  1.673955     NaN
# 3055  0.000402  1.681309     NaN
# 1986  0.000402  1.687114     NaN
# 3365  0.000402  1.710535     NaN
# 3566  0.000402  1.715328     NaN
# 3557  0.000402  1.715449     NaN
# 1739  0.000402  1.733753     NaN
# 3063  0.000402  1.747855     NaN
# 2033  0.000402  1.748692     NaN

# %%
y_km = temp_cluster_result['cluster'].values

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style

# %%
plt.scatter(X[y_km==0,0],X[y_km==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[y_km==1,0],X[y_km==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[y_km==2,0],X[y_km==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[y_km==3,0],X[y_km==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[y_km==4,0],X[y_km==4,1],c='red',marker='v',s=10 , label='cluster5')
#plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],c='red',marker='*',s=30 , label='center cluster')

plt.legend()
plt.grid(True)
plt.show()

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==0]) # 투자
# Out:
# 2799

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==1]) # 거래소
# Out:
# 709

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==2]) # 인플
# Out:
# 109

# %%
len(temp_cluster_result[temp_cluster_result['cluster']==3]) # 비즈
# Out:
# 46

# %%
temp_cluster_result['category'] = 3 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
#temp_cluster_result['label'] = 2 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==0,'label'] = 11 # 투자

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==1,'label'] = 12 # 거래소

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==2,'label'] = 6 # 인플

# %%
temp_cluster_result.loc[temp_cluster_result['cluster']==3,'label'] = 7 # 비즈

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=NUM_CLUSTERS)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
kmeans.inertia_
# Out:
# 32.53550338745117

# %%
print ("Cluster id labels for inputted data")
print (labels)
# Out:
# Cluster id labels for inputted data
# [1 2 3 ... 1 1 1]

# %%
cluster_values= list(model.wv.vocab)

# %%
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -32.53550338745117

# %%
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')

# %%
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.6905706

# %%
kmeans_label = kmeans.labels_

plt.scatter(X[kmeans_label==0,0],X[kmeans_label==0,1],c='lightgreen',marker='s',s=10 , label='cluster1')
plt.scatter(X[kmeans_label==1,0],X[kmeans_label==1,1],c='orange',marker='o',s=10 , label='cluster2')
plt.scatter(X[kmeans_label==2,0],X[kmeans_label==2,1],c='lightblue',marker='v',s=10 , label='cluster3')
plt.scatter(X[kmeans_label==3,0],X[kmeans_label==3,1],c='yellow',marker='v',s=10 , label='cluster4')
#plt.scatter(X[kmeans_label==4,0],X[kmeans_label==4,1],c='red',marker='v',s=10 , label='cluster5')

plt.legend()
plt.grid(True)
plt.show()

# %%
temp_cluster_result1 = pd.DataFrame(columns=temp_heder)
temp_cluster_result1['word'] = list(model.wv.vocab)
temp_cluster_result1['cluster'] = kmeans_label

# %%
#temp_cluster_result1[temp_cluster_result1['cluster']==0].head(30) #시도 및 혼돈  # 혼란 부정적 
temp_cluster_result1['raw_data'] = X.tolist()

# %%
temp_cluster_result1['centroid'] = temp_cluster_result1['cluster'].apply(lambda x : centroids[x])

# %%
euclidean_centroid_list = []
for euclidean_centroid in temp_cluster_result1['centroid'] :
    euclidean_centroid_list.append(euclidean_centroid.tolist())

# %%
temp_distance1 = pairwise_distances(X,euclidean_centroid_list, metric='euclidean')

# %%
import scipy.spatial.distance as dist

# %%
temp_cluster_result1['distance'] = temp_cluster_result1.apply(lambda x : dist.euclidean(x.raw_data,x.centroid),axis=1)

# %%
temp_cluster_result1['tfidf'] = tf_idf_value
temp_cluster_result1['score'] = temp_cluster_result1.apply(lambda x : x.distance + (1- x.tfidf),axis=1)
#temp_cluster_result1

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==0].sort_values('score',ascending=False).nsmallest(50,'score') # 긍정
# Out:
#                                                raw_data               word  \
# 41    [0.030534492805600166, 0.0007691369974054396, ...               cash
# 1324  [0.03009175881743431, 0.006610131822526455, 0....             bitmex
# 292   [0.02681899443268776, 0.014548943378031254, 0....           register
# 28    [0.031632743775844574, 0.011499423533678055, 0...             precio
# 1170  [0.025894491001963615, 0.005132885184139013, 0...               term
# 916   [0.03392179310321808, 0.008315450511872768, 0....           giveaway
# 1832  [0.027208587154746056, 0.011272897943854332, 0...               grow
# 468   [0.023967625573277473, 0.013506102375686169, 0...               love
# 12    [0.029329923912882805, 0.006981635466217995, 0...           telegram
# 143   [0.025793734937906265, 0.012072531506419182, 0...              huobi
# 320   [0.02894820272922516, 0.010071923024952412, 0....               lose
# 477   [0.027325663715600967, 0.00809547770768404, 0....            january
# 321   [0.029585549607872963, 0.011862821877002716, 0...              grind
# 254   [0.029120467603206635, 0.007290909066796303, 0...               face
# 645   [0.023316219449043274, 0.004742764867842197, 0...               late
# 816   [0.027302851900458336, 0.014436211436986923, 0...             please
# 1542  [0.02988315001130104, 0.009099935181438923, 0....          perpetual
# 182   [0.03049752116203308, 0.01078070979565382, 0.0...              agree
# 1287  [0.030216166749596596, 0.007960005663335323, 0...              pcpie
# 247   [0.025107307359576225, 0.014582978561520576, 0...            address
# 359   [0.03424227610230446, 0.005752823781222105, 0....           bitcoins
# 332   [0.029348742216825485, 0.013515204191207886, 0...              stock
# 377   [0.029844656586647034, 0.011196923442184925, 0...  criptomonedaseico
# 375   [0.030364226549863815, 0.007770056836307049, 0...             medium
# 804   [0.03093331679701805, 0.014392207376658916, 0....            selloff
# 630   [0.034108810126781464, 0.010463347658514977, 0...      cryptotrading
# 2077  [0.027681708335876465, 0.005042874254286289, 0...              asset
# 1528  [0.029844576492905617, 0.006050670053809881, 0...          inversion
# 3096  [0.03226039558649063, 0.014932695776224136, 0....          devastate
# 765   [0.02932630106806755, 0.005904089659452438, 0....               miss
# 175   [0.03215327486395836, 0.008199790492653847, 0....              chain
# 2331  [0.027522282674908638, 0.005433680955320597, 0...       entscheidung
# 1340  [0.025204753503203392, 0.014337760396301746, 0...              trend
# 278   [0.026880331337451935, 0.005411971360445023, 0...         mantenerse
# 1683  [0.031797103583812714, 0.007147887255996466, 0...               show
# 228   [0.025789575651288033, 0.00766719738021493, 0....           standard
# 449   [0.029038771986961365, 0.008037240244448185, 0...               week
# 85    [0.030764225870370865, 0.006020252592861652, 0...       instabitcoin
# 1507  [0.034336503595113754, 0.007073769345879555, 0...           ontology
# 249   [0.02536768652498722, 0.009286364540457726, 0....            buterin
# 533   [0.026871947571635246, 0.007320803124457598, 0...              bring
# 1546  [0.03153069689869881, 0.009375233203172684, 0....               nyse
# 1049  [0.03155749663710594, 0.010334708727896214, 0....         prediction
# 277   [0.023289907723665237, 0.006777955684810877, 0...              lucha
# 1674  [0.02240392193198204, 0.010806269012391567, 0....           consider
# 780   [0.02907891385257244, 0.005247498396784067, 0....            awesome
# 376   [0.02708931639790535, 0.011924844235181808, 0....             reddit
# 398   [0.02794347144663334, 0.012175907380878925, 0....     constantinople
# 1682  [0.02250588871538639, 0.012660199776291847, 0....               name
# 422   [0.024962859228253365, 0.006500956602394581, 0...             social
#
#       cluster                                           centroid  distance  \
# 41          0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.076337
# 1324        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.026915
# 292         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.030260
# 28          0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033962
# 1170        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.027297
# 916         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.027800
# 1832        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.027960
# 468         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.028974
# 12          0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.028698
# 143         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.029976
# 320         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.030721
# 477         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.029174
# 321         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.030685
# 254         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031594
# 645         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031698
# 816         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031109
# 1542        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.029957
# 182         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.029567
# 1287        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.030170
# 247         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031790
# 359         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031931
# 332         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031305
# 377         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032002
# 375         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031641
# 804         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031644
# 630         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032496
# 2077        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031325
# 1528        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031786
# 3096        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033093
# 765         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031565
# 175         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032609
# 2331        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.030604
# 1340        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032214
# 278         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031593
# 1683        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032881
# 228         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.031332
# 449         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.034885
# 85          0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033388
# 1507        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.032741
# 249         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033579
# 533         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033446
# 1546        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033171
# 1049        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.034273
# 277         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033716
# 1674        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.033544
# 780         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.034089
# 376         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.039122
# 398         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.036429
# 1682        0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.035149
# 422         0  [0.029038427, 0.00981395, 0.009952289, -0.0582...  0.036828
#
#          tfidf     score closer#
# 41    0.073971  1.002366     NaN
# 1324  0.004422  1.022493     NaN
# 292   0.007236  1.023024     NaN
# 28    0.010854  1.023108     NaN
# 1170  0.003216  1.024081     NaN
# 916   0.003618  1.024181     NaN
# 1832  0.003618  1.024342     NaN
# 468   0.004422  1.024552     NaN
# 12    0.003618  1.025079     NaN
# 143   0.004824  1.025152     NaN
# 320   0.005226  1.025495     NaN
# 477   0.003618  1.025556     NaN
# 321   0.004824  1.025860     NaN
# 254   0.005628  1.025965     NaN
# 645   0.005628  1.026070     NaN
# 816   0.004824  1.026285     NaN
# 1542  0.003618  1.026339     NaN
# 182   0.003216  1.026351     NaN
# 1287  0.003618  1.026552     NaN
# 247   0.004422  1.027368     NaN
# 359   0.004422  1.027509     NaN
# 332   0.003216  1.028089     NaN
# 377   0.003618  1.028383     NaN
# 375   0.003216  1.028425     NaN
# 804   0.003216  1.028427     NaN
# 630   0.004020  1.028476     NaN
# 2077  0.002814  1.028510     NaN
# 1528  0.003216  1.028570     NaN
# 3096  0.004422  1.028670     NaN
# 765   0.002814  1.028751     NaN
# 175   0.003618  1.028990     NaN
# 2331  0.001608  1.028996     NaN
# 1340  0.003216  1.028998     NaN
# 278   0.002412  1.029181     NaN
# 1683  0.003618  1.029263     NaN
# 228   0.002010  1.029322     NaN
# 449   0.005226  1.029658     NaN
# 85    0.003618  1.029770     NaN
# 1507  0.002412  1.030329     NaN
# 249   0.003216  1.030363     NaN
# 533   0.002814  1.030632     NaN
# 1546  0.002412  1.030759     NaN
# 1049  0.003216  1.031057     NaN
# 277   0.002412  1.031304     NaN
# 1674  0.002010  1.031534     NaN
# 780   0.002412  1.031677     NaN
# 376   0.006834  1.032288     NaN
# 398   0.003618  1.032811     NaN
# 1682  0.002010  1.033139     NaN
# 422   0.003216  1.033611     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==1].sort_values('score',ascending=False).nsmallest(50,'score') # 인플
# Out:
#                                                raw_data             word  \
# 156   [0.005106745287775993, 0.00026669149519875646,...   cyrptocurrency
# 2270  [0.001001380500383675, 0.0022883836645632982, ...       eosnairobi
# 2419  [0.009013069793581963, 0.0014869081787765026, ...            bryer
# 1806  [0.007342513184994459, 0.0004970133886672556, ...         referral
# 1056  [0.0061041442677378654, -0.0024708916898816824...        verstärkt
# 2538  [0.004027029033750296, 0.0004413760907482356, ...          anlalyy
# 473   [0.0052664875984191895, 0.006158927921205759, ...     minefilecoin
# 2625  [0.006875261664390564, 0.0035377289168536663, ...       allmarkets
# 177   [0.007250011432915926, 0.0021082409657537937, ...           corner
# 2601  [0.0037743733264505863, 0.003107785014435649, ...           native
# 2924  [0.009436470456421375, 0.002331931609660387, 0...         makerdao
# 529   [0.007516629993915558, -0.0026078892406076193,...     actualizados
# 1769  [0.002368110930547118, 0.004447584506124258, 0...             alto
# 1048  [0.006367129273712635, 0.0013891557464376092, ...         obsolete
# 1379  [0.0022612970788031816, 0.0045654624700546265,...       continuará
# 2459  [0.006960180588066578, 0.00014570042549166828,...             word
# 3432  [0.009652630425989628, 0.0024373717606067657, ...             xmas
# 309   [0.009469257667660713, 0.0004036817990709096, ...             dent
# 2914  [0.00667777843773365, 0.002057282254099846, 0....         musician
# 1795  [0.009426369331777096, 0.0033858788665384054, ...     conservative
# 1867  [0.004861865658313036, -1.4306060620583594e-05...           castor
# 2856  [0.003796805627644062, -0.0008191633387468755,...     forextrading
# 1625  [0.008266236633062363, 0.0022417509462684393, ...             iftf
# 1758  [0.0031626273412257433, 0.002365953056141734, ...            rival
# 2780  [0.004179090727120638, -0.0001844438666012138,...          hareket
# 1872  [0.00461787823587656, 0.0019604030530899763, 0...            mayor
# 287   [0.0009483933681622148, -0.002278875559568405,...         theblock
# 1059  [0.010901195928454399, 0.0060339621268212795, ...         zunächst
# 1828  [0.0048213982954621315, 0.005119578912854195, ...            house
# 1905  [0.005427904427051544, 0.004155599046498537, 0...      información
# 2954  [0.005805057007819414, 0.002134606707841158, -...    vulnerability
# 3495  [0.0007561483071185648, 0.004497929476201534, ...   bitcointrading
# 1653  [0.006241132505238056, 0.0018647141987457871, ...          suppose
# 3072  [0.0014376110630109906, 0.002632864285260439, ...             icin
# 1920  [0.002306923968717456, 0.0020453042816370726, ...          quantum
# 3178  [0.001115141436457634, 0.0003933716507162899, ...       googleplay
# 3526  [0.007297337055206299, 0.004603588487952948, 0...  article=bitcoin
# 1680  [0.009647793136537075, 0.003374999389052391, 0...            magic
# 2148  [0.009665697813034058, 0.004693010821938515, 0...          bloocys
# 162   [0.004337831865996122, 0.005021460819989443, 0...         dividend
# 2248  [0.005885112565010786, 0.0029721814207732677, ...           cosmos
# 2872  [0.007528395392000675, 0.004103472456336021, -...             defi
# 3042  [0.007426518946886063, 0.003757285885512829, 0...             pave
# 1137  [0.001026018406264484, 0.006831947714090347, -...           etcusd
# 1303  [0.0013457542518153787, 0.004134311340749264, ...         carolina
# 1220  [0.006159286014735699, -0.0011765239760279655,...         japanese
# 387   [0.0002041338011622429, 0.0024599905591458082,...         american
# 693   [0.002055862918496132, 0.00464329170063138, -0...           travel
# 3390  [0.008475436829030514, 0.0023813231382519007, ...            linux
# 1068  [0.003444185247644782, 0.004561828449368477, 0...           contra
#
#       cluster                                           centroid  distance  \
# 156         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.025694
# 2270        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.025426
# 2419        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.025486
# 1806        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027258
# 1056        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.025859
# 2538        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.025925
# 473         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026061
# 2625        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026159
# 177         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026572
# 2601        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026237
# 2924        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026243
# 529         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027096
# 1769        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026323
# 1048        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027267
# 1379        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026539
# 2459        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026569
# 3432        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026574
# 309         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026624
# 2914        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026726
# 1795        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026758
# 1867        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026772
# 2856        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026788
# 1625        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026863
# 1758        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026890
# 2780        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026892
# 1872        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026940
# 287         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027769
# 1059        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026975
# 1828        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026979
# 1905        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.026984
# 2954        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027397
# 3495        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027016
# 1653        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027422
# 3072        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027044
# 1920        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027064
# 3178        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027105
# 3526        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027172
# 1680        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027587
# 2148        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027246
# 162         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027648
# 2248        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027250
# 2872        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.028090
# 3042        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027312
# 1137        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027752
# 1303        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027355
# 1220        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.028162
# 387         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027373
# 693         1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027785
# 3390        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027419
# 1068        1  [0.005829834, 0.0020686262, 0.0021301818, -0.0...  0.027423
#
#          tfidf     score closer#
# 156   0.001206  1.024488     NaN
# 2270  0.000402  1.025024     NaN
# 2419  0.000402  1.025084     NaN
# 1806  0.002010  1.025248     NaN
# 1056  0.000402  1.025457     NaN
# 2538  0.000402  1.025523     NaN
# 473   0.000402  1.025659     NaN
# 2625  0.000402  1.025757     NaN
# 177   0.000804  1.025768     NaN
# 2601  0.000402  1.025835     NaN
# 2924  0.000402  1.025841     NaN
# 529   0.001206  1.025890     NaN
# 1769  0.000402  1.025921     NaN
# 1048  0.001206  1.026061     NaN
# 1379  0.000402  1.026137     NaN
# 2459  0.000402  1.026167     NaN
# 3432  0.000402  1.026172     NaN
# 309   0.000402  1.026222     NaN
# 2914  0.000402  1.026324     NaN
# 1795  0.000402  1.026356     NaN
# 1867  0.000402  1.026370     NaN
# 2856  0.000402  1.026386     NaN
# 1625  0.000402  1.026461     NaN
# 1758  0.000402  1.026488     NaN
# 2780  0.000402  1.026490     NaN
# 1872  0.000402  1.026538     NaN
# 287   0.001206  1.026563     NaN
# 1059  0.000402  1.026573     NaN
# 1828  0.000402  1.026577     NaN
# 1905  0.000402  1.026582     NaN
# 2954  0.000804  1.026593     NaN
# 3495  0.000402  1.026614     NaN
# 1653  0.000804  1.026618     NaN
# 3072  0.000402  1.026642     NaN
# 1920  0.000402  1.026662     NaN
# 3178  0.000402  1.026703     NaN
# 3526  0.000402  1.026770     NaN
# 1680  0.000804  1.026783     NaN
# 2148  0.000402  1.026844     NaN
# 162   0.000804  1.026844     NaN
# 2248  0.000402  1.026848     NaN
# 2872  0.001206  1.026884     NaN
# 3042  0.000402  1.026910     NaN
# 1137  0.000804  1.026948     NaN
# 1303  0.000402  1.026953     NaN
# 1220  0.001206  1.026956     NaN
# 387   0.000402  1.026971     NaN
# 693   0.000804  1.026981     NaN
# 3390  0.000402  1.027017     NaN
# 1068  0.000402  1.027021     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==2].sort_values('score',ascending=False).nsmallest(20,'score')  # 투자
# Out:
#                                               raw_data            word  \
# 809  [0.15935952961444855, 0.050434451550245285, 0....        platform
# 64   [0.14764909446239471, 0.05353055149316788, 0.0...           trade
# 75   [0.1612396538257599, 0.053474485874176025, 0.0...         airdrop
# 49   [0.16832438111305237, 0.05322611331939697, 0.0...  cryptocurrency
# 126  [0.15967240929603577, 0.055764976888895035, 0....        exchange
# 4    [0.14748261868953705, 0.05388098210096359, 0.0...          market
# 273  [0.15123899281024933, 0.054305173456668854, 0....        contract
# 282  [0.15481404960155487, 0.05360519140958786, 0.0...   criptomonedas
# 70   [0.1437961459159851, 0.04384468123316765, 0.05...          wallet
# 13   [0.21774178743362427, 0.07257799804210663, 0.0...         bitcoin
# 213  [0.13384342193603516, 0.04869094491004944, 0.0...            time
# 52   [0.13606487214565277, 0.04307685047388077, 0.0...            news
# 134  [0.130472332239151, 0.04226335138082504, 0.052...            coin
# 122  [0.12453573197126389, 0.045390449464321136, 0....            join
# 209  [0.18499860167503357, 0.06513142585754395, 0.0...           token
# 509  [0.1365921050310135, 0.0423995666205883, 0.045...            user
# 170  [0.12141790241003036, 0.04711528122425079, 0.0...            make
# 595  [0.11648081988096237, 0.043141379952430725, 0....            good
# 62   [0.1956222802400589, 0.06759674847126007, 0.07...         project
# 198  [0.11808361113071442, 0.040100496262311935, 0....           value
#
#      cluster                                           centroid  distance  \
# 809        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.031004
# 64         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.088827
# 75         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.089273
# 49         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.181048
# 126        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.080023
# 4          2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.143116
# 273        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.110641
# 282        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.120767
# 70         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.258689
# 13         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.756101
# 213        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.266644
# 52         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.336638
# 134        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.319028
# 122        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.332579
# 209        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.364944
# 509        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.361311
# 170        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.458007
# 595        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.489584
# 62         2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.511771
# 198        2  [0.15785286, 0.053300973, 0.05771646, -0.32312...  0.528000
#
#         tfidf     score closer#
# 809  0.019699  1.011306     NaN
# 64   0.060303  1.028524     NaN
# 75   0.052262  1.037011     NaN
# 49   0.133872  1.047176     NaN
# 126  0.026935  1.053088     NaN
# 4    0.061509  1.081607     NaN
# 273  0.015679  1.094963     NaN
# 282  0.020101  1.100666     NaN
# 70   0.020101  1.238588     NaN
# 13   0.515388  1.240714     NaN
# 213  0.022915  1.243729     NaN
# 52   0.056283  1.280356     NaN
# 134  0.023317  1.295711     NaN
# 122  0.024925  1.307654     NaN
# 209  0.042212  1.322732     NaN
# 509  0.012061  1.349251     NaN
# 170  0.014071  1.443936     NaN
# 595  0.016483  1.473101     NaN
# 62   0.026533  1.485238     NaN
# 198  0.020101  1.507899     NaN

# %%
temp_cluster_result1[temp_cluster_result1['cluster']==3].sort_values('score',ascending=False).nsmallest(20,'score') # 비즈
# Out:
#                                                raw_data           word  \
# 14    [0.07261882722377777, 0.026392212137579918, 0....         ripple
# 43    [0.06665079295635223, 0.019300546497106552, 0....           hour
# 1418  [0.07233090698719025, 0.02484153024852276, 0.0...           tuur
# 914   [0.06957437843084335, 0.02447553724050522, 0.0...           come
# 598   [0.06497839838266373, 0.02185608632862568, 0.0...           know
# 599   [0.06574244797229767, 0.024595580995082855, 0....         thread
# 1031  [0.06505004316568375, 0.01995134726166725, 0.0...  tuurdemeester
# 1002  [0.06727897375822067, 0.020812958478927612, 0....          build
# 130   [0.06394743174314499, 0.02306791953742504, 0.0...       freecoin
# 35    [0.06876365840435028, 0.019916201010346413, 0....          bitso
# 639   [0.0735652819275856, 0.0248801838606596, 0.029...          close
# 458   [0.0669211894273758, 0.0179633479565382, 0.022...    transaction
# 664   [0.06400375813245773, 0.021395573392510414, 0....          store
# 176   [0.061823613941669464, 0.022347096353769302, 0...          scale
# 504   [0.07359759509563446, 0.026585644111037254, 0....       investor
# 1019  [0.0746874138712883, 0.02502480335533619, 0.02...           take
# 157   [0.061013493686914444, 0.026319822296500206, 0...           post
# 166   [0.06519193947315216, 0.019269928336143494, 0....           last
# 265   [0.07714135944843292, 0.023646313697099686, 0....        fintech
# 2322  [0.07285723090171814, 0.022183166816830635, 0....    nachrichten
#
#       cluster                                           centroid  distance  \
# 14          3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.060592
# 43          3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.042404
# 1418        3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.032415
# 914         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.031883
# 598         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.030793
# 599         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.033277
# 1031        3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.032079
# 1002        3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.038351
# 130         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.040910
# 35          3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.042752
# 639         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.044747
# 458         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.050943
# 664         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.050482
# 176         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.056495
# 504         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.055540
# 1019        3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.058987
# 157         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.061093
# 166         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.064467
# 265         3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.072119
# 2322        3  [0.06907216, 0.023370745, 0.024875397, -0.1411...  0.070127
#
#          tfidf     score closer#
# 14    0.101711  0.958881     NaN
# 43    0.028945  1.013459     NaN
# 1418  0.009246  1.023169     NaN
# 914   0.008442  1.023441     NaN
# 598   0.007236  1.023557     NaN
# 599   0.009648  1.023629     NaN
# 1031  0.007638  1.024441     NaN
# 1002  0.008442  1.029908     NaN
# 130   0.009648  1.031262     NaN
# 35    0.009648  1.033103     NaN
# 639   0.009648  1.035099     NaN
# 458   0.007638  1.043305     NaN
# 664   0.006030  1.044451     NaN
# 176   0.009648  1.046846     NaN
# 504   0.006834  1.048705     NaN
# 1019  0.008442  1.050545     NaN
# 157   0.009246  1.051846     NaN
# 166   0.009246  1.055220     NaN
# 265   0.011659  1.060461     NaN
# 2322  0.009648  1.060478     NaN

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==0]) # 긍정
# Out:
# 462

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==1]) # 인플
# Out:
# 3048

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==2]) # 투자
# Out:
# 26

# %%
len(temp_cluster_result1[temp_cluster_result1['cluster']==3]) # 비즈
# Out:
# 127

# %%
temp_cluster_result1['category'] = 3 # 1 영문뉴스, 2 국문뉴스 , 3 twitter

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==0,'label'] = 1 # 긍정

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==1,'label'] = 6 # 인플

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==2,'label'] = 11 # 투자

# %%
temp_cluster_result1.loc[temp_cluster_result1['cluster']==3,'label'] = 7 # 비즈

# %%
temp_cluster_result1['Silhouette'] =0.6905706
temp_cluster_result['Silhouette'] = 0.6905706
temp_cluster_result1['result'] = 1
temp_cluster_result['result'] = 1

# %%
temp_cluster_result1.to_csv("../analysis/cluster/causeanalysis/BTC/after_up_ETH3_euclidean.csv")
temp_cluster_result.to_csv("../analysis/cluster/causeanalysis/BTC/after_up_ETH3_cosine")
