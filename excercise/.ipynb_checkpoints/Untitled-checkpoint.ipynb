# '-0.031141214072704315, 0.020134948194026947, 0.038739338517189026, -0.05017434060573578, -0.03516233339905739, 0.0471779964864254, 0.0034799405839294195, 0.012950288131833076, -0.010285892523825169, 0.022356046363711357, 0.007006651256233454, -0.014632664620876312, 0.012657168321311474, -0.02691671997308731, -0.011334559880197048, -0.04356205090880394, -0.01345750316977501, -0.011980650015175343, 0.005174598656594753, 0.024231720715761185, -0.011651577427983284, 0.0013040686026215553, -0.042068928480148315, 0.023494118824601173, 0.025419315323233604, 0.04351908341050148, -0.033311910927295685, -0.030461560934782028, -0.023692989721894264, 0.009896611794829369, 0.040498919785022736, 0.050081849098205566, -0.06433260440826416, 0.0025726149324327707, 0.02136252075433731, 0.015291506424546242, -0.041867345571517944, -0.023470506072044373, -0.037987120449543, -0.03274165093898773, -0.001092313090339303, 0.035980552434921265, -0.013788953423500061, 0.021715160459280014, 0.0204366780817508
# ...

# %%
test_list = test_str[1:len(test_str)-1].split(',')

# %%
test_list1 = [float(i.replace(" ","")) for i in test_list]

# %%
array1 = np.array(test_list1)

# %%
array1
# Out:
# array([-3.11412141e-02,  2.01349482e-02,  3.87393385e-02, -5.01743406e-02,
#        -3.51623334e-02,  4.71779965e-02,  3.47994058e-03,  1.29502881e-02,
#        -1.02858925e-02,  2.23560464e-02,  7.00665126e-03, -1.46326646e-02,
#         1.26571683e-02, -2.69167200e-02, -1.13345599e-02, -4.35620509e-02,
#        -1.34575032e-02, -1.19806500e-02,  5.17459866e-03,  2.42317207e-02,
#        -1.16515774e-02,  1.30406860e-03, -4.20689285e-02,  2.34941188e-02,
#         2.54193153e-02,  4.35190834e-02, -3.33119109e-02, -3.04615609e-02,
#        -2.36929897e-02,  9.89661179e-03,  4.04989198e-02,  5.00818491e-02,
#        -6.43326044e-02,  2.57261493e-03,  2.13625208e-02,  1.52915064e-02,
#        -4.18673456e-02, -2.34705061e-02, -3.79871204e-02, -3.27416509e-02,
#        -1.09231309e-03,  3.59805524e-02, -1.37889534e-02,  2.17151605e-02,
#         2.04366781e-02, -3.58751118e-02, -1.35653503e-02, -1.99306421e-02,
# ...

# %%
header = []
for i in range(1,101) :
    header.append('C'+str(i))

# %%
header
# Out:
# ['C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C28',
#  'C29',
#  'C30',
#  'C31',
#  'C32',
#  'C33',
#  'C34',
#  'C35',
#  'C36',
#  'C37',
#  'C38',
#  'C39',
#  'C40',
#  'C41',
#  'C42',
#  'C43',
#  'C44',
#  'C45',
#  'C46',
#  'C47',
#  'C48',
#  'C49',
#  'C50',
#  'C51',
#  'C52',
#  'C53',
#  'C54',
#  'C55',
#  'C56',
#  'C57',
#  'C58',
#  'C59',
#  'C60',
#  'C61',
#  'C62',
#  'C63',
#  'C64',
#  'C65',
#  'C66',
#  'C67',
#  'C68',
#  'C69',
#  'C70',
#  'C71',
#  'C72',
#  'C73',
#  'C74',
#  'C75',
#  'C76',
#  'C77',
#  'C78',
#  'C79',
#  'C80',
#  'C81',
#  'C82',
#  'C83',
#  'C84',
#  'C85',
#  'C86',
#  'C87',
#  'C88',
#  'C89',
#  'C90',
#  'C91',
#  'C92',
#  'C93',
#  'C94',
#  'C95',
#  'C96',
#  'C97',
#  'C98',
#  'C99',
#  'C100']

# %%
testFrame = pd.DataFrame(header)

# %%
for j in range[0,100]:
    temp = j+1
    print('C'+str(temp))
    col = 'C'+str(temp)
    testFrame[col] = array1[j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7df21e73d467> in <module>
# ----> 1 for j in range[0,100]:
#       2     temp = j+1
#       3     testFrame['C'+str(temp)] = array1[j]
#
# TypeError: 'type' object is not subscriptable
